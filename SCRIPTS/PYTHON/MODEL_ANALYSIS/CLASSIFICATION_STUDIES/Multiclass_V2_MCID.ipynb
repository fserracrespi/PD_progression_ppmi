# %%
import pandas as pd
import json
import numpy as np
from pathlib import Path

current_dir = Path.cwd()
project_root = current_dir.parents[3]

import matplotlib.pyplot as plt


y_MCID_v2 = pd.read_csv(project_root / "SCRIPTS/PYTHON/MODEL_ANALYSIS/DATA/V2_version/y_MCID_v2_final.csv", index_col=0)
print("y_MCID shape:", y_MCID_v2.shape)



datasets = {
    "y_MCID": y_MCID_v2,
}

fig, ax = plt.subplots(figsize=(6, 5))

df = y_MCID_v2

counts = df.iloc[:,0].value_counts().sort_index()
percentages = counts / counts.sum() * 100

bars = ax.bar(counts.index.astype(str), counts.values)

# añadir texto con conteo y porcentaje
for i, (count, pct) in enumerate(zip(counts.values, percentages.values)):
    ax.text(i, count, f"{count} ({pct:.1f}%)", 
            ha='center', va='bottom')

ax.set_title("y_MCID")
ax.set_xlabel("Class")
ax.set_ylabel("Count")

plt.suptitle("Ordinal Class Distribution")
plt.tight_layout()
plt.show()
# Out:
# y_MCID shape: (956, 1)

# %% [markdown]
# # FILES

# %%
import os
import re

with open(project_root/"SCRIPTS/PYTHON/MODEL_ANALYSIS/DATA/Domain_data.json", "r") as archivo:
    full_domain = json.load(archivo)

with open(project_root/"SCRIPTS/PYTHON/MODEL_ANALYSIS/DATA/UPDRS_Domain_data.json", "r") as archivo:
    updrs_domain = json.load(archivo)

X_multiples_MCID= {'X_STATS_V2':project_root/'SCRIPTS/PYTHON/MODEL_ANALYSIS/DATA/V2_version/X_stats_v2_final_HY3.csv',
                'X_VX_STATS_V2': project_root/'SCRIPTS/PYTHON/MODEL_ANALYSIS/DATA/V2_version/X_vx_stats_v2_final_HY3.csv',
                'X_VX_DELTA_V2': project_root/'SCRIPTS/PYTHON/MODEL_ANALYSIS/DATA/V2_version/X_vx_delta_v2_final_HY3.csv',
                }
y_multiples_MCID = {'MCID_v2': project_root / "SCRIPTS/PYTHON/MODEL_ANALYSIS/DATA/V2_version/y_MCID_v2_final.csv"}

pairs_init_MCID=[('X_STATS_V2', 'MCID_v2'),
        ('X_VX_STATS_V2', 'MCID_v2'),
        ('X_VX_DELTA_V2', 'MCID_v2')]


output_path= project_root / "SCRIPTS/PYTHON/MODEL_ANALYSIS/Performance_Results/Multiclass/V2_analysis/"

# %% [markdown]
# # MODELS BASELINE

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from imblearn.pipeline import Pipeline


# 🔹 pesos a probar
weight_configs_MCID = {
    "balanced": "balanced",
    "w_c2_10": {0: 10, 1: 1, 2: 10},
    "w_c2_20": {0: 20, 1: 1, 2: 20},
}

def build_models(class_weight):
    return {
        "decision_tree": Pipeline([
            ("model", DecisionTreeClassifier(
                random_state=42,
                class_weight=class_weight
            ))
        ]),

        "random_forest": Pipeline([
            ("model", RandomForestClassifier(
                random_state=42,
                n_jobs=-1,
                class_weight=class_weight
            ))
        ]),

        "extra_trees": Pipeline([
            ("model", ExtraTreesClassifier(
                random_state=42,
                n_jobs=-1,
                class_weight=class_weight
            ))
        ]),

        "xgboost": Pipeline([
            ("model", XGBClassifier(
                tree_method="hist",
                device="cuda",
                eval_metric="logloss",
                n_jobs=-1,
                random_state=42))
        ]),

        "adaboost": Pipeline([
            ("model", AdaBoostClassifier(
                algorithm="SAMME",
                random_state=42
            ))
        ]),

        "svm": Pipeline([
            ("model", SVC(
                kernel="rbf",
                probability=True,
                random_state=42,
                class_weight=class_weight
            ))
        ]),

        "logistic_regression": Pipeline([
            ("model", LogisticRegression(
                random_state=42,
                n_jobs=-1,
                max_iter=10000,
                class_weight=class_weight
            ))
        ]),

        "knn": Pipeline([
            ("model", KNeighborsClassifier(n_jobs=-1))
        ]),

        "gaussian_nb": Pipeline([
            ("model", GaussianNB())
        ]),

        "mlp3216": Pipeline([
            ("model", MLPClassifier(
                hidden_layer_sizes=(32, 16),
                activation='relu',
                solver='adam',
                alpha=0.0001,
                learning_rate='adaptive',
                max_iter=1000,
                random_state=42
            ))
        ])
    }


# ESTRUCTURA FINAL: un dict por weight
classification_models_by_weight_MCID = {
    w_name: build_models(w_value)
    for w_name, w_value in weight_configs_MCID.items()
}

# %%
def build_models_reg(class_weight):

    return {
        "decision_tree_reg": Pipeline([
            ("model", DecisionTreeClassifier(
                random_state=42,
                class_weight=class_weight,
                max_depth=3,
                min_samples_split=40,
                min_samples_leaf=15,
                max_features="sqrt",
                ccp_alpha=0.005
            ))
        ]),

        "random_forest_reg": Pipeline([
            ("model", RandomForestClassifier(
                random_state=42,
                n_jobs=-1,
                class_weight=class_weight,
                n_estimators=160,
                max_depth=4,
                min_samples_split=30,
                min_samples_leaf=12,
                max_features="sqrt",
                max_samples=0.80,
                bootstrap=True
            ))
        ]),

        "extra_trees_reg": Pipeline([
            ("model", ExtraTreesClassifier(
                random_state=42,
                n_jobs=-1,
                class_weight=class_weight,
                n_estimators=160,
                max_depth=4,
                min_samples_split=30,
                min_samples_leaf=12,
                max_features="sqrt",
                max_samples=0.80,
                bootstrap=True
            ))
        ]),

        "xgboost_reg": Pipeline([
            ("model", XGBClassifier(
                tree_method="hist",
                device="cuda",
                eval_metric="logloss",
                n_jobs=-1,
                random_state=42,
                n_estimators=120,
                learning_rate=0.04,
                max_depth=4,
                min_child_weight=10,
                gamma=2.0,
                subsample=0.80,
                colsample_bytree=0.80,
                reg_alpha=4.0,
                reg_lambda=12.0
            ))
        ]),

        "adaboost_reg": Pipeline([
            ("model", AdaBoostClassifier(
                n_estimators=60,
                learning_rate=0.04,
                algorithm="SAMME",
                random_state=42
            ))
        ]),

        "svm_reg": Pipeline([
            ("scaler", StandardScaler()),
            ("model", SVC(
                kernel="rbf",
                C=0.15,
                gamma="scale",
                probability=True,
                random_state=42,
                class_weight=class_weight
            ))
        ]),

        "logistic_regression_reg": Pipeline([
            ("scaler", StandardScaler()),
            ("model", LogisticRegression(
                random_state=42,
                max_iter=10000,
                C=0.08,
                penalty="l2",
                solver="liblinear",
                class_weight=class_weight
            ))
        ]),

        "knn_reg": Pipeline([
            ("scaler", StandardScaler()),
            ("model", KNeighborsClassifier(
                n_neighbors=25,
                weights="distance",
                p=2,
                n_jobs=-1
            ))
        ]),

        "gaussian_nb_reg": Pipeline([
            ("model", GaussianNB(
                var_smoothing=1e-6
            ))
        ]),

        "mlp3216_reg": Pipeline([
            ("scaler", StandardScaler()),
            ("model", MLPClassifier(
                hidden_layer_sizes=(10,),
                activation="relu",
                solver="adam",
                alpha=0.05,
                learning_rate="adaptive",
                early_stopping=True,
                validation_fraction=0.20,
                n_iter_no_change=20,
                max_iter=400,
                random_state=42
            ))
        ])
    }


classification_models_by_weight_reg_MCID = {
    w_name: build_models_reg(w_value)
    for w_name, w_value in weight_configs_MCID.items()
}

# %%
from imblearn.pipeline import Pipeline
from imblearn.under_sampling import RandomUnderSampler

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler

from xgboost import XGBClassifier


def build_models_reg_UNDER(class_weight):
    return {
        "decision_tree_reg": Pipeline([
            ("undersample", RandomUnderSampler(sampling_strategy="auto", random_state=42)),
            ("model", DecisionTreeClassifier(
                random_state=42,
                class_weight=class_weight,
                max_depth=3,
                min_samples_split=40,
                min_samples_leaf=15,
                max_features="sqrt",
                ccp_alpha=0.005
            ))
        ]),

        "random_forest_reg": Pipeline([
            ("undersample", RandomUnderSampler(sampling_strategy="auto", random_state=42)),
            ("model", RandomForestClassifier(
                random_state=42,
                n_jobs=-1,
                class_weight=class_weight,
                n_estimators=160,
                max_depth=4,
                min_samples_split=30,
                min_samples_leaf=12,
                max_features="sqrt",
                max_samples=0.80,
                bootstrap=True
            ))
        ]),

        "extra_trees_reg": Pipeline([
            ("undersample", RandomUnderSampler(sampling_strategy="auto", random_state=42)),
            ("model", ExtraTreesClassifier(
                random_state=42,
                n_jobs=-1,
                class_weight=class_weight,
                n_estimators=160,
                max_depth=4,
                min_samples_split=30,
                min_samples_leaf=12,
                max_features="sqrt",
                max_samples=0.80,
                bootstrap=True
            ))
        ]),

        "xgboost_reg": Pipeline([
            ("undersample", RandomUnderSampler(sampling_strategy="auto", random_state=42)),
            ("model", XGBClassifier(
                tree_method="hist",
                device="cuda",
                eval_metric="logloss",
                n_jobs=-1,
                random_state=42,
                n_estimators=120,
                learning_rate=0.04,
                max_depth=4,
                min_child_weight=10,
                gamma=2.0,
                subsample=0.80,
                colsample_bytree=0.80,
                reg_alpha=4.0,
                reg_lambda=12.0
            ))
        ]),

        "adaboost_reg": Pipeline([
            ("undersample", RandomUnderSampler(sampling_strategy="auto", random_state=42)),
            ("model", AdaBoostClassifier(
                n_estimators=60,
                learning_rate=0.04,
                algorithm="SAMME",
                random_state=42
            ))
        ]),

        "svm_reg": Pipeline([
            ("undersample", RandomUnderSampler(sampling_strategy="auto", random_state=42)),
            ("scaler", StandardScaler()),
            ("model", SVC(
                kernel="rbf",
                C=0.15,
                gamma="scale",
                probability=True,
                random_state=42,
                class_weight=class_weight
            ))
        ]),

        "logistic_regression_reg": Pipeline([
            ("undersample", RandomUnderSampler(sampling_strategy="auto", random_state=42)),
            ("scaler", StandardScaler()),
            ("model", LogisticRegression(
                random_state=42,
                max_iter=10000,
                C=0.08,
                penalty="l2",
                solver="liblinear",
                class_weight=class_weight
            ))
        ]),

        "knn_reg": Pipeline([
            ("undersample", RandomUnderSampler(sampling_strategy="auto", random_state=42)),
            ("scaler", StandardScaler()),
            ("model", KNeighborsClassifier(
                n_neighbors=25,
                weights="distance",
                p=2,
                n_jobs=-1
            ))
        ]),

        "gaussian_nb_reg": Pipeline([
            ("undersample", RandomUnderSampler(sampling_strategy="auto", random_state=42)),
            ("model", GaussianNB(
                var_smoothing=1e-6
            ))
        ]),

        "mlp3216_reg": Pipeline([
            ("undersample", RandomUnderSampler(sampling_strategy="auto", random_state=42)),
            ("scaler", StandardScaler()),
            ("model", MLPClassifier(
                hidden_layer_sizes=(10,),
                activation="relu",
                solver="adam",
                alpha=0.05,
                learning_rate="adaptive",
                early_stopping=True,
                validation_fraction=0.20,
                n_iter_no_change=20,
                max_iter=400,
                random_state=42
            ))
        ])
    }


classification_models_by_weight_reg_UNDER_MCID = {
    w_name: build_models_reg_UNDER(w_value)
    for w_name, w_value in weight_configs_MCID.items()
}

# %% [markdown]
# # MODEL PERFORMANCE FUNCTION

# %%
import numpy as np
import pandas as pd

from sklearn.base import clone
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    recall_score,
    precision_score,
    roc_auc_score,
    precision_recall_fscore_support,
    average_precision_score,
    confusion_matrix,
)
from sklearn.preprocessing import label_binarize, LabelEncoder

from imblearn.over_sampling import RandomOverSampler, SMOTE

from sdv.metadata import Metadata
from sdv.single_table import CTGANSynthesizer


def _compute_metrics_multiclass(
    y_true,
    y_pred,
    y_proba=None,
    classes=None,
    cost_matrix=None
):
    metrics = {}

    y_true = np.asarray(y_true).ravel()
    y_pred = np.asarray(y_pred).ravel()

    if classes is None:
        classes = np.unique(np.concatenate([y_true, y_pred]))
    classes = np.asarray(classes)

    n_classes = len(classes)

    metrics["accuracy"] = accuracy_score(y_true, y_pred)

    metrics["f1_macro"] = f1_score(y_true, y_pred, average="macro", zero_division=0)
    metrics["f1_weighted"] = f1_score(y_true, y_pred, average="weighted", zero_division=0)

    metrics["recall_macro"] = recall_score(y_true, y_pred, average="macro", zero_division=0)
    metrics["recall_weighted"] = recall_score(y_true, y_pred, average="weighted", zero_division=0)

    metrics["precision_macro"] = precision_score(y_true, y_pred, average="macro", zero_division=0)
    metrics["precision_weighted"] = precision_score(y_true, y_pred, average="weighted", zero_division=0)

    # =========================================================
    # COST MATRIX
    # =========================================================
    if cost_matrix is None:
        cost_matrix = np.array([
            [0, 1, 10],
            [5, 0, 1],
            [10, 3, 0]
        ], dtype=float)
    else:
        cost_matrix = np.asarray(cost_matrix, dtype=float)
        if cost_matrix.shape != (n_classes, n_classes):
            raise ValueError(
                f"cost_matrix debe tener shape {(n_classes, n_classes)} "
                f"y tiene {cost_matrix.shape}"
            )

    sample_costs = cost_matrix[y_true, y_pred]
    metrics["misclassification_cost_mean"] = sample_costs.mean()
    metrics["misclassification_cost_total"] = sample_costs.sum()
    metrics["misclassification_score"] = -sample_costs.mean()

    for cls in classes:
        mask = (y_true == cls)
        metrics[f"misclassification_cost_mean_true_class_{cls}"] = (
            sample_costs[mask].mean() if mask.sum() > 0 else np.nan
        )

    # =========================================================
    # METRICS PER CLASS
    # =========================================================
    prec, rec, f1, supp = precision_recall_fscore_support(
        y_true,
        y_pred,
        labels=classes,
        zero_division=0
    )

    for i, cls in enumerate(classes):
        metrics[f"precision_class_{cls}"] = prec[i]
        metrics[f"recall_class_{cls}"] = rec[i]
        metrics[f"f1_class_{cls}"] = f1[i]
        metrics[f"support_class_{cls}"] = supp[i]

    # =========================================================
    # CONFUSION MATRIX
    # =========================================================
    cm = confusion_matrix(y_true, y_pred, labels=classes)

    for i, cls_true in enumerate(classes):
        for j, cls_pred in enumerate(classes):
            metrics[f"cm_true_{cls_true}_pred_{cls_pred}"] = cm[i, j]

    for i, cls in enumerate(classes):
        tp = cm[i, i]
        fn = cm[i, :].sum() - tp
        fp = cm[:, i].sum() - tp
        tn = cm.sum() - tp - fn - fp

        metrics[f"tp_class_{cls}"] = tp
        metrics[f"fn_class_{cls}"] = fn
        metrics[f"fp_class_{cls}"] = fp
        metrics[f"tn_class_{cls}"] = tn

        metrics[f"specificity_class_{cls}"] = tn / (tn + fp) if (tn + fp) > 0 else 0.0
        metrics[f"npv_class_{cls}"] = tn / (tn + fn) if (tn + fn) > 0 else 0.0
        metrics[f"fpr_class_{cls}"] = fp / (fp + tn) if (fp + tn) > 0 else 0.0
        metrics[f"fnr_class_{cls}"] = fn / (fn + tp) if (fn + tp) > 0 else 0.0

    # =========================================================
    # PROBABILITY-BASED METRICS
    # =========================================================
    if y_proba is not None:
        try:
            y_proba = np.asarray(y_proba)

            if y_proba.ndim != 2 or y_proba.shape[1] != n_classes:
                raise ValueError(
                    f"y_proba debe tener shape (n_samples, {n_classes}) "
                    f"y tiene {y_proba.shape}"
                )

            # ROC AUC multiclass
            metrics["roc_auc_ovr_macro"] = roc_auc_score(
                y_true, y_proba, multi_class="ovr", average="macro"
            )
            metrics["roc_auc_ovr_weighted"] = roc_auc_score(
                y_true, y_proba, multi_class="ovr", average="weighted"
            )
            metrics["roc_auc_ovo_macro"] = roc_auc_score(
                y_true, y_proba, multi_class="ovo", average="macro"
            )
            metrics["roc_auc_ovo_weighted"] = roc_auc_score(
                y_true, y_proba, multi_class="ovo", average="weighted"
            )

            # AUCPR multiclass
            y_true_bin = label_binarize(y_true, classes=classes)

            metrics["aucpr_macro"] = average_precision_score(
                y_true_bin, y_proba, average="macro"
            )
            metrics["aucpr_weighted"] = average_precision_score(
                y_true_bin, y_proba, average="weighted"
            )

            class_prevalences = y_true_bin.mean(axis=0)
            metrics["aucpr_macro_baseline"] = class_prevalences.mean()
            metrics["aucpr_weighted_baseline"] = np.sum(class_prevalences ** 2)

        except Exception:
            metrics["roc_auc_ovr_macro"] = np.nan
            metrics["roc_auc_ovr_weighted"] = np.nan
            metrics["roc_auc_ovo_macro"] = np.nan
            metrics["roc_auc_ovo_weighted"] = np.nan
            metrics["aucpr_macro"] = np.nan
            metrics["aucpr_weighted"] = np.nan
            metrics["aucpr_macro_baseline"] = np.nan
            metrics["aucpr_weighted_baseline"] = np.nan
    else:
        metrics["roc_auc_ovr_macro"] = np.nan
        metrics["roc_auc_ovr_weighted"] = np.nan
        metrics["roc_auc_ovo_macro"] = np.nan
        metrics["roc_auc_ovo_weighted"] = np.nan
        metrics["aucpr_macro"] = np.nan
        metrics["aucpr_weighted"] = np.nan
        metrics["aucpr_macro_baseline"] = np.nan
        metrics["aucpr_weighted_baseline"] = np.nan

    return metrics


def _mean_metrics(metrics_list):
    keys = metrics_list[0].keys()
    return {k: np.mean([m[k] for m in metrics_list]) for k in keys}


def _build_row_multiclass(results, model_name, sampler_name, classes_original):
    metric_names = list(results[0]["cv"].keys())

    row = {
        "model": model_name,
        "sampler": sampler_name,
        "target_type": "multiclass",
        "classes": list(classes_original),
        "n_classes": len(classes_original),
    }

    for metric in metric_names:
        cv_vals = [r["cv"][metric] for r in results]
        train_vals = [r["train"][metric] for r in results]
        test_vals = [r["test"][metric] for r in results]

        row[f"{metric}_cv_mean"] = np.mean(cv_vals)
        row[f"{metric}_cv_std"] = np.std(cv_vals, ddof=1)

        row[f"{metric}_train_mean"] = np.mean(train_vals)
        row[f"{metric}_train_std"] = np.std(train_vals, ddof=1)

        row[f"{metric}_test_mean"] = np.mean(test_vals)
        row[f"{metric}_test_std"] = np.std(test_vals, ddof=1)

    return row


def _resolve_target_class_counts(y_train_inner, target_class_counts):
    """
    Devuelve un dict {clase: cantidad_final_deseada} para ROS/SMOTE/CTGAN.

    target_class_counts puede ser:
    - None
    - int: lleva toda clase con menos de ese valor hasta ese valor
    - dict: {clase: cantidad_final}
    - "balance_to_majority": lleva todas las clases al tamaño de la mayoritaria
    """
    y_sr = pd.Series(y_train_inner)
    class_counts = y_sr.value_counts().sort_index().to_dict()

    if target_class_counts is None:
        return None

    if isinstance(target_class_counts, str):
        if target_class_counts != "balance_to_majority":
            raise ValueError(
                "Si es string, target_class_counts debe ser 'balance_to_majority'."
            )
        majority_count = max(class_counts.values())
        return {
            cls: majority_count
            for cls, count in class_counts.items()
            if count < majority_count
        }

    if isinstance(target_class_counts, int):
        return {
            cls: int(target_class_counts)
            for cls, count in class_counts.items()
            if count < int(target_class_counts)
        }

    if isinstance(target_class_counts, dict):
        resolved = {}
        for cls, desired in target_class_counts.items():
            if cls not in class_counts:
                continue
            if desired < class_counts[cls]:
                raise ValueError(
                    f"Para clase {cls}, target={desired} no puede ser menor "
                    f"que el count actual={class_counts[cls]}"
                )
            if desired > class_counts[cls]:
                resolved[cls] = int(desired)
        return resolved if len(resolved) > 0 else None

    raise ValueError(
        "target_class_counts debe ser None, int, dict o 'balance_to_majority'."
    )


def _apply_single_resampling_method_multiclass(
    X_train_inner,
    y_train_inner,
    resampling_method=None,
    target_class_counts=None,
    random_state=42,
    smote_k_neighbors=3,
    ctgan_epochs=300
):
    X_df = pd.DataFrame(X_train_inner).reset_index(drop=True)
    y_sr = pd.Series(y_train_inner).reset_index(drop=True)

    if resampling_method is None or target_class_counts is None:
        return X_df.to_numpy(), y_sr.to_numpy()

    if resampling_method not in {"ros", "smote", "ctgan"}:
        raise ValueError(
            "resampling_method debe ser uno de: None, 'ros', 'smote', 'ctgan'"
        )

    sampling_strategy = _resolve_target_class_counts(y_sr, target_class_counts)

    if sampling_strategy is None or len(sampling_strategy) == 0:
        return X_df.to_numpy(), y_sr.to_numpy()

    if resampling_method == "ros":
        ros = RandomOverSampler(
            sampling_strategy=sampling_strategy,
            random_state=random_state
        )
        X_res, y_res = ros.fit_resample(X_df, y_sr)
        return np.asarray(X_res), np.asarray(y_res)

    if resampling_method == "smote":
        class_counts = y_sr.value_counts().to_dict()
        for cls in sampling_strategy:
            if class_counts[cls] <= smote_k_neighbors:
                raise ValueError(
                    f"La clase {cls} tiene {class_counts[cls]} muestras. "
                    f"SMOTE requiere más de k_neighbors={smote_k_neighbors}."
                )

        smote = SMOTE(
            sampling_strategy=sampling_strategy,
            k_neighbors=smote_k_neighbors,
            random_state=random_state
        )
        X_res, y_res = smote.fit_resample(X_df, y_sr)
        return np.asarray(X_res), np.asarray(y_res)

    if resampling_method == "ctgan":
        synthetic_parts = []
        synthetic_labels = []

        for cls, target_count in sampling_strategy.items():
            current_count = int((y_sr == cls).sum())
            rows_to_generate = int(target_count - current_count)

            if rows_to_generate <= 0:
                continue

            X_class = X_df[y_sr == cls].copy()

            if len(X_class) < 2:
                raise ValueError(
                    f"No hay suficientes muestras de la clase {cls} para entrenar CTGAN."
                )

            metadata = Metadata.detect_from_dataframe(data=X_class)

            ctgan_model = CTGANSynthesizer(
                metadata=metadata,
                epochs=ctgan_epochs
            )

            ctgan_model.fit(X_class)
            synthetic_data = ctgan_model.sample(num_rows=rows_to_generate)

            synthetic_parts.append(synthetic_data)
            synthetic_labels.append(pd.Series([cls] * rows_to_generate))

        if len(synthetic_parts) == 0:
            return X_df.to_numpy(), y_sr.to_numpy()

        X_syn = pd.concat(synthetic_parts, ignore_index=True)
        y_syn = pd.concat(synthetic_labels, ignore_index=True)

        X_res = pd.concat([X_df, X_syn], ignore_index=True)
        y_res = pd.concat([y_sr, y_syn], ignore_index=True)

        return X_res.to_numpy(), y_res.to_numpy()

    return X_df.to_numpy(), y_sr.to_numpy()


def evaluate_model_10x10_metrics_multiclass_sampler(
    model_dict: dict,
    X,
    y,
    n_outer=10,
    n_inner=10,
    test_size_outer=0.30,
    test_size_inner=0.30,
    random_state=42,
    cost_matrix=None,
    resampling_method=None,
    target_class_counts=None,
    smote_k_neighbors=3,
    ctgan_epochs=300,
):
    """
    Evalúa modelos multiclase con validación 10x10 y remuestreo en:
    - inner train: ~70% del target del outer
    - outer train final: target_class_counts completo

    target_class_counts:
    - None
    - int
    - dict
    - "balance_to_majority"
    """

    X_arr = X.values if hasattr(X, "iloc") else np.asarray(X)
    y_arr_raw = y.values if hasattr(y, "iloc") else np.asarray(y)
    y_arr_raw = np.asarray(y_arr_raw).ravel()

    le = LabelEncoder()
    y_arr = le.fit_transform(y_arr_raw)
    classes_encoded = np.arange(len(le.classes_))
    classes_original = le.classes_

    if len(classes_encoded) < 3:
        raise ValueError(
            f"Esta función es para multiclase. Clases encontradas: {classes_original}"
        )

    all_rows = []

    for model_name, model in model_dict.items():
        print(f"Evaluating model: {model_name}")

        outer_cv = StratifiedShuffleSplit(
            n_splits=n_outer,
            test_size=test_size_outer,
            random_state=random_state
        )

        results = []

        for outer_fold, (train_idx, test_idx) in enumerate(
            outer_cv.split(X_arr, y_arr),
            start=1
        ):
            X_train_outer, X_test_outer = X_arr[train_idx], X_arr[test_idx]
            y_train_outer, y_test_outer = y_arr[train_idx], y_arr[test_idx]

            inner_cv = StratifiedShuffleSplit(
                n_splits=n_inner,
                test_size=test_size_inner,
                random_state=random_state + outer_fold
            )

            inner_scores = []

            for inner_fold, (train_inner_idx, val_inner_idx) in enumerate(
                inner_cv.split(X_train_outer, y_train_outer),
                start=1
            ):
                X_train_inner = X_train_outer[train_inner_idx]
                y_train_inner = y_train_outer[train_inner_idx]
                X_val_inner = X_train_outer[val_inner_idx]
                y_val_inner = y_train_outer[val_inner_idx]

                inner_target_class_counts = None
                if target_class_counts is not None:
                    resolved_outer = _resolve_target_class_counts(
                        y_train_outer,
                        target_class_counts
                    )

                    if resolved_outer is not None:
                        inner_target_class_counts = {}
                        current_inner_counts = pd.Series(y_train_inner).value_counts().to_dict()

                        for cls, outer_target in resolved_outer.items():
                            current_inner = current_inner_counts.get(cls, 0)
                            inner_target = max(
                                current_inner,
                                int(np.floor(outer_target * 0.70))
                            )
                            if inner_target > current_inner:
                                inner_target_class_counts[cls] = inner_target

                        if len(inner_target_class_counts) == 0:
                            inner_target_class_counts = None

                X_train_inner_res, y_train_inner_res = _apply_single_resampling_method_multiclass(
                    X_train_inner=X_train_inner,
                    y_train_inner=y_train_inner,
                    resampling_method=resampling_method,
                    target_class_counts=inner_target_class_counts,
                    random_state=random_state + outer_fold * 100 + inner_fold,
                    smote_k_neighbors=smote_k_neighbors,
                    ctgan_epochs=ctgan_epochs
                )

                est = clone(model)
                est.fit(X_train_inner_res, y_train_inner_res)

                y_pred_val = est.predict(X_val_inner)

                y_proba_val = (
                    est.predict_proba(X_val_inner)
                    if hasattr(est, "predict_proba")
                    else None
                )

                inner_scores.append(
                    _compute_metrics_multiclass(
                        y_true=y_val_inner,
                        y_pred=y_pred_val,
                        y_proba=y_proba_val,
                        classes=classes_encoded,
                        cost_matrix=cost_matrix
                    )
                )

            cv_mean_scores = _mean_metrics(inner_scores)

            X_train_outer_res, y_train_outer_res = _apply_single_resampling_method_multiclass(
                X_train_inner=X_train_outer,
                y_train_inner=y_train_outer,
                resampling_method=resampling_method,
                target_class_counts=target_class_counts,
                random_state=random_state + outer_fold,
                smote_k_neighbors=smote_k_neighbors,
                ctgan_epochs=ctgan_epochs
            )

            final_model = clone(model)
            final_model.fit(X_train_outer_res, y_train_outer_res)

            y_pred_train = final_model.predict(X_train_outer_res)
            y_proba_train = (
                final_model.predict_proba(X_train_outer_res)
                if hasattr(final_model, "predict_proba")
                else None
            )

            train_scores = _compute_metrics_multiclass(
                y_true=y_train_outer_res,
                y_pred=y_pred_train,
                y_proba=y_proba_train,
                classes=classes_encoded,
                cost_matrix=cost_matrix
            )

            y_pred_test = final_model.predict(X_test_outer)
            y_proba_test = (
                final_model.predict_proba(X_test_outer)
                if hasattr(final_model, "predict_proba")
                else None
            )

            test_scores = _compute_metrics_multiclass(
                y_true=y_test_outer,
                y_pred=y_pred_test,
                y_proba=y_proba_test,
                classes=classes_encoded,
                cost_matrix=cost_matrix
            )

            results.append({
                "cv": cv_mean_scores,
                "train": train_scores,
                "test": test_scores
            })

        row = _build_row_multiclass(
            results=results,
            model_name=model_name,
            sampler_name=resampling_method,
            classes_original=classes_original
        )
        all_rows.append(row)

        print(
            f"{model_name} | "
            f"Sampler={resampling_method} | "
            f"ACC CV={row['accuracy_cv_mean']:.4f} | "
            f"ACC Train={row['accuracy_train_mean']:.4f} | "
            f"ACC Test={row['accuracy_test_mean']:.4f} | "
            f"F1 macro CV={row['f1_macro_cv_mean']:.4f} | "
            f"F1 macro Test={row['f1_macro_test_mean']:.4f} | "
            f"ROC AUC OVR macro CV={row['roc_auc_ovr_macro_cv_mean']:.4f} | "
            f"ROC AUC OVR macro Test={row['roc_auc_ovr_macro_test_mean']:.4f} | "
            f"AUCPR macro CV={row['aucpr_macro_cv_mean']:.4f} | "
            f"AUCPR macro Test={row['aucpr_macro_test_mean']:.4f}"
        )

    return pd.DataFrame(all_rows)

# %% [markdown]
# # MODEL DEVELOPMENT

# %% [markdown]
# # BASELINE MODELS

# %% [markdown]
# ## MCID

# %%
data_df_ovr=[]
for val1,val2 in pairs_init_MCID:
    y = pd.read_csv(y_multiples_MCID[val2], index_col=0)
    print(f"Evaluating for target: {val2} with features: {val1}")
    X = pd.read_csv(X_multiples_MCID[val1], index_col=0)
    print(f"\tLoaded X shape: {X.shape}, y shape: {y.shape}")
    for pipeline_weight in classification_models_by_weight_MCID:
        print(f"\tPipeline weight config: {pipeline_weight}")
        classification_models = classification_models_by_weight_MCID[pipeline_weight]
        print(f"\tEvaluating multiclass classification for {val2} \n")
        results_df = evaluate_model_10x10_metrics_multiclass_sampler(
            model_dict=classification_models,
            X=X,
            y=y,
            n_outer=10,
            n_inner=10,
            test_size_outer=0.30,
            test_size_inner=0.30,
            random_state=42,
            cost_matrix=None,
            resampling_method=None,
            target_class_counts=None
        )
        results_df["weight_config"] = pipeline_weight
        results_df["feature_set"] = val1
        results_df["sampler_config"] = np.nan
        data_df_ovr.append(results_df)

        for sampler_dict in [{0:180, 2:270}, {0:200, 2:290}, {0:220, 2:310}]:
            print(f"\tEvaluating with ROS sampler config: {sampler_dict} \n")
            results_df_ros = evaluate_model_10x10_metrics_multiclass_sampler(
                model_dict=classification_models,
                X=X,
                y=y,
                n_inner=5,
                resampling_method="ros",
                target_class_counts=sampler_dict)
            
            results_df_ros["weight_config"] = pipeline_weight
            results_df_ros["feature_set"] = val1
            results_df_ros["sampler_config"] = f"ROS_{sampler_dict}"
            data_df_ovr.append(results_df_ros)
            
            print(f"\tEvaluating with SMOTE sampler config: {sampler_dict} \n")
            results_df_smote = evaluate_model_10x10_metrics_multiclass_sampler(
                        model_dict=classification_models,
                        X=X,
                        y=y,
                        n_inner=5,
                        resampling_method="smote",
                        target_class_counts=sampler_dict,
                        smote_k_neighbors=3)
            
            results_df_smote["weight_config"] = pipeline_weight
            results_df_smote["feature_set"] = val1
            results_df_smote["sampler_config"] = f"SMOTE_{sampler_dict}"
            data_df_ovr.append(results_df_smote)

final_results_df_ovr = pd.concat(data_df_ovr, ignore_index=True)
final_results_df_ovr.to_csv(output_path / "multiclass_classification_results_MCID_v2.csv", index=False)
# Out:
# Evaluating for target: MCID_v2 with features: X_STATS_V2
# 	Loaded X shape: (956, 301), y shape: (956, 1)
# 	Pipeline weight config: balanced
# 	Evaluating multiclass classification for MCID_v2
#
# Evaluating model: decision_tree
# decision_tree | Sampler=None | ACC CV=0.4874 | ACC Train=1.0000 | ACC Test=0.4659 | F1 macro CV=0.4137 | F1 macro Test=0.3901 | ROC AUC OVR macro CV=0.5694 | ROC AUC OVR macro Test=0.5517 | AUCPR macro CV=0.3746 | AUCPR macro Test=0.3637
# Evaluating model: random_forest
# random_forest | Sampler=None | ACC CV=0.5653 | ACC Train=1.0000 | ACC Test=0.5634 | F1 macro CV=0.4210 | F1 macro Test=0.4180 | ROC AUC OVR macro CV=0.6983 | ROC AUC OVR macro Test=0.6984 | AUCPR macro CV=0.4966 | AUCPR macro Test=0.4931
# Evaluating model: extra_trees
# extra_trees | Sampler=None | ACC CV=0.5626 | ACC Train=1.0000 | ACC Test=0.5585 | F1 macro CV=0.4244 | F1 macro Test=0.4188 | ROC AUC OVR macro CV=0.6983 | ROC AUC OVR macro Test=0.6966 | AUCPR macro CV=0.4984 | AUCPR macro Test=0.4898
# Evaluating model: xgboost
# /Users/fserracrespi/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/training.py:200: UserWarning: [15:41:57] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/fserracrespi/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/training.py:200: UserWarning: [15:41:58] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/fserracrespi/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/training.py:200: UserWarning: [15:41:58] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/fserracrespi/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/training.py:200: UserWarning: [15:41:59] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/fserracrespi/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/training.py:200: UserWarning: [15:41:59] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/fserracrespi/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/training.py:200: UserWarning: [15:42:00] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/fserracrespi/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/training.py:200: UserWarning: [15:42:01] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/fserracrespi/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/training.py:200: UserWarning: [15:42:01] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/fserracrespi/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/training.py:200: UserWarning: [15:42:02] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/fserracrespi/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/training.py:200: UserWarning: [15:42:02] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/fserracrespi/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/training.py:200: UserWarning: [15:42:03] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/fserracrespi/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/training.py:200: UserWarning: [15:42:04] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/fserracrespi/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/training.py:200: UserWarning: [15:42:04] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/fserracrespi/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/training.py:200: UserWarning: [15:42:05] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# Exception ignored on calling ctypes callback function: <bound method DataIter._next_wrapper of <xgboost.data.SingleBatchInternalIter object at 0x135206110>>
# Traceback (most recent call last):
#   File "/Users/fserracrespi/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/core.py", line 607, in _next_wrapper
#     def _next_wrapper(self, this: None) -> int:  # pylint: disable=unused-argument
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[36], line 11
#       9 classification_models = classification_models_by_weight_MCID[pipeline_weight]
#      10 print(f"\tEvaluating multiclass classification for {val2} \n")
# ---> 11 results_df = evaluate_model_10x10_metrics_multiclass_sampler(
#      12     model_dict=classification_models,
#      13     X=X,
#      14     y=y,
#      15     n_outer=10,
#      16     n_inner=10,
#      17     test_size_outer=0.30,
#      18     test_size_inner=0.30,
#      19     random_state=42,
#      20     cost_matrix=None,
#      21     resampling_method=None,
#      22     target_class_counts=None
#      23 )
#      24 results_df["weight_config"] = pipeline_weight
#      25 results_df["feature_set"] = val1
#
# Cell In[35], line 479, in evaluate_model_10x10_metrics_multiclass_sampler(model_dict, X, y, n_outer, n_inner, test_size_outer, test_size_inner, random_state, cost_matrix, resampling_method, target_class_counts, smote_k_neighbors, ctgan_epochs)
#     468 X_train_inner_res, y_train_inner_res = _apply_single_resampling_method_multiclass(
#     469     X_train_inner=X_train_inner,
#     470     y_train_inner=y_train_inner,
#    (...)
#     475     ctgan_epochs=ctgan_epochs
#     476 )
#     478 est = clone(model)
# --> 479 est.fit(X_train_inner_res, y_train_inner_res)
#     481 y_pred_val = est.predict(X_val_inner)
#     483 y_proba_val = (
#     484     est.predict_proba(X_val_inner)
#     485     if hasattr(est, "predict_proba")
#     486     else None
#     487 )
#
# File ~/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/imblearn/pipeline.py:522, in Pipeline.fit(self, X, y, **params)
#     516     if self._final_estimator != "passthrough":
#     517         last_step_params = self._get_metadata_for_step(
#     518             step_idx=len(self) - 1,
#     519             step_params=routed_params[self.steps[-1][0]],
#     520             all_params=params,
#     521         )
# --> 522         self._final_estimator.fit(Xt, yt, **last_step_params["fit"])
#     523 return self
#
# File ~/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/core.py:751, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     749 for k, arg in zip(sig.parameters, args):
#     750     kwargs[k] = arg
# --> 751 return func(**kwargs)
#
# File ~/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/sklearn.py:1787, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1784 model, feature_types = get_model_categories(X, model, self.feature_types)
#    1786 evals_result: EvalsLog = {}
# -> 1787 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1788     missing=self.missing,
#    1789     X=X,
#    1790     y=y,
#    1791     group=None,
#    1792     qid=None,
#    1793     sample_weight=sample_weight,
#    1794     base_margin=base_margin,
#    1795     feature_weights=feature_weights,
#    1796     eval_set=eval_set,
#    1797     sample_weight_eval_set=sample_weight_eval_set,
#    1798     base_margin_eval_set=base_margin_eval_set,
#    1799     eval_group=None,
#    1800     eval_qid=None,
#    1801     create_dmatrix=self._create_dmatrix,
#    1802     enable_categorical=self.enable_categorical,
#    1803     feature_types=feature_types,
#    1804 )
#    1806 self._Booster = train(
#    1807     params,
#    1808     train_dmatrix,
#    (...)
#    1817     callbacks=self.callbacks,
#    1818 )
#    1820 if not callable(self.objective):
#
# File ~/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/sklearn.py:700, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     695 """Convert array_like evaluation matrices into DMatrix. Perform sanity checks on the
#     696 way.
#     697
#     698 """
#     699 # Feature_types contains the optional reference categories from the booster object.
# --> 700 train_dmatrix = create_dmatrix(
#     701     data=X,
#     702     label=y,
#     703     group=group,
#     704     qid=qid,
#     705     weight=sample_weight,
#     706     base_margin=base_margin,
#     707     feature_weights=feature_weights,
#     708     missing=missing,
#     709     enable_categorical=enable_categorical,
#     710     feature_types=feature_types,
#     711     ref=None,
#     712 )
#     714 n_validation = 0 if eval_set is None else len(eval_set)
#     715 if hasattr(train_dmatrix, "get_categories"):
#
# File ~/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/sklearn.py:1257, in XGBModel._create_dmatrix(self, ref, **kwargs)
#    1255 if _can_use_qdm(self.tree_method, self.device) and self.booster != "gblinear":
#    1256     try:
# -> 1257         return QuantileDMatrix(
#    1258             **kwargs, ref=ref, nthread=self.n_jobs, max_bin=self.max_bin
#    1259         )
#    1260     except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
#    1261         pass
#
# File ~/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/core.py:751, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     749 for k, arg in zip(sig.parameters, args):
#     750     kwargs[k] = arg
# --> 751 return func(**kwargs)
#
# File ~/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/core.py:1719, in QuantileDMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, max_bin, ref, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical, max_quantile_batches, data_split_mode)
#    1699     if any(
#    1700         info is not None
#    1701         for info in (
#    (...)
#    1712         )
#    1713     ):
#    1714         raise ValueError(
#    1715             "If data iterator is used as input, data like label should be "
#    1716             "specified as batch argument."
#    1717         )
# -> 1719 self._init(
#    1720     data,
#    1721     ref=ref,
#    1722     label=label,
#    1723     weight=weight,
#    1724     base_margin=base_margin,
#    1725     group=group,
#    1726     qid=qid,
#    1727     label_lower_bound=label_lower_bound,
#    1728     label_upper_bound=label_upper_bound,
#    1729     feature_weights=feature_weights,
#    1730     feature_names=feature_names,
#    1731     feature_types=feature_types,
#    1732     enable_categorical=enable_categorical,
#    1733     max_quantile_blocks=max_quantile_batches,
#    1734 )
#
# File ~/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/core.py:1785, in QuantileDMatrix._init(self, data, ref, enable_categorical, max_quantile_blocks, **meta)
#    1783 it.reraise()
#    1784 # delay check_call to throw intermediate exception first
# -> 1785 _check_call(ret)
#    1786 self.handle = handle
#    1788 if ref is not None:
#
# File ~/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/core.py:324, in _check_call(ret)
#     313 """Check the return value of C API call
#     314
#     315 This function will raise exception when error occurs.
#    (...)
#     321     return value from API calls
#     322 """
#     323 if ret != 0:
# --> 324     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#
# XGBoostError: [15:42:05] /Users/runner/work/xgboost/xgboost/src/data/iterative_dmatrix.cc:100: Check failed: rbegin == Info().num_row_ (936 vs. 468) :
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001346e7dd8 dmlc::LogMessageFatal::~LogMessageFatal() + 124
#   [bt] (1) 2   libxgboost.dylib                    0x00000001348f9ce8 xgboost::data::IterativeDMatrix::InitFromCPU(xgboost::Context const*, xgboost::BatchParam const&, xgboost::data::DataIterProxy<void (void*), int (void*)>&&, float, std::__1::shared_ptr<xgboost::DMatrix>) + 2668
#   [bt] (2) 3   libxgboost.dylib                    0x00000001348f8e20 xgboost::data::IterativeDMatrix::IterativeDMatrix(void*, void*, std::__1::shared_ptr<xgboost::DMatrix>, void (*)(void*), int (*)(void*), float, int, int, long long) + 908
#   [bt] (3) 4   libxgboost.dylib                    0x0000000134878414 xgboost::DMatrix* xgboost::DMatrix::Create<void*, void*, void (void*), int (void*)>(void*, void*, std::__1::shared_ptr<xgboost::DMatrix>, void (*)(void*), int (*)(void*), float, int, int, long long) + 152
#   [bt] (4) 5   libxgboost.dylib                    0x00000001346f21ac XGQuantileDMatrixCreateFromCallback + 520
#   [bt] (5) 6   libffi.dylib                        0x000000019899e050 ffi_call_SYSV + 80
#   [bt] (6) 7   libffi.dylib                        0x00000001989a6af0 ffi_call_int + 1220
#   [bt] (7) 8   _ctypes.cpython-310-darwin.so       0x0000000107a0f9a0 _ctypes_callproc + 1348
#   [bt] (8) 9   _ctypes.cpython-310-darwin.so       0x0000000107a0830c PyCFuncPtr_call + 1176

# %% [markdown]
# ### TRESHOLDING PARA OPTIMIZAR F1_MACRO

# %%
import numpy as np
import pandas as pd

from sklearn.base import clone
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import f1_score, accuracy_score


def predict_with_thresholds_3class(proba, thresholds):
    proba = np.asarray(proba, dtype=float)
    thresholds = np.asarray(thresholds, dtype=float)

    if proba.shape[1] != 3:
        raise ValueError("Este helper espera exactamente 3 clases.")
    if thresholds.shape[0] != 3:
        raise ValueError("thresholds debe tener longitud 3.")

    adjusted = proba / thresholds.reshape(1, -1)
    return np.argmax(adjusted, axis=1)


def greedy_search_thresholds_3class(y_true, y_proba, grid=None, n_rounds=3):
    y_true = np.asarray(y_true).ravel()
    y_proba = np.asarray(y_proba, dtype=float)

    if y_proba.shape[1] != 3:
        raise ValueError("y_proba debe tener 3 columnas (3 clases).")

    if grid is None:
        grid = np.arange(0.5, 1.51, 0.05)

    thresholds = np.ones(3, dtype=float)

    y_pred = predict_with_thresholds_3class(y_proba, thresholds)
    best_f1 = f1_score(y_true, y_pred, average="macro", zero_division=0)

    for _ in range(n_rounds):
        improved = False

        for c in range(3):
            best_local_t = thresholds[c]
            best_local_f1 = best_f1

            for t in grid:
                candidate = thresholds.copy()
                candidate[c] = t

                y_pred_candidate = predict_with_thresholds_3class(y_proba, candidate)
                score = f1_score(y_true, y_pred_candidate, average="macro", zero_division=0)

                if score > best_local_f1:
                    best_local_f1 = score
                    best_local_t = t

            if best_local_f1 > best_f1:
                thresholds[c] = best_local_t
                best_f1 = best_local_f1
                improved = True

        if not improved:
            break

    return thresholds, best_f1


def evaluate_model_10x10_f1macro_thresholds_3class(
    model_dict,
    X,
    y,
    n_outer=10,
    n_inner=10,
    test_size_outer=0.30,
    test_size_inner=0.30,
    random_state=42,
    threshold_grid=None,
    threshold_aggregation="median",   # "median" o "mean"
    greedy_rounds=3,
    verbose=True,
):
    X_arr = X.values if hasattr(X, "iloc") else np.asarray(X)
    y_arr = y.values if hasattr(y, "iloc") else np.asarray(y)
    y_arr = np.asarray(y_arr).ravel()

    labels = np.unique(y_arr)
    if len(labels) != 3:
        raise ValueError(f"Esta función espera exactamente 3 clases. Clases encontradas: {labels}")

    # Reindexar a 0,1,2
    label_to_idx = {label: i for i, label in enumerate(labels)}
    idx_to_label = {i: label for label, i in label_to_idx.items()}
    y_idx = np.vectorize(label_to_idx.get)(y_arr)

    if threshold_grid is None:
        threshold_grid = np.arange(0.5, 1.51, 0.05)

    if threshold_aggregation not in {"mean", "median"}:
        raise ValueError("threshold_aggregation debe ser 'mean' o 'median'.")

    rows = []
    detailed_results = {}

    for model_name, model in model_dict.items():
        if verbose:
            print(f"Evaluating model: {model_name}")

        outer_cv = StratifiedShuffleSplit(
            n_splits=n_outer,
            test_size=test_size_outer,
            random_state=random_state
        )

        outer_results = []

        for outer_fold, (train_idx, test_idx) in enumerate(outer_cv.split(X_arr, y_idx), start=1):
            X_train_outer, X_test_outer = X_arr[train_idx], X_arr[test_idx]
            y_train_outer, y_test_outer = y_idx[train_idx], y_idx[test_idx]

            inner_cv = StratifiedShuffleSplit(
                n_splits=n_inner,
                test_size=test_size_inner,
                random_state=random_state + outer_fold
            )

            inner_best_thresholds = []
            inner_best_f1s = []

            for train_inner_idx, val_inner_idx in inner_cv.split(X_train_outer, y_train_outer):
                X_train_inner = X_train_outer[train_inner_idx]
                y_train_inner = y_train_outer[train_inner_idx]
                X_val_inner = X_train_outer[val_inner_idx]
                y_val_inner = y_train_outer[val_inner_idx]

                est = clone(model)
                est.fit(X_train_inner, y_train_inner)

                if not hasattr(est, "predict_proba"):
                    raise ValueError(
                        f"El modelo '{model_name}' no tiene predict_proba(), necesario para thresholds multiclass."
                    )

                y_proba_val = est.predict_proba(X_val_inner)

                best_thresholds_inner, best_f1_inner = greedy_search_thresholds_3class(
                    y_true=y_val_inner,
                    y_proba=y_proba_val,
                    grid=threshold_grid,
                    n_rounds=greedy_rounds
                )

                inner_best_thresholds.append(best_thresholds_inner)
                inner_best_f1s.append(best_f1_inner)

            inner_best_thresholds = np.asarray(inner_best_thresholds, dtype=float)

            if threshold_aggregation == "median":
                best_thresholds_outer = np.median(inner_best_thresholds, axis=0)
            else:
                best_thresholds_outer = np.mean(inner_best_thresholds, axis=0)

            final_model = clone(model)
            final_model.fit(X_train_outer, y_train_outer)

            y_proba_test = final_model.predict_proba(X_test_outer)
            y_pred_test = predict_with_thresholds_3class(y_proba_test, best_thresholds_outer)

            test_f1_macro = f1_score(y_test_outer, y_pred_test, average="macro", zero_division=0)
            test_acc = accuracy_score(y_test_outer, y_pred_test)

            outer_results.append({
                "outer_fold": outer_fold,
                "best_thresholds_outer": best_thresholds_outer,
                "inner_f1_macro_mean": float(np.mean(inner_best_f1s)),
                "test_f1_macro": float(test_f1_macro),
                "test_accuracy": float(test_acc),
            })

            if verbose:
                print(
                    f"  Outer fold {outer_fold:02d} | "
                    f"best_thresholds={np.round(best_thresholds_outer, 4)} | "
                    f"inner_f1_macro={np.mean(inner_best_f1s):.4f} | "
                    f"test_f1_macro={test_f1_macro:.4f} | "
                    f"test_acc={test_acc:.4f}"
                )

        all_thresholds = np.array([r["best_thresholds_outer"] for r in outer_results], dtype=float)
        all_test_f1 = np.array([r["test_f1_macro"] for r in outer_results], dtype=float)
        all_test_acc = np.array([r["test_accuracy"] for r in outer_results], dtype=float)

        if threshold_aggregation == "median":
            best_thresholds_final = np.median(all_thresholds, axis=0)
        else:
            best_thresholds_final = np.mean(all_thresholds, axis=0)

        row = {
            "model": model_name,
            "classes_originales": list(labels),
            "best_thresholds_final": best_thresholds_final,
            "test_f1_macro_mean": all_test_f1.mean(),
            "test_f1_macro_std": all_test_f1.std(ddof=1),
            "test_accuracy_mean": all_test_acc.mean(),
            "test_accuracy_std": all_test_acc.std(ddof=1),
        }

        rows.append(row)
        detailed_results[model_name] = outer_results

    df_results = pd.DataFrame(rows)
    return df_results, detailed_results

# %%
df_results, detailed_results = evaluate_model_10x10_f1macro_thresholds_3class(
    model_dict={'XGBOOST': classification_models_by_weight_MCID['w_c2_10']['xgboost']},
    X=pd.read_csv(X_multiples_HY3['X_VX_STATS_V2'], index_col=0),
    y=pd.read_csv(y_multiples_MCID['MCID_v2'], index_col=0),
    n_outer=10,
    n_inner=10,
    test_size_outer=0.30,
    test_size_inner=0.30,
    random_state=42,
    threshold_grid=np.arange(0.5, 1.51, 0.05),
    threshold_aggregation="median",
    greedy_rounds=3,
    verbose=True
)

df_results
# Out:
# Evaluating model: XGBOOST
#   Outer fold 01 | best_thresholds=[0.7 1.  1. ] | inner_f1_macro=0.7761 | test_f1_macro=0.8077 | test_acc=0.8711
#   Outer fold 02 | best_thresholds=[1.    1.075 0.65 ] | inner_f1_macro=0.8220 | test_f1_macro=0.7836 | test_acc=0.8641
#   Outer fold 03 | best_thresholds=[0.5 1.  1. ] | inner_f1_macro=0.7597 | test_f1_macro=0.8359 | test_acc=0.8815
#   Outer fold 04 | best_thresholds=[0.825 0.9   1.   ] | inner_f1_macro=0.7787 | test_f1_macro=0.7878 | test_acc=0.8571
#   Outer fold 05 | best_thresholds=[0.775 1.05  1.   ] | inner_f1_macro=0.8295 | test_f1_macro=0.7467 | test_acc=0.8537
#   Outer fold 06 | best_thresholds=[1.05  1.025 1.   ] | inner_f1_macro=0.8160 | test_f1_macro=0.7885 | test_acc=0.8711
#   Outer fold 07 | best_thresholds=[0.95  0.925 1.   ] | inner_f1_macro=0.7772 | test_f1_macro=0.7795 | test_acc=0.8885
#   Outer fold 08 | best_thresholds=[0.6 1.  1. ] | inner_f1_macro=0.7884 | test_f1_macro=0.8150 | test_acc=0.8746
#   Outer fold 09 | best_thresholds=[0.625 1.05  1.   ] | inner_f1_macro=0.7988 | test_f1_macro=0.8478 | test_acc=0.8990
#   Outer fold 10 | best_thresholds=[0.6   0.875 1.   ] | inner_f1_macro=0.7932 | test_f1_macro=0.7968 | test_acc=0.8746
#      model classes_originales           best_thresholds_final  \
# 0  XGBOOST          [0, 1, 2]  [0.7375000000000003, 1.0, 1.0]
#
#    test_f1_macro_mean  test_f1_macro_std  test_accuracy_mean  \
# 0            0.798912           0.029191            0.873519
#
#    test_accuracy_std
# 0           0.013747

# %% [markdown]
# # REGULARIZED MODELS

# %% [markdown]
# ## MCID

# %%
data_df_ovr=[]
for val1,val2 in pairs_init_MCID:
    y = pd.read_csv(y_multiples_MCID[val2], index_col=0)
    print(f"Evaluating for target: {val2} with features: {val1}")
    X = pd.read_csv(X_multiples_MCID[val1], index_col=0)
    print(f"\tLoaded X shape: {X.shape}, y shape: {y.shape}")
    for pipeline_weight in classification_models_by_weight_reg_MCID:
        print(f"\tPipeline weight config: {pipeline_weight}")
        classification_models = classification_models_by_weight_reg_MCID[pipeline_weight]
        print(f"\tEvaluating multiclass classification for {val2} \n")
        results_df = evaluate_model_10x10_metrics_multiclass_sampler(
            model_dict=classification_models,
            X=X,
            y=y,
            n_outer=10,
            n_inner=10,
            test_size_outer=0.30,
            test_size_inner=0.30,
            random_state=42,
            cost_matrix=None,
            resampling_method=None,
            target_class_counts=None
        )
        results_df["weight_config"] = pipeline_weight
        results_df["feature_set"] = val1
        results_df["sampler_config"] = np.nan
        data_df_ovr.append(results_df)

        for sampler_dict in [{0:180, 2:270}, {0:200, 2:290}, {0:220, 2:310}]:
            print(f"\tEvaluating with ROS sampler config: {sampler_dict} \n")
            results_df_ros = evaluate_model_10x10_metrics_multiclass_sampler(
                model_dict=classification_models,
                X=X,
                y=y,
                n_inner=5,
                resampling_method="ros",
                target_class_counts=sampler_dict)
            
            results_df_ros["weight_config"] = pipeline_weight
            results_df_ros["feature_set"] = val1
            results_df_ros["sampler_config"] = f"ROS_{sampler_dict}"
            data_df_ovr.append(results_df_ros)
            
            print(f"\tEvaluating with SMOTE sampler config: {sampler_dict} \n")
            results_df_smote = evaluate_model_10x10_metrics_multiclass_sampler(
                        model_dict=classification_models,
                        X=X,
                        y=y,
                        n_inner=5,
                        resampling_method="smote",
                        target_class_counts=sampler_dict,
                        smote_k_neighbors=3)
            
            results_df_smote["weight_config"] = pipeline_weight
            results_df_smote["feature_set"] = val1
            results_df_smote["sampler_config"] = f"SMOTE_{sampler_dict}"
            data_df_ovr.append(results_df_smote)

final_results_df_ovr = pd.concat(data_df_ovr, ignore_index=True)
final_results_df_ovr.to_csv(output_path / "multiclass_classification_results_reg_MCID_v2.csv", index=False)
# Out:
# Evaluating for target: MCID_v2 with features: X_STATS_V2
# 	Loaded X shape: (956, 301), y shape: (956, 1)
# 	Pipeline weight config: balanced
# 	Evaluating multiclass classification for MCID_v2
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=None | ACC CV=0.4792 | ACC Train=0.5262 | ACC Test=0.4596 | F1 macro CV=0.4305 | F1 macro Test=0.4140 | ROC AUC OVR macro CV=0.6600 | ROC AUC OVR macro Test=0.6575 | AUCPR macro CV=0.4461 | AUCPR macro Test=0.4424
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=None | ACC CV=0.5396 | ACC Train=0.6900 | ACC Test=0.5408 | F1 macro CV=0.4646 | F1 macro Test=0.4653 | ROC AUC OVR macro CV=0.7103 | ROC AUC OVR macro Test=0.7129 | AUCPR macro CV=0.5078 | AUCPR macro Test=0.5038
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=None | ACC CV=0.5466 | ACC Train=0.6743 | ACC Test=0.5401 | F1 macro CV=0.4699 | F1 macro Test=0.4613 | ROC AUC OVR macro CV=0.7155 | ROC AUC OVR macro Test=0.7197 | AUCPR macro CV=0.5128 | AUCPR macro Test=0.5129
# Evaluating model: xgboost_reg
# /Users/fserracrespi/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/training.py:200: UserWarning: [15:42:58] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/fserracrespi/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/training.py:200: UserWarning: [15:42:58] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/fserracrespi/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/training.py:200: UserWarning: [15:42:58] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/fserracrespi/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/training.py:200: UserWarning: [15:42:58] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/fserracrespi/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/training.py:200: UserWarning: [15:42:59] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/fserracrespi/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/training.py:200: UserWarning: [15:42:59] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/fserracrespi/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/training.py:200: UserWarning: [15:42:59] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/fserracrespi/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/training.py:200: UserWarning: [15:43:00] WARNING: /Users/runner/work/xgboost/xgboost/src/context.cc:207: Device is changed from GPU to CPU as we couldn't find any available GPU on the system.
#   bst.update(dtrain, iteration=i, fobj=obj)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 11
#       9 classification_models = classification_models_by_weight_reg_MCID[pipeline_weight]
#      10 print(f"\tEvaluating multiclass classification for {val2} \n")
# ---> 11 results_df = evaluate_model_10x10_metrics_multiclass_sampler(
#      12     model_dict=classification_models,
#      13     X=X,
#      14     y=y,
#      15     n_outer=10,
#      16     n_inner=10,
#      17     test_size_outer=0.30,
#      18     test_size_inner=0.30,
#      19     random_state=42,
#      20     cost_matrix=None,
#      21     resampling_method=None,
#      22     target_class_counts=None
#      23 )
#      24 results_df["weight_config"] = pipeline_weight
#      25 results_df["feature_set"] = val1
#
# Cell In[35], line 479, in evaluate_model_10x10_metrics_multiclass_sampler(model_dict, X, y, n_outer, n_inner, test_size_outer, test_size_inner, random_state, cost_matrix, resampling_method, target_class_counts, smote_k_neighbors, ctgan_epochs)
#     468 X_train_inner_res, y_train_inner_res = _apply_single_resampling_method_multiclass(
#     469     X_train_inner=X_train_inner,
#     470     y_train_inner=y_train_inner,
#    (...)
#     475     ctgan_epochs=ctgan_epochs
#     476 )
#     478 est = clone(model)
# --> 479 est.fit(X_train_inner_res, y_train_inner_res)
#     481 y_pred_val = est.predict(X_val_inner)
#     483 y_proba_val = (
#     484     est.predict_proba(X_val_inner)
#     485     if hasattr(est, "predict_proba")
#     486     else None
#     487 )
#
# File ~/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/imblearn/pipeline.py:522, in Pipeline.fit(self, X, y, **params)
#     516     if self._final_estimator != "passthrough":
#     517         last_step_params = self._get_metadata_for_step(
#     518             step_idx=len(self) - 1,
#     519             step_params=routed_params[self.steps[-1][0]],
#     520             all_params=params,
#     521         )
# --> 522         self._final_estimator.fit(Xt, yt, **last_step_params["fit"])
#     523 return self
#
# File ~/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/core.py:751, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     749 for k, arg in zip(sig.parameters, args):
#     750     kwargs[k] = arg
# --> 751 return func(**kwargs)
#
# File ~/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/sklearn.py:1806, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1786 evals_result: EvalsLog = {}
#    1787 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1788     missing=self.missing,
#    1789     X=X,
#    (...)
#    1803     feature_types=feature_types,
#    1804 )
# -> 1806 self._Booster = train(
#    1807     params,
#    1808     train_dmatrix,
#    1809     self.get_num_boosting_rounds(),
#    1810     evals=evals,
#    1811     early_stopping_rounds=self.early_stopping_rounds,
#    1812     evals_result=evals_result,
#    1813     obj=obj,
#    1814     custom_metric=metric,
#    1815     verbose_eval=verbose,
#    1816     xgb_model=model,
#    1817     callbacks=self.callbacks,
#    1818 )
#    1820 if not callable(self.objective):
#    1821     self.objective = params["objective"]
#
# File ~/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/core.py:751, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     749 for k, arg in zip(sig.parameters, args):
#     750     kwargs[k] = arg
# --> 751 return func(**kwargs)
#
# File ~/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/training.py:200, in train(params, dtrain, num_boost_round, evals, obj, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     198 if cb_container.before_iteration(bst, i, dtrain, evals):
#     199     break
# --> 200 bst.update(dtrain, iteration=i, fobj=obj)
#     201 if cb_container.after_iteration(bst, i, dtrain, evals):
#     202     break
#
# File ~/Desktop/PD_progression_ppmi/.venv/lib/python3.10/site-packages/xgboost/core.py:2391, in Booster.update(self, dtrain, iteration, fobj)
#    2387 self._assign_dmatrix_features(dtrain)
#    2389 if fobj is None:
#    2390     _check_call(
# -> 2391         _LIB.XGBoosterUpdateOneIter(
#    2392             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2393         )
#    2394     )
#    2395     return
#    2397 # Forward the gradient calculation to the boost method.
#
# KeyboardInterrupt:

# %% [markdown]
# # UNDERSAMPLING

# %% [markdown]
# ## MCID

# %%
data_df_ovr=[]
for val1,val2 in pairs_init_MCID:
    y = pd.read_csv(y_multiples_MCID[val2], index_col=0)
    print(f"Evaluating for target: {val2} with features: {val1}")
    X = pd.read_csv(X_multiples_MCID[val1], index_col=0)
    print(f"\tLoaded X shape: {X.shape}, y shape: {y.shape}")
    for pipeline_weight in classification_models_by_weight_reg_UNDER_MCID:
        print(f"\tPipeline weight config: {pipeline_weight}")
        classification_models = classification_models_by_weight_reg_UNDER_MCID[pipeline_weight]
        print(f"\tEvaluating multiclass classification for {val2} \n")
        results_df = evaluate_model_10x10_metrics_multiclass_sampler(
            model_dict=classification_models,
            X=X,
            y=y,
            n_outer=10,
            n_inner=10,
            test_size_outer=0.30,
            test_size_inner=0.30,
            random_state=42,
            cost_matrix=None,
            resampling_method=None,
            target_class_counts=None
        )
        results_df["weight_config"] = pipeline_weight
        results_df["feature_set"] = val1
        results_df["sampler_config"] = np.nan
        data_df_ovr.append(results_df)

        for sampler_dict in [{0:180, 2:270}, {0:200, 2:290}, {0:220, 2:310}]:
            print(f"\tEvaluating with ROS sampler config: {sampler_dict} \n")
            results_df_ros = evaluate_model_10x10_metrics_multiclass_sampler(
                model_dict=classification_models,
                X=X,
                y=y,
                n_inner=5,
                resampling_method="ros",
                target_class_counts=sampler_dict)
            
            results_df_ros["weight_config"] = pipeline_weight
            results_df_ros["feature_set"] = val1
            results_df_ros["sampler_config"] = f"ROS_{sampler_dict}"
            data_df_ovr.append(results_df_ros)
            
            print(f"\tEvaluating with SMOTE sampler config: {sampler_dict} \n")
            results_df_smote = evaluate_model_10x10_metrics_multiclass_sampler(
                        model_dict=classification_models,
                        X=X,
                        y=y,
                        n_inner=5,
                        resampling_method="smote",
                        target_class_counts=sampler_dict,
                        smote_k_neighbors=3)
            
            results_df_smote["weight_config"] = pipeline_weight
            results_df_smote["feature_set"] = val1
            results_df_smote["sampler_config"] = f"SMOTE_{sampler_dict}"
            data_df_ovr.append(results_df_smote)

final_results_df_ovr = pd.concat(data_df_ovr, ignore_index=True)
final_results_df_ovr.to_csv(output_path / "multiclass_classification_results_reg_UNDER_MCID_v2.csv", index=False)
# Out:
# Evaluating for target: HY3_v2 with features: X_STATS_V2
# 	Loaded X shape: (956, 301), y shape: (956, 1)
# 	Pipeline weight config: balanced
# 	Evaluating multiclass classification for HY3_v2
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=None | ACC CV=0.6656 | ACC Train=0.6695 | ACC Test=0.6554 | F1 macro CV=0.5894 | F1 macro Test=0.6024 | ROC AUC OVR macro CV=0.7966 | ROC AUC OVR macro Test=0.8046 | AUCPR macro CV=0.5526 | AUCPR macro Test=0.5748
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=None | ACC CV=0.8026 | ACC Train=0.8380 | ACC Test=0.8188 | F1 macro CV=0.7378 | F1 macro Test=0.7565 | ROC AUC OVR macro CV=0.9513 | ROC AUC OVR macro Test=0.9475 | AUCPR macro CV=0.8533 | AUCPR macro Test=0.8569
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=None | ACC CV=0.7605 | ACC Train=0.8051 | ACC Test=0.8003 | F1 macro CV=0.6966 | F1 macro Test=0.7362 | ROC AUC OVR macro CV=0.9487 | ROC AUC OVR macro Test=0.9477 | AUCPR macro CV=0.8462 | AUCPR macro Test=0.8551
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=None | ACC CV=0.7486 | ACC Train=0.7913 | ACC Test=0.7700 | F1 macro CV=0.6787 | F1 macro Test=0.7015 | ROC AUC OVR macro CV=0.9307 | ROC AUC OVR macro Test=0.9330 | AUCPR macro CV=0.8087 | AUCPR macro Test=0.8305
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=None | ACC CV=0.7306 | ACC Train=0.7414 | ACC Test=0.7223 | F1 macro CV=0.6586 | F1 macro Test=0.6531 | ROC AUC OVR macro CV=0.9079 | ROC AUC OVR macro Test=0.9004 | AUCPR macro CV=0.7399 | AUCPR macro Test=0.7178
# Evaluating model: svm_reg
# svm_reg | Sampler=None | ACC CV=0.7270 | ACC Train=0.7489 | ACC Test=0.7383 | F1 macro CV=0.6645 | F1 macro Test=0.6790 | ROC AUC OVR macro CV=0.9383 | ROC AUC OVR macro Test=0.9369 | AUCPR macro CV=0.8426 | AUCPR macro Test=0.8502
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=None | ACC CV=0.7822 | ACC Train=0.8239 | ACC Test=0.7753 | F1 macro CV=0.7151 | F1 macro Test=0.7134 | ROC AUC OVR macro CV=0.9161 | ROC AUC OVR macro Test=0.9048 | AUCPR macro CV=0.8017 | AUCPR macro Test=0.7809
# Evaluating model: knn_reg
# knn_reg | Sampler=None | ACC CV=0.6681 | ACC Train=0.7656 | ACC Test=0.6847 | F1 macro CV=0.6287 | F1 macro Test=0.6437 | ROC AUC OVR macro CV=0.9281 | ROC AUC OVR macro Test=0.9176 | AUCPR macro CV=0.8143 | AUCPR macro Test=0.7994
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=None | ACC CV=0.7203 | ACC Train=0.7855 | ACC Test=0.7564 | F1 macro CV=0.6654 | F1 macro Test=0.6989 | ROC AUC OVR macro CV=0.8311 | ROC AUC OVR macro Test=0.8578 | AUCPR macro CV=0.6170 | AUCPR macro Test=0.6543
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=None | ACC CV=0.6113 | ACC Train=0.6707 | ACC Test=0.6537 | F1 macro CV=0.5414 | F1 macro Test=0.5871 | ROC AUC OVR macro CV=0.8545 | ROC AUC OVR macro Test=0.9016 | AUCPR macro CV=0.7165 | AUCPR macro Test=0.7632
# 	Evaluating with ROS sampler config: {2: 60}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.6595 | ACC Train=0.6823 | ACC Test=0.6613 | F1 macro CV=0.5917 | F1 macro Test=0.6026 | ROC AUC OVR macro CV=0.8030 | ROC AUC OVR macro Test=0.8259 | AUCPR macro CV=0.5683 | AUCPR macro Test=0.6032
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.8223 | ACC Train=0.8560 | ACC Test=0.8341 | F1 macro CV=0.7582 | F1 macro Test=0.7734 | ROC AUC OVR macro CV=0.9540 | ROC AUC OVR macro Test=0.9489 | AUCPR macro CV=0.8626 | AUCPR macro Test=0.8581
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.7764 | ACC Train=0.8299 | ACC Test=0.8132 | F1 macro CV=0.7110 | F1 macro Test=0.7516 | ROC AUC OVR macro CV=0.9526 | ROC AUC OVR macro Test=0.9487 | AUCPR macro CV=0.8551 | AUCPR macro Test=0.8570
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.7726 | ACC Train=0.8099 | ACC Test=0.7889 | F1 macro CV=0.7025 | F1 macro Test=0.7203 | ROC AUC OVR macro CV=0.9382 | ROC AUC OVR macro Test=0.9369 | AUCPR macro CV=0.8301 | AUCPR macro Test=0.8397
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.7417 | ACC Train=0.7486 | ACC Test=0.7289 | F1 macro CV=0.6705 | F1 macro Test=0.6619 | ROC AUC OVR macro CV=0.9095 | ROC AUC OVR macro Test=0.9089 | AUCPR macro CV=0.7457 | AUCPR macro Test=0.7364
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.7417 | ACC Train=0.7692 | ACC Test=0.7505 | F1 macro CV=0.6781 | F1 macro Test=0.6903 | ROC AUC OVR macro CV=0.9387 | ROC AUC OVR macro Test=0.9379 | AUCPR macro CV=0.8401 | AUCPR macro Test=0.8521
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.7972 | ACC Train=0.8454 | ACC Test=0.7895 | F1 macro CV=0.7278 | F1 macro Test=0.7274 | ROC AUC OVR macro CV=0.9185 | ROC AUC OVR macro Test=0.9087 | AUCPR macro CV=0.8038 | AUCPR macro Test=0.7857
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.6801 | ACC Train=0.7854 | ACC Test=0.6885 | F1 macro CV=0.6412 | F1 macro Test=0.6463 | ROC AUC OVR macro CV=0.9267 | ROC AUC OVR macro Test=0.9205 | AUCPR macro CV=0.8131 | AUCPR macro Test=0.8010
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.7510 | ACC Train=0.8063 | ACC Test=0.7707 | F1 macro CV=0.6926 | F1 macro Test=0.7125 | ROC AUC OVR macro CV=0.8508 | ROC AUC OVR macro Test=0.8668 | AUCPR macro CV=0.6452 | AUCPR macro Test=0.6704
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.6634 | ACC Train=0.7043 | ACC Test=0.6833 | F1 macro CV=0.5967 | F1 macro Test=0.6242 | ROC AUC OVR macro CV=0.8860 | ROC AUC OVR macro Test=0.8899 | AUCPR macro CV=0.7550 | AUCPR macro Test=0.7489
# 	Evaluating with SMOTE sampler config: {2: 60}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.6754 | ACC Train=0.7060 | ACC Test=0.6784 | F1 macro CV=0.6044 | F1 macro Test=0.6138 | ROC AUC OVR macro CV=0.8039 | ROC AUC OVR macro Test=0.8242 | AUCPR macro CV=0.5722 | AUCPR macro Test=0.6103
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.8294 | ACC Train=0.8599 | ACC Test=0.8369 | F1 macro CV=0.7663 | F1 macro Test=0.7754 | ROC AUC OVR macro CV=0.9545 | ROC AUC OVR macro Test=0.9492 | AUCPR macro CV=0.8651 | AUCPR macro Test=0.8602
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.7771 | ACC Train=0.8299 | ACC Test=0.8132 | F1 macro CV=0.7122 | F1 macro Test=0.7512 | ROC AUC OVR macro CV=0.9530 | ROC AUC OVR macro Test=0.9489 | AUCPR macro CV=0.8578 | AUCPR macro Test=0.8615
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.7780 | ACC Train=0.8149 | ACC Test=0.7892 | F1 macro CV=0.7089 | F1 macro Test=0.7198 | ROC AUC OVR macro CV=0.9387 | ROC AUC OVR macro Test=0.9362 | AUCPR macro CV=0.8317 | AUCPR macro Test=0.8382
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.7475 | ACC Train=0.7642 | ACC Test=0.7422 | F1 macro CV=0.6764 | F1 macro Test=0.6723 | ROC AUC OVR macro CV=0.9107 | ROC AUC OVR macro Test=0.9092 | AUCPR macro CV=0.7561 | AUCPR macro Test=0.7424
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.7494 | ACC Train=0.7708 | ACC Test=0.7505 | F1 macro CV=0.6870 | F1 macro Test=0.6918 | ROC AUC OVR macro CV=0.9383 | ROC AUC OVR macro Test=0.9375 | AUCPR macro CV=0.8374 | AUCPR macro Test=0.8475
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.7976 | ACC Train=0.8440 | ACC Test=0.7871 | F1 macro CV=0.7288 | F1 macro Test=0.7235 | ROC AUC OVR macro CV=0.9188 | ROC AUC OVR macro Test=0.9076 | AUCPR macro CV=0.8058 | AUCPR macro Test=0.7824
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.6765 | ACC Train=0.7750 | ACC Test=0.6833 | F1 macro CV=0.6415 | F1 macro Test=0.6450 | ROC AUC OVR macro CV=0.9298 | ROC AUC OVR macro Test=0.9220 | AUCPR macro CV=0.8170 | AUCPR macro Test=0.8044
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.7515 | ACC Train=0.8049 | ACC Test=0.7697 | F1 macro CV=0.6930 | F1 macro Test=0.7103 | ROC AUC OVR macro CV=0.8508 | ROC AUC OVR macro Test=0.8670 | AUCPR macro CV=0.6460 | AUCPR macro Test=0.6713
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.6636 | ACC Train=0.7144 | ACC Test=0.6937 | F1 macro CV=0.5974 | F1 macro Test=0.6358 | ROC AUC OVR macro CV=0.8829 | ROC AUC OVR macro Test=0.9038 | AUCPR macro CV=0.7518 | AUCPR macro Test=0.7657
# 	Evaluating with ROS sampler config: {2: 80}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.6947 | ACC Train=0.7063 | ACC Test=0.6840 | F1 macro CV=0.6244 | F1 macro Test=0.6225 | ROC AUC OVR macro CV=0.8300 | ROC AUC OVR macro Test=0.8259 | AUCPR macro CV=0.6104 | AUCPR macro Test=0.6132
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.8404 | ACC Train=0.8638 | ACC Test=0.8383 | F1 macro CV=0.7759 | F1 macro Test=0.7776 | ROC AUC OVR macro CV=0.9558 | ROC AUC OVR macro Test=0.9498 | AUCPR macro CV=0.8674 | AUCPR macro Test=0.8652
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.8223 | ACC Train=0.8469 | ACC Test=0.8261 | F1 macro CV=0.7596 | F1 macro Test=0.7639 | ROC AUC OVR macro CV=0.9547 | ROC AUC OVR macro Test=0.9497 | AUCPR macro CV=0.8613 | AUCPR macro Test=0.8589
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.7983 | ACC Train=0.8363 | ACC Test=0.8084 | F1 macro CV=0.7286 | F1 macro Test=0.7429 | ROC AUC OVR macro CV=0.9430 | ROC AUC OVR macro Test=0.9408 | AUCPR macro CV=0.8382 | AUCPR macro Test=0.8442
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.7498 | ACC Train=0.7688 | ACC Test=0.7348 | F1 macro CV=0.6764 | F1 macro Test=0.6654 | ROC AUC OVR macro CV=0.9141 | ROC AUC OVR macro Test=0.9104 | AUCPR macro CV=0.7532 | AUCPR macro Test=0.7477
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.7528 | ACC Train=0.7910 | ACC Test=0.7659 | F1 macro CV=0.6882 | F1 macro Test=0.7055 | ROC AUC OVR macro CV=0.9408 | ROC AUC OVR macro Test=0.9385 | AUCPR macro CV=0.8413 | AUCPR macro Test=0.8516
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.8127 | ACC Train=0.8661 | ACC Test=0.7969 | F1 macro CV=0.7411 | F1 macro Test=0.7302 | ROC AUC OVR macro CV=0.9212 | ROC AUC OVR macro Test=0.9128 | AUCPR macro CV=0.8063 | AUCPR macro Test=0.7893
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.6998 | ACC Train=0.8200 | ACC Test=0.6983 | F1 macro CV=0.6556 | F1 macro Test=0.6499 | ROC AUC OVR macro CV=0.9291 | ROC AUC OVR macro Test=0.9203 | AUCPR macro CV=0.8150 | AUCPR macro Test=0.7969
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.7808 | ACC Train=0.8263 | ACC Test=0.7913 | F1 macro CV=0.7205 | F1 macro Test=0.7305 | ROC AUC OVR macro CV=0.8729 | ROC AUC OVR macro Test=0.8808 | AUCPR macro CV=0.6769 | AUCPR macro Test=0.6921
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.7009 | ACC Train=0.7655 | ACC Test=0.7174 | F1 macro CV=0.6346 | F1 macro Test=0.6568 | ROC AUC OVR macro CV=0.9011 | ROC AUC OVR macro Test=0.9107 | AUCPR macro CV=0.7729 | AUCPR macro Test=0.7808
# 	Evaluating with SMOTE sampler config: {2: 80}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.7029 | ACC Train=0.7282 | ACC Test=0.6843 | F1 macro CV=0.6251 | F1 macro Test=0.6187 | ROC AUC OVR macro CV=0.8241 | ROC AUC OVR macro Test=0.8357 | AUCPR macro CV=0.6011 | AUCPR macro Test=0.6222
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.8556 | ACC Train=0.8763 | ACC Test=0.8460 | F1 macro CV=0.7928 | F1 macro Test=0.7840 | ROC AUC OVR macro CV=0.9562 | ROC AUC OVR macro Test=0.9503 | AUCPR macro CV=0.8669 | AUCPR macro Test=0.8680
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.8274 | ACC Train=0.8504 | ACC Test=0.8321 | F1 macro CV=0.7662 | F1 macro Test=0.7717 | ROC AUC OVR macro CV=0.9553 | ROC AUC OVR macro Test=0.9502 | AUCPR macro CV=0.8623 | AUCPR macro Test=0.8620
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.8127 | ACC Train=0.8489 | ACC Test=0.8150 | F1 macro CV=0.7447 | F1 macro Test=0.7473 | ROC AUC OVR macro CV=0.9443 | ROC AUC OVR macro Test=0.9414 | AUCPR macro CV=0.8403 | AUCPR macro Test=0.8466
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.7596 | ACC Train=0.7858 | ACC Test=0.7530 | F1 macro CV=0.6870 | F1 macro Test=0.6850 | ROC AUC OVR macro CV=0.9163 | ROC AUC OVR macro Test=0.9094 | AUCPR macro CV=0.7687 | AUCPR macro Test=0.7491
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.7617 | ACC Train=0.7946 | ACC Test=0.7648 | F1 macro CV=0.6994 | F1 macro Test=0.7072 | ROC AUC OVR macro CV=0.9412 | ROC AUC OVR macro Test=0.9374 | AUCPR macro CV=0.8379 | AUCPR macro Test=0.8397
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.8124 | ACC Train=0.8651 | ACC Test=0.7972 | F1 macro CV=0.7408 | F1 macro Test=0.7311 | ROC AUC OVR macro CV=0.9215 | ROC AUC OVR macro Test=0.9115 | AUCPR macro CV=0.8074 | AUCPR macro Test=0.7872
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.6815 | ACC Train=0.7924 | ACC Test=0.6857 | F1 macro CV=0.6418 | F1 macro Test=0.6479 | ROC AUC OVR macro CV=0.9343 | ROC AUC OVR macro Test=0.9249 | AUCPR macro CV=0.8225 | AUCPR macro Test=0.8059
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.7835 | ACC Train=0.8279 | ACC Test=0.7951 | F1 macro CV=0.7245 | F1 macro Test=0.7378 | ROC AUC OVR macro CV=0.8731 | ROC AUC OVR macro Test=0.8803 | AUCPR macro CV=0.6799 | AUCPR macro Test=0.6925
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.7027 | ACC Train=0.7760 | ACC Test=0.7345 | F1 macro CV=0.6362 | F1 macro Test=0.6741 | ROC AUC OVR macro CV=0.9074 | ROC AUC OVR macro Test=0.9121 | AUCPR macro CV=0.7832 | AUCPR macro Test=0.7848
# 	Evaluating with ROS sampler config: {2: 100}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.6956 | ACC Train=0.7149 | ACC Test=0.6857 | F1 macro CV=0.6224 | F1 macro Test=0.6145 | ROC AUC OVR macro CV=0.8315 | ROC AUC OVR macro Test=0.8291 | AUCPR macro CV=0.6155 | AUCPR macro Test=0.6078
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.8498 | ACC Train=0.8695 | ACC Test=0.8411 | F1 macro CV=0.7876 | F1 macro Test=0.7815 | ROC AUC OVR macro CV=0.9563 | ROC AUC OVR macro Test=0.9507 | AUCPR macro CV=0.8665 | AUCPR macro Test=0.8655
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.8335 | ACC Train=0.8549 | ACC Test=0.8338 | F1 macro CV=0.7704 | F1 macro Test=0.7749 | ROC AUC OVR macro CV=0.9561 | ROC AUC OVR macro Test=0.9503 | AUCPR macro CV=0.8624 | AUCPR macro Test=0.8611
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.8102 | ACC Train=0.8502 | ACC Test=0.8157 | F1 macro CV=0.7400 | F1 macro Test=0.7527 | ROC AUC OVR macro CV=0.9466 | ROC AUC OVR macro Test=0.9430 | AUCPR macro CV=0.8449 | AUCPR macro Test=0.8412
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.7393 | ACC Train=0.7548 | ACC Test=0.7261 | F1 macro CV=0.6665 | F1 macro Test=0.6600 | ROC AUC OVR macro CV=0.9155 | ROC AUC OVR macro Test=0.9094 | AUCPR macro CV=0.7564 | AUCPR macro Test=0.7440
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.7706 | ACC Train=0.8083 | ACC Test=0.7746 | F1 macro CV=0.7050 | F1 macro Test=0.7136 | ROC AUC OVR macro CV=0.9427 | ROC AUC OVR macro Test=0.9405 | AUCPR macro CV=0.8426 | AUCPR macro Test=0.8514
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.8159 | ACC Train=0.8787 | ACC Test=0.8017 | F1 macro CV=0.7409 | F1 macro Test=0.7310 | ROC AUC OVR macro CV=0.9213 | ROC AUC OVR macro Test=0.9146 | AUCPR macro CV=0.8029 | AUCPR macro Test=0.7940
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.7153 | ACC Train=0.8424 | ACC Test=0.7111 | F1 macro CV=0.6678 | F1 macro Test=0.6606 | ROC AUC OVR macro CV=0.9300 | ROC AUC OVR macro Test=0.9210 | AUCPR macro CV=0.8163 | AUCPR macro Test=0.8008
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.7994 | ACC Train=0.8373 | ACC Test=0.7997 | F1 macro CV=0.7368 | F1 macro Test=0.7380 | ROC AUC OVR macro CV=0.8865 | ROC AUC OVR macro Test=0.8877 | AUCPR macro CV=0.6985 | AUCPR macro Test=0.7050
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.7236 | ACC Train=0.7965 | ACC Test=0.7530 | F1 macro CV=0.6578 | F1 macro Test=0.6964 | ROC AUC OVR macro CV=0.9158 | ROC AUC OVR macro Test=0.9175 | AUCPR macro CV=0.7939 | AUCPR macro Test=0.7909
# 	Evaluating with SMOTE sampler config: {2: 100}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.7064 | ACC Train=0.7421 | ACC Test=0.7174 | F1 macro CV=0.6257 | F1 macro Test=0.6507 | ROC AUC OVR macro CV=0.8261 | ROC AUC OVR macro Test=0.8361 | AUCPR macro CV=0.6050 | AUCPR macro Test=0.6339
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.8662 | ACC Train=0.8860 | ACC Test=0.8526 | F1 macro CV=0.8036 | F1 macro Test=0.7937 | ROC AUC OVR macro CV=0.9574 | ROC AUC OVR macro Test=0.9516 | AUCPR macro CV=0.8673 | AUCPR macro Test=0.8669
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.8405 | ACC Train=0.8644 | ACC Test=0.8387 | F1 macro CV=0.7788 | F1 macro Test=0.7796 | ROC AUC OVR macro CV=0.9564 | ROC AUC OVR macro Test=0.9518 | AUCPR macro CV=0.8629 | AUCPR macro Test=0.8659
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.8306 | ACC Train=0.8669 | ACC Test=0.8279 | F1 macro CV=0.7632 | F1 macro Test=0.7629 | ROC AUC OVR macro CV=0.9471 | ROC AUC OVR macro Test=0.9416 | AUCPR macro CV=0.8447 | AUCPR macro Test=0.8479
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.7658 | ACC Train=0.7915 | ACC Test=0.7561 | F1 macro CV=0.6943 | F1 macro Test=0.6848 | ROC AUC OVR macro CV=0.9169 | ROC AUC OVR macro Test=0.9080 | AUCPR macro CV=0.7678 | AUCPR macro Test=0.7534
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.7802 | ACC Train=0.8093 | ACC Test=0.7739 | F1 macro CV=0.7182 | F1 macro Test=0.7146 | ROC AUC OVR macro CV=0.9432 | ROC AUC OVR macro Test=0.9393 | AUCPR macro CV=0.8387 | AUCPR macro Test=0.8381
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.8170 | ACC Train=0.8800 | ACC Test=0.7997 | F1 macro CV=0.7446 | F1 macro Test=0.7301 | ROC AUC OVR macro CV=0.9214 | ROC AUC OVR macro Test=0.9137 | AUCPR macro CV=0.8038 | AUCPR macro Test=0.7907
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.6875 | ACC Train=0.8104 | ACC Test=0.6854 | F1 macro CV=0.6424 | F1 macro Test=0.6404 | ROC AUC OVR macro CV=0.9364 | ROC AUC OVR macro Test=0.9270 | AUCPR macro CV=0.8233 | AUCPR macro Test=0.8118
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.8031 | ACC Train=0.8420 | ACC Test=0.8056 | F1 macro CV=0.7425 | F1 macro Test=0.7487 | ROC AUC OVR macro CV=0.8868 | ROC AUC OVR macro Test=0.8880 | AUCPR macro CV=0.7032 | AUCPR macro Test=0.7108
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.7262 | ACC Train=0.8231 | ACC Test=0.7679 | F1 macro CV=0.6625 | F1 macro Test=0.7078 | ROC AUC OVR macro CV=0.9135 | ROC AUC OVR macro Test=0.9199 | AUCPR macro CV=0.7914 | AUCPR macro Test=0.8010
# 	Pipeline weight config: w_c2_10
# 	Evaluating multiclass classification for HY3_v2
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=None | ACC CV=0.4118 | ACC Train=0.3951 | ACC Test=0.4000 | F1 macro CV=0.3475 | F1 macro Test=0.3652 | ROC AUC OVR macro CV=0.7007 | ROC AUC OVR macro Test=0.7787 | AUCPR macro CV=0.4852 | AUCPR macro Test=0.5618
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=None | ACC CV=0.4777 | ACC Train=0.4859 | ACC Test=0.4791 | F1 macro CV=0.3802 | F1 macro Test=0.3898 | ROC AUC OVR macro CV=0.7889 | ROC AUC OVR macro Test=0.8751 | AUCPR macro CV=0.7138 | AUCPR macro Test=0.7885
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=None | ACC CV=0.4454 | ACC Train=0.4608 | ACC Test=0.4596 | F1 macro CV=0.3705 | F1 macro Test=0.3772 | ROC AUC OVR macro CV=0.7390 | ROC AUC OVR macro Test=0.8154 | AUCPR macro CV=0.6710 | AUCPR macro Test=0.7390
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=None | ACC CV=0.7486 | ACC Train=0.7913 | ACC Test=0.7700 | F1 macro CV=0.6787 | F1 macro Test=0.7015 | ROC AUC OVR macro CV=0.9307 | ROC AUC OVR macro Test=0.9330 | AUCPR macro CV=0.8087 | AUCPR macro Test=0.8305
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=None | ACC CV=0.7306 | ACC Train=0.7414 | ACC Test=0.7223 | F1 macro CV=0.6586 | F1 macro Test=0.6531 | ROC AUC OVR macro CV=0.9079 | ROC AUC OVR macro Test=0.9004 | AUCPR macro CV=0.7399 | AUCPR macro Test=0.7178
# Evaluating model: svm_reg
# svm_reg | Sampler=None | ACC CV=0.4619 | ACC Train=0.4836 | ACC Test=0.4801 | F1 macro CV=0.3725 | F1 macro Test=0.3948 | ROC AUC OVR macro CV=0.9326 | ROC AUC OVR macro Test=0.9312 | AUCPR macro CV=0.8263 | AUCPR macro Test=0.8288
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=None | ACC CV=0.7677 | ACC Train=0.8133 | ACC Test=0.7561 | F1 macro CV=0.6985 | F1 macro Test=0.6914 | ROC AUC OVR macro CV=0.9135 | ROC AUC OVR macro Test=0.9024 | AUCPR macro CV=0.7969 | AUCPR macro Test=0.7746
# Evaluating model: knn_reg
# knn_reg | Sampler=None | ACC CV=0.6681 | ACC Train=0.7656 | ACC Test=0.6847 | F1 macro CV=0.6287 | F1 macro Test=0.6437 | ROC AUC OVR macro CV=0.9281 | ROC AUC OVR macro Test=0.9176 | AUCPR macro CV=0.8143 | AUCPR macro Test=0.7994
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=None | ACC CV=0.7203 | ACC Train=0.7855 | ACC Test=0.7564 | F1 macro CV=0.6654 | F1 macro Test=0.6989 | ROC AUC OVR macro CV=0.8311 | ROC AUC OVR macro Test=0.8578 | AUCPR macro CV=0.6170 | AUCPR macro Test=0.6543
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=None | ACC CV=0.6113 | ACC Train=0.6707 | ACC Test=0.6537 | F1 macro CV=0.5414 | F1 macro Test=0.5871 | ROC AUC OVR macro CV=0.8545 | ROC AUC OVR macro Test=0.9016 | AUCPR macro CV=0.7165 | AUCPR macro Test=0.7632
# 	Evaluating with ROS sampler config: {2: 60}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.4254 | ACC Train=0.4975 | ACC Test=0.4889 | F1 macro CV=0.3646 | F1 macro Test=0.4389 | ROC AUC OVR macro CV=0.7250 | ROC AUC OVR macro Test=0.7560 | AUCPR macro CV=0.5091 | AUCPR macro Test=0.5403
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.4846 | ACC Train=0.5184 | ACC Test=0.5021 | F1 macro CV=0.3882 | F1 macro Test=0.4213 | ROC AUC OVR macro CV=0.8498 | ROC AUC OVR macro Test=0.8935 | AUCPR macro CV=0.7648 | AUCPR macro Test=0.8032
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.4588 | ACC Train=0.4775 | ACC Test=0.4659 | F1 macro CV=0.3762 | F1 macro Test=0.3792 | ROC AUC OVR macro CV=0.7751 | ROC AUC OVR macro Test=0.8491 | AUCPR macro CV=0.7076 | AUCPR macro Test=0.7644
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.7726 | ACC Train=0.8099 | ACC Test=0.7889 | F1 macro CV=0.7025 | F1 macro Test=0.7203 | ROC AUC OVR macro CV=0.9382 | ROC AUC OVR macro Test=0.9369 | AUCPR macro CV=0.8301 | AUCPR macro Test=0.8397
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.7417 | ACC Train=0.7486 | ACC Test=0.7289 | F1 macro CV=0.6705 | F1 macro Test=0.6619 | ROC AUC OVR macro CV=0.9095 | ROC AUC OVR macro Test=0.9089 | AUCPR macro CV=0.7457 | AUCPR macro Test=0.7364
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.4740 | ACC Train=0.5272 | ACC Test=0.5167 | F1 macro CV=0.3861 | F1 macro Test=0.4421 | ROC AUC OVR macro CV=0.9367 | ROC AUC OVR macro Test=0.9339 | AUCPR macro CV=0.8300 | AUCPR macro Test=0.8331
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.7852 | ACC Train=0.8331 | ACC Test=0.7721 | F1 macro CV=0.7152 | F1 macro Test=0.7085 | ROC AUC OVR macro CV=0.9164 | ROC AUC OVR macro Test=0.9065 | AUCPR macro CV=0.7995 | AUCPR macro Test=0.7802
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.6801 | ACC Train=0.7854 | ACC Test=0.6885 | F1 macro CV=0.6412 | F1 macro Test=0.6463 | ROC AUC OVR macro CV=0.9267 | ROC AUC OVR macro Test=0.9205 | AUCPR macro CV=0.8131 | AUCPR macro Test=0.8010
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.7510 | ACC Train=0.8063 | ACC Test=0.7707 | F1 macro CV=0.6926 | F1 macro Test=0.7125 | ROC AUC OVR macro CV=0.8508 | ROC AUC OVR macro Test=0.8668 | AUCPR macro CV=0.6452 | AUCPR macro Test=0.6704
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.6634 | ACC Train=0.7043 | ACC Test=0.6833 | F1 macro CV=0.5967 | F1 macro Test=0.6242 | ROC AUC OVR macro CV=0.8860 | ROC AUC OVR macro Test=0.8899 | AUCPR macro CV=0.7550 | AUCPR macro Test=0.7489
# 	Evaluating with SMOTE sampler config: {2: 60}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.4238 | ACC Train=0.4850 | ACC Test=0.4808 | F1 macro CV=0.3615 | F1 macro Test=0.4313 | ROC AUC OVR macro CV=0.7390 | ROC AUC OVR macro Test=0.7545 | AUCPR macro CV=0.5204 | AUCPR macro Test=0.5425
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.4905 | ACC Train=0.5253 | ACC Test=0.5118 | F1 macro CV=0.3934 | F1 macro Test=0.4322 | ROC AUC OVR macro CV=0.8593 | ROC AUC OVR macro Test=0.8967 | AUCPR macro CV=0.7743 | AUCPR macro Test=0.8080
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.4613 | ACC Train=0.4772 | ACC Test=0.4652 | F1 macro CV=0.3775 | F1 macro Test=0.3788 | ROC AUC OVR macro CV=0.7794 | ROC AUC OVR macro Test=0.8465 | AUCPR macro CV=0.7109 | AUCPR macro Test=0.7644
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.7780 | ACC Train=0.8149 | ACC Test=0.7892 | F1 macro CV=0.7089 | F1 macro Test=0.7198 | ROC AUC OVR macro CV=0.9387 | ROC AUC OVR macro Test=0.9362 | AUCPR macro CV=0.8317 | AUCPR macro Test=0.8382
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.7475 | ACC Train=0.7642 | ACC Test=0.7422 | F1 macro CV=0.6764 | F1 macro Test=0.6723 | ROC AUC OVR macro CV=0.9107 | ROC AUC OVR macro Test=0.9092 | AUCPR macro CV=0.7561 | AUCPR macro Test=0.7424
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.4717 | ACC Train=0.5250 | ACC Test=0.5132 | F1 macro CV=0.3840 | F1 macro Test=0.4386 | ROC AUC OVR macro CV=0.9359 | ROC AUC OVR macro Test=0.9331 | AUCPR macro CV=0.8273 | AUCPR macro Test=0.8289
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.7843 | ACC Train=0.8330 | ACC Test=0.7718 | F1 macro CV=0.7136 | F1 macro Test=0.7078 | ROC AUC OVR macro CV=0.9167 | ROC AUC OVR macro Test=0.9055 | AUCPR macro CV=0.8016 | AUCPR macro Test=0.7772
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.6765 | ACC Train=0.7750 | ACC Test=0.6833 | F1 macro CV=0.6415 | F1 macro Test=0.6450 | ROC AUC OVR macro CV=0.9298 | ROC AUC OVR macro Test=0.9220 | AUCPR macro CV=0.8170 | AUCPR macro Test=0.8044
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.7515 | ACC Train=0.8049 | ACC Test=0.7697 | F1 macro CV=0.6930 | F1 macro Test=0.7103 | ROC AUC OVR macro CV=0.8508 | ROC AUC OVR macro Test=0.8670 | AUCPR macro CV=0.6460 | AUCPR macro Test=0.6713
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.6636 | ACC Train=0.7144 | ACC Test=0.6937 | F1 macro CV=0.5974 | F1 macro Test=0.6358 | ROC AUC OVR macro CV=0.8829 | ROC AUC OVR macro Test=0.9038 | AUCPR macro CV=0.7518 | AUCPR macro Test=0.7657
# 	Evaluating with ROS sampler config: {2: 80}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.4411 | ACC Train=0.4991 | ACC Test=0.4732 | F1 macro CV=0.3907 | F1 macro Test=0.4313 | ROC AUC OVR macro CV=0.7470 | ROC AUC OVR macro Test=0.7519 | AUCPR macro CV=0.5330 | AUCPR macro Test=0.5372
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.5137 | ACC Train=0.5707 | ACC Test=0.5355 | F1 macro CV=0.4268 | F1 macro Test=0.4628 | ROC AUC OVR macro CV=0.8926 | ROC AUC OVR macro Test=0.9055 | AUCPR macro CV=0.7994 | AUCPR macro Test=0.8165
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.4709 | ACC Train=0.5023 | ACC Test=0.4780 | F1 macro CV=0.3805 | F1 macro Test=0.3876 | ROC AUC OVR macro CV=0.8350 | ROC AUC OVR macro Test=0.8738 | AUCPR macro CV=0.7516 | AUCPR macro Test=0.7902
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.7983 | ACC Train=0.8363 | ACC Test=0.8084 | F1 macro CV=0.7286 | F1 macro Test=0.7429 | ROC AUC OVR macro CV=0.9430 | ROC AUC OVR macro Test=0.9408 | AUCPR macro CV=0.8382 | AUCPR macro Test=0.8442
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.7498 | ACC Train=0.7688 | ACC Test=0.7348 | F1 macro CV=0.6764 | F1 macro Test=0.6654 | ROC AUC OVR macro CV=0.9141 | ROC AUC OVR macro Test=0.9104 | AUCPR macro CV=0.7532 | AUCPR macro Test=0.7477
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.5308 | ACC Train=0.6312 | ACC Test=0.6035 | F1 macro CV=0.4573 | F1 macro Test=0.5440 | ROC AUC OVR macro CV=0.9406 | ROC AUC OVR macro Test=0.9359 | AUCPR macro CV=0.8341 | AUCPR macro Test=0.8324
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.8019 | ACC Train=0.8555 | ACC Test=0.7854 | F1 macro CV=0.7295 | F1 macro Test=0.7187 | ROC AUC OVR macro CV=0.9192 | ROC AUC OVR macro Test=0.9110 | AUCPR macro CV=0.8021 | AUCPR macro Test=0.7850
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.6998 | ACC Train=0.8200 | ACC Test=0.6983 | F1 macro CV=0.6556 | F1 macro Test=0.6499 | ROC AUC OVR macro CV=0.9291 | ROC AUC OVR macro Test=0.9203 | AUCPR macro CV=0.8150 | AUCPR macro Test=0.7969
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.7808 | ACC Train=0.8263 | ACC Test=0.7913 | F1 macro CV=0.7205 | F1 macro Test=0.7305 | ROC AUC OVR macro CV=0.8729 | ROC AUC OVR macro Test=0.8808 | AUCPR macro CV=0.6769 | AUCPR macro Test=0.6921
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.7009 | ACC Train=0.7655 | ACC Test=0.7174 | F1 macro CV=0.6346 | F1 macro Test=0.6568 | ROC AUC OVR macro CV=0.9011 | ROC AUC OVR macro Test=0.9107 | AUCPR macro CV=0.7729 | AUCPR macro Test=0.7808
# 	Evaluating with SMOTE sampler config: {2: 80}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.4746 | ACC Train=0.5170 | ACC Test=0.4892 | F1 macro CV=0.4222 | F1 macro Test=0.4605 | ROC AUC OVR macro CV=0.7557 | ROC AUC OVR macro Test=0.7517 | AUCPR macro CV=0.5365 | AUCPR macro Test=0.5398
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.5476 | ACC Train=0.6146 | ACC Test=0.5829 | F1 macro CV=0.4673 | F1 macro Test=0.5171 | ROC AUC OVR macro CV=0.9100 | ROC AUC OVR macro Test=0.9146 | AUCPR macro CV=0.8142 | AUCPR macro Test=0.8264
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.4728 | ACC Train=0.5021 | ACC Test=0.4777 | F1 macro CV=0.3812 | F1 macro Test=0.3871 | ROC AUC OVR macro CV=0.8418 | ROC AUC OVR macro Test=0.8780 | AUCPR macro CV=0.7597 | AUCPR macro Test=0.7913
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.8127 | ACC Train=0.8489 | ACC Test=0.8150 | F1 macro CV=0.7447 | F1 macro Test=0.7473 | ROC AUC OVR macro CV=0.9443 | ROC AUC OVR macro Test=0.9414 | AUCPR macro CV=0.8403 | AUCPR macro Test=0.8466
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.7596 | ACC Train=0.7858 | ACC Test=0.7530 | F1 macro CV=0.6870 | F1 macro Test=0.6850 | ROC AUC OVR macro CV=0.9163 | ROC AUC OVR macro Test=0.9094 | AUCPR macro CV=0.7687 | AUCPR macro Test=0.7491
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.5191 | ACC Train=0.6200 | ACC Test=0.5969 | F1 macro CV=0.4441 | F1 macro Test=0.5379 | ROC AUC OVR macro CV=0.9392 | ROC AUC OVR macro Test=0.9354 | AUCPR macro CV=0.8292 | AUCPR macro Test=0.8278
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.8023 | ACC Train=0.8554 | ACC Test=0.7854 | F1 macro CV=0.7294 | F1 macro Test=0.7186 | ROC AUC OVR macro CV=0.9197 | ROC AUC OVR macro Test=0.9091 | AUCPR macro CV=0.8031 | AUCPR macro Test=0.7824
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.6815 | ACC Train=0.7924 | ACC Test=0.6857 | F1 macro CV=0.6418 | F1 macro Test=0.6479 | ROC AUC OVR macro CV=0.9343 | ROC AUC OVR macro Test=0.9249 | AUCPR macro CV=0.8225 | AUCPR macro Test=0.8059
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.7835 | ACC Train=0.8279 | ACC Test=0.7951 | F1 macro CV=0.7245 | F1 macro Test=0.7378 | ROC AUC OVR macro CV=0.8731 | ROC AUC OVR macro Test=0.8803 | AUCPR macro CV=0.6799 | AUCPR macro Test=0.6925
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.7027 | ACC Train=0.7760 | ACC Test=0.7345 | F1 macro CV=0.6362 | F1 macro Test=0.6741 | ROC AUC OVR macro CV=0.9074 | ROC AUC OVR macro Test=0.9121 | AUCPR macro CV=0.7832 | AUCPR macro Test=0.7848
# 	Evaluating with ROS sampler config: {2: 100}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.4982 | ACC Train=0.5473 | ACC Test=0.4962 | F1 macro CV=0.4530 | F1 macro Test=0.4556 | ROC AUC OVR macro CV=0.7401 | ROC AUC OVR macro Test=0.7434 | AUCPR macro CV=0.5260 | AUCPR macro Test=0.5383
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.5517 | ACC Train=0.6200 | ACC Test=0.5847 | F1 macro CV=0.4737 | F1 macro Test=0.5204 | ROC AUC OVR macro CV=0.9068 | ROC AUC OVR macro Test=0.9129 | AUCPR macro CV=0.8098 | AUCPR macro Test=0.8229
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.4800 | ACC Train=0.5288 | ACC Test=0.4909 | F1 macro CV=0.3866 | F1 macro Test=0.4031 | ROC AUC OVR macro CV=0.8670 | ROC AUC OVR macro Test=0.8879 | AUCPR macro CV=0.7792 | AUCPR macro Test=0.8039
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.8102 | ACC Train=0.8502 | ACC Test=0.8157 | F1 macro CV=0.7400 | F1 macro Test=0.7527 | ROC AUC OVR macro CV=0.9466 | ROC AUC OVR macro Test=0.9430 | AUCPR macro CV=0.8449 | AUCPR macro Test=0.8412
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.7393 | ACC Train=0.7548 | ACC Test=0.7261 | F1 macro CV=0.6665 | F1 macro Test=0.6600 | ROC AUC OVR macro CV=0.9155 | ROC AUC OVR macro Test=0.9094 | AUCPR macro CV=0.7564 | AUCPR macro Test=0.7440
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.6062 | ACC Train=0.6997 | ACC Test=0.6631 | F1 macro CV=0.5425 | F1 macro Test=0.6036 | ROC AUC OVR macro CV=0.9423 | ROC AUC OVR macro Test=0.9387 | AUCPR macro CV=0.8352 | AUCPR macro Test=0.8357
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.8072 | ACC Train=0.8707 | ACC Test=0.7934 | F1 macro CV=0.7326 | F1 macro Test=0.7227 | ROC AUC OVR macro CV=0.9194 | ROC AUC OVR macro Test=0.9124 | AUCPR macro CV=0.7985 | AUCPR macro Test=0.7890
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.7153 | ACC Train=0.8424 | ACC Test=0.7111 | F1 macro CV=0.6678 | F1 macro Test=0.6606 | ROC AUC OVR macro CV=0.9300 | ROC AUC OVR macro Test=0.9210 | AUCPR macro CV=0.8163 | AUCPR macro Test=0.8008
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.7994 | ACC Train=0.8373 | ACC Test=0.7997 | F1 macro CV=0.7368 | F1 macro Test=0.7380 | ROC AUC OVR macro CV=0.8865 | ROC AUC OVR macro Test=0.8877 | AUCPR macro CV=0.6985 | AUCPR macro Test=0.7050
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.7236 | ACC Train=0.7965 | ACC Test=0.7530 | F1 macro CV=0.6578 | F1 macro Test=0.6964 | ROC AUC OVR macro CV=0.9158 | ROC AUC OVR macro Test=0.9175 | AUCPR macro CV=0.7939 | AUCPR macro Test=0.7909
# 	Evaluating with SMOTE sampler config: {2: 100}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.5100 | ACC Train=0.5666 | ACC Test=0.5174 | F1 macro CV=0.4622 | F1 macro Test=0.4685 | ROC AUC OVR macro CV=0.7516 | ROC AUC OVR macro Test=0.7470 | AUCPR macro CV=0.5387 | AUCPR macro Test=0.5391
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.6126 | ACC Train=0.6853 | ACC Test=0.6533 | F1 macro CV=0.5422 | F1 macro Test=0.5904 | ROC AUC OVR macro CV=0.9247 | ROC AUC OVR macro Test=0.9241 | AUCPR macro CV=0.8271 | AUCPR macro Test=0.8341
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.4815 | ACC Train=0.5371 | ACC Test=0.4969 | F1 macro CV=0.3867 | F1 macro Test=0.4112 | ROC AUC OVR macro CV=0.8745 | ROC AUC OVR macro Test=0.8944 | AUCPR macro CV=0.7849 | AUCPR macro Test=0.8118
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.8306 | ACC Train=0.8669 | ACC Test=0.8279 | F1 macro CV=0.7632 | F1 macro Test=0.7629 | ROC AUC OVR macro CV=0.9471 | ROC AUC OVR macro Test=0.9416 | AUCPR macro CV=0.8447 | AUCPR macro Test=0.8479
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.7658 | ACC Train=0.7915 | ACC Test=0.7561 | F1 macro CV=0.6943 | F1 macro Test=0.6848 | ROC AUC OVR macro CV=0.9169 | ROC AUC OVR macro Test=0.9080 | AUCPR macro CV=0.7678 | AUCPR macro Test=0.7534
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.5825 | ACC Train=0.6793 | ACC Test=0.6411 | F1 macro CV=0.5176 | F1 macro Test=0.5829 | ROC AUC OVR macro CV=0.9411 | ROC AUC OVR macro Test=0.9368 | AUCPR macro CV=0.8303 | AUCPR macro Test=0.8252
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.8068 | ACC Train=0.8713 | ACC Test=0.7909 | F1 macro CV=0.7325 | F1 macro Test=0.7205 | ROC AUC OVR macro CV=0.9195 | ROC AUC OVR macro Test=0.9113 | AUCPR macro CV=0.8000 | AUCPR macro Test=0.7862
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.6875 | ACC Train=0.8104 | ACC Test=0.6854 | F1 macro CV=0.6424 | F1 macro Test=0.6404 | ROC AUC OVR macro CV=0.9364 | ROC AUC OVR macro Test=0.9270 | AUCPR macro CV=0.8233 | AUCPR macro Test=0.8118
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.8031 | ACC Train=0.8420 | ACC Test=0.8056 | F1 macro CV=0.7425 | F1 macro Test=0.7487 | ROC AUC OVR macro CV=0.8868 | ROC AUC OVR macro Test=0.8880 | AUCPR macro CV=0.7032 | AUCPR macro Test=0.7108
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.7262 | ACC Train=0.8231 | ACC Test=0.7679 | F1 macro CV=0.6625 | F1 macro Test=0.7078 | ROC AUC OVR macro CV=0.9135 | ROC AUC OVR macro Test=0.9199 | AUCPR macro CV=0.7914 | AUCPR macro Test=0.8010
# 	Pipeline weight config: w_c2_20
# 	Evaluating multiclass classification for HY3_v2
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=None | ACC CV=0.3187 | ACC Train=0.3496 | ACC Test=0.3477 | F1 macro CV=0.2637 | F1 macro Test=0.3128 | ROC AUC OVR macro CV=0.6818 | ROC AUC OVR macro Test=0.7106 | AUCPR macro CV=0.4703 | AUCPR macro Test=0.5054
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=None | ACC CV=0.4682 | ACC Train=0.4689 | ACC Test=0.4669 | F1 macro CV=0.3782 | F1 macro Test=0.3808 | ROC AUC OVR macro CV=0.7337 | ROC AUC OVR macro Test=0.8262 | AUCPR macro CV=0.6627 | AUCPR macro Test=0.7432
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=None | ACC CV=0.3917 | ACC Train=0.4383 | ACC Test=0.4362 | F1 macro CV=0.3423 | F1 macro Test=0.3665 | ROC AUC OVR macro CV=0.7071 | ROC AUC OVR macro Test=0.7470 | AUCPR macro CV=0.6461 | AUCPR macro Test=0.6839
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=None | ACC CV=0.7486 | ACC Train=0.7913 | ACC Test=0.7700 | F1 macro CV=0.6787 | F1 macro Test=0.7015 | ROC AUC OVR macro CV=0.9307 | ROC AUC OVR macro Test=0.9330 | AUCPR macro CV=0.8087 | AUCPR macro Test=0.8305
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=None | ACC CV=0.7306 | ACC Train=0.7414 | ACC Test=0.7223 | F1 macro CV=0.6586 | F1 macro Test=0.6531 | ROC AUC OVR macro CV=0.9079 | ROC AUC OVR macro Test=0.9004 | AUCPR macro CV=0.7399 | AUCPR macro Test=0.7178
# Evaluating model: svm_reg
# svm_reg | Sampler=None | ACC CV=0.4619 | ACC Train=0.4836 | ACC Test=0.4801 | F1 macro CV=0.3725 | F1 macro Test=0.3948 | ROC AUC OVR macro CV=0.9326 | ROC AUC OVR macro Test=0.9312 | AUCPR macro CV=0.8263 | AUCPR macro Test=0.8288
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=None | ACC CV=0.7640 | ACC Train=0.8090 | ACC Test=0.7530 | F1 macro CV=0.6944 | F1 macro Test=0.6882 | ROC AUC OVR macro CV=0.9129 | ROC AUC OVR macro Test=0.9017 | AUCPR macro CV=0.7958 | AUCPR macro Test=0.7729
# Evaluating model: knn_reg
# knn_reg | Sampler=None | ACC CV=0.6681 | ACC Train=0.7656 | ACC Test=0.6847 | F1 macro CV=0.6287 | F1 macro Test=0.6437 | ROC AUC OVR macro CV=0.9281 | ROC AUC OVR macro Test=0.9176 | AUCPR macro CV=0.8143 | AUCPR macro Test=0.7994
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=None | ACC CV=0.7203 | ACC Train=0.7855 | ACC Test=0.7564 | F1 macro CV=0.6654 | F1 macro Test=0.6989 | ROC AUC OVR macro CV=0.8311 | ROC AUC OVR macro Test=0.8578 | AUCPR macro CV=0.6170 | AUCPR macro Test=0.6543
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=None | ACC CV=0.6113 | ACC Train=0.6707 | ACC Test=0.6537 | F1 macro CV=0.5414 | F1 macro Test=0.5871 | ROC AUC OVR macro CV=0.8545 | ROC AUC OVR macro Test=0.9016 | AUCPR macro CV=0.7165 | AUCPR macro Test=0.7632
# 	Evaluating with ROS sampler config: {2: 60}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.3509 | ACC Train=0.4109 | ACC Test=0.3916 | F1 macro CV=0.3054 | F1 macro Test=0.3539 | ROC AUC OVR macro CV=0.6695 | ROC AUC OVR macro Test=0.7145 | AUCPR macro CV=0.4647 | AUCPR macro Test=0.4999
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.4716 | ACC Train=0.4835 | ACC Test=0.4742 | F1 macro CV=0.3799 | F1 macro Test=0.3884 | ROC AUC OVR macro CV=0.7824 | ROC AUC OVR macro Test=0.8576 | AUCPR macro CV=0.7053 | AUCPR macro Test=0.7671
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.4335 | ACC Train=0.4642 | ACC Test=0.4509 | F1 macro CV=0.3651 | F1 macro Test=0.3737 | ROC AUC OVR macro CV=0.7208 | ROC AUC OVR macro Test=0.7878 | AUCPR macro CV=0.6588 | AUCPR macro Test=0.7110
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.7726 | ACC Train=0.8099 | ACC Test=0.7889 | F1 macro CV=0.7025 | F1 macro Test=0.7203 | ROC AUC OVR macro CV=0.9382 | ROC AUC OVR macro Test=0.9369 | AUCPR macro CV=0.8301 | AUCPR macro Test=0.8397
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.7417 | ACC Train=0.7486 | ACC Test=0.7289 | F1 macro CV=0.6705 | F1 macro Test=0.6619 | ROC AUC OVR macro CV=0.9095 | ROC AUC OVR macro Test=0.9089 | AUCPR macro CV=0.7457 | AUCPR macro Test=0.7364
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.4740 | ACC Train=0.5272 | ACC Test=0.5167 | F1 macro CV=0.3861 | F1 macro Test=0.4421 | ROC AUC OVR macro CV=0.9367 | ROC AUC OVR macro Test=0.9339 | AUCPR macro CV=0.8300 | AUCPR macro Test=0.8331
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.7816 | ACC Train=0.8277 | ACC Test=0.7683 | F1 macro CV=0.7113 | F1 macro Test=0.7042 | ROC AUC OVR macro CV=0.9159 | ROC AUC OVR macro Test=0.9058 | AUCPR macro CV=0.7985 | AUCPR macro Test=0.7783
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.6801 | ACC Train=0.7854 | ACC Test=0.6885 | F1 macro CV=0.6412 | F1 macro Test=0.6463 | ROC AUC OVR macro CV=0.9267 | ROC AUC OVR macro Test=0.9205 | AUCPR macro CV=0.8131 | AUCPR macro Test=0.8010
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.7510 | ACC Train=0.8063 | ACC Test=0.7707 | F1 macro CV=0.6926 | F1 macro Test=0.7125 | ROC AUC OVR macro CV=0.8508 | ROC AUC OVR macro Test=0.8668 | AUCPR macro CV=0.6452 | AUCPR macro Test=0.6704
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.6634 | ACC Train=0.7043 | ACC Test=0.6833 | F1 macro CV=0.5967 | F1 macro Test=0.6242 | ROC AUC OVR macro CV=0.8860 | ROC AUC OVR macro Test=0.8899 | AUCPR macro CV=0.7550 | AUCPR macro Test=0.7489
# 	Evaluating with SMOTE sampler config: {2: 60}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.3612 | ACC Train=0.4171 | ACC Test=0.4003 | F1 macro CV=0.3131 | F1 macro Test=0.3685 | ROC AUC OVR macro CV=0.6752 | ROC AUC OVR macro Test=0.7293 | AUCPR macro CV=0.4719 | AUCPR macro Test=0.5144
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.4765 | ACC Train=0.4863 | ACC Test=0.4746 | F1 macro CV=0.3822 | F1 macro Test=0.3886 | ROC AUC OVR macro CV=0.7962 | ROC AUC OVR macro Test=0.8614 | AUCPR macro CV=0.7184 | AUCPR macro Test=0.7726
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.4362 | ACC Train=0.4626 | ACC Test=0.4477 | F1 macro CV=0.3665 | F1 macro Test=0.3719 | ROC AUC OVR macro CV=0.7235 | ROC AUC OVR macro Test=0.7838 | AUCPR macro CV=0.6615 | AUCPR macro Test=0.7074
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.7780 | ACC Train=0.8149 | ACC Test=0.7892 | F1 macro CV=0.7089 | F1 macro Test=0.7198 | ROC AUC OVR macro CV=0.9387 | ROC AUC OVR macro Test=0.9362 | AUCPR macro CV=0.8317 | AUCPR macro Test=0.8382
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.7475 | ACC Train=0.7642 | ACC Test=0.7422 | F1 macro CV=0.6764 | F1 macro Test=0.6723 | ROC AUC OVR macro CV=0.9107 | ROC AUC OVR macro Test=0.9092 | AUCPR macro CV=0.7561 | AUCPR macro Test=0.7424
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.4717 | ACC Train=0.5250 | ACC Test=0.5132 | F1 macro CV=0.3840 | F1 macro Test=0.4386 | ROC AUC OVR macro CV=0.9359 | ROC AUC OVR macro Test=0.9331 | AUCPR macro CV=0.8273 | AUCPR macro Test=0.8289
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.7812 | ACC Train=0.8296 | ACC Test=0.7655 | F1 macro CV=0.7106 | F1 macro Test=0.7003 | ROC AUC OVR macro CV=0.9162 | ROC AUC OVR macro Test=0.9049 | AUCPR macro CV=0.8004 | AUCPR macro Test=0.7760
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.6765 | ACC Train=0.7750 | ACC Test=0.6833 | F1 macro CV=0.6415 | F1 macro Test=0.6450 | ROC AUC OVR macro CV=0.9298 | ROC AUC OVR macro Test=0.9220 | AUCPR macro CV=0.8170 | AUCPR macro Test=0.8044
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.7515 | ACC Train=0.8049 | ACC Test=0.7697 | F1 macro CV=0.6930 | F1 macro Test=0.7103 | ROC AUC OVR macro CV=0.8508 | ROC AUC OVR macro Test=0.8670 | AUCPR macro CV=0.6460 | AUCPR macro Test=0.6713
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.6636 | ACC Train=0.7144 | ACC Test=0.6937 | F1 macro CV=0.5974 | F1 macro Test=0.6358 | ROC AUC OVR macro CV=0.8829 | ROC AUC OVR macro Test=0.9038 | AUCPR macro CV=0.7518 | AUCPR macro Test=0.7657
# 	Evaluating with ROS sampler config: {2: 80}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.4110 | ACC Train=0.4874 | ACC Test=0.4547 | F1 macro CV=0.3600 | F1 macro Test=0.4197 | ROC AUC OVR macro CV=0.6919 | ROC AUC OVR macro Test=0.6844 | AUCPR macro CV=0.4907 | AUCPR macro Test=0.4826
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.4879 | ACC Train=0.5210 | ACC Test=0.4948 | F1 macro CV=0.3973 | F1 macro Test=0.4120 | ROC AUC OVR macro CV=0.8489 | ROC AUC OVR macro Test=0.8777 | AUCPR macro CV=0.7589 | AUCPR macro Test=0.7886
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.4551 | ACC Train=0.4860 | ACC Test=0.4578 | F1 macro CV=0.3749 | F1 macro Test=0.3755 | ROC AUC OVR macro CV=0.7691 | ROC AUC OVR macro Test=0.8273 | AUCPR macro CV=0.6952 | AUCPR macro Test=0.7499
# ...
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.0852 | ACC Train=0.2854 | ACC Test=0.2767 | F1 macro CV=0.0591 | F1 macro Test=0.2624 | ROC AUC OVR macro CV=0.7033 | ROC AUC OVR macro Test=0.7215 | AUCPR macro CV=0.6211 | AUCPR macro Test=0.6567
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.7478 | ACC Train=0.7850 | ACC Test=0.7704 | F1 macro CV=0.6752 | F1 macro Test=0.7066 | ROC AUC OVR macro CV=0.9252 | ROC AUC OVR macro Test=0.9337 | AUCPR macro CV=0.7987 | AUCPR macro Test=0.8217
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.7339 | ACC Train=0.7398 | ACC Test=0.7282 | F1 macro CV=0.6610 | F1 macro Test=0.6601 | ROC AUC OVR macro CV=0.8978 | ROC AUC OVR macro Test=0.9021 | AUCPR macro CV=0.7336 | AUCPR macro Test=0.7502
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.4494 | ACC Train=0.4652 | ACC Test=0.4502 | F1 macro CV=0.3651 | F1 macro Test=0.3643 | ROC AUC OVR macro CV=0.9108 | ROC AUC OVR macro Test=0.9152 | AUCPR macro CV=0.7823 | AUCPR macro Test=0.8030
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.7099 | ACC Train=0.7766 | ACC Test=0.7080 | F1 macro CV=0.6380 | F1 macro Test=0.6430 | ROC AUC OVR macro CV=0.8759 | ROC AUC OVR macro Test=0.8782 | AUCPR macro CV=0.7410 | AUCPR macro Test=0.7651
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.4377 | ACC Train=0.6029 | ACC Test=0.4383 | F1 macro CV=0.2458 | F1 macro Test=0.2671 | ROC AUC OVR macro CV=0.8165 | ROC AUC OVR macro Test=0.7900 | AUCPR macro CV=0.6595 | AUCPR macro Test=0.6392
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.7203 | ACC Train=0.7873 | ACC Test=0.7568 | F1 macro CV=0.6606 | F1 macro Test=0.6960 | ROC AUC OVR macro CV=0.8339 | ROC AUC OVR macro Test=0.8729 | AUCPR macro CV=0.6167 | AUCPR macro Test=0.6663
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.5997 | ACC Train=0.6589 | ACC Test=0.6049 | F1 macro CV=0.5101 | F1 macro Test=0.5262 | ROC AUC OVR macro CV=0.7426 | ROC AUC OVR macro Test=0.7692 | AUCPR macro CV=0.5726 | AUCPR macro Test=0.5931
# 	Evaluating with SMOTE sampler config: {2: 60}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.4386 | ACC Train=0.4242 | ACC Test=0.4073 | F1 macro CV=0.3493 | F1 macro Test=0.3312 | ROC AUC OVR macro CV=0.6352 | ROC AUC OVR macro Test=0.6359 | AUCPR macro CV=0.4405 | AUCPR macro Test=0.4357
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.4064 | ACC Train=0.4551 | ACC Test=0.4352 | F1 macro CV=0.3495 | F1 macro Test=0.3629 | ROC AUC OVR macro CV=0.7178 | ROC AUC OVR macro Test=0.7657 | AUCPR macro CV=0.6296 | AUCPR macro Test=0.7037
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.0843 | ACC Train=0.2959 | ACC Test=0.2902 | F1 macro CV=0.0583 | F1 macro Test=0.2744 | ROC AUC OVR macro CV=0.7025 | ROC AUC OVR macro Test=0.7226 | AUCPR macro CV=0.6179 | AUCPR macro Test=0.6545
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.7487 | ACC Train=0.7966 | ACC Test=0.7732 | F1 macro CV=0.6769 | F1 macro Test=0.7081 | ROC AUC OVR macro CV=0.9257 | ROC AUC OVR macro Test=0.9342 | AUCPR macro CV=0.7981 | AUCPR macro Test=0.8265
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.7336 | ACC Train=0.7398 | ACC Test=0.7247 | F1 macro CV=0.6601 | F1 macro Test=0.6547 | ROC AUC OVR macro CV=0.8980 | ROC AUC OVR macro Test=0.9041 | AUCPR macro CV=0.7330 | AUCPR macro Test=0.7512
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.4465 | ACC Train=0.4619 | ACC Test=0.4474 | F1 macro CV=0.3644 | F1 macro Test=0.3637 | ROC AUC OVR macro CV=0.9113 | ROC AUC OVR macro Test=0.9164 | AUCPR macro CV=0.7836 | AUCPR macro Test=0.8151
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.7091 | ACC Train=0.7748 | ACC Test=0.7045 | F1 macro CV=0.6370 | F1 macro Test=0.6395 | ROC AUC OVR macro CV=0.8755 | ROC AUC OVR macro Test=0.8768 | AUCPR macro CV=0.7411 | AUCPR macro Test=0.7626
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.4409 | ACC Train=0.6021 | ACC Test=0.4474 | F1 macro CV=0.2742 | F1 macro Test=0.3225 | ROC AUC OVR macro CV=0.8377 | ROC AUC OVR macro Test=0.8163 | AUCPR macro CV=0.6813 | AUCPR macro Test=0.6737
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.7185 | ACC Train=0.7842 | ACC Test=0.7537 | F1 macro CV=0.6593 | F1 macro Test=0.6921 | ROC AUC OVR macro CV=0.8334 | ROC AUC OVR macro Test=0.8729 | AUCPR macro CV=0.6161 | AUCPR macro Test=0.6663
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.5967 | ACC Train=0.6816 | ACC Test=0.6192 | F1 macro CV=0.5104 | F1 macro Test=0.5386 | ROC AUC OVR macro CV=0.7488 | ROC AUC OVR macro Test=0.7970 | AUCPR macro CV=0.5802 | AUCPR macro Test=0.6253
# 	Evaluating with ROS sampler config: {2: 80}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.4371 | ACC Train=0.4485 | ACC Test=0.4157 | F1 macro CV=0.3484 | F1 macro Test=0.3379 | ROC AUC OVR macro CV=0.6325 | ROC AUC OVR macro Test=0.6315 | AUCPR macro CV=0.4400 | AUCPR macro Test=0.4381
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.4421 | ACC Train=0.4817 | ACC Test=0.4498 | F1 macro CV=0.3665 | F1 macro Test=0.3692 | ROC AUC OVR macro CV=0.7494 | ROC AUC OVR macro Test=0.7949 | AUCPR macro CV=0.6621 | AUCPR macro Test=0.7308
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.2822 | ACC Train=0.4144 | ACC Test=0.3798 | F1 macro CV=0.2651 | F1 macro Test=0.3371 | ROC AUC OVR macro CV=0.7146 | ROC AUC OVR macro Test=0.7342 | AUCPR macro CV=0.6305 | AUCPR macro Test=0.6727
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.7716 | ACC Train=0.8152 | ACC Test=0.7878 | F1 macro CV=0.6973 | F1 macro Test=0.7211 | ROC AUC OVR macro CV=0.9308 | ROC AUC OVR macro Test=0.9380 | AUCPR macro CV=0.8053 | AUCPR macro Test=0.8327
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.7193 | ACC Train=0.7385 | ACC Test=0.7199 | F1 macro CV=0.6442 | F1 macro Test=0.6508 | ROC AUC OVR macro CV=0.8954 | ROC AUC OVR macro Test=0.9041 | AUCPR macro CV=0.7191 | AUCPR macro Test=0.7537
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.4575 | ACC Train=0.4974 | ACC Test=0.4683 | F1 macro CV=0.3679 | F1 macro Test=0.3815 | ROC AUC OVR macro CV=0.9182 | ROC AUC OVR macro Test=0.9191 | AUCPR macro CV=0.7884 | AUCPR macro Test=0.8064
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.7370 | ACC Train=0.8142 | ACC Test=0.7240 | F1 macro CV=0.6628 | F1 macro Test=0.6586 | ROC AUC OVR macro CV=0.8819 | ROC AUC OVR macro Test=0.8771 | AUCPR macro CV=0.7399 | AUCPR macro Test=0.7522
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.4413 | ACC Train=0.6443 | ACC Test=0.4439 | F1 macro CV=0.2618 | F1 macro Test=0.2871 | ROC AUC OVR macro CV=0.7940 | ROC AUC OVR macro Test=0.7712 | AUCPR macro CV=0.6354 | AUCPR macro Test=0.6168
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.7614 | ACC Train=0.8152 | ACC Test=0.7770 | F1 macro CV=0.6970 | F1 macro Test=0.7141 | ROC AUC OVR macro CV=0.8696 | ROC AUC OVR macro Test=0.8906 | AUCPR macro CV=0.6643 | AUCPR macro Test=0.6920
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.6420 | ACC Train=0.7446 | ACC Test=0.6732 | F1 macro CV=0.5584 | F1 macro Test=0.6058 | ROC AUC OVR macro CV=0.7993 | ROC AUC OVR macro Test=0.8356 | AUCPR macro CV=0.6274 | AUCPR macro Test=0.6759
# 	Evaluating with SMOTE sampler config: {2: 80}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.4387 | ACC Train=0.4526 | ACC Test=0.4185 | F1 macro CV=0.3493 | F1 macro Test=0.3432 | ROC AUC OVR macro CV=0.6364 | ROC AUC OVR macro Test=0.6455 | AUCPR macro CV=0.4420 | AUCPR macro Test=0.4478
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.4568 | ACC Train=0.4884 | ACC Test=0.4596 | F1 macro CV=0.3730 | F1 macro Test=0.3743 | ROC AUC OVR macro CV=0.7702 | ROC AUC OVR macro Test=0.8177 | AUCPR macro CV=0.6800 | AUCPR macro Test=0.7484
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.3015 | ACC Train=0.4223 | ACC Test=0.3892 | F1 macro CV=0.2802 | F1 macro Test=0.3424 | ROC AUC OVR macro CV=0.7121 | ROC AUC OVR macro Test=0.7372 | AUCPR macro CV=0.6312 | AUCPR macro Test=0.6747
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.7963 | ACC Train=0.8379 | ACC Test=0.8038 | F1 macro CV=0.7239 | F1 macro Test=0.7371 | ROC AUC OVR macro CV=0.9338 | ROC AUC OVR macro Test=0.9403 | AUCPR macro CV=0.8151 | AUCPR macro Test=0.8442
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.7542 | ACC Train=0.7575 | ACC Test=0.7387 | F1 macro CV=0.6799 | F1 macro Test=0.6704 | ROC AUC OVR macro CV=0.9000 | ROC AUC OVR macro Test=0.9055 | AUCPR macro CV=0.7398 | AUCPR macro Test=0.7574
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.4529 | ACC Train=0.4867 | ACC Test=0.4540 | F1 macro CV=0.3668 | F1 macro Test=0.3673 | ROC AUC OVR macro CV=0.9180 | ROC AUC OVR macro Test=0.9206 | AUCPR macro CV=0.7920 | AUCPR macro Test=0.8232
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.7343 | ACC Train=0.8110 | ACC Test=0.7206 | F1 macro CV=0.6598 | F1 macro Test=0.6535 | ROC AUC OVR macro CV=0.8808 | ROC AUC OVR macro Test=0.8743 | AUCPR macro CV=0.7407 | AUCPR macro Test=0.7496
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.4512 | ACC Train=0.6406 | ACC Test=0.4571 | F1 macro CV=0.3325 | F1 macro Test=0.3701 | ROC AUC OVR macro CV=0.8292 | ROC AUC OVR macro Test=0.8112 | AUCPR macro CV=0.6741 | AUCPR macro Test=0.6756
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.7637 | ACC Train=0.8133 | ACC Test=0.7760 | F1 macro CV=0.6996 | F1 macro Test=0.7117 | ROC AUC OVR macro CV=0.8687 | ROC AUC OVR macro Test=0.8909 | AUCPR macro CV=0.6649 | AUCPR macro Test=0.6963
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.6359 | ACC Train=0.7554 | ACC Test=0.6669 | F1 macro CV=0.5514 | F1 macro Test=0.6005 | ROC AUC OVR macro CV=0.7930 | ROC AUC OVR macro Test=0.8399 | AUCPR macro CV=0.6235 | AUCPR macro Test=0.6868
# 	Evaluating with ROS sampler config: {2: 100}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.4403 | ACC Train=0.4693 | ACC Test=0.4209 | F1 macro CV=0.3511 | F1 macro Test=0.3384 | ROC AUC OVR macro CV=0.6379 | ROC AUC OVR macro Test=0.6334 | AUCPR macro CV=0.4430 | AUCPR macro Test=0.4336
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.4591 | ACC Train=0.5047 | ACC Test=0.4617 | F1 macro CV=0.3734 | F1 macro Test=0.3757 | ROC AUC OVR macro CV=0.7837 | ROC AUC OVR macro Test=0.8293 | AUCPR macro CV=0.6957 | AUCPR macro Test=0.7610
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.3866 | ACC Train=0.4631 | ACC Test=0.4129 | F1 macro CV=0.3395 | F1 macro Test=0.3548 | ROC AUC OVR macro CV=0.7241 | ROC AUC OVR macro Test=0.7553 | AUCPR macro CV=0.6406 | AUCPR macro Test=0.6981
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.7911 | ACC Train=0.8328 | ACC Test=0.8024 | F1 macro CV=0.7175 | F1 macro Test=0.7373 | ROC AUC OVR macro CV=0.9354 | ROC AUC OVR macro Test=0.9405 | AUCPR macro CV=0.8181 | AUCPR macro Test=0.8390
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.7194 | ACC Train=0.7346 | ACC Test=0.7167 | F1 macro CV=0.6457 | F1 macro Test=0.6524 | ROC AUC OVR macro CV=0.8953 | ROC AUC OVR macro Test=0.9044 | AUCPR macro CV=0.7211 | AUCPR macro Test=0.7580
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.4711 | ACC Train=0.5659 | ACC Test=0.5115 | F1 macro CV=0.3823 | F1 macro Test=0.4421 | ROC AUC OVR macro CV=0.9204 | ROC AUC OVR macro Test=0.9213 | AUCPR macro CV=0.7909 | AUCPR macro Test=0.8084
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.7479 | ACC Train=0.8396 | ACC Test=0.7300 | F1 macro CV=0.6716 | F1 macro Test=0.6587 | ROC AUC OVR macro CV=0.8852 | ROC AUC OVR macro Test=0.8785 | AUCPR macro CV=0.7428 | AUCPR macro Test=0.7510
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.4447 | ACC Train=0.6828 | ACC Test=0.4495 | F1 macro CV=0.2731 | F1 macro Test=0.3163 | ROC AUC OVR macro CV=0.7826 | ROC AUC OVR macro Test=0.7676 | AUCPR macro CV=0.6203 | AUCPR macro Test=0.6121
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.7881 | ACC Train=0.8235 | ACC Test=0.7836 | F1 macro CV=0.7199 | F1 macro Test=0.7192 | ROC AUC OVR macro CV=0.8921 | ROC AUC OVR macro Test=0.9000 | AUCPR macro CV=0.6982 | AUCPR macro Test=0.7087
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.6508 | ACC Train=0.7905 | ACC Test=0.7007 | F1 macro CV=0.5680 | F1 macro Test=0.6353 | ROC AUC OVR macro CV=0.8211 | ROC AUC OVR macro Test=0.8702 | AUCPR macro CV=0.6512 | AUCPR macro Test=0.7326
# 	Evaluating with SMOTE sampler config: {2: 100}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.4407 | ACC Train=0.4772 | ACC Test=0.4314 | F1 macro CV=0.3523 | F1 macro Test=0.3468 | ROC AUC OVR macro CV=0.6430 | ROC AUC OVR macro Test=0.6392 | AUCPR macro CV=0.4475 | AUCPR macro Test=0.4426
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.4735 | ACC Train=0.5171 | ACC Test=0.4756 | F1 macro CV=0.3789 | F1 macro Test=0.3847 | ROC AUC OVR macro CV=0.8228 | ROC AUC OVR macro Test=0.8614 | AUCPR macro CV=0.7277 | AUCPR macro Test=0.7808
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.3969 | ACC Train=0.4680 | ACC Test=0.4199 | F1 macro CV=0.3455 | F1 macro Test=0.3585 | ROC AUC OVR macro CV=0.7261 | ROC AUC OVR macro Test=0.7549 | AUCPR macro CV=0.6400 | AUCPR macro Test=0.6977
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.8143 | ACC Train=0.8545 | ACC Test=0.8199 | F1 macro CV=0.7419 | F1 macro Test=0.7563 | ROC AUC OVR macro CV=0.9381 | ROC AUC OVR macro Test=0.9430 | AUCPR macro CV=0.8264 | AUCPR macro Test=0.8487
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.7545 | ACC Train=0.7885 | ACC Test=0.7672 | F1 macro CV=0.6781 | F1 macro Test=0.6998 | ROC AUC OVR macro CV=0.8995 | ROC AUC OVR macro Test=0.9095 | AUCPR macro CV=0.7439 | AUCPR macro Test=0.7719
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.4576 | ACC Train=0.5174 | ACC Test=0.4659 | F1 macro CV=0.3698 | F1 macro Test=0.3830 | ROC AUC OVR macro CV=0.9188 | ROC AUC OVR macro Test=0.9216 | AUCPR macro CV=0.7904 | AUCPR macro Test=0.8244
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.7471 | ACC Train=0.8391 | ACC Test=0.7275 | F1 macro CV=0.6711 | F1 macro Test=0.6570 | ROC AUC OVR macro CV=0.8837 | ROC AUC OVR macro Test=0.8751 | AUCPR macro CV=0.7427 | AUCPR macro Test=0.7485
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.4584 | ACC Train=0.6789 | ACC Test=0.4641 | F1 macro CV=0.3593 | F1 macro Test=0.3863 | ROC AUC OVR macro CV=0.8240 | ROC AUC OVR macro Test=0.8124 | AUCPR macro CV=0.6731 | AUCPR macro Test=0.6775
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.7902 | ACC Train=0.8225 | ACC Test=0.7843 | F1 macro CV=0.7203 | F1 macro Test=0.7189 | ROC AUC OVR macro CV=0.8909 | ROC AUC OVR macro Test=0.8996 | AUCPR macro CV=0.7004 | AUCPR macro Test=0.7131
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.6560 | ACC Train=0.7793 | ACC Test=0.6801 | F1 macro CV=0.5757 | F1 macro Test=0.6104 | ROC AUC OVR macro CV=0.8256 | ROC AUC OVR macro Test=0.8598 | AUCPR macro CV=0.6606 | AUCPR macro Test=0.7154
