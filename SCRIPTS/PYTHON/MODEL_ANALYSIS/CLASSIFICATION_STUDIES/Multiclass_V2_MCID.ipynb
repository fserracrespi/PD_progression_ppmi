# %%
import pandas as pd
import json
import numpy as np
from pathlib import Path

current_dir = Path.cwd()
project_root = current_dir.parents[3]

import matplotlib.pyplot as plt


y_MCID_v2 = pd.read_csv(project_root / "SCRIPTS/PYTHON/MODEL_ANALYSIS/DATA/V2_version/y_MCID_v2_final.csv", index_col=0)
print("y_MCID shape:", y_MCID_v2.shape)



datasets = {
    "y_MCID": y_MCID_v2,
}

fig, ax = plt.subplots(figsize=(6, 5))

df = y_MCID_v2

counts = df.iloc[:,0].value_counts().sort_index()
percentages = counts / counts.sum() * 100

bars = ax.bar(counts.index.astype(str), counts.values)

# añadir texto con conteo y porcentaje
for i, (count, pct) in enumerate(zip(counts.values, percentages.values)):
    ax.text(i, count, f"{count} ({pct:.1f}%)", 
            ha='center', va='bottom')

ax.set_title("y_MCID")
ax.set_xlabel("Class")
ax.set_ylabel("Count")

plt.suptitle("Ordinal Class Distribution")
plt.tight_layout()
plt.show()
# Out:
# y_MCID shape: (956, 1)

# %% [markdown]
# # FILES

# %%
import os
import re

with open(project_root/"SCRIPTS/PYTHON/MODEL_ANALYSIS/DATA/Domain_data.json", "r") as archivo:
    full_domain = json.load(archivo)

with open(project_root/"SCRIPTS/PYTHON/MODEL_ANALYSIS/DATA/UPDRS_Domain_data.json", "r") as archivo:
    updrs_domain = json.load(archivo)

X_multiples_MCID= {'X_STATS_V2':project_root/'SCRIPTS/PYTHON/MODEL_ANALYSIS/DATA/V2_version/X_stats_v2_final_HY3.csv',
                'X_VX_STATS_V2': project_root/'SCRIPTS/PYTHON/MODEL_ANALYSIS/DATA/V2_version/X_vx_stats_v2_final_HY3.csv',
                'X_VX_DELTA_V2': project_root/'SCRIPTS/PYTHON/MODEL_ANALYSIS/DATA/V2_version/X_vx_delta_v2_final_HY3.csv',
                }
y_multiples_MCID = {'MCID_v2': project_root / "SCRIPTS/PYTHON/MODEL_ANALYSIS/DATA/V2_version/y_MCID_v2_final.csv"}

pairs_init_MCID=[('X_STATS_V2', 'MCID_v2'),
        ('X_VX_STATS_V2', 'MCID_v2'),
        ('X_VX_DELTA_V2', 'MCID_v2')]


output_path= project_root / "SCRIPTS/PYTHON/MODEL_ANALYSIS/Performance_Results/Multiclass/V2_analysis/"

# %% [markdown]
# # MODELS BASELINE

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from imblearn.pipeline import Pipeline


# 🔹 pesos a probar
weight_configs_MCID = {
    "balanced": "balanced",
    "w_c2_10": {0: 10, 1: 1, 2: 10},
    "w_c2_20": {0: 20, 1: 1, 2: 20},
}

def build_models(class_weight):
    return {
        "decision_tree": Pipeline([
            ("model", DecisionTreeClassifier(
                random_state=42,
                class_weight=class_weight
            ))
        ]),

        "random_forest": Pipeline([
            ("model", RandomForestClassifier(
                random_state=42,
                n_jobs=-1,
                class_weight=class_weight
            ))
        ]),

        "extra_trees": Pipeline([
            ("model", ExtraTreesClassifier(
                random_state=42,
                n_jobs=-1,
                class_weight=class_weight
            ))
        ]),

        "xgboost": Pipeline([
            ("model", XGBClassifier(
                tree_method="hist",
                device="cuda",
                eval_metric="logloss",
                n_jobs=-1,
                random_state=42))
        ]),

        "adaboost": Pipeline([
            ("model", AdaBoostClassifier(
                algorithm="SAMME",
                random_state=42
            ))
        ]),

        "svm": Pipeline([
            ("model", SVC(
                kernel="rbf",
                probability=True,
                random_state=42,
                class_weight=class_weight
            ))
        ]),

        "logistic_regression": Pipeline([
            ("model", LogisticRegression(
                random_state=42,
                n_jobs=-1,
                max_iter=10000,
                class_weight=class_weight
            ))
        ]),

        "knn": Pipeline([
            ("model", KNeighborsClassifier(n_jobs=-1))
        ]),

        "gaussian_nb": Pipeline([
            ("model", GaussianNB())
        ]),

        "mlp3216": Pipeline([
            ("model", MLPClassifier(
                hidden_layer_sizes=(32, 16),
                activation='relu',
                solver='adam',
                alpha=0.0001,
                learning_rate='adaptive',
                max_iter=1000,
                random_state=42
            ))
        ])
    }


# ESTRUCTURA FINAL: un dict por weight
classification_models_by_weight_MCID = {
    w_name: build_models(w_value)
    for w_name, w_value in weight_configs_MCID.items()
}

# %%
def build_models_reg(class_weight):

    return {
        "decision_tree_reg": Pipeline([
            ("model", DecisionTreeClassifier(
                random_state=42,
                class_weight=class_weight,
                max_depth=3,
                min_samples_split=40,
                min_samples_leaf=15,
                max_features="sqrt",
                ccp_alpha=0.005
            ))
        ]),

        "random_forest_reg": Pipeline([
            ("model", RandomForestClassifier(
                random_state=42,
                n_jobs=-1,
                class_weight=class_weight,
                n_estimators=160,
                max_depth=4,
                min_samples_split=30,
                min_samples_leaf=12,
                max_features="sqrt",
                max_samples=0.80,
                bootstrap=True
            ))
        ]),

        "extra_trees_reg": Pipeline([
            ("model", ExtraTreesClassifier(
                random_state=42,
                n_jobs=-1,
                class_weight=class_weight,
                n_estimators=160,
                max_depth=4,
                min_samples_split=30,
                min_samples_leaf=12,
                max_features="sqrt",
                max_samples=0.80,
                bootstrap=True
            ))
        ]),

        "xgboost_reg": Pipeline([
            ("model", XGBClassifier(
                tree_method="hist",
                device="cuda",
                eval_metric="logloss",
                n_jobs=-1,
                random_state=42,
                n_estimators=120,
                learning_rate=0.04,
                max_depth=4,
                min_child_weight=10,
                gamma=2.0,
                subsample=0.80,
                colsample_bytree=0.80,
                reg_alpha=4.0,
                reg_lambda=12.0
            ))
        ]),

        "adaboost_reg": Pipeline([
            ("model", AdaBoostClassifier(
                n_estimators=60,
                learning_rate=0.04,
                algorithm="SAMME",
                random_state=42
            ))
        ]),

        "svm_reg": Pipeline([
            ("scaler", StandardScaler()),
            ("model", SVC(
                kernel="rbf",
                C=0.15,
                gamma="scale",
                probability=True,
                random_state=42,
                class_weight=class_weight
            ))
        ]),

        "logistic_regression_reg": Pipeline([
            ("scaler", StandardScaler()),
            ("model", LogisticRegression(
                random_state=42,
                max_iter=10000,
                C=0.08,
                penalty="l2",
                solver="liblinear",
                class_weight=class_weight
            ))
        ]),

        "knn_reg": Pipeline([
            ("scaler", StandardScaler()),
            ("model", KNeighborsClassifier(
                n_neighbors=25,
                weights="distance",
                p=2,
                n_jobs=-1
            ))
        ]),

        "gaussian_nb_reg": Pipeline([
            ("model", GaussianNB(
                var_smoothing=1e-6
            ))
        ]),

        "mlp3216_reg": Pipeline([
            ("scaler", StandardScaler()),
            ("model", MLPClassifier(
                hidden_layer_sizes=(10,),
                activation="relu",
                solver="adam",
                alpha=0.05,
                learning_rate="adaptive",
                early_stopping=True,
                validation_fraction=0.20,
                n_iter_no_change=20,
                max_iter=400,
                random_state=42
            ))
        ])
    }


classification_models_by_weight_reg_MCID = {
    w_name: build_models_reg(w_value)
    for w_name, w_value in weight_configs_MCID.items()
}

# %%
from imblearn.pipeline import Pipeline
from imblearn.under_sampling import RandomUnderSampler

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler

from xgboost import XGBClassifier


def build_models_reg_UNDER(class_weight):
    return {
        "decision_tree_reg": Pipeline([
            ("undersample", RandomUnderSampler(sampling_strategy="auto", random_state=42)),
            ("model", DecisionTreeClassifier(
                random_state=42,
                class_weight=class_weight,
                max_depth=3,
                min_samples_split=40,
                min_samples_leaf=15,
                max_features="sqrt",
                ccp_alpha=0.005
            ))
        ]),

        "random_forest_reg": Pipeline([
            ("undersample", RandomUnderSampler(sampling_strategy="auto", random_state=42)),
            ("model", RandomForestClassifier(
                random_state=42,
                n_jobs=-1,
                class_weight=class_weight,
                n_estimators=160,
                max_depth=4,
                min_samples_split=30,
                min_samples_leaf=12,
                max_features="sqrt",
                max_samples=0.80,
                bootstrap=True
            ))
        ]),

        "extra_trees_reg": Pipeline([
            ("undersample", RandomUnderSampler(sampling_strategy="auto", random_state=42)),
            ("model", ExtraTreesClassifier(
                random_state=42,
                n_jobs=-1,
                class_weight=class_weight,
                n_estimators=160,
                max_depth=4,
                min_samples_split=30,
                min_samples_leaf=12,
                max_features="sqrt",
                max_samples=0.80,
                bootstrap=True
            ))
        ]),

        "xgboost_reg": Pipeline([
            ("undersample", RandomUnderSampler(sampling_strategy="auto", random_state=42)),
            ("model", XGBClassifier(
                tree_method="hist",
                device="cuda",
                eval_metric="logloss",
                n_jobs=-1,
                random_state=42,
                n_estimators=120,
                learning_rate=0.04,
                max_depth=4,
                min_child_weight=10,
                gamma=2.0,
                subsample=0.80,
                colsample_bytree=0.80,
                reg_alpha=4.0,
                reg_lambda=12.0
            ))
        ]),

        "adaboost_reg": Pipeline([
            ("undersample", RandomUnderSampler(sampling_strategy="auto", random_state=42)),
            ("model", AdaBoostClassifier(
                n_estimators=60,
                learning_rate=0.04,
                algorithm="SAMME",
                random_state=42
            ))
        ]),

        "svm_reg": Pipeline([
            ("undersample", RandomUnderSampler(sampling_strategy="auto", random_state=42)),
            ("scaler", StandardScaler()),
            ("model", SVC(
                kernel="rbf",
                C=0.15,
                gamma="scale",
                probability=True,
                random_state=42,
                class_weight=class_weight
            ))
        ]),

        "logistic_regression_reg": Pipeline([
            ("undersample", RandomUnderSampler(sampling_strategy="auto", random_state=42)),
            ("scaler", StandardScaler()),
            ("model", LogisticRegression(
                random_state=42,
                max_iter=10000,
                C=0.08,
                penalty="l2",
                solver="liblinear",
                class_weight=class_weight
            ))
        ]),

        "knn_reg": Pipeline([
            ("undersample", RandomUnderSampler(sampling_strategy="auto", random_state=42)),
            ("scaler", StandardScaler()),
            ("model", KNeighborsClassifier(
                n_neighbors=25,
                weights="distance",
                p=2,
                n_jobs=-1
            ))
        ]),

        "gaussian_nb_reg": Pipeline([
            ("undersample", RandomUnderSampler(sampling_strategy="auto", random_state=42)),
            ("model", GaussianNB(
                var_smoothing=1e-6
            ))
        ]),

        "mlp3216_reg": Pipeline([
            ("undersample", RandomUnderSampler(sampling_strategy="auto", random_state=42)),
            ("scaler", StandardScaler()),
            ("model", MLPClassifier(
                hidden_layer_sizes=(10,),
                activation="relu",
                solver="adam",
                alpha=0.05,
                learning_rate="adaptive",
                early_stopping=True,
                validation_fraction=0.20,
                n_iter_no_change=20,
                max_iter=400,
                random_state=42
            ))
        ])
    }


classification_models_by_weight_reg_UNDER_MCID = {
    w_name: build_models_reg_UNDER(w_value)
    for w_name, w_value in weight_configs_MCID.items()
}

# %% [markdown]
# # MODEL PERFORMANCE FUNCTION

# %%
import numpy as np
import pandas as pd

from sklearn.base import clone
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    recall_score,
    precision_score,
    roc_auc_score,
    precision_recall_fscore_support,
    average_precision_score,
    confusion_matrix,
)
from sklearn.preprocessing import label_binarize, LabelEncoder

from imblearn.over_sampling import RandomOverSampler, SMOTE

from sdv.metadata import Metadata
from sdv.single_table import CTGANSynthesizer


def _compute_metrics_multiclass(
    y_true,
    y_pred,
    y_proba=None,
    classes=None,
    cost_matrix=None
):
    metrics = {}

    y_true = np.asarray(y_true).ravel()
    y_pred = np.asarray(y_pred).ravel()

    if classes is None:
        classes = np.unique(np.concatenate([y_true, y_pred]))
    classes = np.asarray(classes)

    n_classes = len(classes)

    metrics["accuracy"] = accuracy_score(y_true, y_pred)

    metrics["f1_macro"] = f1_score(y_true, y_pred, average="macro", zero_division=0)
    metrics["f1_weighted"] = f1_score(y_true, y_pred, average="weighted", zero_division=0)

    metrics["recall_macro"] = recall_score(y_true, y_pred, average="macro", zero_division=0)
    metrics["recall_weighted"] = recall_score(y_true, y_pred, average="weighted", zero_division=0)

    metrics["precision_macro"] = precision_score(y_true, y_pred, average="macro", zero_division=0)
    metrics["precision_weighted"] = precision_score(y_true, y_pred, average="weighted", zero_division=0)

    # =========================================================
    # COST MATRIX
    # =========================================================
    if cost_matrix is None:
        cost_matrix = np.array([
            [0, 1, 10],
            [5, 0, 1],
            [10, 3, 0]
        ], dtype=float)
    else:
        cost_matrix = np.asarray(cost_matrix, dtype=float)
        if cost_matrix.shape != (n_classes, n_classes):
            raise ValueError(
                f"cost_matrix debe tener shape {(n_classes, n_classes)} "
                f"y tiene {cost_matrix.shape}"
            )

    sample_costs = cost_matrix[y_true, y_pred]
    metrics["misclassification_cost_mean"] = sample_costs.mean()
    metrics["misclassification_cost_total"] = sample_costs.sum()
    metrics["misclassification_score"] = -sample_costs.mean()

    for cls in classes:
        mask = (y_true == cls)
        metrics[f"misclassification_cost_mean_true_class_{cls}"] = (
            sample_costs[mask].mean() if mask.sum() > 0 else np.nan
        )

    # =========================================================
    # METRICS PER CLASS
    # =========================================================
    prec, rec, f1, supp = precision_recall_fscore_support(
        y_true,
        y_pred,
        labels=classes,
        zero_division=0
    )

    for i, cls in enumerate(classes):
        metrics[f"precision_class_{cls}"] = prec[i]
        metrics[f"recall_class_{cls}"] = rec[i]
        metrics[f"f1_class_{cls}"] = f1[i]
        metrics[f"support_class_{cls}"] = supp[i]

    # =========================================================
    # CONFUSION MATRIX
    # =========================================================
    cm = confusion_matrix(y_true, y_pred, labels=classes)

    for i, cls_true in enumerate(classes):
        for j, cls_pred in enumerate(classes):
            metrics[f"cm_true_{cls_true}_pred_{cls_pred}"] = cm[i, j]

    for i, cls in enumerate(classes):
        tp = cm[i, i]
        fn = cm[i, :].sum() - tp
        fp = cm[:, i].sum() - tp
        tn = cm.sum() - tp - fn - fp

        metrics[f"tp_class_{cls}"] = tp
        metrics[f"fn_class_{cls}"] = fn
        metrics[f"fp_class_{cls}"] = fp
        metrics[f"tn_class_{cls}"] = tn

        metrics[f"specificity_class_{cls}"] = tn / (tn + fp) if (tn + fp) > 0 else 0.0
        metrics[f"npv_class_{cls}"] = tn / (tn + fn) if (tn + fn) > 0 else 0.0
        metrics[f"fpr_class_{cls}"] = fp / (fp + tn) if (fp + tn) > 0 else 0.0
        metrics[f"fnr_class_{cls}"] = fn / (fn + tp) if (fn + tp) > 0 else 0.0

    # =========================================================
    # PROBABILITY-BASED METRICS
    # =========================================================
    if y_proba is not None:
        try:
            y_proba = np.asarray(y_proba)

            if y_proba.ndim != 2 or y_proba.shape[1] != n_classes:
                raise ValueError(
                    f"y_proba debe tener shape (n_samples, {n_classes}) "
                    f"y tiene {y_proba.shape}"
                )

            # ROC AUC multiclass
            metrics["roc_auc_ovr_macro"] = roc_auc_score(
                y_true, y_proba, multi_class="ovr", average="macro"
            )
            metrics["roc_auc_ovr_weighted"] = roc_auc_score(
                y_true, y_proba, multi_class="ovr", average="weighted"
            )
            metrics["roc_auc_ovo_macro"] = roc_auc_score(
                y_true, y_proba, multi_class="ovo", average="macro"
            )
            metrics["roc_auc_ovo_weighted"] = roc_auc_score(
                y_true, y_proba, multi_class="ovo", average="weighted"
            )

            # AUCPR multiclass
            y_true_bin = label_binarize(y_true, classes=classes)

            metrics["aucpr_macro"] = average_precision_score(
                y_true_bin, y_proba, average="macro"
            )
            metrics["aucpr_weighted"] = average_precision_score(
                y_true_bin, y_proba, average="weighted"
            )

            class_prevalences = y_true_bin.mean(axis=0)
            metrics["aucpr_macro_baseline"] = class_prevalences.mean()
            metrics["aucpr_weighted_baseline"] = np.sum(class_prevalences ** 2)

        except Exception:
            metrics["roc_auc_ovr_macro"] = np.nan
            metrics["roc_auc_ovr_weighted"] = np.nan
            metrics["roc_auc_ovo_macro"] = np.nan
            metrics["roc_auc_ovo_weighted"] = np.nan
            metrics["aucpr_macro"] = np.nan
            metrics["aucpr_weighted"] = np.nan
            metrics["aucpr_macro_baseline"] = np.nan
            metrics["aucpr_weighted_baseline"] = np.nan
    else:
        metrics["roc_auc_ovr_macro"] = np.nan
        metrics["roc_auc_ovr_weighted"] = np.nan
        metrics["roc_auc_ovo_macro"] = np.nan
        metrics["roc_auc_ovo_weighted"] = np.nan
        metrics["aucpr_macro"] = np.nan
        metrics["aucpr_weighted"] = np.nan
        metrics["aucpr_macro_baseline"] = np.nan
        metrics["aucpr_weighted_baseline"] = np.nan

    return metrics


def _mean_metrics(metrics_list):
    keys = metrics_list[0].keys()
    return {k: np.mean([m[k] for m in metrics_list]) for k in keys}


def _build_row_multiclass(results, model_name, sampler_name, classes_original):
    metric_names = list(results[0]["cv"].keys())

    row = {
        "model": model_name,
        "sampler": sampler_name,
        "target_type": "multiclass",
        "classes": list(classes_original),
        "n_classes": len(classes_original),
    }

    for metric in metric_names:
        cv_vals = [r["cv"][metric] for r in results]
        train_vals = [r["train"][metric] for r in results]
        test_vals = [r["test"][metric] for r in results]

        row[f"{metric}_cv_mean"] = np.mean(cv_vals)
        row[f"{metric}_cv_std"] = np.std(cv_vals, ddof=1)

        row[f"{metric}_train_mean"] = np.mean(train_vals)
        row[f"{metric}_train_std"] = np.std(train_vals, ddof=1)

        row[f"{metric}_test_mean"] = np.mean(test_vals)
        row[f"{metric}_test_std"] = np.std(test_vals, ddof=1)

    return row


def _resolve_target_class_counts(y_train_inner, target_class_counts):
    """
    Devuelve un dict {clase: cantidad_final_deseada} para ROS/SMOTE/CTGAN.

    target_class_counts puede ser:
    - None
    - int: lleva toda clase con menos de ese valor hasta ese valor
    - dict: {clase: cantidad_final}
    - "balance_to_majority": lleva todas las clases al tamaño de la mayoritaria
    """
    y_sr = pd.Series(y_train_inner)
    class_counts = y_sr.value_counts().sort_index().to_dict()

    if target_class_counts is None:
        return None

    if isinstance(target_class_counts, str):
        if target_class_counts != "balance_to_majority":
            raise ValueError(
                "Si es string, target_class_counts debe ser 'balance_to_majority'."
            )
        majority_count = max(class_counts.values())
        return {
            cls: majority_count
            for cls, count in class_counts.items()
            if count < majority_count
        }

    if isinstance(target_class_counts, int):
        return {
            cls: int(target_class_counts)
            for cls, count in class_counts.items()
            if count < int(target_class_counts)
        }

    if isinstance(target_class_counts, dict):
        resolved = {}
        for cls, desired in target_class_counts.items():
            if cls not in class_counts:
                continue
            if desired < class_counts[cls]:
                raise ValueError(
                    f"Para clase {cls}, target={desired} no puede ser menor "
                    f"que el count actual={class_counts[cls]}"
                )
            if desired > class_counts[cls]:
                resolved[cls] = int(desired)
        return resolved if len(resolved) > 0 else None

    raise ValueError(
        "target_class_counts debe ser None, int, dict o 'balance_to_majority'."
    )


def _apply_single_resampling_method_multiclass(
    X_train_inner,
    y_train_inner,
    resampling_method=None,
    target_class_counts=None,
    random_state=42,
    smote_k_neighbors=3,
    ctgan_epochs=300
):
    X_df = pd.DataFrame(X_train_inner).reset_index(drop=True)
    y_sr = pd.Series(y_train_inner).reset_index(drop=True)

    if resampling_method is None or target_class_counts is None:
        return X_df.to_numpy(), y_sr.to_numpy()

    if resampling_method not in {"ros", "smote", "ctgan"}:
        raise ValueError(
            "resampling_method debe ser uno de: None, 'ros', 'smote', 'ctgan'"
        )

    sampling_strategy = _resolve_target_class_counts(y_sr, target_class_counts)

    if sampling_strategy is None or len(sampling_strategy) == 0:
        return X_df.to_numpy(), y_sr.to_numpy()

    if resampling_method == "ros":
        ros = RandomOverSampler(
            sampling_strategy=sampling_strategy,
            random_state=random_state
        )
        X_res, y_res = ros.fit_resample(X_df, y_sr)
        return np.asarray(X_res), np.asarray(y_res)

    if resampling_method == "smote":
        class_counts = y_sr.value_counts().to_dict()
        for cls in sampling_strategy:
            if class_counts[cls] <= smote_k_neighbors:
                raise ValueError(
                    f"La clase {cls} tiene {class_counts[cls]} muestras. "
                    f"SMOTE requiere más de k_neighbors={smote_k_neighbors}."
                )

        smote = SMOTE(
            sampling_strategy=sampling_strategy,
            k_neighbors=smote_k_neighbors,
            random_state=random_state
        )
        X_res, y_res = smote.fit_resample(X_df, y_sr)
        return np.asarray(X_res), np.asarray(y_res)

    if resampling_method == "ctgan":
        synthetic_parts = []
        synthetic_labels = []

        for cls, target_count in sampling_strategy.items():
            current_count = int((y_sr == cls).sum())
            rows_to_generate = int(target_count - current_count)

            if rows_to_generate <= 0:
                continue

            X_class = X_df[y_sr == cls].copy()

            if len(X_class) < 2:
                raise ValueError(
                    f"No hay suficientes muestras de la clase {cls} para entrenar CTGAN."
                )

            metadata = Metadata.detect_from_dataframe(data=X_class)

            ctgan_model = CTGANSynthesizer(
                metadata=metadata,
                epochs=ctgan_epochs
            )

            ctgan_model.fit(X_class)
            synthetic_data = ctgan_model.sample(num_rows=rows_to_generate)

            synthetic_parts.append(synthetic_data)
            synthetic_labels.append(pd.Series([cls] * rows_to_generate))

        if len(synthetic_parts) == 0:
            return X_df.to_numpy(), y_sr.to_numpy()

        X_syn = pd.concat(synthetic_parts, ignore_index=True)
        y_syn = pd.concat(synthetic_labels, ignore_index=True)

        X_res = pd.concat([X_df, X_syn], ignore_index=True)
        y_res = pd.concat([y_sr, y_syn], ignore_index=True)

        return X_res.to_numpy(), y_res.to_numpy()

    return X_df.to_numpy(), y_sr.to_numpy()


def evaluate_model_10x10_metrics_multiclass_sampler(
    model_dict: dict,
    X,
    y,
    n_outer=10,
    n_inner=10,
    test_size_outer=0.30,
    test_size_inner=0.30,
    random_state=42,
    cost_matrix=None,
    resampling_method=None,
    target_class_counts=None,
    smote_k_neighbors=3,
    ctgan_epochs=300,
):
    """
    Evalúa modelos multiclase con validación 10x10 y remuestreo en:
    - inner train: ~70% del target del outer
    - outer train final: target_class_counts completo

    target_class_counts:
    - None
    - int
    - dict
    - "balance_to_majority"
    """

    X_arr = X.values if hasattr(X, "iloc") else np.asarray(X)
    y_arr_raw = y.values if hasattr(y, "iloc") else np.asarray(y)
    y_arr_raw = np.asarray(y_arr_raw).ravel()

    le = LabelEncoder()
    y_arr = le.fit_transform(y_arr_raw)
    classes_encoded = np.arange(len(le.classes_))
    classes_original = le.classes_

    if len(classes_encoded) < 3:
        raise ValueError(
            f"Esta función es para multiclase. Clases encontradas: {classes_original}"
        )

    all_rows = []

    for model_name, model in model_dict.items():
        print(f"Evaluating model: {model_name}")

        outer_cv = StratifiedShuffleSplit(
            n_splits=n_outer,
            test_size=test_size_outer,
            random_state=random_state
        )

        results = []

        for outer_fold, (train_idx, test_idx) in enumerate(
            outer_cv.split(X_arr, y_arr),
            start=1
        ):
            X_train_outer, X_test_outer = X_arr[train_idx], X_arr[test_idx]
            y_train_outer, y_test_outer = y_arr[train_idx], y_arr[test_idx]

            inner_cv = StratifiedShuffleSplit(
                n_splits=n_inner,
                test_size=test_size_inner,
                random_state=random_state + outer_fold
            )

            inner_scores = []

            for inner_fold, (train_inner_idx, val_inner_idx) in enumerate(
                inner_cv.split(X_train_outer, y_train_outer),
                start=1
            ):
                X_train_inner = X_train_outer[train_inner_idx]
                y_train_inner = y_train_outer[train_inner_idx]
                X_val_inner = X_train_outer[val_inner_idx]
                y_val_inner = y_train_outer[val_inner_idx]

                inner_target_class_counts = None
                if target_class_counts is not None:
                    resolved_outer = _resolve_target_class_counts(
                        y_train_outer,
                        target_class_counts
                    )

                    if resolved_outer is not None:
                        inner_target_class_counts = {}
                        current_inner_counts = pd.Series(y_train_inner).value_counts().to_dict()

                        for cls, outer_target in resolved_outer.items():
                            current_inner = current_inner_counts.get(cls, 0)
                            inner_target = max(
                                current_inner,
                                int(np.floor(outer_target * 0.70))
                            )
                            if inner_target > current_inner:
                                inner_target_class_counts[cls] = inner_target

                        if len(inner_target_class_counts) == 0:
                            inner_target_class_counts = None

                X_train_inner_res, y_train_inner_res = _apply_single_resampling_method_multiclass(
                    X_train_inner=X_train_inner,
                    y_train_inner=y_train_inner,
                    resampling_method=resampling_method,
                    target_class_counts=inner_target_class_counts,
                    random_state=random_state + outer_fold * 100 + inner_fold,
                    smote_k_neighbors=smote_k_neighbors,
                    ctgan_epochs=ctgan_epochs
                )

                est = clone(model)
                est.fit(X_train_inner_res, y_train_inner_res)

                y_pred_val = est.predict(X_val_inner)

                y_proba_val = (
                    est.predict_proba(X_val_inner)
                    if hasattr(est, "predict_proba")
                    else None
                )

                inner_scores.append(
                    _compute_metrics_multiclass(
                        y_true=y_val_inner,
                        y_pred=y_pred_val,
                        y_proba=y_proba_val,
                        classes=classes_encoded,
                        cost_matrix=cost_matrix
                    )
                )

            cv_mean_scores = _mean_metrics(inner_scores)

            X_train_outer_res, y_train_outer_res = _apply_single_resampling_method_multiclass(
                X_train_inner=X_train_outer,
                y_train_inner=y_train_outer,
                resampling_method=resampling_method,
                target_class_counts=target_class_counts,
                random_state=random_state + outer_fold,
                smote_k_neighbors=smote_k_neighbors,
                ctgan_epochs=ctgan_epochs
            )

            final_model = clone(model)
            final_model.fit(X_train_outer_res, y_train_outer_res)

            y_pred_train = final_model.predict(X_train_outer_res)
            y_proba_train = (
                final_model.predict_proba(X_train_outer_res)
                if hasattr(final_model, "predict_proba")
                else None
            )

            train_scores = _compute_metrics_multiclass(
                y_true=y_train_outer_res,
                y_pred=y_pred_train,
                y_proba=y_proba_train,
                classes=classes_encoded,
                cost_matrix=cost_matrix
            )

            y_pred_test = final_model.predict(X_test_outer)
            y_proba_test = (
                final_model.predict_proba(X_test_outer)
                if hasattr(final_model, "predict_proba")
                else None
            )

            test_scores = _compute_metrics_multiclass(
                y_true=y_test_outer,
                y_pred=y_pred_test,
                y_proba=y_proba_test,
                classes=classes_encoded,
                cost_matrix=cost_matrix
            )

            results.append({
                "cv": cv_mean_scores,
                "train": train_scores,
                "test": test_scores
            })

        row = _build_row_multiclass(
            results=results,
            model_name=model_name,
            sampler_name=resampling_method,
            classes_original=classes_original
        )
        all_rows.append(row)

        print(
            f"{model_name} | "
            f"Sampler={resampling_method} | "
            f"ACC CV={row['accuracy_cv_mean']:.4f} | "
            f"ACC Train={row['accuracy_train_mean']:.4f} | "
            f"ACC Test={row['accuracy_test_mean']:.4f} | "
            f"F1 macro CV={row['f1_macro_cv_mean']:.4f} | "
            f"F1 macro Test={row['f1_macro_test_mean']:.4f} | "
            f"ROC AUC OVR macro CV={row['roc_auc_ovr_macro_cv_mean']:.4f} | "
            f"ROC AUC OVR macro Test={row['roc_auc_ovr_macro_test_mean']:.4f} | "
            f"AUCPR macro CV={row['aucpr_macro_cv_mean']:.4f} | "
            f"AUCPR macro Test={row['aucpr_macro_test_mean']:.4f}"
        )

    return pd.DataFrame(all_rows)

# %% [markdown]
# # MODEL DEVELOPMENT

# %% [markdown]
# # BASELINE MODELS

# %% [markdown]
# ## MCID

# %%
data_df_ovr=[]
for val1,val2 in pairs_init_MCID:
    y = pd.read_csv(y_multiples_MCID[val2], index_col=0)
    print(f"Evaluating for target: {val2} with features: {val1}")
    X = pd.read_csv(X_multiples_MCID[val1], index_col=0)
    print(f"\tLoaded X shape: {X.shape}, y shape: {y.shape}")
    for pipeline_weight in classification_models_by_weight_MCID:
        print(f"\tPipeline weight config: {pipeline_weight}")
        classification_models = classification_models_by_weight_MCID[pipeline_weight]
        print(f"\tEvaluating multiclass classification for {val2} \n")
        results_df = evaluate_model_10x10_metrics_multiclass_sampler(
            model_dict=classification_models,
            X=X,
            y=y,
            n_outer=10,
            n_inner=10,
            test_size_outer=0.30,
            test_size_inner=0.30,
            random_state=42,
            cost_matrix=None,
            resampling_method=None,
            target_class_counts=None
        )
        results_df["weight_config"] = pipeline_weight
        results_df["feature_set"] = val1
        results_df["sampler_config"] = np.nan
        data_df_ovr.append(results_df)

        for sampler_dict in [{0:180, 2:270}, {0:200, 2:290}, {0:220, 2:310}]:
            print(f"\tEvaluating with ROS sampler config: {sampler_dict} \n")
            results_df_ros = evaluate_model_10x10_metrics_multiclass_sampler(
                model_dict=classification_models,
                X=X,
                y=y,
                n_inner=5,
                resampling_method="ros",
                target_class_counts=sampler_dict)
            
            results_df_ros["weight_config"] = pipeline_weight
            results_df_ros["feature_set"] = val1
            results_df_ros["sampler_config"] = f"ROS_{sampler_dict}"
            data_df_ovr.append(results_df_ros)
            
            print(f"\tEvaluating with SMOTE sampler config: {sampler_dict} \n")
            results_df_smote = evaluate_model_10x10_metrics_multiclass_sampler(
                        model_dict=classification_models,
                        X=X,
                        y=y,
                        n_inner=5,
                        resampling_method="smote",
                        target_class_counts=sampler_dict,
                        smote_k_neighbors=3)
            
            results_df_smote["weight_config"] = pipeline_weight
            results_df_smote["feature_set"] = val1
            results_df_smote["sampler_config"] = f"SMOTE_{sampler_dict}"
            data_df_ovr.append(results_df_smote)

final_results_df_ovr = pd.concat(data_df_ovr, ignore_index=True)
final_results_df_ovr.to_csv(output_path / "multiclass_classification_results_MCID_v2.csv", index=False)
# Out:
# Evaluating for target: MCID_v2 with features: X_STATS_V2
# 	Loaded X shape: (956, 301), y shape: (956, 1)
# 	Pipeline weight config: balanced
# 	Evaluating multiclass classification for MCID_v2
#
# Evaluating model: decision_tree
# decision_tree | Sampler=None | ACC CV=0.4871 | ACC Train=1.0000 | ACC Test=0.4672 | F1 macro CV=0.4132 | F1 macro Test=0.3913 | ROC AUC OVR macro CV=0.5691 | ROC AUC OVR macro Test=0.5532 | AUCPR macro CV=0.3745 | AUCPR macro Test=0.3648
# Evaluating model: random_forest
# random_forest | Sampler=None | ACC CV=0.5647 | ACC Train=1.0000 | ACC Test=0.5645 | F1 macro CV=0.4206 | F1 macro Test=0.4134 | ROC AUC OVR macro CV=0.6979 | ROC AUC OVR macro Test=0.6979 | AUCPR macro CV=0.4959 | AUCPR macro Test=0.4929
# Evaluating model: extra_trees
# extra_trees | Sampler=None | ACC CV=0.5617 | ACC Train=1.0000 | ACC Test=0.5599 | F1 macro CV=0.4229 | F1 macro Test=0.4243 | ROC AUC OVR macro CV=0.6986 | ROC AUC OVR macro Test=0.6942 | AUCPR macro CV=0.4985 | AUCPR macro Test=0.4898
# Evaluating model: xgboost
# /home/fsc/Desktop/PD_progression_ppmi/.venv/lib/python3.12/site-packages/xgboost/core.py:751: UserWarning: [10:49:35] WARNING: /__w/xgboost/xgboost/src/common/error_msg.cc:62: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)
# xgboost | Sampler=None | ACC CV=0.5376 | ACC Train=1.0000 | ACC Test=0.5307 | F1 macro CV=0.4293 | F1 macro Test=0.4175 | ROC AUC OVR macro CV=0.6799 | ROC AUC OVR macro Test=0.6752 | AUCPR macro CV=0.4861 | AUCPR macro Test=0.4796
# Evaluating model: adaboost
# adaboost | Sampler=None | ACC CV=0.5505 | ACC Train=0.6262 | ACC Test=0.5571 | F1 macro CV=0.4377 | F1 macro Test=0.4338 | ROC AUC OVR macro CV=0.6754 | ROC AUC OVR macro Test=0.6809 | AUCPR macro CV=0.4785 | AUCPR macro Test=0.4777
# Evaluating model: svm
# svm | Sampler=None | ACC CV=0.5294 | ACC Train=0.5668 | ACC Test=0.5383 | F1 macro CV=0.4353 | F1 macro Test=0.4498 | ROC AUC OVR macro CV=0.7149 | ROC AUC OVR macro Test=0.7237 | AUCPR macro CV=0.5109 | AUCPR macro Test=0.5157
# Evaluating model: logistic_regression
# logistic_regression | Sampler=None | ACC CV=0.4926 | ACC Train=0.8025 | ACC Test=0.4808 | F1 macro CV=0.4256 | F1 macro Test=0.4167 | ROC AUC OVR macro CV=0.5924 | ROC AUC OVR macro Test=0.5929 | AUCPR macro CV=0.4277 | AUCPR macro Test=0.4280
# Evaluating model: knn
# knn | Sampler=None | ACC CV=0.5397 | ACC Train=0.6694 | ACC Test=0.5408 | F1 macro CV=0.4177 | F1 macro Test=0.4207 | ROC AUC OVR macro CV=0.6568 | ROC AUC OVR macro Test=0.6559 | AUCPR macro CV=0.4508 | AUCPR macro Test=0.4499
# Evaluating model: gaussian_nb
# gaussian_nb | Sampler=None | ACC CV=0.5434 | ACC Train=0.6046 | ACC Test=0.5432 | F1 macro CV=0.4639 | F1 macro Test=0.4592 | ROC AUC OVR macro CV=0.6889 | ROC AUC OVR macro Test=0.6885 | AUCPR macro CV=0.4739 | AUCPR macro Test=0.4709
# Evaluating model: mlp3216
# /home/fsc/Desktop/PD_progression_ppmi/.venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# mlp3216 | Sampler=None | ACC CV=0.4876 | ACC Train=0.9997 | ACC Test=0.4728 | F1 macro CV=0.4105 | F1 macro Test=0.4037 | ROC AUC OVR macro CV=0.5843 | ROC AUC OVR macro Test=0.5700 | AUCPR macro CV=0.4096 | AUCPR macro Test=0.3997
# 	Evaluating with ROS sampler config: {0: 180, 2: 270}
#
# Evaluating model: decision_tree
# decision_tree | Sampler=ros | ACC CV=0.4752 | ACC Train=1.0000 | ACC Test=0.4683 | F1 macro CV=0.4090 | F1 macro Test=0.3978 | ROC AUC OVR macro CV=0.5653 | ROC AUC OVR macro Test=0.5568 | AUCPR macro CV=0.3718 | AUCPR macro Test=0.3653
# Evaluating model: random_forest
# random_forest | Sampler=ros | ACC CV=0.5661 | ACC Train=1.0000 | ACC Test=0.5655 | F1 macro CV=0.4387 | F1 macro Test=0.4354 | ROC AUC OVR macro CV=0.6988 | ROC AUC OVR macro Test=0.6939 | AUCPR macro CV=0.4984 | AUCPR macro Test=0.4919
# Evaluating model: extra_trees
# extra_trees | Sampler=ros | ACC CV=0.5624 | ACC Train=1.0000 | ACC Test=0.5557 | F1 macro CV=0.4279 | F1 macro Test=0.4099 | ROC AUC OVR macro CV=0.6956 | ROC AUC OVR macro Test=0.6999 | AUCPR macro CV=0.4950 | AUCPR macro Test=0.4922
# Evaluating model: xgboost
# xgboost | Sampler=ros | ACC CV=0.5366 | ACC Train=1.0000 | ACC Test=0.5265 | F1 macro CV=0.4312 | F1 macro Test=0.4177 | ROC AUC OVR macro CV=0.6769 | ROC AUC OVR macro Test=0.6719 | AUCPR macro CV=0.4839 | AUCPR macro Test=0.4740
# Evaluating model: adaboost
# adaboost | Sampler=ros | ACC CV=0.5418 | ACC Train=0.6090 | ACC Test=0.5547 | F1 macro CV=0.4437 | F1 macro Test=0.4533 | ROC AUC OVR macro CV=0.6706 | ROC AUC OVR macro Test=0.6855 | AUCPR macro CV=0.4748 | AUCPR macro Test=0.4818
# Evaluating model: svm
# svm | Sampler=ros | ACC CV=0.5321 | ACC Train=0.5526 | ACC Test=0.5401 | F1 macro CV=0.4481 | F1 macro Test=0.4548 | ROC AUC OVR macro CV=0.7121 | ROC AUC OVR macro Test=0.7213 | AUCPR macro CV=0.5095 | AUCPR macro Test=0.5178
# Evaluating model: logistic_regression
# logistic_regression | Sampler=ros | ACC CV=0.4923 | ACC Train=0.8229 | ACC Test=0.4875 | F1 macro CV=0.4250 | F1 macro Test=0.4240 | ROC AUC OVR macro CV=0.5897 | ROC AUC OVR macro Test=0.5910 | AUCPR macro CV=0.4256 | AUCPR macro Test=0.4258
# Evaluating model: knn
# knn | Sampler=ros | ACC CV=0.5270 | ACC Train=0.6949 | ACC Test=0.5244 | F1 macro CV=0.4386 | F1 macro Test=0.4375 | ROC AUC OVR macro CV=0.6465 | ROC AUC OVR macro Test=0.6429 | AUCPR macro CV=0.4447 | AUCPR macro Test=0.4401
# Evaluating model: gaussian_nb
# gaussian_nb | Sampler=ros | ACC CV=0.5415 | ACC Train=0.5857 | ACC Test=0.5505 | F1 macro CV=0.4635 | F1 macro Test=0.4681 | ROC AUC OVR macro CV=0.6847 | ROC AUC OVR macro Test=0.6876 | AUCPR macro CV=0.4707 | AUCPR macro Test=0.4713
# Evaluating model: mlp3216
# mlp3216 | Sampler=ros | ACC CV=0.4815 | ACC Train=0.9997 | ACC Test=0.4815 | F1 macro CV=0.4061 | F1 macro Test=0.4125 | ROC AUC OVR macro CV=0.5858 | ROC AUC OVR macro Test=0.5661 | AUCPR macro CV=0.4140 | AUCPR macro Test=0.3927
# 	Evaluating with SMOTE sampler config: {0: 180, 2: 270}
#
# Evaluating model: decision_tree
# decision_tree | Sampler=smote | ACC CV=0.4872 | ACC Train=1.0000 | ACC Test=0.4812 | F1 macro CV=0.4225 | F1 macro Test=0.4155 | ROC AUC OVR macro CV=0.5766 | ROC AUC OVR macro Test=0.5713 | AUCPR macro CV=0.3788 | AUCPR macro Test=0.3748
# Evaluating model: random_forest
# random_forest | Sampler=smote | ACC CV=0.5660 | ACC Train=1.0000 | ACC Test=0.5634 | F1 macro CV=0.4371 | F1 macro Test=0.4308 | ROC AUC OVR macro CV=0.6959 | ROC AUC OVR macro Test=0.6987 | AUCPR macro CV=0.4950 | AUCPR macro Test=0.4931
# Evaluating model: extra_trees
# extra_trees | Sampler=smote | ACC CV=0.5633 | ACC Train=1.0000 | ACC Test=0.5732 | F1 macro CV=0.4386 | F1 macro Test=0.4429 | ROC AUC OVR macro CV=0.6956 | ROC AUC OVR macro Test=0.6930 | AUCPR macro CV=0.4957 | AUCPR macro Test=0.4892
# Evaluating model: xgboost
# xgboost | Sampler=smote | ACC CV=0.5354 | ACC Train=1.0000 | ACC Test=0.5338 | F1 macro CV=0.4307 | F1 macro Test=0.4217 | ROC AUC OVR macro CV=0.6774 | ROC AUC OVR macro Test=0.6698 | AUCPR macro CV=0.4839 | AUCPR macro Test=0.4712
# Evaluating model: adaboost
# adaboost | Sampler=smote | ACC CV=0.5425 | ACC Train=0.6370 | ACC Test=0.5432 | F1 macro CV=0.4442 | F1 macro Test=0.4453 | ROC AUC OVR macro CV=0.6692 | ROC AUC OVR macro Test=0.6806 | AUCPR macro CV=0.4770 | AUCPR macro Test=0.4817
# Evaluating model: svm
# svm | Sampler=smote | ACC CV=0.5338 | ACC Train=0.5425 | ACC Test=0.5449 | F1 macro CV=0.4488 | F1 macro Test=0.4629 | ROC AUC OVR macro CV=0.7110 | ROC AUC OVR macro Test=0.7225 | AUCPR macro CV=0.5048 | AUCPR macro Test=0.5162
# Evaluating model: logistic_regression
# logistic_regression | Sampler=smote | ACC CV=0.4903 | ACC Train=0.8148 | ACC Test=0.4847 | F1 macro CV=0.4238 | F1 macro Test=0.4209 | ROC AUC OVR macro CV=0.5883 | ROC AUC OVR macro Test=0.5888 | AUCPR macro CV=0.4243 | AUCPR macro Test=0.4225
# Evaluating model: knn
# knn | Sampler=smote | ACC CV=0.5183 | ACC Train=0.7395 | ACC Test=0.5226 | F1 macro CV=0.4515 | F1 macro Test=0.4570 | ROC AUC OVR macro CV=0.6491 | ROC AUC OVR macro Test=0.6476 | AUCPR macro CV=0.4481 | AUCPR macro Test=0.4442
# Evaluating model: gaussian_nb
# gaussian_nb | Sampler=smote | ACC CV=0.5432 | ACC Train=0.5779 | ACC Test=0.5505 | F1 macro CV=0.4695 | F1 macro Test=0.4717 | ROC AUC OVR macro CV=0.6847 | ROC AUC OVR macro Test=0.6847 | AUCPR macro CV=0.4733 | AUCPR macro Test=0.4702
# Evaluating model: mlp3216
# mlp3216 | Sampler=smote | ACC CV=0.4827 | ACC Train=0.9995 | ACC Test=0.4683 | F1 macro CV=0.4107 | F1 macro Test=0.4002 | ROC AUC OVR macro CV=0.5828 | ROC AUC OVR macro Test=0.5732 | AUCPR macro CV=0.4114 | AUCPR macro Test=0.3990
# 	Evaluating with ROS sampler config: {0: 200, 2: 290}
#
# Evaluating model: decision_tree
# decision_tree | Sampler=ros | ACC CV=0.4737 | ACC Train=1.0000 | ACC Test=0.4934 | F1 macro CV=0.4038 | F1 macro Test=0.4196 | ROC AUC OVR macro CV=0.5621 | ROC AUC OVR macro Test=0.5743 | AUCPR macro CV=0.3706 | AUCPR macro Test=0.3772
# Evaluating model: random_forest
# random_forest | Sampler=ros | ACC CV=0.5603 | ACC Train=1.0000 | ACC Test=0.5624 | F1 macro CV=0.4348 | F1 macro Test=0.4316 | ROC AUC OVR macro CV=0.6965 | ROC AUC OVR macro Test=0.6922 | AUCPR macro CV=0.4964 | AUCPR macro Test=0.4902
# Evaluating model: extra_trees
# extra_trees | Sampler=ros | ACC CV=0.5611 | ACC Train=1.0000 | ACC Test=0.5655 | F1 macro CV=0.4240 | F1 macro Test=0.4376 | ROC AUC OVR macro CV=0.6945 | ROC AUC OVR macro Test=0.6996 | AUCPR macro CV=0.4958 | AUCPR macro Test=0.4987
# Evaluating model: xgboost
# xgboost | Sampler=ros | ACC CV=0.5333 | ACC Train=1.0000 | ACC Test=0.5324 | F1 macro CV=0.4275 | F1 macro Test=0.4238 | ROC AUC OVR macro CV=0.6774 | ROC AUC OVR macro Test=0.6695 | AUCPR macro CV=0.4842 | AUCPR macro Test=0.4702
# Evaluating model: adaboost
# adaboost | Sampler=ros | ACC CV=0.5369 | ACC Train=0.6066 | ACC Test=0.5544 | F1 macro CV=0.4503 | F1 macro Test=0.4545 | ROC AUC OVR macro CV=0.6704 | ROC AUC OVR macro Test=0.6836 | AUCPR macro CV=0.4753 | AUCPR macro Test=0.4802
# Evaluating model: svm
# svm | Sampler=ros | ACC CV=0.5343 | ACC Train=0.5475 | ACC Test=0.5470 | F1 macro CV=0.4507 | F1 macro Test=0.4642 | ROC AUC OVR macro CV=0.7128 | ROC AUC OVR macro Test=0.7218 | AUCPR macro CV=0.5094 | AUCPR macro Test=0.5193
# Evaluating model: logistic_regression
# logistic_regression | Sampler=ros | ACC CV=0.4902 | ACC Train=0.8252 | ACC Test=0.4857 | F1 macro CV=0.4235 | F1 macro Test=0.4216 | ROC AUC OVR macro CV=0.5879 | ROC AUC OVR macro Test=0.5895 | AUCPR macro CV=0.4243 | AUCPR macro Test=0.4246
# Evaluating model: knn
# knn | Sampler=ros | ACC CV=0.5242 | ACC Train=0.7041 | ACC Test=0.5192 | F1 macro CV=0.4425 | F1 macro Test=0.4359 | ROC AUC OVR macro CV=0.6456 | ROC AUC OVR macro Test=0.6400 | AUCPR macro CV=0.4447 | AUCPR macro Test=0.4384
# Evaluating model: gaussian_nb
# gaussian_nb | Sampler=ros | ACC CV=0.5404 | ACC Train=0.5846 | ACC Test=0.5460 | F1 macro CV=0.4629 | F1 macro Test=0.4614 | ROC AUC OVR macro CV=0.6845 | ROC AUC OVR macro Test=0.6882 | AUCPR macro CV=0.4713 | AUCPR macro Test=0.4725
# Evaluating model: mlp3216
# mlp3216 | Sampler=ros | ACC CV=0.4827 | ACC Train=0.9996 | ACC Test=0.4697 | F1 macro CV=0.4081 | F1 macro Test=0.4028 | ROC AUC OVR macro CV=0.5866 | ROC AUC OVR macro Test=0.5729 | AUCPR macro CV=0.4138 | AUCPR macro Test=0.4007
# 	Evaluating with SMOTE sampler config: {0: 200, 2: 290}
#
# Evaluating model: decision_tree
# decision_tree | Sampler=smote | ACC CV=0.4818 | ACC Train=1.0000 | ACC Test=0.4767 | F1 macro CV=0.4116 | F1 macro Test=0.4142 | ROC AUC OVR macro CV=0.5686 | ROC AUC OVR macro Test=0.5693 | AUCPR macro CV=0.3738 | AUCPR macro Test=0.3734
# Evaluating model: random_forest
# random_forest | Sampler=smote | ACC CV=0.5636 | ACC Train=1.0000 | ACC Test=0.5641 | F1 macro CV=0.4395 | F1 macro Test=0.4353 | ROC AUC OVR macro CV=0.6969 | ROC AUC OVR macro Test=0.6999 | AUCPR macro CV=0.4959 | AUCPR macro Test=0.4966
# Evaluating model: extra_trees
# extra_trees | Sampler=smote | ACC CV=0.5599 | ACC Train=1.0000 | ACC Test=0.5662 | F1 macro CV=0.4371 | F1 macro Test=0.4388 | ROC AUC OVR macro CV=0.6938 | ROC AUC OVR macro Test=0.6947 | AUCPR macro CV=0.4937 | AUCPR macro Test=0.4885
# Evaluating model: xgboost
# xgboost | Sampler=smote | ACC CV=0.5358 | ACC Train=1.0000 | ACC Test=0.5404 | F1 macro CV=0.4300 | F1 macro Test=0.4343 | ROC AUC OVR macro CV=0.6769 | ROC AUC OVR macro Test=0.6717 | AUCPR macro CV=0.4832 | AUCPR macro Test=0.4737
# Evaluating model: adaboost
# adaboost | Sampler=smote | ACC CV=0.5408 | ACC Train=0.6428 | ACC Test=0.5470 | F1 macro CV=0.4508 | F1 macro Test=0.4520 | ROC AUC OVR macro CV=0.6716 | ROC AUC OVR macro Test=0.6772 | AUCPR macro CV=0.4813 | AUCPR macro Test=0.4790
# Evaluating model: svm
# svm | Sampler=smote | ACC CV=0.5378 | ACC Train=0.5412 | ACC Test=0.5463 | F1 macro CV=0.4559 | F1 macro Test=0.4665 | ROC AUC OVR macro CV=0.7118 | ROC AUC OVR macro Test=0.7216 | AUCPR macro CV=0.5042 | AUCPR macro Test=0.5160
# Evaluating model: logistic_regression
# logistic_regression | Sampler=smote | ACC CV=0.4900 | ACC Train=0.8236 | ACC Test=0.4805 | F1 macro CV=0.4224 | F1 macro Test=0.4144 | ROC AUC OVR macro CV=0.5864 | ROC AUC OVR macro Test=0.5858 | AUCPR macro CV=0.4226 | AUCPR macro Test=0.4203
# Evaluating model: knn
# knn | Sampler=smote | ACC CV=0.5109 | ACC Train=0.7525 | ACC Test=0.5101 | F1 macro CV=0.4526 | F1 macro Test=0.4515 | ROC AUC OVR macro CV=0.6491 | ROC AUC OVR macro Test=0.6462 | AUCPR macro CV=0.4484 | AUCPR macro Test=0.4414
# Evaluating model: gaussian_nb
# gaussian_nb | Sampler=smote | ACC CV=0.5434 | ACC Train=0.5720 | ACC Test=0.5502 | F1 macro CV=0.4696 | F1 macro Test=0.4722 | ROC AUC OVR macro CV=0.6834 | ROC AUC OVR macro Test=0.6840 | AUCPR macro CV=0.4739 | AUCPR macro Test=0.4713
# Evaluating model: mlp3216
# mlp3216 | Sampler=smote | ACC CV=0.4806 | ACC Train=0.9998 | ACC Test=0.4843 | F1 macro CV=0.4074 | F1 macro Test=0.4074 | ROC AUC OVR macro CV=0.5846 | ROC AUC OVR macro Test=0.5770 | AUCPR macro CV=0.4105 | AUCPR macro Test=0.4052
# 	Evaluating with ROS sampler config: {0: 220, 2: 310}
#
# Evaluating model: decision_tree
# decision_tree | Sampler=ros | ACC CV=0.4859 | ACC Train=1.0000 | ACC Test=0.4920 | F1 macro CV=0.4149 | F1 macro Test=0.4258 | ROC AUC OVR macro CV=0.5697 | ROC AUC OVR macro Test=0.5777 | AUCPR macro CV=0.3749 | AUCPR macro Test=0.3789
# Evaluating model: random_forest
# random_forest | Sampler=ros | ACC CV=0.5643 | ACC Train=1.0000 | ACC Test=0.5638 | F1 macro CV=0.4402 | F1 macro Test=0.4385 | ROC AUC OVR macro CV=0.6981 | ROC AUC OVR macro Test=0.6929 | AUCPR macro CV=0.4950 | AUCPR macro Test=0.4895
# Evaluating model: extra_trees
# extra_trees | Sampler=ros | ACC CV=0.5655 | ACC Train=1.0000 | ACC Test=0.5652 | F1 macro CV=0.4270 | F1 macro Test=0.4258 | ROC AUC OVR macro CV=0.6987 | ROC AUC OVR macro Test=0.7015 | AUCPR macro CV=0.4986 | AUCPR macro Test=0.4998
# Evaluating model: xgboost
# xgboost | Sampler=ros | ACC CV=0.5404 | ACC Train=1.0000 | ACC Test=0.5324 | F1 macro CV=0.4376 | F1 macro Test=0.4236 | ROC AUC OVR macro CV=0.6789 | ROC AUC OVR macro Test=0.6720 | AUCPR macro CV=0.4864 | AUCPR macro Test=0.4712
# Evaluating model: adaboost
# adaboost | Sampler=ros | ACC CV=0.5377 | ACC Train=0.6052 | ACC Test=0.5425 | F1 macro CV=0.4528 | F1 macro Test=0.4501 | ROC AUC OVR macro CV=0.6736 | ROC AUC OVR macro Test=0.6769 | AUCPR macro CV=0.4787 | AUCPR macro Test=0.4756
# Evaluating model: svm
# svm | Sampler=ros | ACC CV=0.5332 | ACC Train=0.5446 | ACC Test=0.5484 | F1 macro CV=0.4525 | F1 macro Test=0.4688 | ROC AUC OVR macro CV=0.7115 | ROC AUC OVR macro Test=0.7208 | AUCPR macro CV=0.5073 | AUCPR macro Test=0.5163
# Evaluating model: logistic_regression
# logistic_regression | Sampler=ros | ACC CV=0.4908 | ACC Train=0.8272 | ACC Test=0.4812 | F1 macro CV=0.4235 | F1 macro Test=0.4184 | ROC AUC OVR macro CV=0.5869 | ROC AUC OVR macro Test=0.5892 | AUCPR macro CV=0.4229 | AUCPR macro Test=0.4232
# Evaluating model: knn
# knn | Sampler=ros | ACC CV=0.5187 | ACC Train=0.7145 | ACC Test=0.5146 | F1 macro CV=0.4440 | F1 macro Test=0.4347 | ROC AUC OVR macro CV=0.6421 | ROC AUC OVR macro Test=0.6377 | AUCPR macro CV=0.4421 | AUCPR macro Test=0.4398
# Evaluating model: gaussian_nb
# gaussian_nb | Sampler=ros | ACC CV=0.5408 | ACC Train=0.5755 | ACC Test=0.5516 | F1 macro CV=0.4641 | F1 macro Test=0.4698 | ROC AUC OVR macro CV=0.6844 | ROC AUC OVR macro Test=0.6887 | AUCPR macro CV=0.4705 | AUCPR macro Test=0.4723
# Evaluating model: mlp3216
# mlp3216 | Sampler=ros | ACC CV=0.4961 | ACC Train=0.9995 | ACC Test=0.4652 | F1 macro CV=0.4234 | F1 macro Test=0.3960 | ROC AUC OVR macro CV=0.5933 | ROC AUC OVR macro Test=0.5578 | AUCPR macro CV=0.4225 | AUCPR macro Test=0.3885
# 	Evaluating with SMOTE sampler config: {0: 220, 2: 310}
#
# Evaluating model: decision_tree
# decision_tree | Sampler=smote | ACC CV=0.4886 | ACC Train=1.0000 | ACC Test=0.4666 | F1 macro CV=0.4150 | F1 macro Test=0.4023 | ROC AUC OVR macro CV=0.5712 | ROC AUC OVR macro Test=0.5613 | AUCPR macro CV=0.3757 | AUCPR macro Test=0.3701
# Evaluating model: random_forest
# random_forest | Sampler=smote | ACC CV=0.5623 | ACC Train=1.0000 | ACC Test=0.5714 | F1 macro CV=0.4396 | F1 macro Test=0.4446 | ROC AUC OVR macro CV=0.6959 | ROC AUC OVR macro Test=0.6979 | AUCPR macro CV=0.4950 | AUCPR macro Test=0.4939
# Evaluating model: extra_trees
# extra_trees | Sampler=smote | ACC CV=0.5618 | ACC Train=1.0000 | ACC Test=0.5585 | F1 macro CV=0.4355 | F1 macro Test=0.4300 | ROC AUC OVR macro CV=0.6983 | ROC AUC OVR macro Test=0.7000 | AUCPR macro CV=0.4968 | AUCPR macro Test=0.4951
# Evaluating model: xgboost
# xgboost | Sampler=smote | ACC CV=0.5291 | ACC Train=1.0000 | ACC Test=0.5324 | F1 macro CV=0.4242 | F1 macro Test=0.4246 | ROC AUC OVR macro CV=0.6755 | ROC AUC OVR macro Test=0.6726 | AUCPR macro CV=0.4825 | AUCPR macro Test=0.4749
# Evaluating model: adaboost
# adaboost | Sampler=smote | ACC CV=0.5412 | ACC Train=0.6438 | ACC Test=0.5467 | F1 macro CV=0.4505 | F1 macro Test=0.4563 | ROC AUC OVR macro CV=0.6660 | ROC AUC OVR macro Test=0.6802 | AUCPR macro CV=0.4785 | AUCPR macro Test=0.4840
# Evaluating model: svm
# svm | Sampler=smote | ACC CV=0.5354 | ACC Train=0.5366 | ACC Test=0.5453 | F1 macro CV=0.4558 | F1 macro Test=0.4644 | ROC AUC OVR macro CV=0.7099 | ROC AUC OVR macro Test=0.7222 | AUCPR macro CV=0.5051 | AUCPR macro Test=0.5166
# Evaluating model: logistic_regression
# logistic_regression | Sampler=smote | ACC CV=0.4900 | ACC Train=0.8221 | ACC Test=0.4812 | F1 macro CV=0.4236 | F1 macro Test=0.4158 | ROC AUC OVR macro CV=0.5849 | ROC AUC OVR macro Test=0.5862 | AUCPR macro CV=0.4210 | AUCPR macro Test=0.4194
# Evaluating model: knn
# knn | Sampler=smote | ACC CV=0.5004 | ACC Train=0.7633 | ACC Test=0.4930 | F1 macro CV=0.4487 | F1 macro Test=0.4422 | ROC AUC OVR macro CV=0.6457 | ROC AUC OVR macro Test=0.6403 | AUCPR macro CV=0.4461 | AUCPR macro Test=0.4388
# Evaluating model: gaussian_nb
# gaussian_nb | Sampler=smote | ACC CV=0.5443 | ACC Train=0.5663 | ACC Test=0.5488 | F1 macro CV=0.4713 | F1 macro Test=0.4714 | ROC AUC OVR macro CV=0.6832 | ROC AUC OVR macro Test=0.6846 | AUCPR macro CV=0.4746 | AUCPR macro Test=0.4717
# Evaluating model: mlp3216
# mlp3216 | Sampler=smote | ACC CV=0.4929 | ACC Train=0.9998 | ACC Test=0.4805 | F1 macro CV=0.4205 | F1 macro Test=0.4169 | ROC AUC OVR macro CV=0.5925 | ROC AUC OVR macro Test=0.5650 | AUCPR macro CV=0.4213 | AUCPR macro Test=0.3982
# 	Pipeline weight config: w_c2_10
# 	Evaluating multiclass classification for MCID_v2
#
# Evaluating model: decision_tree
# decision_tree | Sampler=None | ACC CV=0.4776 | ACC Train=1.0000 | ACC Test=0.4686 | F1 macro CV=0.4053 | F1 macro Test=0.3955 | ROC AUC OVR macro CV=0.5622 | ROC AUC OVR macro Test=0.5554 | AUCPR macro CV=0.3698 | AUCPR macro Test=0.3649
# Evaluating model: random_forest
# random_forest | Sampler=None | ACC CV=0.5591 | ACC Train=1.0000 | ACC Test=0.5655 | F1 macro CV=0.4060 | F1 macro Test=0.4118 | ROC AUC OVR macro CV=0.6984 | ROC AUC OVR macro Test=0.7003 | AUCPR macro CV=0.4966 | AUCPR macro Test=0.4919
# Evaluating model: extra_trees
# extra_trees | Sampler=None | ACC CV=0.5583 | ACC Train=1.0000 | ACC Test=0.5516 | F1 macro CV=0.4130 | F1 macro Test=0.4037 | ROC AUC OVR macro CV=0.6957 | ROC AUC OVR macro Test=0.6934 | AUCPR macro CV=0.4951 | AUCPR macro Test=0.4898
# Evaluating model: xgboost
# xgboost | Sampler=None | ACC CV=0.5376 | ACC Train=1.0000 | ACC Test=0.5307 | F1 macro CV=0.4293 | F1 macro Test=0.4175 | ROC AUC OVR macro CV=0.6799 | ROC AUC OVR macro Test=0.6752 | AUCPR macro CV=0.4861 | AUCPR macro Test=0.4796
# Evaluating model: adaboost
# adaboost | Sampler=None | ACC CV=0.5505 | ACC Train=0.6262 | ACC Test=0.5571 | F1 macro CV=0.4377 | F1 macro Test=0.4338 | ROC AUC OVR macro CV=0.6754 | ROC AUC OVR macro Test=0.6809 | AUCPR macro CV=0.4785 | AUCPR macro Test=0.4777
# Evaluating model: svm
# svm | Sampler=None | ACC CV=0.2919 | ACC Train=0.2936 | ACC Test=0.2916 | F1 macro CV=0.1526 | F1 macro Test=0.1505 | ROC AUC OVR macro CV=0.6740 | ROC AUC OVR macro Test=0.6750 | AUCPR macro CV=0.4770 | AUCPR macro Test=0.4751
# Evaluating model: logistic_regression
# logistic_regression | Sampler=None | ACC CV=0.4286 | ACC Train=0.7489 | ACC Test=0.4007 | F1 macro CV=0.3929 | F1 macro Test=0.3740 | ROC AUC OVR macro CV=0.5618 | ROC AUC OVR macro Test=0.5548 | AUCPR macro CV=0.4060 | AUCPR macro Test=0.3992
# Evaluating model: knn
# knn | Sampler=None | ACC CV=0.5397 | ACC Train=0.6694 | ACC Test=0.5408 | F1 macro CV=0.4177 | F1 macro Test=0.4207 | ROC AUC OVR macro CV=0.6568 | ROC AUC OVR macro Test=0.6559 | AUCPR macro CV=0.4508 | AUCPR macro Test=0.4499
# Evaluating model: gaussian_nb
# gaussian_nb | Sampler=None | ACC CV=0.5434 | ACC Train=0.6046 | ACC Test=0.5432 | F1 macro CV=0.4639 | F1 macro Test=0.4592 | ROC AUC OVR macro CV=0.6889 | ROC AUC OVR macro Test=0.6885 | AUCPR macro CV=0.4739 | AUCPR macro Test=0.4709
# Evaluating model: mlp3216
# /home/fsc/Desktop/PD_progression_ppmi/.venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# mlp3216 | Sampler=None | ACC CV=0.4876 | ACC Train=0.9997 | ACC Test=0.4728 | F1 macro CV=0.4105 | F1 macro Test=0.4037 | ROC AUC OVR macro CV=0.5843 | ROC AUC OVR macro Test=0.5700 | AUCPR macro CV=0.4096 | AUCPR macro Test=0.3997
# 	Evaluating with ROS sampler config: {0: 180, 2: 270}
#
# Evaluating model: decision_tree
# decision_tree | Sampler=ros | ACC CV=0.4668 | ACC Train=1.0000 | ACC Test=0.4767 | F1 macro CV=0.3943 | F1 macro Test=0.4033 | ROC AUC OVR macro CV=0.5536 | ROC AUC OVR macro Test=0.5611 | AUCPR macro CV=0.3644 | AUCPR macro Test=0.3693
# Evaluating model: random_forest
# random_forest | Sampler=ros | ACC CV=0.5620 | ACC Train=1.0000 | ACC Test=0.5679 | F1 macro CV=0.4209 | F1 macro Test=0.4265 | ROC AUC OVR macro CV=0.6955 | ROC AUC OVR macro Test=0.7001 | AUCPR macro CV=0.4938 | AUCPR macro Test=0.4988
# Evaluating model: extra_trees
# extra_trees | Sampler=ros | ACC CV=0.5561 | ACC Train=1.0000 | ACC Test=0.5557 | F1 macro CV=0.4052 | F1 macro Test=0.4030 | ROC AUC OVR macro CV=0.6946 | ROC AUC OVR macro Test=0.6976 | AUCPR macro CV=0.4949 | AUCPR macro Test=0.4936
# Evaluating model: xgboost
# xgboost | Sampler=ros | ACC CV=0.5366 | ACC Train=1.0000 | ACC Test=0.5265 | F1 macro CV=0.4312 | F1 macro Test=0.4177 | ROC AUC OVR macro CV=0.6769 | ROC AUC OVR macro Test=0.6719 | AUCPR macro CV=0.4839 | AUCPR macro Test=0.4740
# Evaluating model: adaboost
# adaboost | Sampler=ros | ACC CV=0.5418 | ACC Train=0.6090 | ACC Test=0.5547 | F1 macro CV=0.4437 | F1 macro Test=0.4533 | ROC AUC OVR macro CV=0.6706 | ROC AUC OVR macro Test=0.6855 | AUCPR macro CV=0.4748 | AUCPR macro Test=0.4818
# Evaluating model: svm
# svm | Sampler=ros | ACC CV=0.2800 | ACC Train=0.3817 | ACC Test=0.2808 | F1 macro CV=0.1768 | F1 macro Test=0.1760 | ROC AUC OVR macro CV=0.6538 | ROC AUC OVR macro Test=0.6526 | AUCPR macro CV=0.4572 | AUCPR macro Test=0.4568
# Evaluating model: logistic_regression
# logistic_regression | Sampler=ros | ACC CV=0.4216 | ACC Train=0.7680 | ACC Test=0.3902 | F1 macro CV=0.3898 | F1 macro Test=0.3672 | ROC AUC OVR macro CV=0.5605 | ROC AUC OVR macro Test=0.5515 | AUCPR macro CV=0.4050 | AUCPR macro Test=0.3980
# Evaluating model: knn
# knn | Sampler=ros | ACC CV=0.5270 | ACC Train=0.6949 | ACC Test=0.5244 | F1 macro CV=0.4386 | F1 macro Test=0.4375 | ROC AUC OVR macro CV=0.6465 | ROC AUC OVR macro Test=0.6429 | AUCPR macro CV=0.4447 | AUCPR macro Test=0.4401
# Evaluating model: gaussian_nb
# gaussian_nb | Sampler=ros | ACC CV=0.5415 | ACC Train=0.5857 | ACC Test=0.5505 | F1 macro CV=0.4635 | F1 macro Test=0.4681 | ROC AUC OVR macro CV=0.6847 | ROC AUC OVR macro Test=0.6876 | AUCPR macro CV=0.4707 | AUCPR macro Test=0.4713
# Evaluating model: mlp3216
# mlp3216 | Sampler=ros | ACC CV=0.4815 | ACC Train=0.9997 | ACC Test=0.4815 | F1 macro CV=0.4061 | F1 macro Test=0.4125 | ROC AUC OVR macro CV=0.5858 | ROC AUC OVR macro Test=0.5661 | AUCPR macro CV=0.4140 | AUCPR macro Test=0.3927
# 	Evaluating with SMOTE sampler config: {0: 180, 2: 270}
#
# Evaluating model: decision_tree
# decision_tree | Sampler=smote | ACC CV=0.4731 | ACC Train=1.0000 | ACC Test=0.4714 | F1 macro CV=0.4055 | F1 macro Test=0.3988 | ROC AUC OVR macro CV=0.5614 | ROC AUC OVR macro Test=0.5566 | AUCPR macro CV=0.3690 | AUCPR macro Test=0.3663
# Evaluating model: random_forest
# random_forest | Sampler=smote | ACC CV=0.5605 | ACC Train=1.0000 | ACC Test=0.5557 | F1 macro CV=0.4199 | F1 macro Test=0.4165 | ROC AUC OVR macro CV=0.6947 | ROC AUC OVR macro Test=0.6971 | AUCPR macro CV=0.4937 | AUCPR macro Test=0.4937
# Evaluating model: extra_trees
# extra_trees | Sampler=smote | ACC CV=0.5637 | ACC Train=1.0000 | ACC Test=0.5603 | F1 macro CV=0.4305 | F1 macro Test=0.4268 | ROC AUC OVR macro CV=0.6972 | ROC AUC OVR macro Test=0.6986 | AUCPR macro CV=0.4973 | AUCPR macro Test=0.4952
# Evaluating model: xgboost
# xgboost | Sampler=smote | ACC CV=0.5354 | ACC Train=1.0000 | ACC Test=0.5338 | F1 macro CV=0.4307 | F1 macro Test=0.4217 | ROC AUC OVR macro CV=0.6774 | ROC AUC OVR macro Test=0.6698 | AUCPR macro CV=0.4839 | AUCPR macro Test=0.4712
# Evaluating model: adaboost
# adaboost | Sampler=smote | ACC CV=0.5425 | ACC Train=0.6370 | ACC Test=0.5432 | F1 macro CV=0.4442 | F1 macro Test=0.4453 | ROC AUC OVR macro CV=0.6692 | ROC AUC OVR macro Test=0.6806 | AUCPR macro CV=0.4770 | AUCPR macro Test=0.4817
# Evaluating model: svm
# svm | Sampler=smote | ACC CV=0.2793 | ACC Train=0.3670 | ACC Test=0.2826 | F1 macro CV=0.1770 | F1 macro Test=0.1671 | ROC AUC OVR macro CV=0.6483 | ROC AUC OVR macro Test=0.6422 | AUCPR macro CV=0.4548 | AUCPR macro Test=0.4474
# Evaluating model: logistic_regression
# logistic_regression | Sampler=smote | ACC CV=0.4194 | ACC Train=0.7695 | ACC Test=0.3864 | F1 macro CV=0.3875 | F1 macro Test=0.3637 | ROC AUC OVR macro CV=0.5602 | ROC AUC OVR macro Test=0.5505 | AUCPR macro CV=0.4053 | AUCPR macro Test=0.3959
# Evaluating model: knn
# knn | Sampler=smote | ACC CV=0.5183 | ACC Train=0.7395 | ACC Test=0.5226 | F1 macro CV=0.4515 | F1 macro Test=0.4570 | ROC AUC OVR macro CV=0.6491 | ROC AUC OVR macro Test=0.6476 | AUCPR macro CV=0.4481 | AUCPR macro Test=0.4442
# Evaluating model: gaussian_nb
# gaussian_nb | Sampler=smote | ACC CV=0.5432 | ACC Train=0.5779 | ACC Test=0.5505 | F1 macro CV=0.4695 | F1 macro Test=0.4717 | ROC AUC OVR macro CV=0.6847 | ROC AUC OVR macro Test=0.6847 | AUCPR macro CV=0.4733 | AUCPR macro Test=0.4702
# Evaluating model: mlp3216
# mlp3216 | Sampler=smote | ACC CV=0.4827 | ACC Train=0.9995 | ACC Test=0.4683 | F1 macro CV=0.4107 | F1 macro Test=0.4002 | ROC AUC OVR macro CV=0.5828 | ROC AUC OVR macro Test=0.5732 | AUCPR macro CV=0.4114 | AUCPR macro Test=0.3990
# 	Evaluating with ROS sampler config: {0: 200, 2: 290}
#
# Evaluating model: decision_tree
# decision_tree | Sampler=ros | ACC CV=0.4668 | ACC Train=1.0000 | ACC Test=0.4693 | F1 macro CV=0.3952 | F1 macro Test=0.3942 | ROC AUC OVR macro CV=0.5539 | ROC AUC OVR macro Test=0.5536 | AUCPR macro CV=0.3646 | AUCPR macro Test=0.3640
# Evaluating model: random_forest
# random_forest | Sampler=ros | ACC CV=0.5596 | ACC Train=1.0000 | ACC Test=0.5627 | F1 macro CV=0.4233 | F1 macro Test=0.4213 | ROC AUC OVR macro CV=0.6950 | ROC AUC OVR macro Test=0.6972 | AUCPR macro CV=0.4942 | AUCPR macro Test=0.4920
# Evaluating model: extra_trees
# extra_trees | Sampler=ros | ACC CV=0.5521 | ACC Train=1.0000 | ACC Test=0.5523 | F1 macro CV=0.4065 | F1 macro Test=0.3972 | ROC AUC OVR macro CV=0.6947 | ROC AUC OVR macro Test=0.6971 | AUCPR macro CV=0.4967 | AUCPR macro Test=0.4937
# Evaluating model: xgboost
# xgboost | Sampler=ros | ACC CV=0.5333 | ACC Train=1.0000 | ACC Test=0.5324 | F1 macro CV=0.4275 | F1 macro Test=0.4238 | ROC AUC OVR macro CV=0.6774 | ROC AUC OVR macro Test=0.6695 | AUCPR macro CV=0.4842 | AUCPR macro Test=0.4702
# Evaluating model: adaboost
# adaboost | Sampler=ros | ACC CV=0.5369 | ACC Train=0.6066 | ACC Test=0.5544 | F1 macro CV=0.4503 | F1 macro Test=0.4545 | ROC AUC OVR macro CV=0.6704 | ROC AUC OVR macro Test=0.6836 | AUCPR macro CV=0.4753 | AUCPR macro Test=0.4802
# Evaluating model: svm
# svm | Sampler=ros | ACC CV=0.2750 | ACC Train=0.4060 | ACC Test=0.2756 | F1 macro CV=0.1915 | F1 macro Test=0.1821 | ROC AUC OVR macro CV=0.6489 | ROC AUC OVR macro Test=0.6514 | AUCPR macro CV=0.4537 | AUCPR macro Test=0.4551
# Evaluating model: logistic_regression
# logistic_regression | Sampler=ros | ACC CV=0.4175 | ACC Train=0.7770 | ACC Test=0.3840 | F1 macro CV=0.3868 | F1 macro Test=0.3630 | ROC AUC OVR macro CV=0.5596 | ROC AUC OVR macro Test=0.5504 | AUCPR macro CV=0.4046 | AUCPR macro Test=0.3975
# Evaluating model: knn
# knn | Sampler=ros | ACC CV=0.5242 | ACC Train=0.7041 | ACC Test=0.5192 | F1 macro CV=0.4425 | F1 macro Test=0.4359 | ROC AUC OVR macro CV=0.6456 | ROC AUC OVR macro Test=0.6400 | AUCPR macro CV=0.4447 | AUCPR macro Test=0.4384
# Evaluating model: gaussian_nb
# gaussian_nb | Sampler=ros | ACC CV=0.5404 | ACC Train=0.5846 | ACC Test=0.5460 | F1 macro CV=0.4629 | F1 macro Test=0.4614 | ROC AUC OVR macro CV=0.6845 | ROC AUC OVR macro Test=0.6882 | AUCPR macro CV=0.4713 | AUCPR macro Test=0.4725
# Evaluating model: mlp3216
# mlp3216 | Sampler=ros | ACC CV=0.4827 | ACC Train=0.9996 | ACC Test=0.4697 | F1 macro CV=0.4081 | F1 macro Test=0.4028 | ROC AUC OVR macro CV=0.5866 | ROC AUC OVR macro Test=0.5729 | AUCPR macro CV=0.4138 | AUCPR macro Test=0.4007
# 	Evaluating with SMOTE sampler config: {0: 200, 2: 290}
#
# Evaluating model: decision_tree
# decision_tree | Sampler=smote | ACC CV=0.4560 | ACC Train=1.0000 | ACC Test=0.4606 | F1 macro CV=0.3860 | F1 macro Test=0.4008 | ROC AUC OVR macro CV=0.5471 | ROC AUC OVR macro Test=0.5559 | AUCPR macro CV=0.3608 | AUCPR macro Test=0.3636
# Evaluating model: random_forest
# random_forest | Sampler=smote | ACC CV=0.5593 | ACC Train=1.0000 | ACC Test=0.5610 | F1 macro CV=0.4209 | F1 macro Test=0.4248 | ROC AUC OVR macro CV=0.6948 | ROC AUC OVR macro Test=0.7028 | AUCPR macro CV=0.4927 | AUCPR macro Test=0.4958
# Evaluating model: extra_trees
# extra_trees | Sampler=smote | ACC CV=0.5586 | ACC Train=1.0000 | ACC Test=0.5638 | F1 macro CV=0.4237 | F1 macro Test=0.4248 | ROC AUC OVR macro CV=0.6970 | ROC AUC OVR macro Test=0.7002 | AUCPR macro CV=0.4962 | AUCPR macro Test=0.4954
# Evaluating model: xgboost
# xgboost | Sampler=smote | ACC CV=0.5358 | ACC Train=1.0000 | ACC Test=0.5404 | F1 macro CV=0.4300 | F1 macro Test=0.4343 | ROC AUC OVR macro CV=0.6769 | ROC AUC OVR macro Test=0.6717 | AUCPR macro CV=0.4832 | AUCPR macro Test=0.4737
# Evaluating model: adaboost
# adaboost | Sampler=smote | ACC CV=0.5408 | ACC Train=0.6428 | ACC Test=0.5470 | F1 macro CV=0.4508 | F1 macro Test=0.4520 | ROC AUC OVR macro CV=0.6716 | ROC AUC OVR macro Test=0.6772 | AUCPR macro CV=0.4813 | AUCPR macro Test=0.4790
# Evaluating model: svm
# svm | Sampler=smote | ACC CV=0.2732 | ACC Train=0.3884 | ACC Test=0.2714 | F1 macro CV=0.1908 | F1 macro Test=0.1664 | ROC AUC OVR macro CV=0.6453 | ROC AUC OVR macro Test=0.6391 | AUCPR macro CV=0.4524 | AUCPR macro Test=0.4440
# Evaluating model: logistic_regression
# logistic_regression | Sampler=smote | ACC CV=0.4188 | ACC Train=0.7779 | ACC Test=0.3812 | F1 macro CV=0.3882 | F1 macro Test=0.3604 | ROC AUC OVR macro CV=0.5592 | ROC AUC OVR macro Test=0.5486 | AUCPR macro CV=0.4045 | AUCPR macro Test=0.3945
# Evaluating model: knn
# knn | Sampler=smote | ACC CV=0.5109 | ACC Train=0.7525 | ACC Test=0.5101 | F1 macro CV=0.4526 | F1 macro Test=0.4515 | ROC AUC OVR macro CV=0.6491 | ROC AUC OVR macro Test=0.6462 | AUCPR macro CV=0.4484 | AUCPR macro Test=0.4414
# Evaluating model: gaussian_nb
# gaussian_nb | Sampler=smote | ACC CV=0.5434 | ACC Train=0.5720 | ACC Test=0.5502 | F1 macro CV=0.4696 | F1 macro Test=0.4722 | ROC AUC OVR macro CV=0.6834 | ROC AUC OVR macro Test=0.6840 | AUCPR macro CV=0.4739 | AUCPR macro Test=0.4713
# Evaluating model: mlp3216
# mlp3216 | Sampler=smote | ACC CV=0.4806 | ACC Train=0.9998 | ACC Test=0.4843 | F1 macro CV=0.4074 | F1 macro Test=0.4074 | ROC AUC OVR macro CV=0.5846 | ROC AUC OVR macro Test=0.5770 | AUCPR macro CV=0.4105 | AUCPR macro Test=0.4052
# 	Evaluating with ROS sampler config: {0: 220, 2: 310}
#
# Evaluating model: decision_tree
# decision_tree | Sampler=ros | ACC CV=0.4708 | ACC Train=1.0000 | ACC Test=0.4652 | F1 macro CV=0.3989 | F1 macro Test=0.3905 | ROC AUC OVR macro CV=0.5564 | ROC AUC OVR macro Test=0.5516 | AUCPR macro CV=0.3656 | AUCPR macro Test=0.3629
# Evaluating model: random_forest
# random_forest | Sampler=ros | ACC CV=0.5605 | ACC Train=1.0000 | ACC Test=0.5610 | F1 macro CV=0.4299 | F1 macro Test=0.4302 | ROC AUC OVR macro CV=0.6932 | ROC AUC OVR macro Test=0.6948 | AUCPR macro CV=0.4919 | AUCPR macro Test=0.4944
# Evaluating model: extra_trees
# extra_trees | Sampler=ros | ACC CV=0.5562 | ACC Train=1.0000 | ACC Test=0.5704 | F1 macro CV=0.4066 | F1 macro Test=0.4159 | ROC AUC OVR macro CV=0.6950 | ROC AUC OVR macro Test=0.6980 | AUCPR macro CV=0.4963 | AUCPR macro Test=0.4983
# Evaluating model: xgboost
# xgboost | Sampler=ros | ACC CV=0.5404 | ACC Train=1.0000 | ACC Test=0.5324 | F1 macro CV=0.4376 | F1 macro Test=0.4236 | ROC AUC OVR macro CV=0.6789 | ROC AUC OVR macro Test=0.6720 | AUCPR macro CV=0.4864 | AUCPR macro Test=0.4712
# Evaluating model: adaboost
# adaboost | Sampler=ros | ACC CV=0.5377 | ACC Train=0.6052 | ACC Test=0.5425 | F1 macro CV=0.4528 | F1 macro Test=0.4501 | ROC AUC OVR macro CV=0.6736 | ROC AUC OVR macro Test=0.6769 | AUCPR macro CV=0.4787 | AUCPR macro Test=0.4756
# Evaluating model: svm
# svm | Sampler=ros | ACC CV=0.2687 | ACC Train=0.4359 | ACC Test=0.2662 | F1 macro CV=0.1995 | F1 macro Test=0.1926 | ROC AUC OVR macro CV=0.6442 | ROC AUC OVR macro Test=0.6454 | AUCPR macro CV=0.4510 | AUCPR macro Test=0.4518
# Evaluating model: logistic_regression
# logistic_regression | Sampler=ros | ACC CV=0.4165 | ACC Train=0.7856 | ACC Test=0.3805 | F1 macro CV=0.3860 | F1 macro Test=0.3597 | ROC AUC OVR macro CV=0.5591 | ROC AUC OVR macro Test=0.5497 | AUCPR macro CV=0.4042 | AUCPR macro Test=0.3957
# Evaluating model: knn
# knn | Sampler=ros | ACC CV=0.5187 | ACC Train=0.7145 | ACC Test=0.5146 | F1 macro CV=0.4440 | F1 macro Test=0.4347 | ROC AUC OVR macro CV=0.6421 | ROC AUC OVR macro Test=0.6377 | AUCPR macro CV=0.4421 | AUCPR macro Test=0.4398
# Evaluating model: gaussian_nb
# gaussian_nb | Sampler=ros | ACC CV=0.5408 | ACC Train=0.5755 | ACC Test=0.5516 | F1 macro CV=0.4641 | F1 macro Test=0.4698 | ROC AUC OVR macro CV=0.6844 | ROC AUC OVR macro Test=0.6887 | AUCPR macro CV=0.4705 | AUCPR macro Test=0.4723
# Evaluating model: mlp3216
# mlp3216 | Sampler=ros | ACC CV=0.4961 | ACC Train=0.9995 | ACC Test=0.4652 | F1 macro CV=0.4234 | F1 macro Test=0.3960 | ROC AUC OVR macro CV=0.5933 | ROC AUC OVR macro Test=0.5578 | AUCPR macro CV=0.4225 | AUCPR macro Test=0.3885
# 	Evaluating with SMOTE sampler config: {0: 220, 2: 310}
#
# Evaluating model: decision_tree
# decision_tree | Sampler=smote | ACC CV=0.4708 | ACC Train=1.0000 | ACC Test=0.4638 | F1 macro CV=0.4001 | F1 macro Test=0.3968 | ROC AUC OVR macro CV=0.5587 | ROC AUC OVR macro Test=0.5551 | AUCPR macro CV=0.3676 | AUCPR macro Test=0.3636
# Evaluating model: random_forest
# random_forest | Sampler=smote | ACC CV=0.5611 | ACC Train=1.0000 | ACC Test=0.5561 | F1 macro CV=0.4252 | F1 macro Test=0.4266 | ROC AUC OVR macro CV=0.6958 | ROC AUC OVR macro Test=0.6995 | AUCPR macro CV=0.4914 | AUCPR macro Test=0.4969
# Evaluating model: extra_trees
# extra_trees | Sampler=smote | ACC CV=0.5565 | ACC Train=1.0000 | ACC Test=0.5547 | F1 macro CV=0.4293 | F1 macro Test=0.4206 | ROC AUC OVR macro CV=0.6944 | ROC AUC OVR macro Test=0.6940 | AUCPR macro CV=0.4947 | AUCPR macro Test=0.4914
# Evaluating model: xgboost
# xgboost | Sampler=smote | ACC CV=0.5291 | ACC Train=1.0000 | ACC Test=0.5324 | F1 macro CV=0.4242 | F1 macro Test=0.4246 | ROC AUC OVR macro CV=0.6755 | ROC AUC OVR macro Test=0.6726 | AUCPR macro CV=0.4825 | AUCPR macro Test=0.4749
# Evaluating model: adaboost
# adaboost | Sampler=smote | ACC CV=0.5412 | ACC Train=0.6438 | ACC Test=0.5467 | F1 macro CV=0.4505 | F1 macro Test=0.4563 | ROC AUC OVR macro CV=0.6660 | ROC AUC OVR macro Test=0.6802 | AUCPR macro CV=0.4785 | AUCPR macro Test=0.4840
# Evaluating model: svm
# svm | Sampler=smote | ACC CV=0.2632 | ACC Train=0.4138 | ACC Test=0.2652 | F1 macro CV=0.1951 | F1 macro Test=0.1803 | ROC AUC OVR macro CV=0.6384 | ROC AUC OVR macro Test=0.6338 | AUCPR macro CV=0.4478 | AUCPR macro Test=0.4420
# Evaluating model: logistic_regression
# logistic_regression | Sampler=smote | ACC CV=0.4165 | ACC Train=0.7841 | ACC Test=0.3787 | F1 macro CV=0.3866 | F1 macro Test=0.3586 | ROC AUC OVR macro CV=0.5588 | ROC AUC OVR macro Test=0.5496 | AUCPR macro CV=0.4038 | AUCPR macro Test=0.3955
# Evaluating model: knn
# knn | Sampler=smote | ACC CV=0.5004 | ACC Train=0.7633 | ACC Test=0.4930 | F1 macro CV=0.4487 | F1 macro Test=0.4422 | ROC AUC OVR macro CV=0.6457 | ROC AUC OVR macro Test=0.6403 | AUCPR macro CV=0.4461 | AUCPR macro Test=0.4388
# Evaluating model: gaussian_nb
# gaussian_nb | Sampler=smote | ACC CV=0.5443 | ACC Train=0.5663 | ACC Test=0.5488 | F1 macro CV=0.4713 | F1 macro Test=0.4714 | ROC AUC OVR macro CV=0.6832 | ROC AUC OVR macro Test=0.6846 | AUCPR macro CV=0.4746 | AUCPR macro Test=0.4717
# Evaluating model: mlp3216
# mlp3216 | Sampler=smote | ACC CV=0.4929 | ACC Train=0.9998 | ACC Test=0.4805 | F1 macro CV=0.4205 | F1 macro Test=0.4169 | ROC AUC OVR macro CV=0.5925 | ROC AUC OVR macro Test=0.5650 | AUCPR macro CV=0.4213 | AUCPR macro Test=0.3982
# 	Pipeline weight config: w_c2_20
# 	Evaluating multiclass classification for MCID_v2
#
# Evaluating model: decision_tree
# decision_tree | Sampler=None | ACC CV=0.4700 | ACC Train=1.0000 | ACC Test=0.4557 | F1 macro CV=0.3962 | F1 macro Test=0.3833 | ROC AUC OVR macro CV=0.5550 | ROC AUC OVR macro Test=0.5456 | AUCPR macro CV=0.3651 | AUCPR macro Test=0.3591
# Evaluating model: random_forest
# random_forest | Sampler=None | ACC CV=0.5576 | ACC Train=1.0000 | ACC Test=0.5655 | F1 macro CV=0.3969 | F1 macro Test=0.4019 | ROC AUC OVR macro CV=0.6963 | ROC AUC OVR macro Test=0.7038 | AUCPR macro CV=0.4931 | AUCPR macro Test=0.4993
# Evaluating model: extra_trees
# extra_trees | Sampler=None | ACC CV=0.5567 | ACC Train=1.0000 | ACC Test=0.5599 | F1 macro CV=0.4082 | F1 macro Test=0.4090 | ROC AUC OVR macro CV=0.6961 | ROC AUC OVR macro Test=0.6937 | AUCPR macro CV=0.4962 | AUCPR macro Test=0.4930
# Evaluating model: xgboost
# xgboost | Sampler=None | ACC CV=0.5376 | ACC Train=1.0000 | ACC Test=0.5307 | F1 macro CV=0.4293 | F1 macro Test=0.4175 | ROC AUC OVR macro CV=0.6799 | ROC AUC OVR macro Test=0.6752 | AUCPR macro CV=0.4861 | AUCPR macro Test=0.4796
# Evaluating model: adaboost
# adaboost | Sampler=None | ACC CV=0.5505 | ACC Train=0.6262 | ACC Test=0.5571 | F1 macro CV=0.4377 | F1 macro Test=0.4338 | ROC AUC OVR macro CV=0.6754 | ROC AUC OVR macro Test=0.6809 | AUCPR macro CV=0.4785 | AUCPR macro Test=0.4777
# Evaluating model: svm
# svm | Sampler=None | ACC CV=0.2766 | ACC Train=0.3223 | ACC Test=0.2791 | F1 macro CV=0.1782 | F1 macro Test=0.1641 | ROC AUC OVR macro CV=0.6481 | ROC AUC OVR macro Test=0.6433 | AUCPR macro CV=0.4550 | AUCPR macro Test=0.4453
# Evaluating model: logistic_regression
# logistic_regression | Sampler=None | ACC CV=0.4069 | ACC Train=0.7010 | ACC Test=0.3683 | F1 macro CV=0.3788 | F1 macro Test=0.3502 | ROC AUC OVR macro CV=0.5568 | ROC AUC OVR macro Test=0.5476 | AUCPR macro CV=0.4026 | AUCPR macro Test=0.3938
# Evaluating model: knn
# knn | Sampler=None | ACC CV=0.5397 | ACC Train=0.6694 | ACC Test=0.5408 | F1 macro CV=0.4177 | F1 macro Test=0.4207 | ROC AUC OVR macro CV=0.6568 | ROC AUC OVR macro Test=0.6559 | AUCPR macro CV=0.4508 | AUCPR macro Test=0.4499
# Evaluating model: gaussian_nb
# gaussian_nb | Sampler=None | ACC CV=0.5434 | ACC Train=0.6046 | ACC Test=0.5432 | F1 macro CV=0.4639 | F1 macro Test=0.4592 | ROC AUC OVR macro CV=0.6889 | ROC AUC OVR macro Test=0.6885 | AUCPR macro CV=0.4739 | AUCPR macro Test=0.4709
# Evaluating model: mlp3216
# /home/fsc/Desktop/PD_progression_ppmi/.venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# mlp3216 | Sampler=None | ACC CV=0.4876 | ACC Train=0.9997 | ACC Test=0.4728 | F1 macro CV=0.4105 | F1 macro Test=0.4037 | ROC AUC OVR macro CV=0.5843 | ROC AUC OVR macro Test=0.5700 | AUCPR macro CV=0.4096 | AUCPR macro Test=0.3997
# 	Evaluating with ROS sampler config: {0: 180, 2: 270}
#
# Evaluating model: decision_tree
# decision_tree | Sampler=ros | ACC CV=0.4656 | ACC Train=1.0000 | ACC Test=0.4749 | F1 macro CV=0.3911 | F1 macro Test=0.3922 | ROC AUC OVR macro CV=0.5511 | ROC AUC OVR macro Test=0.5536 | AUCPR macro CV=0.3632 | AUCPR macro Test=0.3669
# Evaluating model: random_forest
# random_forest | Sampler=ros | ACC CV=0.5564 | ACC Train=1.0000 | ACC Test=0.5679 | F1 macro CV=0.4115 | F1 macro Test=0.4284 | ROC AUC OVR macro CV=0.6952 | ROC AUC OVR macro Test=0.7003 | AUCPR macro CV=0.4938 | AUCPR macro Test=0.4959
# Evaluating model: extra_trees
# extra_trees | Sampler=ros | ACC CV=0.5568 | ACC Train=1.0000 | ACC Test=0.5564 | F1 macro CV=0.4066 | F1 macro Test=0.4020 | ROC AUC OVR macro CV=0.6941 | ROC AUC OVR macro Test=0.6957 | AUCPR macro CV=0.4964 | AUCPR macro Test=0.4918
# Evaluating model: xgboost
# xgboost | Sampler=ros | ACC CV=0.5366 | ACC Train=1.0000 | ACC Test=0.5265 | F1 macro CV=0.4312 | F1 macro Test=0.4177 | ROC AUC OVR macro CV=0.6769 | ROC AUC OVR macro Test=0.6719 | AUCPR macro CV=0.4839 | AUCPR macro Test=0.4740
# Evaluating model: adaboost
# adaboost | Sampler=ros | ACC CV=0.5418 | ACC Train=0.6090 | ACC Test=0.5547 | F1 macro CV=0.4437 | F1 macro Test=0.4533 | ROC AUC OVR macro CV=0.6706 | ROC AUC OVR macro Test=0.6855 | AUCPR macro CV=0.4748 | AUCPR macro Test=0.4818
# Evaluating model: svm
# svm | Sampler=ros | ACC CV=0.2636 | ACC Train=0.4279 | ACC Test=0.2606 | F1 macro CV=0.2020 | F1 macro Test=0.1974 | ROC AUC OVR macro CV=0.6314 | ROC AUC OVR macro Test=0.6247 | AUCPR macro CV=0.4398 | AUCPR macro Test=0.4328
# Evaluating model: logistic_regression
# logistic_regression | Sampler=ros | ACC CV=0.4033 | ACC Train=0.7391 | ACC Test=0.3617 | F1 macro CV=0.3779 | F1 macro Test=0.3460 | ROC AUC OVR macro CV=0.5567 | ROC AUC OVR macro Test=0.5464 | AUCPR macro CV=0.4025 | AUCPR macro Test=0.3944
# Evaluating model: knn
# knn | Sampler=ros | ACC CV=0.5270 | ACC Train=0.6949 | ACC Test=0.5244 | F1 macro CV=0.4386 | F1 macro Test=0.4375 | ROC AUC OVR macro CV=0.6465 | ROC AUC OVR macro Test=0.6429 | AUCPR macro CV=0.4447 | AUCPR macro Test=0.4401
# Evaluating model: gaussian_nb
# gaussian_nb | Sampler=ros | ACC CV=0.5415 | ACC Train=0.5857 | ACC Test=0.5505 | F1 macro CV=0.4635 | F1 macro Test=0.4681 | ROC AUC OVR macro CV=0.6847 | ROC AUC OVR macro Test=0.6876 | AUCPR macro CV=0.4707 | AUCPR macro Test=0.4713
# Evaluating model: mlp3216
# mlp3216 | Sampler=ros | ACC CV=0.4815 | ACC Train=0.9997 | ACC Test=0.4815 | F1 macro CV=0.4061 | F1 macro Test=0.4125 | ROC AUC OVR macro CV=0.5858 | ROC AUC OVR macro Test=0.5661 | AUCPR macro CV=0.4140 | AUCPR macro Test=0.3927
# 	Evaluating with SMOTE sampler config: {0: 180, 2: 270}
#
# Evaluating model: decision_tree
# decision_tree | Sampler=smote | ACC CV=0.4753 | ACC Train=1.0000 | ACC Test=0.4749 | F1 macro CV=0.4016 | F1 macro Test=0.4110 | ROC AUC OVR macro CV=0.5591 | ROC AUC OVR macro Test=0.5647 | AUCPR macro CV=0.3677 | AUCPR macro Test=0.3692
# Evaluating model: random_forest
# random_forest | Sampler=smote | ACC CV=0.5595 | ACC Train=1.0000 | ACC Test=0.5561 | F1 macro CV=0.4163 | F1 macro Test=0.4165 | ROC AUC OVR macro CV=0.6960 | ROC AUC OVR macro Test=0.6956 | AUCPR macro CV=0.4924 | AUCPR macro Test=0.4958
# Evaluating model: extra_trees
# extra_trees | Sampler=smote | ACC CV=0.5620 | ACC Train=1.0000 | ACC Test=0.5624 | F1 macro CV=0.4260 | F1 macro Test=0.4212 | ROC AUC OVR macro CV=0.6952 | ROC AUC OVR macro Test=0.6990 | AUCPR macro CV=0.4967 | AUCPR macro Test=0.4947
# Evaluating model: xgboost
# xgboost | Sampler=smote | ACC CV=0.5354 | ACC Train=1.0000 | ACC Test=0.5338 | F1 macro CV=0.4307 | F1 macro Test=0.4217 | ROC AUC OVR macro CV=0.6774 | ROC AUC OVR macro Test=0.6698 | AUCPR macro CV=0.4839 | AUCPR macro Test=0.4712
# Evaluating model: adaboost
# adaboost | Sampler=smote | ACC CV=0.5425 | ACC Train=0.6370 | ACC Test=0.5432 | F1 macro CV=0.4442 | F1 macro Test=0.4453 | ROC AUC OVR macro CV=0.6692 | ROC AUC OVR macro Test=0.6806 | AUCPR macro CV=0.4770 | AUCPR macro Test=0.4817
# Evaluating model: svm
# svm | Sampler=smote | ACC CV=0.2602 | ACC Train=0.4264 | ACC Test=0.2603 | F1 macro CV=0.1996 | F1 macro Test=0.1999 | ROC AUC OVR macro CV=0.6278 | ROC AUC OVR macro Test=0.6212 | AUCPR macro CV=0.4376 | AUCPR macro Test=0.4298
# Evaluating model: logistic_regression
# logistic_regression | Sampler=smote | ACC CV=0.4034 | ACC Train=0.7383 | ACC Test=0.3638 | F1 macro CV=0.3777 | F1 macro Test=0.3479 | ROC AUC OVR macro CV=0.5564 | ROC AUC OVR macro Test=0.5449 | AUCPR macro CV=0.4028 | AUCPR macro Test=0.3913
# Evaluating model: knn
# knn | Sampler=smote | ACC CV=0.5183 | ACC Train=0.7395 | ACC Test=0.5226 | F1 macro CV=0.4515 | F1 macro Test=0.4570 | ROC AUC OVR macro CV=0.6491 | ROC AUC OVR macro Test=0.6476 | AUCPR macro CV=0.4481 | AUCPR macro Test=0.4442
# Evaluating model: gaussian_nb
# gaussian_nb | Sampler=smote | ACC CV=0.5432 | ACC Train=0.5779 | ACC Test=0.5505 | F1 macro CV=0.4695 | F1 macro Test=0.4717 | ROC AUC OVR macro CV=0.6847 | ROC AUC OVR macro Test=0.6847 | AUCPR macro CV=0.4733 | AUCPR macro Test=0.4702
# Evaluating model: mlp3216
# mlp3216 | Sampler=smote | ACC CV=0.4827 | ACC Train=0.9995 | ACC Test=0.4683 | F1 macro CV=0.4107 | F1 macro Test=0.4002 | ROC AUC OVR macro CV=0.5828 | ROC AUC OVR macro Test=0.5732 | AUCPR macro CV=0.4114 | AUCPR macro Test=0.3990
# 	Evaluating with ROS sampler config: {0: 200, 2: 290}
#
# Evaluating model: decision_tree
# decision_tree | Sampler=ros | ACC CV=0.4689 | ACC Train=1.0000 | ACC Test=0.4596 | F1 macro CV=0.3967 | F1 macro Test=0.3805 | ROC AUC OVR macro CV=0.5552 | ROC AUC OVR macro Test=0.5427 | AUCPR macro CV=0.3657 | AUCPR macro Test=0.3573
# Evaluating model: random_forest
# random_forest | Sampler=ros | ACC CV=0.5566 | ACC Train=1.0000 | ACC Test=0.5676 | F1 macro CV=0.4171 | F1 macro Test=0.4203 | ROC AUC OVR macro CV=0.6942 | ROC AUC OVR macro Test=0.6952 | AUCPR macro CV=0.4928 | AUCPR macro Test=0.4914
# Evaluating model: extra_trees
# ...
# Evaluating model: random_forest
# random_forest | Sampler=ros | ACC CV=0.5596 | ACC Train=1.0000 | ACC Test=0.5578 | F1 macro CV=0.4303 | F1 macro Test=0.4284 | ROC AUC OVR macro CV=0.7275 | ROC AUC OVR macro Test=0.7353 | AUCPR macro CV=0.5328 | AUCPR macro Test=0.5365
# Evaluating model: extra_trees
# extra_trees | Sampler=ros | ACC CV=0.5620 | ACC Train=1.0000 | ACC Test=0.5638 | F1 macro CV=0.4168 | F1 macro Test=0.4253 | ROC AUC OVR macro CV=0.7354 | ROC AUC OVR macro Test=0.7459 | AUCPR macro CV=0.5380 | AUCPR macro Test=0.5473
# Evaluating model: xgboost
# xgboost | Sampler=ros | ACC CV=0.5585 | ACC Train=1.0000 | ACC Test=0.5624 | F1 macro CV=0.4771 | F1 macro Test=0.4877 | ROC AUC OVR macro CV=0.7151 | ROC AUC OVR macro Test=0.7207 | AUCPR macro CV=0.5189 | AUCPR macro Test=0.5251
# Evaluating model: adaboost
# adaboost | Sampler=ros | ACC CV=0.5718 | ACC Train=0.6365 | ACC Test=0.5707 | F1 macro CV=0.4919 | F1 macro Test=0.4982 | ROC AUC OVR macro CV=0.7014 | ROC AUC OVR macro Test=0.7127 | AUCPR macro CV=0.5120 | AUCPR macro Test=0.5221
# Evaluating model: svm
# svm | Sampler=ros | ACC CV=0.3034 | ACC Train=0.4897 | ACC Test=0.3101 | F1 macro CV=0.2611 | F1 macro Test=0.2702 | ROC AUC OVR macro CV=0.6676 | ROC AUC OVR macro Test=0.6904 | AUCPR macro CV=0.4889 | AUCPR macro Test=0.5093
# Evaluating model: logistic_regression
# logistic_regression | Sampler=ros | ACC CV=0.4531 | ACC Train=0.7746 | ACC Test=0.4470 | F1 macro CV=0.4247 | F1 macro Test=0.4333 | ROC AUC OVR macro CV=0.6020 | ROC AUC OVR macro Test=0.6164 | AUCPR macro CV=0.4367 | AUCPR macro Test=0.4448
# Evaluating model: knn
# knn | Sampler=ros | ACC CV=0.5213 | ACC Train=0.6376 | ACC Test=0.5328 | F1 macro CV=0.3492 | F1 macro Test=0.3632 | ROC AUC OVR macro CV=0.6031 | ROC AUC OVR macro Test=0.6094 | AUCPR macro CV=0.4021 | AUCPR macro Test=0.4074
# Evaluating model: gaussian_nb
# gaussian_nb | Sampler=ros | ACC CV=0.5615 | ACC Train=0.6252 | ACC Test=0.5728 | F1 macro CV=0.4969 | F1 macro Test=0.5011 | ROC AUC OVR macro CV=0.7115 | ROC AUC OVR macro Test=0.7151 | AUCPR macro CV=0.5054 | AUCPR macro Test=0.5030
# Evaluating model: mlp3216
# mlp3216 | Sampler=ros | ACC CV=0.5328 | ACC Train=0.9999 | ACC Test=0.5449 | F1 macro CV=0.4695 | F1 macro Test=0.4797 | ROC AUC OVR macro CV=0.6395 | ROC AUC OVR macro Test=0.6567 | AUCPR macro CV=0.4669 | AUCPR macro Test=0.4812
# 	Evaluating with SMOTE sampler config: {0: 180, 2: 270}
#
# Evaluating model: decision_tree
# decision_tree | Sampler=smote | ACC CV=0.4573 | ACC Train=1.0000 | ACC Test=0.4575 | F1 macro CV=0.4024 | F1 macro Test=0.3983 | ROC AUC OVR macro CV=0.5542 | ROC AUC OVR macro Test=0.5522 | AUCPR macro CV=0.3636 | AUCPR macro Test=0.3608
# Evaluating model: random_forest
# random_forest | Sampler=smote | ACC CV=0.5527 | ACC Train=1.0000 | ACC Test=0.5589 | F1 macro CV=0.4130 | F1 macro Test=0.4277 | ROC AUC OVR macro CV=0.7301 | ROC AUC OVR macro Test=0.7399 | AUCPR macro CV=0.5334 | AUCPR macro Test=0.5419
# Evaluating model: extra_trees
# extra_trees | Sampler=smote | ACC CV=0.5649 | ACC Train=1.0000 | ACC Test=0.5812 | F1 macro CV=0.4457 | F1 macro Test=0.4646 | ROC AUC OVR macro CV=0.7333 | ROC AUC OVR macro Test=0.7489 | AUCPR macro CV=0.5360 | AUCPR macro Test=0.5513
# Evaluating model: xgboost
# xgboost | Sampler=smote | ACC CV=0.5617 | ACC Train=1.0000 | ACC Test=0.5627 | F1 macro CV=0.4786 | F1 macro Test=0.4857 | ROC AUC OVR macro CV=0.7171 | ROC AUC OVR macro Test=0.7225 | AUCPR macro CV=0.5208 | AUCPR macro Test=0.5263
# Evaluating model: adaboost
# adaboost | Sampler=smote | ACC CV=0.5568 | ACC Train=0.6664 | ACC Test=0.5777 | F1 macro CV=0.4711 | F1 macro Test=0.5041 | ROC AUC OVR macro CV=0.6949 | ROC AUC OVR macro Test=0.7107 | AUCPR macro CV=0.5093 | AUCPR macro Test=0.5220
# Evaluating model: svm
# svm | Sampler=smote | ACC CV=0.3013 | ACC Train=0.4952 | ACC Test=0.3192 | F1 macro CV=0.2600 | F1 macro Test=0.2812 | ROC AUC OVR macro CV=0.6651 | ROC AUC OVR macro Test=0.6878 | AUCPR macro CV=0.4861 | AUCPR macro Test=0.5083
# Evaluating model: logistic_regression
# logistic_regression | Sampler=smote | ACC CV=0.4529 | ACC Train=0.7731 | ACC Test=0.4436 | F1 macro CV=0.4257 | F1 macro Test=0.4302 | ROC AUC OVR macro CV=0.6013 | ROC AUC OVR macro Test=0.6156 | AUCPR macro CV=0.4362 | AUCPR macro Test=0.4430
# Evaluating model: knn
# knn | Sampler=smote | ACC CV=0.5145 | ACC Train=0.7283 | ACC Test=0.5206 | F1 macro CV=0.4107 | F1 macro Test=0.4257 | ROC AUC OVR macro CV=0.6261 | ROC AUC OVR macro Test=0.6319 | AUCPR macro CV=0.4213 | AUCPR macro Test=0.4280
# Evaluating model: gaussian_nb
# gaussian_nb | Sampler=smote | ACC CV=0.5648 | ACC Train=0.5878 | ACC Test=0.5735 | F1 macro CV=0.5019 | F1 macro Test=0.5053 | ROC AUC OVR macro CV=0.7136 | ROC AUC OVR macro Test=0.7199 | AUCPR macro CV=0.5125 | AUCPR macro Test=0.5156
# Evaluating model: mlp3216
# mlp3216 | Sampler=smote | ACC CV=0.5285 | ACC Train=1.0000 | ACC Test=0.5467 | F1 macro CV=0.4671 | F1 macro Test=0.4861 | ROC AUC OVR macro CV=0.6420 | ROC AUC OVR macro Test=0.6520 | AUCPR macro CV=0.4700 | AUCPR macro Test=0.4754
# 	Evaluating with ROS sampler config: {0: 200, 2: 290}
#
# Evaluating model: decision_tree
# decision_tree | Sampler=ros | ACC CV=0.4628 | ACC Train=1.0000 | ACC Test=0.4530 | F1 macro CV=0.4014 | F1 macro Test=0.4001 | ROC AUC OVR macro CV=0.5541 | ROC AUC OVR macro Test=0.5511 | AUCPR macro CV=0.3635 | AUCPR macro Test=0.3602
# Evaluating model: random_forest
# random_forest | Sampler=ros | ACC CV=0.5596 | ACC Train=1.0000 | ACC Test=0.5547 | F1 macro CV=0.4315 | F1 macro Test=0.4342 | ROC AUC OVR macro CV=0.7253 | ROC AUC OVR macro Test=0.7355 | AUCPR macro CV=0.5281 | AUCPR macro Test=0.5389
# Evaluating model: extra_trees
# extra_trees | Sampler=ros | ACC CV=0.5621 | ACC Train=1.0000 | ACC Test=0.5620 | F1 macro CV=0.4167 | F1 macro Test=0.4127 | ROC AUC OVR macro CV=0.7340 | ROC AUC OVR macro Test=0.7436 | AUCPR macro CV=0.5370 | AUCPR macro Test=0.5431
# Evaluating model: xgboost
# xgboost | Sampler=ros | ACC CV=0.5548 | ACC Train=1.0000 | ACC Test=0.5659 | F1 macro CV=0.4706 | F1 macro Test=0.4957 | ROC AUC OVR macro CV=0.7144 | ROC AUC OVR macro Test=0.7258 | AUCPR macro CV=0.5187 | AUCPR macro Test=0.5300
# Evaluating model: adaboost
# adaboost | Sampler=ros | ACC CV=0.5663 | ACC Train=0.6239 | ACC Test=0.5725 | F1 macro CV=0.4906 | F1 macro Test=0.5040 | ROC AUC OVR macro CV=0.6984 | ROC AUC OVR macro Test=0.7172 | AUCPR macro CV=0.5100 | AUCPR macro Test=0.5295
# Evaluating model: svm
# svm | Sampler=ros | ACC CV=0.3054 | ACC Train=0.5099 | ACC Test=0.3118 | F1 macro CV=0.2646 | F1 macro Test=0.2727 | ROC AUC OVR macro CV=0.6661 | ROC AUC OVR macro Test=0.6898 | AUCPR macro CV=0.4878 | AUCPR macro Test=0.5091
# Evaluating model: logistic_regression
# logistic_regression | Sampler=ros | ACC CV=0.4527 | ACC Train=0.7837 | ACC Test=0.4443 | F1 macro CV=0.4256 | F1 macro Test=0.4307 | ROC AUC OVR macro CV=0.6018 | ROC AUC OVR macro Test=0.6161 | AUCPR macro CV=0.4367 | AUCPR macro Test=0.4444
# Evaluating model: knn
# knn | Sampler=ros | ACC CV=0.5239 | ACC Train=0.6576 | ACC Test=0.5331 | F1 macro CV=0.3636 | F1 macro Test=0.3733 | ROC AUC OVR macro CV=0.6015 | ROC AUC OVR macro Test=0.6057 | AUCPR macro CV=0.4011 | AUCPR macro Test=0.4045
# Evaluating model: gaussian_nb
# gaussian_nb | Sampler=ros | ACC CV=0.5619 | ACC Train=0.6214 | ACC Test=0.5707 | F1 macro CV=0.4973 | F1 macro Test=0.4989 | ROC AUC OVR macro CV=0.7109 | ROC AUC OVR macro Test=0.7162 | AUCPR macro CV=0.5051 | AUCPR macro Test=0.5040
# Evaluating model: mlp3216
# mlp3216 | Sampler=ros | ACC CV=0.5305 | ACC Train=1.0000 | ACC Test=0.5366 | F1 macro CV=0.4703 | F1 macro Test=0.4736 | ROC AUC OVR macro CV=0.6372 | ROC AUC OVR macro Test=0.6497 | AUCPR macro CV=0.4650 | AUCPR macro Test=0.4767
# 	Evaluating with SMOTE sampler config: {0: 200, 2: 290}
#
# Evaluating model: decision_tree
# decision_tree | Sampler=smote | ACC CV=0.4547 | ACC Train=1.0000 | ACC Test=0.4571 | F1 macro CV=0.3983 | F1 macro Test=0.4067 | ROC AUC OVR macro CV=0.5521 | ROC AUC OVR macro Test=0.5579 | AUCPR macro CV=0.3614 | AUCPR macro Test=0.3645
# Evaluating model: random_forest
# random_forest | Sampler=smote | ACC CV=0.5558 | ACC Train=1.0000 | ACC Test=0.5624 | F1 macro CV=0.4244 | F1 macro Test=0.4487 | ROC AUC OVR macro CV=0.7288 | ROC AUC OVR macro Test=0.7386 | AUCPR macro CV=0.5329 | AUCPR macro Test=0.5483
# Evaluating model: extra_trees
# extra_trees | Sampler=smote | ACC CV=0.5714 | ACC Train=1.0000 | ACC Test=0.5791 | F1 macro CV=0.4544 | F1 macro Test=0.4763 | ROC AUC OVR macro CV=0.7341 | ROC AUC OVR macro Test=0.7452 | AUCPR macro CV=0.5364 | AUCPR macro Test=0.5446
# Evaluating model: xgboost
# xgboost | Sampler=smote | ACC CV=0.5569 | ACC Train=1.0000 | ACC Test=0.5697 | F1 macro CV=0.4732 | F1 macro Test=0.4941 | ROC AUC OVR macro CV=0.7168 | ROC AUC OVR macro Test=0.7289 | AUCPR macro CV=0.5215 | AUCPR macro Test=0.5293
# Evaluating model: adaboost
# adaboost | Sampler=smote | ACC CV=0.5601 | ACC Train=0.6706 | ACC Test=0.5774 | F1 macro CV=0.4806 | F1 macro Test=0.5108 | ROC AUC OVR macro CV=0.6955 | ROC AUC OVR macro Test=0.7049 | AUCPR macro CV=0.5082 | AUCPR macro Test=0.5215
# Evaluating model: svm
# svm | Sampler=smote | ACC CV=0.3005 | ACC Train=0.5165 | ACC Test=0.3199 | F1 macro CV=0.2600 | F1 macro Test=0.2810 | ROC AUC OVR macro CV=0.6644 | ROC AUC OVR macro Test=0.6871 | AUCPR macro CV=0.4864 | AUCPR macro Test=0.5069
# Evaluating model: logistic_regression
# logistic_regression | Sampler=smote | ACC CV=0.4530 | ACC Train=0.7821 | ACC Test=0.4429 | F1 macro CV=0.4259 | F1 macro Test=0.4291 | ROC AUC OVR macro CV=0.6012 | ROC AUC OVR macro Test=0.6152 | AUCPR macro CV=0.4363 | AUCPR macro Test=0.4432
# Evaluating model: knn
# knn | Sampler=smote | ACC CV=0.5084 | ACC Train=0.7507 | ACC Test=0.5098 | F1 macro CV=0.4194 | F1 macro Test=0.4267 | ROC AUC OVR macro CV=0.6307 | ROC AUC OVR macro Test=0.6326 | AUCPR macro CV=0.4250 | AUCPR macro Test=0.4249
# Evaluating model: gaussian_nb
# gaussian_nb | Sampler=smote | ACC CV=0.5654 | ACC Train=0.5737 | ACC Test=0.5718 | F1 macro CV=0.5027 | F1 macro Test=0.5024 | ROC AUC OVR macro CV=0.7125 | ROC AUC OVR macro Test=0.7195 | AUCPR macro CV=0.5134 | AUCPR macro Test=0.5191
# Evaluating model: mlp3216
# mlp3216 | Sampler=smote | ACC CV=0.5283 | ACC Train=1.0000 | ACC Test=0.5387 | F1 macro CV=0.4678 | F1 macro Test=0.4799 | ROC AUC OVR macro CV=0.6383 | ROC AUC OVR macro Test=0.6582 | AUCPR macro CV=0.4640 | AUCPR macro Test=0.4807
# 	Evaluating with ROS sampler config: {0: 220, 2: 310}
#
# Evaluating model: decision_tree
# decision_tree | Sampler=ros | ACC CV=0.4593 | ACC Train=1.0000 | ACC Test=0.4589 | F1 macro CV=0.3983 | F1 macro Test=0.4035 | ROC AUC OVR macro CV=0.5524 | ROC AUC OVR macro Test=0.5566 | AUCPR macro CV=0.3623 | AUCPR macro Test=0.3634
# Evaluating model: random_forest
# random_forest | Sampler=ros | ACC CV=0.5599 | ACC Train=1.0000 | ACC Test=0.5610 | F1 macro CV=0.4394 | F1 macro Test=0.4507 | ROC AUC OVR macro CV=0.7275 | ROC AUC OVR macro Test=0.7352 | AUCPR macro CV=0.5291 | AUCPR macro Test=0.5373
# Evaluating model: extra_trees
# extra_trees | Sampler=ros | ACC CV=0.5616 | ACC Train=1.0000 | ACC Test=0.5641 | F1 macro CV=0.4148 | F1 macro Test=0.4170 | ROC AUC OVR macro CV=0.7340 | ROC AUC OVR macro Test=0.7427 | AUCPR macro CV=0.5385 | AUCPR macro Test=0.5437
# Evaluating model: xgboost
# xgboost | Sampler=ros | ACC CV=0.5583 | ACC Train=1.0000 | ACC Test=0.5582 | F1 macro CV=0.4791 | F1 macro Test=0.4883 | ROC AUC OVR macro CV=0.7163 | ROC AUC OVR macro Test=0.7238 | AUCPR macro CV=0.5213 | AUCPR macro Test=0.5288
# Evaluating model: adaboost
# adaboost | Sampler=ros | ACC CV=0.5621 | ACC Train=0.6269 | ACC Test=0.5760 | F1 macro CV=0.4883 | F1 macro Test=0.5102 | ROC AUC OVR macro CV=0.6953 | ROC AUC OVR macro Test=0.7151 | AUCPR macro CV=0.5085 | AUCPR macro Test=0.5248
# Evaluating model: svm
# svm | Sampler=ros | ACC CV=0.3036 | ACC Train=0.5333 | ACC Test=0.3098 | F1 macro CV=0.2636 | F1 macro Test=0.2718 | ROC AUC OVR macro CV=0.6656 | ROC AUC OVR macro Test=0.6904 | AUCPR macro CV=0.4881 | AUCPR macro Test=0.5093
# Evaluating model: logistic_regression
# logistic_regression | Sampler=ros | ACC CV=0.4506 | ACC Train=0.7918 | ACC Test=0.4418 | F1 macro CV=0.4236 | F1 macro Test=0.4282 | ROC AUC OVR macro CV=0.6014 | ROC AUC OVR macro Test=0.6162 | AUCPR macro CV=0.4364 | AUCPR macro Test=0.4447
# Evaluating model: knn
# knn | Sampler=ros | ACC CV=0.5179 | ACC Train=0.6753 | ACC Test=0.5314 | F1 macro CV=0.3651 | F1 macro Test=0.3792 | ROC AUC OVR macro CV=0.5991 | ROC AUC OVR macro Test=0.6072 | AUCPR macro CV=0.3992 | AUCPR macro Test=0.4052
# Evaluating model: gaussian_nb
# gaussian_nb | Sampler=ros | ACC CV=0.5617 | ACC Train=0.6183 | ACC Test=0.5732 | F1 macro CV=0.4975 | F1 macro Test=0.5025 | ROC AUC OVR macro CV=0.7107 | ROC AUC OVR macro Test=0.7170 | AUCPR macro CV=0.5051 | AUCPR macro Test=0.5063
# Evaluating model: mlp3216
# mlp3216 | Sampler=ros | ACC CV=0.5349 | ACC Train=0.9999 | ACC Test=0.5429 | F1 macro CV=0.4755 | F1 macro Test=0.4826 | ROC AUC OVR macro CV=0.6478 | ROC AUC OVR macro Test=0.6493 | AUCPR macro CV=0.4740 | AUCPR macro Test=0.4748
# 	Evaluating with SMOTE sampler config: {0: 220, 2: 310}
#
# Evaluating model: decision_tree
# decision_tree | Sampler=smote | ACC CV=0.4638 | ACC Train=1.0000 | ACC Test=0.4568 | F1 macro CV=0.4065 | F1 macro Test=0.4061 | ROC AUC OVR macro CV=0.5578 | ROC AUC OVR macro Test=0.5583 | AUCPR macro CV=0.3655 | AUCPR macro Test=0.3647
# Evaluating model: random_forest
# random_forest | Sampler=smote | ACC CV=0.5570 | ACC Train=1.0000 | ACC Test=0.5544 | F1 macro CV=0.4308 | F1 macro Test=0.4353 | ROC AUC OVR macro CV=0.7294 | ROC AUC OVR macro Test=0.7346 | AUCPR macro CV=0.5337 | AUCPR macro Test=0.5365
# Evaluating model: extra_trees
# extra_trees | Sampler=smote | ACC CV=0.5760 | ACC Train=1.0000 | ACC Test=0.5850 | F1 macro CV=0.4662 | F1 macro Test=0.4893 | ROC AUC OVR macro CV=0.7353 | ROC AUC OVR macro Test=0.7490 | AUCPR macro CV=0.5378 | AUCPR macro Test=0.5489
# Evaluating model: xgboost
# xgboost | Sampler=smote | ACC CV=0.5617 | ACC Train=1.0000 | ACC Test=0.5530 | F1 macro CV=0.4810 | F1 macro Test=0.4768 | ROC AUC OVR macro CV=0.7186 | ROC AUC OVR macro Test=0.7222 | AUCPR macro CV=0.5230 | AUCPR macro Test=0.5268
# Evaluating model: adaboost
# adaboost | Sampler=smote | ACC CV=0.5540 | ACC Train=0.6935 | ACC Test=0.5676 | F1 macro CV=0.4730 | F1 macro Test=0.4986 | ROC AUC OVR macro CV=0.6896 | ROC AUC OVR macro Test=0.7080 | AUCPR macro CV=0.5066 | AUCPR macro Test=0.5258
# Evaluating model: svm
# svm | Sampler=smote | ACC CV=0.3039 | ACC Train=0.5358 | ACC Test=0.3178 | F1 macro CV=0.2643 | F1 macro Test=0.2785 | ROC AUC OVR macro CV=0.6629 | ROC AUC OVR macro Test=0.6867 | AUCPR macro CV=0.4858 | AUCPR macro Test=0.5084
# Evaluating model: logistic_regression
# logistic_regression | Sampler=smote | ACC CV=0.4514 | ACC Train=0.7912 | ACC Test=0.4432 | F1 macro CV=0.4250 | F1 macro Test=0.4301 | ROC AUC OVR macro CV=0.6006 | ROC AUC OVR macro Test=0.6152 | AUCPR macro CV=0.4356 | AUCPR macro Test=0.4425
# Evaluating model: knn
# knn | Sampler=smote | ACC CV=0.5024 | ACC Train=0.7696 | ACC Test=0.5077 | F1 macro CV=0.4250 | F1 macro Test=0.4402 | ROC AUC OVR macro CV=0.6284 | ROC AUC OVR macro Test=0.6341 | AUCPR macro CV=0.4229 | AUCPR macro Test=0.4286
# Evaluating model: gaussian_nb
# gaussian_nb | Sampler=smote | ACC CV=0.5674 | ACC Train=0.5691 | ACC Test=0.5714 | F1 macro CV=0.5044 | F1 macro Test=0.5015 | ROC AUC OVR macro CV=0.7124 | ROC AUC OVR macro Test=0.7171 | AUCPR macro CV=0.5145 | AUCPR macro Test=0.5170
# Evaluating model: mlp3216
# mlp3216 | Sampler=smote | ACC CV=0.5319 | ACC Train=1.0000 | ACC Test=0.5449 | F1 macro CV=0.4734 | F1 macro Test=0.4874 | ROC AUC OVR macro CV=0.6463 | ROC AUC OVR macro Test=0.6572 | AUCPR macro CV=0.4716 | AUCPR macro Test=0.4800

# %% [markdown]
# # REGULARIZED MODELS

# %% [markdown]
# ## MCID

# %%
data_df_ovr=[]
for val1,val2 in pairs_init_MCID:
    y = pd.read_csv(y_multiples_MCID[val2], index_col=0)
    print(f"Evaluating for target: {val2} with features: {val1}")
    X = pd.read_csv(X_multiples_MCID[val1], index_col=0)
    print(f"\tLoaded X shape: {X.shape}, y shape: {y.shape}")
    for pipeline_weight in classification_models_by_weight_reg_MCID:
        print(f"\tPipeline weight config: {pipeline_weight}")
        classification_models = classification_models_by_weight_reg_MCID[pipeline_weight]
        print(f"\tEvaluating multiclass classification for {val2} \n")
        results_df = evaluate_model_10x10_metrics_multiclass_sampler(
            model_dict=classification_models,
            X=X,
            y=y,
            n_outer=10,
            n_inner=10,
            test_size_outer=0.30,
            test_size_inner=0.30,
            random_state=42,
            cost_matrix=None,
            resampling_method=None,
            target_class_counts=None
        )
        results_df["weight_config"] = pipeline_weight
        results_df["feature_set"] = val1
        results_df["sampler_config"] = np.nan
        data_df_ovr.append(results_df)

        for sampler_dict in [{0:180, 2:270}, {0:200, 2:290}, {0:220, 2:310}]:
            print(f"\tEvaluating with ROS sampler config: {sampler_dict} \n")
            results_df_ros = evaluate_model_10x10_metrics_multiclass_sampler(
                model_dict=classification_models,
                X=X,
                y=y,
                n_inner=5,
                resampling_method="ros",
                target_class_counts=sampler_dict)
            
            results_df_ros["weight_config"] = pipeline_weight
            results_df_ros["feature_set"] = val1
            results_df_ros["sampler_config"] = f"ROS_{sampler_dict}"
            data_df_ovr.append(results_df_ros)
            
            print(f"\tEvaluating with SMOTE sampler config: {sampler_dict} \n")
            results_df_smote = evaluate_model_10x10_metrics_multiclass_sampler(
                        model_dict=classification_models,
                        X=X,
                        y=y,
                        n_inner=5,
                        resampling_method="smote",
                        target_class_counts=sampler_dict,
                        smote_k_neighbors=3)
            
            results_df_smote["weight_config"] = pipeline_weight
            results_df_smote["feature_set"] = val1
            results_df_smote["sampler_config"] = f"SMOTE_{sampler_dict}"
            data_df_ovr.append(results_df_smote)

final_results_df_ovr = pd.concat(data_df_ovr, ignore_index=True)
final_results_df_ovr.to_csv(output_path / "multiclass_classification_results_reg_MCID_v2.csv", index=False)
# Out:
# Evaluating for target: MCID_v2 with features: X_STATS_V2
# 	Loaded X shape: (956, 301), y shape: (956, 1)
# 	Pipeline weight config: balanced
# 	Evaluating multiclass classification for MCID_v2
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=None | ACC CV=0.4792 | ACC Train=0.5262 | ACC Test=0.4596 | F1 macro CV=0.4305 | F1 macro Test=0.4140 | ROC AUC OVR macro CV=0.6600 | ROC AUC OVR macro Test=0.6575 | AUCPR macro CV=0.4461 | AUCPR macro Test=0.4424
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=None | ACC CV=0.5395 | ACC Train=0.6903 | ACC Test=0.5408 | F1 macro CV=0.4644 | F1 macro Test=0.4653 | ROC AUC OVR macro CV=0.7103 | ROC AUC OVR macro Test=0.7129 | AUCPR macro CV=0.5078 | AUCPR macro Test=0.5038
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=None | ACC CV=0.5467 | ACC Train=0.6743 | ACC Test=0.5401 | F1 macro CV=0.4700 | F1 macro Test=0.4613 | ROC AUC OVR macro CV=0.7155 | ROC AUC OVR macro Test=0.7196 | AUCPR macro CV=0.5128 | AUCPR macro Test=0.5129
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=None | ACC CV=0.5784 | ACC Train=0.6185 | ACC Test=0.5847 | F1 macro CV=0.4030 | F1 macro Test=0.4100 | ROC AUC OVR macro CV=0.7120 | ROC AUC OVR macro Test=0.7112 | AUCPR macro CV=0.5095 | AUCPR macro Test=0.5023
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=None | ACC CV=0.5821 | ACC Train=0.5952 | ACC Test=0.5822 | F1 macro CV=0.4165 | F1 macro Test=0.4184 | ROC AUC OVR macro CV=0.7095 | ROC AUC OVR macro Test=0.7089 | AUCPR macro CV=0.4954 | AUCPR macro Test=0.4902
# Evaluating model: svm_reg
# svm_reg | Sampler=None | ACC CV=0.5606 | ACC Train=0.5800 | ACC Test=0.4895 | F1 macro CV=0.4279 | F1 macro Test=0.4156 | ROC AUC OVR macro CV=0.7128 | ROC AUC OVR macro Test=0.7186 | AUCPR macro CV=0.5126 | AUCPR macro Test=0.5133
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=None | ACC CV=0.5256 | ACC Train=0.7626 | ACC Test=0.5167 | F1 macro CV=0.4430 | F1 macro Test=0.4306 | ROC AUC OVR macro CV=0.6337 | ROC AUC OVR macro Test=0.6293 | AUCPR macro CV=0.4593 | AUCPR macro Test=0.4543
# Evaluating model: knn_reg
# knn_reg | Sampler=None | ACC CV=0.5619 | ACC Train=1.0000 | ACC Test=0.5652 | F1 macro CV=0.3915 | F1 macro Test=0.3963 | ROC AUC OVR macro CV=0.7005 | ROC AUC OVR macro Test=0.7114 | AUCPR macro CV=0.5010 | AUCPR macro Test=0.5074
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=None | ACC CV=0.5455 | ACC Train=0.6060 | ACC Test=0.5439 | F1 macro CV=0.4656 | F1 macro Test=0.4586 | ROC AUC OVR macro CV=0.6890 | ROC AUC OVR macro Test=0.6888 | AUCPR macro CV=0.4738 | AUCPR macro Test=0.4704
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=None | ACC CV=0.5368 | ACC Train=0.6638 | ACC Test=0.5199 | F1 macro CV=0.4700 | F1 macro Test=0.4417 | ROC AUC OVR macro CV=0.6849 | ROC AUC OVR macro Test=0.6700 | AUCPR macro CV=0.4995 | AUCPR macro Test=0.4790
# 	Evaluating with ROS sampler config: {0: 180, 2: 270}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.4586 | ACC Train=0.5335 | ACC Test=0.4603 | F1 macro CV=0.4136 | F1 macro Test=0.4147 | ROC AUC OVR macro CV=0.6542 | ROC AUC OVR macro Test=0.6590 | AUCPR macro CV=0.4431 | AUCPR macro Test=0.4432
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.5318 | ACC Train=0.7006 | ACC Test=0.5387 | F1 macro CV=0.4619 | F1 macro Test=0.4712 | ROC AUC OVR macro CV=0.7061 | ROC AUC OVR macro Test=0.7137 | AUCPR macro CV=0.5032 | AUCPR macro Test=0.5097
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.5412 | ACC Train=0.6914 | ACC Test=0.5463 | F1 macro CV=0.4684 | F1 macro Test=0.4721 | ROC AUC OVR macro CV=0.7105 | ROC AUC OVR macro Test=0.7194 | AUCPR macro CV=0.5101 | AUCPR macro Test=0.5146
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.5777 | ACC Train=0.6431 | ACC Test=0.5791 | F1 macro CV=0.4290 | F1 macro Test=0.4367 | ROC AUC OVR macro CV=0.7041 | ROC AUC OVR macro Test=0.7086 | AUCPR macro CV=0.5005 | AUCPR macro Test=0.5047
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.5824 | ACC Train=0.5711 | ACC Test=0.5815 | F1 macro CV=0.4216 | F1 macro Test=0.4239 | ROC AUC OVR macro CV=0.7060 | ROC AUC OVR macro Test=0.7081 | AUCPR macro CV=0.4960 | AUCPR macro Test=0.4935
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.5138 | ACC Train=0.6206 | ACC Test=0.5195 | F1 macro CV=0.4461 | F1 macro Test=0.4564 | ROC AUC OVR macro CV=0.7123 | ROC AUC OVR macro Test=0.7164 | AUCPR macro CV=0.5136 | AUCPR macro Test=0.5113
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.5204 | ACC Train=0.7677 | ACC Test=0.5125 | F1 macro CV=0.4413 | F1 macro Test=0.4369 | ROC AUC OVR macro CV=0.6264 | ROC AUC OVR macro Test=0.6216 | AUCPR macro CV=0.4542 | AUCPR macro Test=0.4524
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.5619 | ACC Train=1.0000 | ACC Test=0.5767 | F1 macro CV=0.4284 | F1 macro Test=0.4528 | ROC AUC OVR macro CV=0.6932 | ROC AUC OVR macro Test=0.7068 | AUCPR macro CV=0.4938 | AUCPR macro Test=0.5035
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.5438 | ACC Train=0.5862 | ACC Test=0.5523 | F1 macro CV=0.4651 | F1 macro Test=0.4683 | ROC AUC OVR macro CV=0.6850 | ROC AUC OVR macro Test=0.6882 | AUCPR macro CV=0.4714 | AUCPR macro Test=0.4718
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.5358 | ACC Train=0.7538 | ACC Test=0.5230 | F1 macro CV=0.4679 | F1 macro Test=0.4516 | ROC AUC OVR macro CV=0.6772 | ROC AUC OVR macro Test=0.6561 | AUCPR macro CV=0.4901 | AUCPR macro Test=0.4666
# 	Evaluating with SMOTE sampler config: {0: 180, 2: 270}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.4817 | ACC Train=0.5494 | ACC Test=0.4882 | F1 macro CV=0.4313 | F1 macro Test=0.4235 | ROC AUC OVR macro CV=0.6543 | ROC AUC OVR macro Test=0.6579 | AUCPR macro CV=0.4418 | AUCPR macro Test=0.4413
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.5378 | ACC Train=0.7244 | ACC Test=0.5300 | F1 macro CV=0.4680 | F1 macro Test=0.4567 | ROC AUC OVR macro CV=0.7078 | ROC AUC OVR macro Test=0.7109 | AUCPR macro CV=0.5048 | AUCPR macro Test=0.5054
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.5369 | ACC Train=0.6843 | ACC Test=0.5397 | F1 macro CV=0.4660 | F1 macro Test=0.4635 | ROC AUC OVR macro CV=0.7102 | ROC AUC OVR macro Test=0.7189 | AUCPR macro CV=0.5086 | AUCPR macro Test=0.5138
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.5696 | ACC Train=0.6897 | ACC Test=0.5697 | F1 macro CV=0.4298 | F1 macro Test=0.4342 | ROC AUC OVR macro CV=0.7013 | ROC AUC OVR macro Test=0.7027 | AUCPR macro CV=0.4985 | AUCPR macro Test=0.4957
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.5783 | ACC Train=0.5763 | ACC Test=0.5812 | F1 macro CV=0.4188 | F1 macro Test=0.4219 | ROC AUC OVR macro CV=0.7082 | ROC AUC OVR macro Test=0.7119 | AUCPR macro CV=0.5027 | AUCPR macro Test=0.4960
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.5167 | ACC Train=0.6239 | ACC Test=0.5233 | F1 macro CV=0.4467 | F1 macro Test=0.4627 | ROC AUC OVR macro CV=0.7127 | ROC AUC OVR macro Test=0.7174 | AUCPR macro CV=0.5144 | AUCPR macro Test=0.5151
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.5175 | ACC Train=0.7673 | ACC Test=0.5115 | F1 macro CV=0.4397 | F1 macro Test=0.4354 | ROC AUC OVR macro CV=0.6227 | ROC AUC OVR macro Test=0.6196 | AUCPR macro CV=0.4506 | AUCPR macro Test=0.4490
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.5633 | ACC Train=1.0000 | ACC Test=0.5693 | F1 macro CV=0.4645 | F1 macro Test=0.4740 | ROC AUC OVR macro CV=0.6949 | ROC AUC OVR macro Test=0.7023 | AUCPR macro CV=0.4958 | AUCPR macro Test=0.4972
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.5451 | ACC Train=0.5794 | ACC Test=0.5491 | F1 macro CV=0.4706 | F1 macro Test=0.4682 | ROC AUC OVR macro CV=0.6848 | ROC AUC OVR macro Test=0.6850 | AUCPR macro CV=0.4730 | AUCPR macro Test=0.4706
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.5313 | ACC Train=0.7604 | ACC Test=0.5101 | F1 macro CV=0.4605 | F1 macro Test=0.4366 | ROC AUC OVR macro CV=0.6720 | ROC AUC OVR macro Test=0.6498 | AUCPR macro CV=0.4850 | AUCPR macro Test=0.4648
# 	Evaluating with ROS sampler config: {0: 200, 2: 290}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.4631 | ACC Train=0.5162 | ACC Test=0.4443 | F1 macro CV=0.4189 | F1 macro Test=0.4111 | ROC AUC OVR macro CV=0.6506 | ROC AUC OVR macro Test=0.6585 | AUCPR macro CV=0.4407 | AUCPR macro Test=0.4437
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.5301 | ACC Train=0.7087 | ACC Test=0.5390 | F1 macro CV=0.4599 | F1 macro Test=0.4718 | ROC AUC OVR macro CV=0.7059 | ROC AUC OVR macro Test=0.7131 | AUCPR macro CV=0.5040 | AUCPR macro Test=0.5102
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.5403 | ACC Train=0.6893 | ACC Test=0.5418 | F1 macro CV=0.4687 | F1 macro Test=0.4694 | ROC AUC OVR macro CV=0.7109 | ROC AUC OVR macro Test=0.7203 | AUCPR macro CV=0.5084 | AUCPR macro Test=0.5156
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.5731 | ACC Train=0.6551 | ACC Test=0.5666 | F1 macro CV=0.4441 | F1 macro Test=0.4311 | ROC AUC OVR macro CV=0.7018 | ROC AUC OVR macro Test=0.7074 | AUCPR macro CV=0.4987 | AUCPR macro Test=0.5012
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.5815 | ACC Train=0.5618 | ACC Test=0.5791 | F1 macro CV=0.4216 | F1 macro Test=0.4224 | ROC AUC OVR macro CV=0.7057 | ROC AUC OVR macro Test=0.7068 | AUCPR macro CV=0.4946 | AUCPR macro Test=0.4917
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.5479 | ACC Train=0.6403 | ACC Test=0.5303 | F1 macro CV=0.4568 | F1 macro Test=0.4720 | ROC AUC OVR macro CV=0.7129 | ROC AUC OVR macro Test=0.7156 | AUCPR macro CV=0.5148 | AUCPR macro Test=0.5140
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.5192 | ACC Train=0.7702 | ACC Test=0.5077 | F1 macro CV=0.4420 | F1 macro Test=0.4316 | ROC AUC OVR macro CV=0.6243 | ROC AUC OVR macro Test=0.6190 | AUCPR macro CV=0.4534 | AUCPR macro Test=0.4510
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.5606 | ACC Train=1.0000 | ACC Test=0.5777 | F1 macro CV=0.4405 | F1 macro Test=0.4616 | ROC AUC OVR macro CV=0.6911 | ROC AUC OVR macro Test=0.7032 | AUCPR macro CV=0.4916 | AUCPR macro Test=0.5014
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.5417 | ACC Train=0.5825 | ACC Test=0.5491 | F1 macro CV=0.4635 | F1 macro Test=0.4669 | ROC AUC OVR macro CV=0.6845 | ROC AUC OVR macro Test=0.6884 | AUCPR macro CV=0.4709 | AUCPR macro Test=0.4723
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.5324 | ACC Train=0.7871 | ACC Test=0.5167 | F1 macro CV=0.4627 | F1 macro Test=0.4444 | ROC AUC OVR macro CV=0.6741 | ROC AUC OVR macro Test=0.6485 | AUCPR macro CV=0.4878 | AUCPR macro Test=0.4642
# 	Evaluating with SMOTE sampler config: {0: 200, 2: 290}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.4744 | ACC Train=0.5563 | ACC Test=0.4969 | F1 macro CV=0.4229 | F1 macro Test=0.4280 | ROC AUC OVR macro CV=0.6501 | ROC AUC OVR macro Test=0.6589 | AUCPR macro CV=0.4376 | AUCPR macro Test=0.4437
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.5371 | ACC Train=0.7284 | ACC Test=0.5338 | F1 macro CV=0.4658 | F1 macro Test=0.4599 | ROC AUC OVR macro CV=0.7061 | ROC AUC OVR macro Test=0.7104 | AUCPR macro CV=0.5036 | AUCPR macro Test=0.5047
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.5381 | ACC Train=0.6884 | ACC Test=0.5366 | F1 macro CV=0.4669 | F1 macro Test=0.4592 | ROC AUC OVR macro CV=0.7112 | ROC AUC OVR macro Test=0.7176 | AUCPR macro CV=0.5069 | AUCPR macro Test=0.5130
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.5640 | ACC Train=0.7198 | ACC Test=0.5603 | F1 macro CV=0.4372 | F1 macro Test=0.4337 | ROC AUC OVR macro CV=0.6991 | ROC AUC OVR macro Test=0.7022 | AUCPR macro CV=0.4953 | AUCPR macro Test=0.4971
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.5774 | ACC Train=0.5672 | ACC Test=0.5787 | F1 macro CV=0.4180 | F1 macro Test=0.4199 | ROC AUC OVR macro CV=0.7086 | ROC AUC OVR macro Test=0.7101 | AUCPR macro CV=0.5021 | AUCPR macro Test=0.4960
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.5366 | ACC Train=0.6242 | ACC Test=0.5233 | F1 macro CV=0.4542 | F1 macro Test=0.4591 | ROC AUC OVR macro CV=0.7131 | ROC AUC OVR macro Test=0.7153 | AUCPR macro CV=0.5128 | AUCPR macro Test=0.5191
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.5177 | ACC Train=0.7697 | ACC Test=0.5049 | F1 macro CV=0.4417 | F1 macro Test=0.4272 | ROC AUC OVR macro CV=0.6201 | ROC AUC OVR macro Test=0.6143 | AUCPR macro CV=0.4486 | AUCPR macro Test=0.4456
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.5531 | ACC Train=1.0000 | ACC Test=0.5627 | F1 macro CV=0.4703 | F1 macro Test=0.4809 | ROC AUC OVR macro CV=0.6924 | ROC AUC OVR macro Test=0.7029 | AUCPR macro CV=0.4923 | AUCPR macro Test=0.4997
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.5456 | ACC Train=0.5724 | ACC Test=0.5519 | F1 macro CV=0.4719 | F1 macro Test=0.4725 | ROC AUC OVR macro CV=0.6836 | ROC AUC OVR macro Test=0.6844 | AUCPR macro CV=0.4736 | AUCPR macro Test=0.4714
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.5295 | ACC Train=0.7727 | ACC Test=0.5031 | F1 macro CV=0.4603 | F1 macro Test=0.4368 | ROC AUC OVR macro CV=0.6636 | ROC AUC OVR macro Test=0.6399 | AUCPR macro CV=0.4806 | AUCPR macro Test=0.4561
# 	Evaluating with ROS sampler config: {0: 220, 2: 310}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.4713 | ACC Train=0.5350 | ACC Test=0.4547 | F1 macro CV=0.4192 | F1 macro Test=0.4156 | ROC AUC OVR macro CV=0.6525 | ROC AUC OVR macro Test=0.6567 | AUCPR macro CV=0.4411 | AUCPR macro Test=0.4409
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.5345 | ACC Train=0.7097 | ACC Test=0.5334 | F1 macro CV=0.4667 | F1 macro Test=0.4688 | ROC AUC OVR macro CV=0.7059 | ROC AUC OVR macro Test=0.7113 | AUCPR macro CV=0.5045 | AUCPR macro Test=0.5097
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.5381 | ACC Train=0.6929 | ACC Test=0.5422 | F1 macro CV=0.4652 | F1 macro Test=0.4698 | ROC AUC OVR macro CV=0.7118 | ROC AUC OVR macro Test=0.7195 | AUCPR macro CV=0.5090 | AUCPR macro Test=0.5151
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.5675 | ACC Train=0.6753 | ACC Test=0.5589 | F1 macro CV=0.4462 | F1 macro Test=0.4382 | ROC AUC OVR macro CV=0.7012 | ROC AUC OVR macro Test=0.7049 | AUCPR macro CV=0.4975 | AUCPR macro Test=0.4990
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.5798 | ACC Train=0.5558 | ACC Test=0.5784 | F1 macro CV=0.4213 | F1 macro Test=0.4220 | ROC AUC OVR macro CV=0.7052 | ROC AUC OVR macro Test=0.7039 | AUCPR macro CV=0.4962 | AUCPR macro Test=0.4886
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.5417 | ACC Train=0.6409 | ACC Test=0.5230 | F1 macro CV=0.4612 | F1 macro Test=0.4634 | ROC AUC OVR macro CV=0.7125 | ROC AUC OVR macro Test=0.7150 | AUCPR macro CV=0.5154 | AUCPR macro Test=0.5141
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.5159 | ACC Train=0.7735 | ACC Test=0.5028 | F1 macro CV=0.4396 | F1 macro Test=0.4263 | ROC AUC OVR macro CV=0.6220 | ROC AUC OVR macro Test=0.6174 | AUCPR macro CV=0.4508 | AUCPR macro Test=0.4488
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.5588 | ACC Train=1.0000 | ACC Test=0.5714 | F1 macro CV=0.4479 | F1 macro Test=0.4615 | ROC AUC OVR macro CV=0.6897 | ROC AUC OVR macro Test=0.7025 | AUCPR macro CV=0.4924 | AUCPR macro Test=0.5025
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.5428 | ACC Train=0.5738 | ACC Test=0.5474 | F1 macro CV=0.4657 | F1 macro Test=0.4637 | ROC AUC OVR macro CV=0.6844 | ROC AUC OVR macro Test=0.6889 | AUCPR macro CV=0.4704 | AUCPR macro Test=0.4718
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.5288 | ACC Train=0.7976 | ACC Test=0.5045 | F1 macro CV=0.4623 | F1 macro Test=0.4320 | ROC AUC OVR macro CV=0.6669 | ROC AUC OVR macro Test=0.6385 | AUCPR macro CV=0.4807 | AUCPR macro Test=0.4572
# 	Evaluating with SMOTE sampler config: {0: 220, 2: 310}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.4847 | ACC Train=0.5521 | ACC Test=0.5021 | F1 macro CV=0.4255 | F1 macro Test=0.4246 | ROC AUC OVR macro CV=0.6535 | ROC AUC OVR macro Test=0.6631 | AUCPR macro CV=0.4421 | AUCPR macro Test=0.4461
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.5386 | ACC Train=0.7293 | ACC Test=0.5279 | F1 macro CV=0.4661 | F1 macro Test=0.4532 | ROC AUC OVR macro CV=0.7068 | ROC AUC OVR macro Test=0.7079 | AUCPR macro CV=0.5048 | AUCPR macro Test=0.5026
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.5409 | ACC Train=0.6883 | ACC Test=0.5429 | F1 macro CV=0.4692 | F1 macro Test=0.4671 | ROC AUC OVR macro CV=0.7112 | ROC AUC OVR macro Test=0.7183 | AUCPR macro CV=0.5099 | AUCPR macro Test=0.5141
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.5612 | ACC Train=0.7404 | ACC Test=0.5568 | F1 macro CV=0.4447 | F1 macro Test=0.4349 | ROC AUC OVR macro CV=0.6987 | ROC AUC OVR macro Test=0.6988 | AUCPR macro CV=0.4951 | AUCPR macro Test=0.4939
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.5789 | ACC Train=0.5604 | ACC Test=0.5801 | F1 macro CV=0.4208 | F1 macro Test=0.4232 | ROC AUC OVR macro CV=0.7069 | ROC AUC OVR macro Test=0.7073 | AUCPR macro CV=0.4999 | AUCPR macro Test=0.4936
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.5346 | ACC Train=0.6232 | ACC Test=0.5247 | F1 macro CV=0.4533 | F1 macro Test=0.4586 | ROC AUC OVR macro CV=0.7118 | ROC AUC OVR macro Test=0.7140 | AUCPR macro CV=0.5140 | AUCPR macro Test=0.5184
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.5163 | ACC Train=0.7705 | ACC Test=0.5021 | F1 macro CV=0.4419 | F1 macro Test=0.4284 | ROC AUC OVR macro CV=0.6174 | ROC AUC OVR macro Test=0.6127 | AUCPR macro CV=0.4472 | AUCPR macro Test=0.4448
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.5488 | ACC Train=1.0000 | ACC Test=0.5634 | F1 macro CV=0.4743 | F1 macro Test=0.4947 | ROC AUC OVR macro CV=0.6893 | ROC AUC OVR macro Test=0.7019 | AUCPR macro CV=0.4913 | AUCPR macro Test=0.5013
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.5464 | ACC Train=0.5685 | ACC Test=0.5512 | F1 macro CV=0.4742 | F1 macro Test=0.4718 | ROC AUC OVR macro CV=0.6833 | ROC AUC OVR macro Test=0.6851 | AUCPR macro CV=0.4742 | AUCPR macro Test=0.4714
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.5236 | ACC Train=0.8090 | ACC Test=0.5017 | F1 macro CV=0.4569 | F1 macro Test=0.4364 | ROC AUC OVR macro CV=0.6593 | ROC AUC OVR macro Test=0.6301 | AUCPR macro CV=0.4765 | AUCPR macro Test=0.4517
# 	Pipeline weight config: w_c2_10
# 	Evaluating multiclass classification for MCID_v2
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=None | ACC CV=0.2911 | ACC Train=0.3000 | ACC Test=0.2906 | F1 macro CV=0.2188 | F1 macro Test=0.1696 | ROC AUC OVR macro CV=0.6058 | ROC AUC OVR macro Test=0.6327 | AUCPR macro CV=0.4182 | AUCPR macro Test=0.4267
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=None | ACC CV=0.2937 | ACC Train=0.3269 | ACC Test=0.2930 | F1 macro CV=0.1768 | F1 macro Test=0.1663 | ROC AUC OVR macro CV=0.6764 | ROC AUC OVR macro Test=0.6873 | AUCPR macro CV=0.4904 | AUCPR macro Test=0.4962
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=None | ACC CV=0.2933 | ACC Train=0.2978 | ACC Test=0.2927 | F1 macro CV=0.1573 | F1 macro Test=0.1523 | ROC AUC OVR macro CV=0.6889 | ROC AUC OVR macro Test=0.7008 | AUCPR macro CV=0.4991 | AUCPR macro Test=0.5047
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=None | ACC CV=0.5784 | ACC Train=0.6185 | ACC Test=0.5847 | F1 macro CV=0.4030 | F1 macro Test=0.4100 | ROC AUC OVR macro CV=0.7120 | ROC AUC OVR macro Test=0.7112 | AUCPR macro CV=0.5095 | AUCPR macro Test=0.5023
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=None | ACC CV=0.5821 | ACC Train=0.5952 | ACC Test=0.5822 | F1 macro CV=0.4165 | F1 macro Test=0.4184 | ROC AUC OVR macro CV=0.7095 | ROC AUC OVR macro Test=0.7089 | AUCPR macro CV=0.4954 | AUCPR macro Test=0.4902
# Evaluating model: svm_reg
# svm_reg | Sampler=None | ACC CV=0.2825 | ACC Train=0.4590 | ACC Test=0.2749 | F1 macro CV=0.2100 | F1 macro Test=0.2029 | ROC AUC OVR macro CV=0.6932 | ROC AUC OVR macro Test=0.6832 | AUCPR macro CV=0.4918 | AUCPR macro Test=0.4811
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=None | ACC CV=0.4940 | ACC Train=0.7326 | ACC Test=0.4819 | F1 macro CV=0.4370 | F1 macro Test=0.4286 | ROC AUC OVR macro CV=0.6124 | ROC AUC OVR macro Test=0.6074 | AUCPR macro CV=0.4409 | AUCPR macro Test=0.4371
# Evaluating model: knn_reg
# knn_reg | Sampler=None | ACC CV=0.5619 | ACC Train=1.0000 | ACC Test=0.5652 | F1 macro CV=0.3915 | F1 macro Test=0.3963 | ROC AUC OVR macro CV=0.7005 | ROC AUC OVR macro Test=0.7114 | AUCPR macro CV=0.5010 | AUCPR macro Test=0.5074
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=None | ACC CV=0.5455 | ACC Train=0.6060 | ACC Test=0.5439 | F1 macro CV=0.4656 | F1 macro Test=0.4586 | ROC AUC OVR macro CV=0.6890 | ROC AUC OVR macro Test=0.6888 | AUCPR macro CV=0.4738 | AUCPR macro Test=0.4704
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=None | ACC CV=0.5368 | ACC Train=0.6638 | ACC Test=0.5199 | F1 macro CV=0.4700 | F1 macro Test=0.4417 | ROC AUC OVR macro CV=0.6849 | ROC AUC OVR macro Test=0.6700 | AUCPR macro CV=0.4995 | AUCPR macro Test=0.4790
# 	Evaluating with ROS sampler config: {0: 180, 2: 270}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.2588 | ACC Train=0.3538 | ACC Test=0.2711 | F1 macro CV=0.2067 | F1 macro Test=0.1877 | ROC AUC OVR macro CV=0.5663 | ROC AUC OVR macro Test=0.5809 | AUCPR macro CV=0.3961 | AUCPR macro Test=0.4010
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.2802 | ACC Train=0.4239 | ACC Test=0.2857 | F1 macro CV=0.1785 | F1 macro Test=0.1725 | ROC AUC OVR macro CV=0.6345 | ROC AUC OVR macro Test=0.6584 | AUCPR macro CV=0.4743 | AUCPR macro Test=0.4896
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.2904 | ACC Train=0.3791 | ACC Test=0.2930 | F1 macro CV=0.1647 | F1 macro Test=0.1581 | ROC AUC OVR macro CV=0.6508 | ROC AUC OVR macro Test=0.6698 | AUCPR macro CV=0.4839 | AUCPR macro Test=0.4959
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.5777 | ACC Train=0.6431 | ACC Test=0.5791 | F1 macro CV=0.4290 | F1 macro Test=0.4367 | ROC AUC OVR macro CV=0.7041 | ROC AUC OVR macro Test=0.7086 | AUCPR macro CV=0.5005 | AUCPR macro Test=0.5047
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.5824 | ACC Train=0.5711 | ACC Test=0.5815 | F1 macro CV=0.4216 | F1 macro Test=0.4239 | ROC AUC OVR macro CV=0.7060 | ROC AUC OVR macro Test=0.7081 | AUCPR macro CV=0.4960 | AUCPR macro Test=0.4935
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.2756 | ACC Train=0.5476 | ACC Test=0.2704 | F1 macro CV=0.2158 | F1 macro Test=0.2131 | ROC AUC OVR macro CV=0.6725 | ROC AUC OVR macro Test=0.6672 | AUCPR macro CV=0.4737 | AUCPR macro Test=0.4734
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.4761 | ACC Train=0.7422 | ACC Test=0.4638 | F1 macro CV=0.4293 | F1 macro Test=0.4235 | ROC AUC OVR macro CV=0.6066 | ROC AUC OVR macro Test=0.5995 | AUCPR macro CV=0.4368 | AUCPR macro Test=0.4327
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.5619 | ACC Train=1.0000 | ACC Test=0.5767 | F1 macro CV=0.4284 | F1 macro Test=0.4528 | ROC AUC OVR macro CV=0.6932 | ROC AUC OVR macro Test=0.7068 | AUCPR macro CV=0.4938 | AUCPR macro Test=0.5035
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.5438 | ACC Train=0.5862 | ACC Test=0.5523 | F1 macro CV=0.4651 | F1 macro Test=0.4683 | ROC AUC OVR macro CV=0.6850 | ROC AUC OVR macro Test=0.6882 | AUCPR macro CV=0.4714 | AUCPR macro Test=0.4718
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.5358 | ACC Train=0.7538 | ACC Test=0.5230 | F1 macro CV=0.4679 | F1 macro Test=0.4516 | ROC AUC OVR macro CV=0.6772 | ROC AUC OVR macro Test=0.6561 | AUCPR macro CV=0.4901 | AUCPR macro Test=0.4666
# 	Evaluating with SMOTE sampler config: {0: 180, 2: 270}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.2710 | ACC Train=0.3665 | ACC Test=0.2711 | F1 macro CV=0.2107 | F1 macro Test=0.1988 | ROC AUC OVR macro CV=0.5717 | ROC AUC OVR macro Test=0.5842 | AUCPR macro CV=0.4010 | AUCPR macro Test=0.4011
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.2826 | ACC Train=0.4464 | ACC Test=0.2878 | F1 macro CV=0.1807 | F1 macro Test=0.1827 | ROC AUC OVR macro CV=0.6475 | ROC AUC OVR macro Test=0.6614 | AUCPR macro CV=0.4760 | AUCPR macro Test=0.4893
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.2901 | ACC Train=0.3680 | ACC Test=0.2916 | F1 macro CV=0.1631 | F1 macro Test=0.1578 | ROC AUC OVR macro CV=0.6543 | ROC AUC OVR macro Test=0.6762 | AUCPR macro CV=0.4812 | AUCPR macro Test=0.4973
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.5696 | ACC Train=0.6897 | ACC Test=0.5697 | F1 macro CV=0.4298 | F1 macro Test=0.4342 | ROC AUC OVR macro CV=0.7013 | ROC AUC OVR macro Test=0.7027 | AUCPR macro CV=0.4985 | AUCPR macro Test=0.4957
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.5783 | ACC Train=0.5763 | ACC Test=0.5812 | F1 macro CV=0.4188 | F1 macro Test=0.4219 | ROC AUC OVR macro CV=0.7082 | ROC AUC OVR macro Test=0.7119 | AUCPR macro CV=0.5027 | AUCPR macro Test=0.4960
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.2763 | ACC Train=0.5489 | ACC Test=0.2648 | F1 macro CV=0.2180 | F1 macro Test=0.2050 | ROC AUC OVR macro CV=0.6678 | ROC AUC OVR macro Test=0.6554 | AUCPR macro CV=0.4700 | AUCPR macro Test=0.4641
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.4752 | ACC Train=0.7457 | ACC Test=0.4544 | F1 macro CV=0.4291 | F1 macro Test=0.4162 | ROC AUC OVR macro CV=0.6043 | ROC AUC OVR macro Test=0.5992 | AUCPR macro CV=0.4356 | AUCPR macro Test=0.4322
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.5633 | ACC Train=1.0000 | ACC Test=0.5693 | F1 macro CV=0.4645 | F1 macro Test=0.4740 | ROC AUC OVR macro CV=0.6949 | ROC AUC OVR macro Test=0.7023 | AUCPR macro CV=0.4958 | AUCPR macro Test=0.4972
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.5451 | ACC Train=0.5794 | ACC Test=0.5491 | F1 macro CV=0.4706 | F1 macro Test=0.4682 | ROC AUC OVR macro CV=0.6848 | ROC AUC OVR macro Test=0.6850 | AUCPR macro CV=0.4730 | AUCPR macro Test=0.4706
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.5313 | ACC Train=0.7604 | ACC Test=0.5101 | F1 macro CV=0.4605 | F1 macro Test=0.4366 | ROC AUC OVR macro CV=0.6720 | ROC AUC OVR macro Test=0.6498 | AUCPR macro CV=0.4850 | AUCPR macro Test=0.4648
# 	Evaluating with ROS sampler config: {0: 200, 2: 290}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.2579 | ACC Train=0.3728 | ACC Test=0.2669 | F1 macro CV=0.2040 | F1 macro Test=0.2063 | ROC AUC OVR macro CV=0.5513 | ROC AUC OVR macro Test=0.5729 | AUCPR macro CV=0.3843 | AUCPR macro Test=0.3993
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.2787 | ACC Train=0.4500 | ACC Test=0.2875 | F1 macro CV=0.1833 | F1 macro Test=0.1806 | ROC AUC OVR macro CV=0.6310 | ROC AUC OVR macro Test=0.6478 | AUCPR macro CV=0.4721 | AUCPR macro Test=0.4862
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.2884 | ACC Train=0.4026 | ACC Test=0.2909 | F1 macro CV=0.1693 | F1 macro Test=0.1627 | ROC AUC OVR macro CV=0.6469 | ROC AUC OVR macro Test=0.6662 | AUCPR macro CV=0.4804 | AUCPR macro Test=0.4926
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.5731 | ACC Train=0.6551 | ACC Test=0.5666 | F1 macro CV=0.4441 | F1 macro Test=0.4311 | ROC AUC OVR macro CV=0.7018 | ROC AUC OVR macro Test=0.7074 | AUCPR macro CV=0.4987 | AUCPR macro Test=0.5012
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.5815 | ACC Train=0.5618 | ACC Test=0.5791 | F1 macro CV=0.4216 | F1 macro Test=0.4224 | ROC AUC OVR macro CV=0.7057 | ROC AUC OVR macro Test=0.7068 | AUCPR macro CV=0.4946 | AUCPR macro Test=0.4917
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.2737 | ACC Train=0.5706 | ACC Test=0.2676 | F1 macro CV=0.2169 | F1 macro Test=0.2120 | ROC AUC OVR macro CV=0.6705 | ROC AUC OVR macro Test=0.6646 | AUCPR macro CV=0.4716 | AUCPR macro Test=0.4715
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.4686 | ACC Train=0.7431 | ACC Test=0.4540 | F1 macro CV=0.4250 | F1 macro Test=0.4167 | ROC AUC OVR macro CV=0.6047 | ROC AUC OVR macro Test=0.5960 | AUCPR macro CV=0.4358 | AUCPR macro Test=0.4298
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.5606 | ACC Train=1.0000 | ACC Test=0.5777 | F1 macro CV=0.4405 | F1 macro Test=0.4616 | ROC AUC OVR macro CV=0.6911 | ROC AUC OVR macro Test=0.7032 | AUCPR macro CV=0.4916 | AUCPR macro Test=0.5014
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.5417 | ACC Train=0.5825 | ACC Test=0.5491 | F1 macro CV=0.4635 | F1 macro Test=0.4669 | ROC AUC OVR macro CV=0.6845 | ROC AUC OVR macro Test=0.6884 | AUCPR macro CV=0.4709 | AUCPR macro Test=0.4723
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.5324 | ACC Train=0.7871 | ACC Test=0.5167 | F1 macro CV=0.4627 | F1 macro Test=0.4444 | ROC AUC OVR macro CV=0.6741 | ROC AUC OVR macro Test=0.6485 | AUCPR macro CV=0.4878 | AUCPR macro Test=0.4642
# 	Evaluating with SMOTE sampler config: {0: 200, 2: 290}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.2590 | ACC Train=0.3674 | ACC Test=0.2794 | F1 macro CV=0.2053 | F1 macro Test=0.2012 | ROC AUC OVR macro CV=0.5688 | ROC AUC OVR macro Test=0.5911 | AUCPR macro CV=0.4025 | AUCPR macro Test=0.4073
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.2799 | ACC Train=0.4737 | ACC Test=0.2892 | F1 macro CV=0.1839 | F1 macro Test=0.1844 | ROC AUC OVR macro CV=0.6402 | ROC AUC OVR macro Test=0.6530 | AUCPR macro CV=0.4729 | AUCPR macro Test=0.4841
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.2902 | ACC Train=0.3859 | ACC Test=0.2913 | F1 macro CV=0.1716 | F1 macro Test=0.1617 | ROC AUC OVR macro CV=0.6487 | ROC AUC OVR macro Test=0.6639 | AUCPR macro CV=0.4803 | AUCPR macro Test=0.4915
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.5640 | ACC Train=0.7198 | ACC Test=0.5603 | F1 macro CV=0.4372 | F1 macro Test=0.4337 | ROC AUC OVR macro CV=0.6991 | ROC AUC OVR macro Test=0.7022 | AUCPR macro CV=0.4953 | AUCPR macro Test=0.4971
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.5774 | ACC Train=0.5672 | ACC Test=0.5787 | F1 macro CV=0.4180 | F1 macro Test=0.4199 | ROC AUC OVR macro CV=0.7086 | ROC AUC OVR macro Test=0.7101 | AUCPR macro CV=0.5021 | AUCPR macro Test=0.4960
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.2733 | ACC Train=0.5740 | ACC Test=0.2631 | F1 macro CV=0.2159 | F1 macro Test=0.2058 | ROC AUC OVR macro CV=0.6637 | ROC AUC OVR macro Test=0.6518 | AUCPR macro CV=0.4677 | AUCPR macro Test=0.4606
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.4679 | ACC Train=0.7475 | ACC Test=0.4484 | F1 macro CV=0.4246 | F1 macro Test=0.4137 | ROC AUC OVR macro CV=0.6016 | ROC AUC OVR macro Test=0.5944 | AUCPR macro CV=0.4338 | AUCPR macro Test=0.4304
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.5531 | ACC Train=1.0000 | ACC Test=0.5627 | F1 macro CV=0.4703 | F1 macro Test=0.4809 | ROC AUC OVR macro CV=0.6924 | ROC AUC OVR macro Test=0.7029 | AUCPR macro CV=0.4923 | AUCPR macro Test=0.4997
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.5456 | ACC Train=0.5724 | ACC Test=0.5519 | F1 macro CV=0.4719 | F1 macro Test=0.4725 | ROC AUC OVR macro CV=0.6836 | ROC AUC OVR macro Test=0.6844 | AUCPR macro CV=0.4736 | AUCPR macro Test=0.4714
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.5295 | ACC Train=0.7727 | ACC Test=0.5031 | F1 macro CV=0.4603 | F1 macro Test=0.4368 | ROC AUC OVR macro CV=0.6636 | ROC AUC OVR macro Test=0.6399 | AUCPR macro CV=0.4806 | AUCPR macro Test=0.4561
# 	Evaluating with ROS sampler config: {0: 220, 2: 310}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.2571 | ACC Train=0.3815 | ACC Test=0.2669 | F1 macro CV=0.2083 | F1 macro Test=0.2021 | ROC AUC OVR macro CV=0.5517 | ROC AUC OVR macro Test=0.5879 | AUCPR macro CV=0.3860 | AUCPR macro Test=0.4046
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.2774 | ACC Train=0.4773 | ACC Test=0.2836 | F1 macro CV=0.1872 | F1 macro Test=0.1871 | ROC AUC OVR macro CV=0.6250 | ROC AUC OVR macro Test=0.6401 | AUCPR macro CV=0.4695 | AUCPR macro Test=0.4809
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.2865 | ACC Train=0.4230 | ACC Test=0.2902 | F1 macro CV=0.1696 | F1 macro Test=0.1686 | ROC AUC OVR macro CV=0.6411 | ROC AUC OVR macro Test=0.6535 | AUCPR macro CV=0.4764 | AUCPR macro Test=0.4852
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.5675 | ACC Train=0.6753 | ACC Test=0.5589 | F1 macro CV=0.4462 | F1 macro Test=0.4382 | ROC AUC OVR macro CV=0.7012 | ROC AUC OVR macro Test=0.7049 | AUCPR macro CV=0.4975 | AUCPR macro Test=0.4990
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.5798 | ACC Train=0.5558 | ACC Test=0.5784 | F1 macro CV=0.4213 | F1 macro Test=0.4220 | ROC AUC OVR macro CV=0.7052 | ROC AUC OVR macro Test=0.7039 | AUCPR macro CV=0.4962 | AUCPR macro Test=0.4886
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.2729 | ACC Train=0.5920 | ACC Test=0.2620 | F1 macro CV=0.2184 | F1 macro Test=0.2073 | ROC AUC OVR macro CV=0.6687 | ROC AUC OVR macro Test=0.6629 | AUCPR macro CV=0.4700 | AUCPR macro Test=0.4700
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.4633 | ACC Train=0.7481 | ACC Test=0.4523 | F1 macro CV=0.4228 | F1 macro Test=0.4171 | ROC AUC OVR macro CV=0.6029 | ROC AUC OVR macro Test=0.5943 | AUCPR macro CV=0.4342 | AUCPR macro Test=0.4281
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.5588 | ACC Train=1.0000 | ACC Test=0.5714 | F1 macro CV=0.4479 | F1 macro Test=0.4615 | ROC AUC OVR macro CV=0.6897 | ROC AUC OVR macro Test=0.7025 | AUCPR macro CV=0.4924 | AUCPR macro Test=0.5025
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.5428 | ACC Train=0.5738 | ACC Test=0.5474 | F1 macro CV=0.4657 | F1 macro Test=0.4637 | ROC AUC OVR macro CV=0.6844 | ROC AUC OVR macro Test=0.6889 | AUCPR macro CV=0.4704 | AUCPR macro Test=0.4718
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.5288 | ACC Train=0.7976 | ACC Test=0.5045 | F1 macro CV=0.4623 | F1 macro Test=0.4320 | ROC AUC OVR macro CV=0.6669 | ROC AUC OVR macro Test=0.6385 | AUCPR macro CV=0.4807 | AUCPR macro Test=0.4572
# 	Evaluating with SMOTE sampler config: {0: 220, 2: 310}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.2576 | ACC Train=0.3808 | ACC Test=0.2725 | F1 macro CV=0.2063 | F1 macro Test=0.2019 | ROC AUC OVR macro CV=0.5633 | ROC AUC OVR macro Test=0.5739 | AUCPR macro CV=0.3945 | AUCPR macro Test=0.3964
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.2755 | ACC Train=0.5011 | ACC Test=0.2798 | F1 macro CV=0.1842 | F1 macro Test=0.1799 | ROC AUC OVR macro CV=0.6350 | ROC AUC OVR macro Test=0.6474 | AUCPR macro CV=0.4705 | AUCPR macro Test=0.4802
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.2854 | ACC Train=0.4150 | ACC Test=0.2916 | F1 macro CV=0.1724 | F1 macro Test=0.1653 | ROC AUC OVR macro CV=0.6437 | ROC AUC OVR macro Test=0.6570 | AUCPR macro CV=0.4783 | AUCPR macro Test=0.4876
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.5612 | ACC Train=0.7404 | ACC Test=0.5568 | F1 macro CV=0.4447 | F1 macro Test=0.4349 | ROC AUC OVR macro CV=0.6987 | ROC AUC OVR macro Test=0.6988 | AUCPR macro CV=0.4951 | AUCPR macro Test=0.4939
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.5789 | ACC Train=0.5604 | ACC Test=0.5801 | F1 macro CV=0.4208 | F1 macro Test=0.4232 | ROC AUC OVR macro CV=0.7069 | ROC AUC OVR macro Test=0.7073 | AUCPR macro CV=0.4999 | AUCPR macro Test=0.4936
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.2729 | ACC Train=0.5937 | ACC Test=0.2634 | F1 macro CV=0.2177 | F1 macro Test=0.2072 | ROC AUC OVR macro CV=0.6608 | ROC AUC OVR macro Test=0.6473 | AUCPR macro CV=0.4645 | AUCPR macro Test=0.4556
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.4620 | ACC Train=0.7550 | ACC Test=0.4425 | F1 macro CV=0.4212 | F1 macro Test=0.4086 | ROC AUC OVR macro CV=0.5997 | ROC AUC OVR macro Test=0.5932 | AUCPR macro CV=0.4323 | AUCPR macro Test=0.4288
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.5488 | ACC Train=1.0000 | ACC Test=0.5634 | F1 macro CV=0.4743 | F1 macro Test=0.4947 | ROC AUC OVR macro CV=0.6893 | ROC AUC OVR macro Test=0.7019 | AUCPR macro CV=0.4913 | AUCPR macro Test=0.5013
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.5464 | ACC Train=0.5685 | ACC Test=0.5512 | F1 macro CV=0.4742 | F1 macro Test=0.4718 | ROC AUC OVR macro CV=0.6833 | ROC AUC OVR macro Test=0.6851 | AUCPR macro CV=0.4742 | AUCPR macro Test=0.4714
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.5236 | ACC Train=0.8090 | ACC Test=0.5017 | F1 macro CV=0.4569 | F1 macro Test=0.4364 | ROC AUC OVR macro CV=0.6593 | ROC AUC OVR macro Test=0.6301 | AUCPR macro CV=0.4765 | AUCPR macro Test=0.4517
# 	Pipeline weight config: w_c2_20
# 	Evaluating multiclass classification for MCID_v2
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=None | ACC CV=0.2654 | ACC Train=0.3003 | ACC Test=0.2794 | F1 macro CV=0.1944 | F1 macro Test=0.1942 | ROC AUC OVR macro CV=0.5558 | ROC AUC OVR macro Test=0.5648 | AUCPR macro CV=0.3855 | AUCPR macro Test=0.3940
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=None | ACC CV=0.2877 | ACC Train=0.3221 | ACC Test=0.2889 | F1 macro CV=0.1662 | F1 macro Test=0.1532 | ROC AUC OVR macro CV=0.6293 | ROC AUC OVR macro Test=0.6376 | AUCPR macro CV=0.4700 | AUCPR macro Test=0.4792
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=None | ACC CV=0.2928 | ACC Train=0.2978 | ACC Test=0.2920 | F1 macro CV=0.1560 | F1 macro Test=0.1507 | ROC AUC OVR macro CV=0.6480 | ROC AUC OVR macro Test=0.6601 | AUCPR macro CV=0.4809 | AUCPR macro Test=0.4914
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=None | ACC CV=0.5784 | ACC Train=0.6185 | ACC Test=0.5847 | F1 macro CV=0.4030 | F1 macro Test=0.4100 | ROC AUC OVR macro CV=0.7120 | ROC AUC OVR macro Test=0.7112 | AUCPR macro CV=0.5095 | AUCPR macro Test=0.5023
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=None | ACC CV=0.5821 | ACC Train=0.5952 | ACC Test=0.5822 | F1 macro CV=0.4165 | F1 macro Test=0.4184 | ROC AUC OVR macro CV=0.7095 | ROC AUC OVR macro Test=0.7089 | AUCPR macro CV=0.4954 | AUCPR macro Test=0.4902
# Evaluating model: svm_reg
# svm_reg | Sampler=None | ACC CV=0.2724 | ACC Train=0.4732 | ACC Test=0.2666 | F1 macro CV=0.2186 | F1 macro Test=0.2110 | ROC AUC OVR macro CV=0.6763 | ROC AUC OVR macro Test=0.6613 | AUCPR macro CV=0.4734 | AUCPR macro Test=0.4607
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=None | ACC CV=0.4742 | ACC Train=0.7049 | ACC Test=0.4561 | F1 macro CV=0.4290 | F1 macro Test=0.4173 | ROC AUC OVR macro CV=0.6083 | ROC AUC OVR macro Test=0.6017 | AUCPR macro CV=0.4370 | AUCPR macro Test=0.4328
# Evaluating model: knn_reg
# knn_reg | Sampler=None | ACC CV=0.5619 | ACC Train=1.0000 | ACC Test=0.5652 | F1 macro CV=0.3915 | F1 macro Test=0.3963 | ROC AUC OVR macro CV=0.7005 | ROC AUC OVR macro Test=0.7114 | AUCPR macro CV=0.5010 | AUCPR macro Test=0.5074
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=None | ACC CV=0.5455 | ACC Train=0.6060 | ACC Test=0.5439 | F1 macro CV=0.4656 | F1 macro Test=0.4586 | ROC AUC OVR macro CV=0.6890 | ROC AUC OVR macro Test=0.6888 | AUCPR macro CV=0.4738 | AUCPR macro Test=0.4704
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=None | ACC CV=0.5368 | ACC Train=0.6638 | ACC Test=0.5199 | F1 macro CV=0.4700 | F1 macro Test=0.4417 | ROC AUC OVR macro CV=0.6849 | ROC AUC OVR macro Test=0.6700 | AUCPR macro CV=0.4995 | AUCPR macro Test=0.4790
# 	Evaluating with ROS sampler config: {0: 180, 2: 270}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.2604 | ACC Train=0.3535 | ACC Test=0.2763 | F1 macro CV=0.2003 | F1 macro Test=0.1807 | ROC AUC OVR macro CV=0.5392 | ROC AUC OVR macro Test=0.5390 | AUCPR macro CV=0.3759 | AUCPR macro Test=0.3692
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.2797 | ACC Train=0.4223 | ACC Test=0.2864 | F1 macro CV=0.1778 | F1 macro Test=0.1712 | ROC AUC OVR macro CV=0.6043 | ROC AUC OVR macro Test=0.6222 | AUCPR macro CV=0.4604 | AUCPR macro Test=0.4723
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.2899 | ACC Train=0.3777 | ACC Test=0.2916 | F1 macro CV=0.1635 | F1 macro Test=0.1564 | ROC AUC OVR macro CV=0.6182 | ROC AUC OVR macro Test=0.6344 | AUCPR macro CV=0.4679 | AUCPR macro Test=0.4820
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.5777 | ACC Train=0.6431 | ACC Test=0.5791 | F1 macro CV=0.4290 | F1 macro Test=0.4367 | ROC AUC OVR macro CV=0.7041 | ROC AUC OVR macro Test=0.7086 | AUCPR macro CV=0.5005 | AUCPR macro Test=0.5047
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.5824 | ACC Train=0.5711 | ACC Test=0.5815 | F1 macro CV=0.4216 | F1 macro Test=0.4239 | ROC AUC OVR macro CV=0.7060 | ROC AUC OVR macro Test=0.7081 | AUCPR macro CV=0.4960 | AUCPR macro Test=0.4935
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.2707 | ACC Train=0.5591 | ACC Test=0.2659 | F1 macro CV=0.2189 | F1 macro Test=0.2144 | ROC AUC OVR macro CV=0.6586 | ROC AUC OVR macro Test=0.6446 | AUCPR macro CV=0.4610 | AUCPR macro Test=0.4509
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.4518 | ACC Train=0.7139 | ACC Test=0.4348 | F1 macro CV=0.4162 | F1 macro Test=0.4043 | ROC AUC OVR macro CV=0.6030 | ROC AUC OVR macro Test=0.5940 | AUCPR macro CV=0.4337 | AUCPR macro Test=0.4272
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.5619 | ACC Train=1.0000 | ACC Test=0.5767 | F1 macro CV=0.4284 | F1 macro Test=0.4528 | ROC AUC OVR macro CV=0.6932 | ROC AUC OVR macro Test=0.7068 | AUCPR macro CV=0.4938 | AUCPR macro Test=0.5035
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.5438 | ACC Train=0.5862 | ACC Test=0.5523 | F1 macro CV=0.4651 | F1 macro Test=0.4683 | ROC AUC OVR macro CV=0.6850 | ROC AUC OVR macro Test=0.6882 | AUCPR macro CV=0.4714 | AUCPR macro Test=0.4718
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.5358 | ACC Train=0.7538 | ACC Test=0.5230 | F1 macro CV=0.4679 | F1 macro Test=0.4516 | ROC AUC OVR macro CV=0.6772 | ROC AUC OVR macro Test=0.6561 | AUCPR macro CV=0.4901 | AUCPR macro Test=0.4666
# 	Evaluating with SMOTE sampler config: {0: 180, 2: 270}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.2623 | ACC Train=0.3663 | ACC Test=0.2655 | F1 macro CV=0.2044 | F1 macro Test=0.1935 | ROC AUC OVR macro CV=0.5494 | ROC AUC OVR macro Test=0.5414 | AUCPR macro CV=0.3852 | AUCPR macro Test=0.3776
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.2822 | ACC Train=0.4426 | ACC Test=0.2875 | F1 macro CV=0.1782 | F1 macro Test=0.1792 | ROC AUC OVR macro CV=0.6136 | ROC AUC OVR macro Test=0.6230 | AUCPR macro CV=0.4594 | AUCPR macro Test=0.4700
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.2896 | ACC Train=0.3639 | ACC Test=0.2920 | F1 macro CV=0.1586 | F1 macro Test=0.1543 | ROC AUC OVR macro CV=0.6180 | ROC AUC OVR macro Test=0.6374 | AUCPR macro CV=0.4636 | AUCPR macro Test=0.4817
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.5696 | ACC Train=0.6897 | ACC Test=0.5697 | F1 macro CV=0.4298 | F1 macro Test=0.4342 | ROC AUC OVR macro CV=0.7013 | ROC AUC OVR macro Test=0.7027 | AUCPR macro CV=0.4985 | AUCPR macro Test=0.4957
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.5783 | ACC Train=0.5763 | ACC Test=0.5812 | F1 macro CV=0.4188 | F1 macro Test=0.4219 | ROC AUC OVR macro CV=0.7082 | ROC AUC OVR macro Test=0.7119 | AUCPR macro CV=0.5027 | AUCPR macro Test=0.4960
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.2720 | ACC Train=0.5591 | ACC Test=0.2641 | F1 macro CV=0.2194 | F1 macro Test=0.2113 | ROC AUC OVR macro CV=0.6528 | ROC AUC OVR macro Test=0.6378 | AUCPR macro CV=0.4572 | AUCPR macro Test=0.4451
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.4527 | ACC Train=0.7209 | ACC Test=0.4265 | F1 macro CV=0.4163 | F1 macro Test=0.3981 | ROC AUC OVR macro CV=0.6009 | ROC AUC OVR macro Test=0.5944 | AUCPR macro CV=0.4325 | AUCPR macro Test=0.4284
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.5633 | ACC Train=1.0000 | ACC Test=0.5693 | F1 macro CV=0.4645 | F1 macro Test=0.4740 | ROC AUC OVR macro CV=0.6949 | ROC AUC OVR macro Test=0.7023 | AUCPR macro CV=0.4958 | AUCPR macro Test=0.4972
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.5451 | ACC Train=0.5794 | ACC Test=0.5491 | F1 macro CV=0.4706 | F1 macro Test=0.4682 | ROC AUC OVR macro CV=0.6848 | ROC AUC OVR macro Test=0.6850 | AUCPR macro CV=0.4730 | AUCPR macro Test=0.4706
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.5313 | ACC Train=0.7604 | ACC Test=0.5101 | F1 macro CV=0.4605 | F1 macro Test=0.4366 | ROC AUC OVR macro CV=0.6720 | ROC AUC OVR macro Test=0.6498 | AUCPR macro CV=0.4850 | AUCPR macro Test=0.4648
# 	Evaluating with ROS sampler config: {0: 200, 2: 290}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.2618 | ACC Train=0.3700 | ACC Test=0.2739 | F1 macro CV=0.2026 | F1 macro Test=0.1962 | ROC AUC OVR macro CV=0.5438 | ROC AUC OVR macro Test=0.5534 | AUCPR macro CV=0.3780 | AUCPR macro Test=0.3861
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.2786 | ACC Train=0.4457 | ACC Test=0.2868 | F1 macro CV=0.1807 | F1 macro Test=0.1782 | ROC AUC OVR macro CV=0.6036 | ROC AUC OVR macro Test=0.6166 | AUCPR macro CV=0.4584 | AUCPR macro Test=0.4714
# Evaluating model: extra_trees_reg
# ...
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.2965 | ACC Train=0.3806 | ACC Test=0.2990 | F1 macro CV=0.1715 | F1 macro Test=0.1790 | ROC AUC OVR macro CV=0.6777 | ROC AUC OVR macro Test=0.6968 | AUCPR macro CV=0.5108 | AUCPR macro Test=0.5308
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.5774 | ACC Train=0.6934 | ACC Test=0.5812 | F1 macro CV=0.4660 | F1 macro Test=0.4851 | ROC AUC OVR macro CV=0.7285 | ROC AUC OVR macro Test=0.7414 | AUCPR macro CV=0.5346 | AUCPR macro Test=0.5449
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.5672 | ACC Train=0.5491 | ACC Test=0.5704 | F1 macro CV=0.4090 | F1 macro Test=0.4095 | ROC AUC OVR macro CV=0.7056 | ROC AUC OVR macro Test=0.7121 | AUCPR macro CV=0.4971 | AUCPR macro Test=0.4971
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.3223 | ACC Train=0.5639 | ACC Test=0.3321 | F1 macro CV=0.2765 | F1 macro Test=0.2862 | ROC AUC OVR macro CV=0.7229 | ROC AUC OVR macro Test=0.7363 | AUCPR macro CV=0.5341 | AUCPR macro Test=0.5487
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.4871 | ACC Train=0.7487 | ACC Test=0.4976 | F1 macro CV=0.4619 | F1 macro Test=0.4773 | ROC AUC OVR macro CV=0.6493 | ROC AUC OVR macro Test=0.6654 | AUCPR macro CV=0.4755 | AUCPR macro Test=0.4838
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.5238 | ACC Train=1.0000 | ACC Test=0.5331 | F1 macro CV=0.2855 | F1 macro Test=0.3106 | ROC AUC OVR macro CV=0.6382 | ROC AUC OVR macro Test=0.6494 | AUCPR macro CV=0.4508 | AUCPR macro Test=0.4618
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.5613 | ACC Train=0.6252 | ACC Test=0.5728 | F1 macro CV=0.4968 | F1 macro Test=0.5011 | ROC AUC OVR macro CV=0.7114 | ROC AUC OVR macro Test=0.7152 | AUCPR macro CV=0.5053 | AUCPR macro Test=0.5032
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.5548 | ACC Train=0.8102 | ACC Test=0.5516 | F1 macro CV=0.4838 | F1 macro Test=0.4873 | ROC AUC OVR macro CV=0.6853 | ROC AUC OVR macro Test=0.6954 | AUCPR macro CV=0.4989 | AUCPR macro Test=0.5052
# 	Evaluating with SMOTE sampler config: {0: 180, 2: 270}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.2768 | ACC Train=0.3802 | ACC Test=0.2843 | F1 macro CV=0.2195 | F1 macro Test=0.2323 | ROC AUC OVR macro CV=0.5499 | ROC AUC OVR macro Test=0.5585 | AUCPR macro CV=0.3716 | AUCPR macro Test=0.3758
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.3031 | ACC Train=0.4644 | ACC Test=0.3143 | F1 macro CV=0.2251 | F1 macro Test=0.2417 | ROC AUC OVR macro CV=0.6607 | ROC AUC OVR macro Test=0.6777 | AUCPR macro CV=0.4941 | AUCPR macro Test=0.5112
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.2970 | ACC Train=0.3737 | ACC Test=0.2955 | F1 macro CV=0.1765 | F1 macro Test=0.1754 | ROC AUC OVR macro CV=0.6722 | ROC AUC OVR macro Test=0.6937 | AUCPR macro CV=0.5063 | AUCPR macro Test=0.5271
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.5714 | ACC Train=0.7465 | ACC Test=0.5889 | F1 macro CV=0.4675 | F1 macro Test=0.5033 | ROC AUC OVR macro CV=0.7297 | ROC AUC OVR macro Test=0.7419 | AUCPR macro CV=0.5358 | AUCPR macro Test=0.5463
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.5634 | ACC Train=0.5575 | ACC Test=0.5711 | F1 macro CV=0.4111 | F1 macro Test=0.4173 | ROC AUC OVR macro CV=0.7063 | ROC AUC OVR macro Test=0.7100 | AUCPR macro CV=0.5019 | AUCPR macro Test=0.4956
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.3205 | ACC Train=0.5639 | ACC Test=0.3258 | F1 macro CV=0.2727 | F1 macro Test=0.2774 | ROC AUC OVR macro CV=0.7164 | ROC AUC OVR macro Test=0.7238 | AUCPR macro CV=0.5255 | AUCPR macro Test=0.5345
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.4764 | ACC Train=0.7487 | ACC Test=0.4875 | F1 macro CV=0.4534 | F1 macro Test=0.4703 | ROC AUC OVR macro CV=0.6441 | ROC AUC OVR macro Test=0.6594 | AUCPR macro CV=0.4696 | AUCPR macro Test=0.4793
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.5483 | ACC Train=1.0000 | ACC Test=0.5589 | F1 macro CV=0.3909 | F1 macro Test=0.4204 | ROC AUC OVR macro CV=0.6788 | ROC AUC OVR macro Test=0.6888 | AUCPR macro CV=0.4890 | AUCPR macro Test=0.5023
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.5654 | ACC Train=0.5880 | ACC Test=0.5735 | F1 macro CV=0.5026 | F1 macro Test=0.5053 | ROC AUC OVR macro CV=0.7136 | ROC AUC OVR macro Test=0.7199 | AUCPR macro CV=0.5122 | AUCPR macro Test=0.5156
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.5469 | ACC Train=0.8294 | ACC Test=0.5540 | F1 macro CV=0.4782 | F1 macro Test=0.4957 | ROC AUC OVR macro CV=0.6794 | ROC AUC OVR macro Test=0.6898 | AUCPR macro CV=0.4922 | AUCPR macro Test=0.5062
# 	Evaluating with ROS sampler config: {0: 200, 2: 290}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.2723 | ACC Train=0.3776 | ACC Test=0.2634 | F1 macro CV=0.2102 | F1 macro Test=0.2193 | ROC AUC OVR macro CV=0.5335 | ROC AUC OVR macro Test=0.5390 | AUCPR macro CV=0.3590 | AUCPR macro Test=0.3644
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.3049 | ACC Train=0.4678 | ACC Test=0.3094 | F1 macro CV=0.2282 | F1 macro Test=0.2312 | ROC AUC OVR macro CV=0.6638 | ROC AUC OVR macro Test=0.6888 | AUCPR macro CV=0.5005 | AUCPR macro Test=0.5276
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.2976 | ACC Train=0.4033 | ACC Test=0.2993 | F1 macro CV=0.1833 | F1 macro Test=0.1850 | ROC AUC OVR macro CV=0.6722 | ROC AUC OVR macro Test=0.6996 | AUCPR macro CV=0.5054 | AUCPR macro Test=0.5353
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.5756 | ACC Train=0.7109 | ACC Test=0.5794 | F1 macro CV=0.4813 | F1 macro Test=0.4945 | ROC AUC OVR macro CV=0.7294 | ROC AUC OVR macro Test=0.7422 | AUCPR macro CV=0.5349 | AUCPR macro Test=0.5460
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.5686 | ACC Train=0.5409 | ACC Test=0.5732 | F1 macro CV=0.4181 | F1 macro Test=0.4104 | ROC AUC OVR macro CV=0.7051 | ROC AUC OVR macro Test=0.7081 | AUCPR macro CV=0.4973 | AUCPR macro Test=0.4903
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.3228 | ACC Train=0.5847 | ACC Test=0.3331 | F1 macro CV=0.2773 | F1 macro Test=0.2879 | ROC AUC OVR macro CV=0.7218 | ROC AUC OVR macro Test=0.7335 | AUCPR macro CV=0.5323 | AUCPR macro Test=0.5461
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.4835 | ACC Train=0.7506 | ACC Test=0.4941 | F1 macro CV=0.4603 | F1 macro Test=0.4761 | ROC AUC OVR macro CV=0.6484 | ROC AUC OVR macro Test=0.6644 | AUCPR macro CV=0.4748 | AUCPR macro Test=0.4850
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.5245 | ACC Train=1.0000 | ACC Test=0.5383 | F1 macro CV=0.2947 | F1 macro Test=0.3236 | ROC AUC OVR macro CV=0.6353 | ROC AUC OVR macro Test=0.6487 | AUCPR macro CV=0.4509 | AUCPR macro Test=0.4630
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.5626 | ACC Train=0.6214 | ACC Test=0.5711 | F1 macro CV=0.4982 | F1 macro Test=0.4993 | ROC AUC OVR macro CV=0.7108 | ROC AUC OVR macro Test=0.7162 | AUCPR macro CV=0.5048 | AUCPR macro Test=0.5040
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.5529 | ACC Train=0.8542 | ACC Test=0.5596 | F1 macro CV=0.4863 | F1 macro Test=0.4975 | ROC AUC OVR macro CV=0.6852 | ROC AUC OVR macro Test=0.6952 | AUCPR macro CV=0.4994 | AUCPR macro Test=0.5041
# 	Evaluating with SMOTE sampler config: {0: 200, 2: 290}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.2771 | ACC Train=0.3980 | ACC Test=0.2801 | F1 macro CV=0.2230 | F1 macro Test=0.2323 | ROC AUC OVR macro CV=0.5460 | ROC AUC OVR macro Test=0.5566 | AUCPR macro CV=0.3695 | AUCPR macro Test=0.3705
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.3048 | ACC Train=0.4942 | ACC Test=0.3094 | F1 macro CV=0.2330 | F1 macro Test=0.2388 | ROC AUC OVR macro CV=0.6600 | ROC AUC OVR macro Test=0.6743 | AUCPR macro CV=0.4921 | AUCPR macro Test=0.5095
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.2982 | ACC Train=0.4017 | ACC Test=0.3014 | F1 macro CV=0.1870 | F1 macro Test=0.1934 | ROC AUC OVR macro CV=0.6699 | ROC AUC OVR macro Test=0.6928 | AUCPR macro CV=0.5023 | AUCPR macro Test=0.5318
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.5716 | ACC Train=0.7672 | ACC Test=0.5805 | F1 macro CV=0.4814 | F1 macro Test=0.5042 | ROC AUC OVR macro CV=0.7300 | ROC AUC OVR macro Test=0.7429 | AUCPR macro CV=0.5354 | AUCPR macro Test=0.5507
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.5617 | ACC Train=0.5537 | ACC Test=0.5735 | F1 macro CV=0.4233 | F1 macro Test=0.4282 | ROC AUC OVR macro CV=0.7070 | ROC AUC OVR macro Test=0.7137 | AUCPR macro CV=0.5027 | AUCPR macro Test=0.5074
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.3222 | ACC Train=0.5847 | ACC Test=0.3261 | F1 macro CV=0.2738 | F1 macro Test=0.2774 | ROC AUC OVR macro CV=0.7156 | ROC AUC OVR macro Test=0.7213 | AUCPR macro CV=0.5246 | AUCPR macro Test=0.5321
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.4719 | ACC Train=0.7516 | ACC Test=0.4780 | F1 macro CV=0.4505 | F1 macro Test=0.4620 | ROC AUC OVR macro CV=0.6416 | ROC AUC OVR macro Test=0.6580 | AUCPR macro CV=0.4673 | AUCPR macro Test=0.4794
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.5541 | ACC Train=1.0000 | ACC Test=0.5672 | F1 macro CV=0.4164 | F1 macro Test=0.4486 | ROC AUC OVR macro CV=0.6797 | ROC AUC OVR macro Test=0.6882 | AUCPR macro CV=0.4910 | AUCPR macro Test=0.5044
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.5660 | ACC Train=0.5737 | ACC Test=0.5721 | F1 macro CV=0.5035 | F1 macro Test=0.5027 | ROC AUC OVR macro CV=0.7125 | ROC AUC OVR macro Test=0.7196 | AUCPR macro CV=0.5133 | AUCPR macro Test=0.5190
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.5483 | ACC Train=0.8650 | ACC Test=0.5662 | F1 macro CV=0.4856 | F1 macro Test=0.5092 | ROC AUC OVR macro CV=0.6777 | ROC AUC OVR macro Test=0.6940 | AUCPR macro CV=0.4919 | AUCPR macro Test=0.5063
# 	Evaluating with ROS sampler config: {0: 220, 2: 310}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.2672 | ACC Train=0.3967 | ACC Test=0.2728 | F1 macro CV=0.2105 | F1 macro Test=0.2257 | ROC AUC OVR macro CV=0.5325 | ROC AUC OVR macro Test=0.5507 | AUCPR macro CV=0.3598 | AUCPR macro Test=0.3730
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.3044 | ACC Train=0.4896 | ACC Test=0.3101 | F1 macro CV=0.2296 | F1 macro Test=0.2394 | ROC AUC OVR macro CV=0.6633 | ROC AUC OVR macro Test=0.6884 | AUCPR macro CV=0.4999 | AUCPR macro Test=0.5273
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.2996 | ACC Train=0.4236 | ACC Test=0.2962 | F1 macro CV=0.1898 | F1 macro Test=0.1848 | ROC AUC OVR macro CV=0.6733 | ROC AUC OVR macro Test=0.6966 | AUCPR macro CV=0.5057 | AUCPR macro Test=0.5338
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.5767 | ACC Train=0.7204 | ACC Test=0.5784 | F1 macro CV=0.4936 | F1 macro Test=0.5012 | ROC AUC OVR macro CV=0.7303 | ROC AUC OVR macro Test=0.7439 | AUCPR macro CV=0.5347 | AUCPR macro Test=0.5506
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.5673 | ACC Train=0.5352 | ACC Test=0.5739 | F1 macro CV=0.4215 | F1 macro Test=0.4144 | ROC AUC OVR macro CV=0.7047 | ROC AUC OVR macro Test=0.7100 | AUCPR macro CV=0.4962 | AUCPR macro Test=0.4928
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.3225 | ACC Train=0.6036 | ACC Test=0.3338 | F1 macro CV=0.2771 | F1 macro Test=0.2884 | ROC AUC OVR macro CV=0.7206 | ROC AUC OVR macro Test=0.7335 | AUCPR macro CV=0.5306 | AUCPR macro Test=0.5459
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.4770 | ACC Train=0.7577 | ACC Test=0.4909 | F1 macro CV=0.4554 | F1 macro Test=0.4736 | ROC AUC OVR macro CV=0.6470 | ROC AUC OVR macro Test=0.6639 | AUCPR macro CV=0.4732 | AUCPR macro Test=0.4845
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.5268 | ACC Train=1.0000 | ACC Test=0.5380 | F1 macro CV=0.3055 | F1 macro Test=0.3317 | ROC AUC OVR macro CV=0.6346 | ROC AUC OVR macro Test=0.6504 | AUCPR macro CV=0.4512 | AUCPR macro Test=0.4614
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.5624 | ACC Train=0.6183 | ACC Test=0.5732 | F1 macro CV=0.4986 | F1 macro Test=0.5025 | ROC AUC OVR macro CV=0.7106 | ROC AUC OVR macro Test=0.7170 | AUCPR macro CV=0.5048 | AUCPR macro Test=0.5062
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.5565 | ACC Train=0.8589 | ACC Test=0.5495 | F1 macro CV=0.4952 | F1 macro Test=0.4921 | ROC AUC OVR macro CV=0.6846 | ROC AUC OVR macro Test=0.6898 | AUCPR macro CV=0.5000 | AUCPR macro Test=0.4984
# 	Evaluating with SMOTE sampler config: {0: 220, 2: 310}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.2729 | ACC Train=0.4041 | ACC Test=0.2836 | F1 macro CV=0.2229 | F1 macro Test=0.2284 | ROC AUC OVR macro CV=0.5509 | ROC AUC OVR macro Test=0.5594 | AUCPR macro CV=0.3729 | AUCPR macro Test=0.3787
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.3061 | ACC Train=0.5190 | ACC Test=0.3132 | F1 macro CV=0.2398 | F1 macro Test=0.2533 | ROC AUC OVR macro CV=0.6583 | ROC AUC OVR macro Test=0.6737 | AUCPR macro CV=0.4900 | AUCPR macro Test=0.5079
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.2984 | ACC Train=0.4345 | ACC Test=0.2997 | F1 macro CV=0.1945 | F1 macro Test=0.1956 | ROC AUC OVR macro CV=0.6691 | ROC AUC OVR macro Test=0.6880 | AUCPR macro CV=0.5032 | AUCPR macro Test=0.5202
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.5728 | ACC Train=0.7821 | ACC Test=0.5826 | F1 macro CV=0.4870 | F1 macro Test=0.5085 | ROC AUC OVR macro CV=0.7304 | ROC AUC OVR macro Test=0.7440 | AUCPR macro CV=0.5361 | AUCPR macro Test=0.5510
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.5616 | ACC Train=0.5551 | ACC Test=0.5732 | F1 macro CV=0.4309 | F1 macro Test=0.4397 | ROC AUC OVR macro CV=0.7065 | ROC AUC OVR macro Test=0.7149 | AUCPR macro CV=0.5016 | AUCPR macro Test=0.5089
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.3210 | ACC Train=0.6036 | ACC Test=0.3272 | F1 macro CV=0.2729 | F1 macro Test=0.2775 | ROC AUC OVR macro CV=0.7134 | ROC AUC OVR macro Test=0.7204 | AUCPR macro CV=0.5232 | AUCPR macro Test=0.5322
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.4671 | ACC Train=0.7535 | ACC Test=0.4805 | F1 macro CV=0.4471 | F1 macro Test=0.4663 | ROC AUC OVR macro CV=0.6405 | ROC AUC OVR macro Test=0.6566 | AUCPR macro CV=0.4658 | AUCPR macro Test=0.4788
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.5574 | ACC Train=1.0000 | ACC Test=0.5672 | F1 macro CV=0.4368 | F1 macro Test=0.4654 | ROC AUC OVR macro CV=0.6843 | ROC AUC OVR macro Test=0.6951 | AUCPR macro CV=0.4940 | AUCPR macro Test=0.5086
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.5668 | ACC Train=0.5691 | ACC Test=0.5714 | F1 macro CV=0.5035 | F1 macro Test=0.5015 | ROC AUC OVR macro CV=0.7124 | ROC AUC OVR macro Test=0.7172 | AUCPR macro CV=0.5147 | AUCPR macro Test=0.5171
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.5462 | ACC Train=0.8719 | ACC Test=0.5526 | F1 macro CV=0.4899 | F1 macro Test=0.5019 | ROC AUC OVR macro CV=0.6769 | ROC AUC OVR macro Test=0.6888 | AUCPR macro CV=0.4915 | AUCPR macro Test=0.5054

# %% [markdown]
# # UNDERSAMPLING

# %% [markdown]
# ## MCID

# %%
data_df_ovr=[]
for val1,val2 in pairs_init_MCID:
    y = pd.read_csv(y_multiples_MCID[val2], index_col=0)
    print(f"Evaluating for target: {val2} with features: {val1}")
    X = pd.read_csv(X_multiples_MCID[val1], index_col=0)
    print(f"\tLoaded X shape: {X.shape}, y shape: {y.shape}")
    for pipeline_weight in classification_models_by_weight_reg_UNDER_MCID:
        print(f"\tPipeline weight config: {pipeline_weight}")
        classification_models = classification_models_by_weight_reg_UNDER_MCID[pipeline_weight]
        print(f"\tEvaluating multiclass classification for {val2} \n")
        results_df = evaluate_model_10x10_metrics_multiclass_sampler(
            model_dict=classification_models,
            X=X,
            y=y,
            n_outer=10,
            n_inner=10,
            test_size_outer=0.30,
            test_size_inner=0.30,
            random_state=42,
            cost_matrix=None,
            resampling_method=None,
            target_class_counts=None
        )
        results_df["weight_config"] = pipeline_weight
        results_df["feature_set"] = val1
        results_df["sampler_config"] = np.nan
        data_df_ovr.append(results_df)

        for sampler_dict in [{0:180, 2:270}, {0:200, 2:290}, {0:220, 2:310}]:
            print(f"\tEvaluating with ROS sampler config: {sampler_dict} \n")
            results_df_ros = evaluate_model_10x10_metrics_multiclass_sampler(
                model_dict=classification_models,
                X=X,
                y=y,
                n_inner=5,
                resampling_method="ros",
                target_class_counts=sampler_dict)
            
            results_df_ros["weight_config"] = pipeline_weight
            results_df_ros["feature_set"] = val1
            results_df_ros["sampler_config"] = f"ROS_{sampler_dict}"
            data_df_ovr.append(results_df_ros)
            
            print(f"\tEvaluating with SMOTE sampler config: {sampler_dict} \n")
            results_df_smote = evaluate_model_10x10_metrics_multiclass_sampler(
                        model_dict=classification_models,
                        X=X,
                        y=y,
                        n_inner=5,
                        resampling_method="smote",
                        target_class_counts=sampler_dict,
                        smote_k_neighbors=3)
            
            results_df_smote["weight_config"] = pipeline_weight
            results_df_smote["feature_set"] = val1
            results_df_smote["sampler_config"] = f"SMOTE_{sampler_dict}"
            data_df_ovr.append(results_df_smote)

final_results_df_ovr = pd.concat(data_df_ovr, ignore_index=True)
final_results_df_ovr.to_csv(output_path / "multiclass_classification_results_reg_UNDER_MCID_v2.csv", index=False)
# Out:
# Evaluating for target: HY3_v2 with features: X_STATS_V2
# 	Loaded X shape: (956, 301), y shape: (956, 1)
# 	Pipeline weight config: balanced
# 	Evaluating multiclass classification for HY3_v2
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=None | ACC CV=0.6656 | ACC Train=0.6695 | ACC Test=0.6554 | F1 macro CV=0.5894 | F1 macro Test=0.6024 | ROC AUC OVR macro CV=0.7966 | ROC AUC OVR macro Test=0.8046 | AUCPR macro CV=0.5526 | AUCPR macro Test=0.5748
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=None | ACC CV=0.8026 | ACC Train=0.8380 | ACC Test=0.8188 | F1 macro CV=0.7378 | F1 macro Test=0.7565 | ROC AUC OVR macro CV=0.9513 | ROC AUC OVR macro Test=0.9475 | AUCPR macro CV=0.8533 | AUCPR macro Test=0.8569
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=None | ACC CV=0.7605 | ACC Train=0.8051 | ACC Test=0.8003 | F1 macro CV=0.6966 | F1 macro Test=0.7362 | ROC AUC OVR macro CV=0.9487 | ROC AUC OVR macro Test=0.9477 | AUCPR macro CV=0.8462 | AUCPR macro Test=0.8551
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=None | ACC CV=0.7486 | ACC Train=0.7913 | ACC Test=0.7700 | F1 macro CV=0.6787 | F1 macro Test=0.7015 | ROC AUC OVR macro CV=0.9307 | ROC AUC OVR macro Test=0.9330 | AUCPR macro CV=0.8087 | AUCPR macro Test=0.8305
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=None | ACC CV=0.7306 | ACC Train=0.7414 | ACC Test=0.7223 | F1 macro CV=0.6586 | F1 macro Test=0.6531 | ROC AUC OVR macro CV=0.9079 | ROC AUC OVR macro Test=0.9004 | AUCPR macro CV=0.7399 | AUCPR macro Test=0.7178
# Evaluating model: svm_reg
# svm_reg | Sampler=None | ACC CV=0.7270 | ACC Train=0.7489 | ACC Test=0.7383 | F1 macro CV=0.6645 | F1 macro Test=0.6790 | ROC AUC OVR macro CV=0.9383 | ROC AUC OVR macro Test=0.9369 | AUCPR macro CV=0.8426 | AUCPR macro Test=0.8502
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=None | ACC CV=0.7822 | ACC Train=0.8239 | ACC Test=0.7753 | F1 macro CV=0.7151 | F1 macro Test=0.7134 | ROC AUC OVR macro CV=0.9161 | ROC AUC OVR macro Test=0.9048 | AUCPR macro CV=0.8017 | AUCPR macro Test=0.7809
# Evaluating model: knn_reg
# knn_reg | Sampler=None | ACC CV=0.6681 | ACC Train=0.7656 | ACC Test=0.6847 | F1 macro CV=0.6287 | F1 macro Test=0.6437 | ROC AUC OVR macro CV=0.9281 | ROC AUC OVR macro Test=0.9176 | AUCPR macro CV=0.8143 | AUCPR macro Test=0.7994
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=None | ACC CV=0.7203 | ACC Train=0.7855 | ACC Test=0.7564 | F1 macro CV=0.6654 | F1 macro Test=0.6989 | ROC AUC OVR macro CV=0.8311 | ROC AUC OVR macro Test=0.8578 | AUCPR macro CV=0.6170 | AUCPR macro Test=0.6543
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=None | ACC CV=0.6113 | ACC Train=0.6707 | ACC Test=0.6537 | F1 macro CV=0.5414 | F1 macro Test=0.5871 | ROC AUC OVR macro CV=0.8545 | ROC AUC OVR macro Test=0.9016 | AUCPR macro CV=0.7165 | AUCPR macro Test=0.7632
# 	Evaluating with ROS sampler config: {2: 60}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.6595 | ACC Train=0.6823 | ACC Test=0.6613 | F1 macro CV=0.5917 | F1 macro Test=0.6026 | ROC AUC OVR macro CV=0.8030 | ROC AUC OVR macro Test=0.8259 | AUCPR macro CV=0.5683 | AUCPR macro Test=0.6032
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.8223 | ACC Train=0.8560 | ACC Test=0.8341 | F1 macro CV=0.7582 | F1 macro Test=0.7734 | ROC AUC OVR macro CV=0.9540 | ROC AUC OVR macro Test=0.9489 | AUCPR macro CV=0.8626 | AUCPR macro Test=0.8581
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.7764 | ACC Train=0.8299 | ACC Test=0.8132 | F1 macro CV=0.7110 | F1 macro Test=0.7516 | ROC AUC OVR macro CV=0.9526 | ROC AUC OVR macro Test=0.9487 | AUCPR macro CV=0.8551 | AUCPR macro Test=0.8570
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.7726 | ACC Train=0.8099 | ACC Test=0.7889 | F1 macro CV=0.7025 | F1 macro Test=0.7203 | ROC AUC OVR macro CV=0.9382 | ROC AUC OVR macro Test=0.9369 | AUCPR macro CV=0.8301 | AUCPR macro Test=0.8397
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.7417 | ACC Train=0.7486 | ACC Test=0.7289 | F1 macro CV=0.6705 | F1 macro Test=0.6619 | ROC AUC OVR macro CV=0.9095 | ROC AUC OVR macro Test=0.9089 | AUCPR macro CV=0.7457 | AUCPR macro Test=0.7364
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.7417 | ACC Train=0.7692 | ACC Test=0.7505 | F1 macro CV=0.6781 | F1 macro Test=0.6903 | ROC AUC OVR macro CV=0.9387 | ROC AUC OVR macro Test=0.9379 | AUCPR macro CV=0.8401 | AUCPR macro Test=0.8521
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.7972 | ACC Train=0.8454 | ACC Test=0.7895 | F1 macro CV=0.7278 | F1 macro Test=0.7274 | ROC AUC OVR macro CV=0.9185 | ROC AUC OVR macro Test=0.9087 | AUCPR macro CV=0.8038 | AUCPR macro Test=0.7857
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.6801 | ACC Train=0.7854 | ACC Test=0.6885 | F1 macro CV=0.6412 | F1 macro Test=0.6463 | ROC AUC OVR macro CV=0.9267 | ROC AUC OVR macro Test=0.9205 | AUCPR macro CV=0.8131 | AUCPR macro Test=0.8010
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.7510 | ACC Train=0.8063 | ACC Test=0.7707 | F1 macro CV=0.6926 | F1 macro Test=0.7125 | ROC AUC OVR macro CV=0.8508 | ROC AUC OVR macro Test=0.8668 | AUCPR macro CV=0.6452 | AUCPR macro Test=0.6704
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.6634 | ACC Train=0.7043 | ACC Test=0.6833 | F1 macro CV=0.5967 | F1 macro Test=0.6242 | ROC AUC OVR macro CV=0.8860 | ROC AUC OVR macro Test=0.8899 | AUCPR macro CV=0.7550 | AUCPR macro Test=0.7489
# 	Evaluating with SMOTE sampler config: {2: 60}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.6754 | ACC Train=0.7060 | ACC Test=0.6784 | F1 macro CV=0.6044 | F1 macro Test=0.6138 | ROC AUC OVR macro CV=0.8039 | ROC AUC OVR macro Test=0.8242 | AUCPR macro CV=0.5722 | AUCPR macro Test=0.6103
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.8294 | ACC Train=0.8599 | ACC Test=0.8369 | F1 macro CV=0.7663 | F1 macro Test=0.7754 | ROC AUC OVR macro CV=0.9545 | ROC AUC OVR macro Test=0.9492 | AUCPR macro CV=0.8651 | AUCPR macro Test=0.8602
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.7771 | ACC Train=0.8299 | ACC Test=0.8132 | F1 macro CV=0.7122 | F1 macro Test=0.7512 | ROC AUC OVR macro CV=0.9530 | ROC AUC OVR macro Test=0.9489 | AUCPR macro CV=0.8578 | AUCPR macro Test=0.8615
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.7780 | ACC Train=0.8149 | ACC Test=0.7892 | F1 macro CV=0.7089 | F1 macro Test=0.7198 | ROC AUC OVR macro CV=0.9387 | ROC AUC OVR macro Test=0.9362 | AUCPR macro CV=0.8317 | AUCPR macro Test=0.8382
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.7475 | ACC Train=0.7642 | ACC Test=0.7422 | F1 macro CV=0.6764 | F1 macro Test=0.6723 | ROC AUC OVR macro CV=0.9107 | ROC AUC OVR macro Test=0.9092 | AUCPR macro CV=0.7561 | AUCPR macro Test=0.7424
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.7494 | ACC Train=0.7708 | ACC Test=0.7505 | F1 macro CV=0.6870 | F1 macro Test=0.6918 | ROC AUC OVR macro CV=0.9383 | ROC AUC OVR macro Test=0.9375 | AUCPR macro CV=0.8374 | AUCPR macro Test=0.8475
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.7976 | ACC Train=0.8440 | ACC Test=0.7871 | F1 macro CV=0.7288 | F1 macro Test=0.7235 | ROC AUC OVR macro CV=0.9188 | ROC AUC OVR macro Test=0.9076 | AUCPR macro CV=0.8058 | AUCPR macro Test=0.7824
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.6765 | ACC Train=0.7750 | ACC Test=0.6833 | F1 macro CV=0.6415 | F1 macro Test=0.6450 | ROC AUC OVR macro CV=0.9298 | ROC AUC OVR macro Test=0.9220 | AUCPR macro CV=0.8170 | AUCPR macro Test=0.8044
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.7515 | ACC Train=0.8049 | ACC Test=0.7697 | F1 macro CV=0.6930 | F1 macro Test=0.7103 | ROC AUC OVR macro CV=0.8508 | ROC AUC OVR macro Test=0.8670 | AUCPR macro CV=0.6460 | AUCPR macro Test=0.6713
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.6636 | ACC Train=0.7144 | ACC Test=0.6937 | F1 macro CV=0.5974 | F1 macro Test=0.6358 | ROC AUC OVR macro CV=0.8829 | ROC AUC OVR macro Test=0.9038 | AUCPR macro CV=0.7518 | AUCPR macro Test=0.7657
# 	Evaluating with ROS sampler config: {2: 80}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.6947 | ACC Train=0.7063 | ACC Test=0.6840 | F1 macro CV=0.6244 | F1 macro Test=0.6225 | ROC AUC OVR macro CV=0.8300 | ROC AUC OVR macro Test=0.8259 | AUCPR macro CV=0.6104 | AUCPR macro Test=0.6132
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.8404 | ACC Train=0.8638 | ACC Test=0.8383 | F1 macro CV=0.7759 | F1 macro Test=0.7776 | ROC AUC OVR macro CV=0.9558 | ROC AUC OVR macro Test=0.9498 | AUCPR macro CV=0.8674 | AUCPR macro Test=0.8652
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.8223 | ACC Train=0.8469 | ACC Test=0.8261 | F1 macro CV=0.7596 | F1 macro Test=0.7639 | ROC AUC OVR macro CV=0.9547 | ROC AUC OVR macro Test=0.9497 | AUCPR macro CV=0.8613 | AUCPR macro Test=0.8589
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.7983 | ACC Train=0.8363 | ACC Test=0.8084 | F1 macro CV=0.7286 | F1 macro Test=0.7429 | ROC AUC OVR macro CV=0.9430 | ROC AUC OVR macro Test=0.9408 | AUCPR macro CV=0.8382 | AUCPR macro Test=0.8442
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.7498 | ACC Train=0.7688 | ACC Test=0.7348 | F1 macro CV=0.6764 | F1 macro Test=0.6654 | ROC AUC OVR macro CV=0.9141 | ROC AUC OVR macro Test=0.9104 | AUCPR macro CV=0.7532 | AUCPR macro Test=0.7477
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.7528 | ACC Train=0.7910 | ACC Test=0.7659 | F1 macro CV=0.6882 | F1 macro Test=0.7055 | ROC AUC OVR macro CV=0.9408 | ROC AUC OVR macro Test=0.9385 | AUCPR macro CV=0.8413 | AUCPR macro Test=0.8516
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.8127 | ACC Train=0.8661 | ACC Test=0.7969 | F1 macro CV=0.7411 | F1 macro Test=0.7302 | ROC AUC OVR macro CV=0.9212 | ROC AUC OVR macro Test=0.9128 | AUCPR macro CV=0.8063 | AUCPR macro Test=0.7893
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.6998 | ACC Train=0.8200 | ACC Test=0.6983 | F1 macro CV=0.6556 | F1 macro Test=0.6499 | ROC AUC OVR macro CV=0.9291 | ROC AUC OVR macro Test=0.9203 | AUCPR macro CV=0.8150 | AUCPR macro Test=0.7969
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.7808 | ACC Train=0.8263 | ACC Test=0.7913 | F1 macro CV=0.7205 | F1 macro Test=0.7305 | ROC AUC OVR macro CV=0.8729 | ROC AUC OVR macro Test=0.8808 | AUCPR macro CV=0.6769 | AUCPR macro Test=0.6921
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.7009 | ACC Train=0.7655 | ACC Test=0.7174 | F1 macro CV=0.6346 | F1 macro Test=0.6568 | ROC AUC OVR macro CV=0.9011 | ROC AUC OVR macro Test=0.9107 | AUCPR macro CV=0.7729 | AUCPR macro Test=0.7808
# 	Evaluating with SMOTE sampler config: {2: 80}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.7029 | ACC Train=0.7282 | ACC Test=0.6843 | F1 macro CV=0.6251 | F1 macro Test=0.6187 | ROC AUC OVR macro CV=0.8241 | ROC AUC OVR macro Test=0.8357 | AUCPR macro CV=0.6011 | AUCPR macro Test=0.6222
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.8556 | ACC Train=0.8763 | ACC Test=0.8460 | F1 macro CV=0.7928 | F1 macro Test=0.7840 | ROC AUC OVR macro CV=0.9562 | ROC AUC OVR macro Test=0.9503 | AUCPR macro CV=0.8669 | AUCPR macro Test=0.8680
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.8274 | ACC Train=0.8504 | ACC Test=0.8321 | F1 macro CV=0.7662 | F1 macro Test=0.7717 | ROC AUC OVR macro CV=0.9553 | ROC AUC OVR macro Test=0.9502 | AUCPR macro CV=0.8623 | AUCPR macro Test=0.8620
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.8127 | ACC Train=0.8489 | ACC Test=0.8150 | F1 macro CV=0.7447 | F1 macro Test=0.7473 | ROC AUC OVR macro CV=0.9443 | ROC AUC OVR macro Test=0.9414 | AUCPR macro CV=0.8403 | AUCPR macro Test=0.8466
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.7596 | ACC Train=0.7858 | ACC Test=0.7530 | F1 macro CV=0.6870 | F1 macro Test=0.6850 | ROC AUC OVR macro CV=0.9163 | ROC AUC OVR macro Test=0.9094 | AUCPR macro CV=0.7687 | AUCPR macro Test=0.7491
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.7617 | ACC Train=0.7946 | ACC Test=0.7648 | F1 macro CV=0.6994 | F1 macro Test=0.7072 | ROC AUC OVR macro CV=0.9412 | ROC AUC OVR macro Test=0.9374 | AUCPR macro CV=0.8379 | AUCPR macro Test=0.8397
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.8124 | ACC Train=0.8651 | ACC Test=0.7972 | F1 macro CV=0.7408 | F1 macro Test=0.7311 | ROC AUC OVR macro CV=0.9215 | ROC AUC OVR macro Test=0.9115 | AUCPR macro CV=0.8074 | AUCPR macro Test=0.7872
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.6815 | ACC Train=0.7924 | ACC Test=0.6857 | F1 macro CV=0.6418 | F1 macro Test=0.6479 | ROC AUC OVR macro CV=0.9343 | ROC AUC OVR macro Test=0.9249 | AUCPR macro CV=0.8225 | AUCPR macro Test=0.8059
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.7835 | ACC Train=0.8279 | ACC Test=0.7951 | F1 macro CV=0.7245 | F1 macro Test=0.7378 | ROC AUC OVR macro CV=0.8731 | ROC AUC OVR macro Test=0.8803 | AUCPR macro CV=0.6799 | AUCPR macro Test=0.6925
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.7027 | ACC Train=0.7760 | ACC Test=0.7345 | F1 macro CV=0.6362 | F1 macro Test=0.6741 | ROC AUC OVR macro CV=0.9074 | ROC AUC OVR macro Test=0.9121 | AUCPR macro CV=0.7832 | AUCPR macro Test=0.7848
# 	Evaluating with ROS sampler config: {2: 100}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.6956 | ACC Train=0.7149 | ACC Test=0.6857 | F1 macro CV=0.6224 | F1 macro Test=0.6145 | ROC AUC OVR macro CV=0.8315 | ROC AUC OVR macro Test=0.8291 | AUCPR macro CV=0.6155 | AUCPR macro Test=0.6078
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.8498 | ACC Train=0.8695 | ACC Test=0.8411 | F1 macro CV=0.7876 | F1 macro Test=0.7815 | ROC AUC OVR macro CV=0.9563 | ROC AUC OVR macro Test=0.9507 | AUCPR macro CV=0.8665 | AUCPR macro Test=0.8655
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.8335 | ACC Train=0.8549 | ACC Test=0.8338 | F1 macro CV=0.7704 | F1 macro Test=0.7749 | ROC AUC OVR macro CV=0.9561 | ROC AUC OVR macro Test=0.9503 | AUCPR macro CV=0.8624 | AUCPR macro Test=0.8611
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.8102 | ACC Train=0.8502 | ACC Test=0.8157 | F1 macro CV=0.7400 | F1 macro Test=0.7527 | ROC AUC OVR macro CV=0.9466 | ROC AUC OVR macro Test=0.9430 | AUCPR macro CV=0.8449 | AUCPR macro Test=0.8412
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.7393 | ACC Train=0.7548 | ACC Test=0.7261 | F1 macro CV=0.6665 | F1 macro Test=0.6600 | ROC AUC OVR macro CV=0.9155 | ROC AUC OVR macro Test=0.9094 | AUCPR macro CV=0.7564 | AUCPR macro Test=0.7440
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.7706 | ACC Train=0.8083 | ACC Test=0.7746 | F1 macro CV=0.7050 | F1 macro Test=0.7136 | ROC AUC OVR macro CV=0.9427 | ROC AUC OVR macro Test=0.9405 | AUCPR macro CV=0.8426 | AUCPR macro Test=0.8514
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.8159 | ACC Train=0.8787 | ACC Test=0.8017 | F1 macro CV=0.7409 | F1 macro Test=0.7310 | ROC AUC OVR macro CV=0.9213 | ROC AUC OVR macro Test=0.9146 | AUCPR macro CV=0.8029 | AUCPR macro Test=0.7940
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.7153 | ACC Train=0.8424 | ACC Test=0.7111 | F1 macro CV=0.6678 | F1 macro Test=0.6606 | ROC AUC OVR macro CV=0.9300 | ROC AUC OVR macro Test=0.9210 | AUCPR macro CV=0.8163 | AUCPR macro Test=0.8008
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.7994 | ACC Train=0.8373 | ACC Test=0.7997 | F1 macro CV=0.7368 | F1 macro Test=0.7380 | ROC AUC OVR macro CV=0.8865 | ROC AUC OVR macro Test=0.8877 | AUCPR macro CV=0.6985 | AUCPR macro Test=0.7050
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.7236 | ACC Train=0.7965 | ACC Test=0.7530 | F1 macro CV=0.6578 | F1 macro Test=0.6964 | ROC AUC OVR macro CV=0.9158 | ROC AUC OVR macro Test=0.9175 | AUCPR macro CV=0.7939 | AUCPR macro Test=0.7909
# 	Evaluating with SMOTE sampler config: {2: 100}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.7064 | ACC Train=0.7421 | ACC Test=0.7174 | F1 macro CV=0.6257 | F1 macro Test=0.6507 | ROC AUC OVR macro CV=0.8261 | ROC AUC OVR macro Test=0.8361 | AUCPR macro CV=0.6050 | AUCPR macro Test=0.6339
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.8662 | ACC Train=0.8860 | ACC Test=0.8526 | F1 macro CV=0.8036 | F1 macro Test=0.7937 | ROC AUC OVR macro CV=0.9574 | ROC AUC OVR macro Test=0.9516 | AUCPR macro CV=0.8673 | AUCPR macro Test=0.8669
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.8405 | ACC Train=0.8644 | ACC Test=0.8387 | F1 macro CV=0.7788 | F1 macro Test=0.7796 | ROC AUC OVR macro CV=0.9564 | ROC AUC OVR macro Test=0.9518 | AUCPR macro CV=0.8629 | AUCPR macro Test=0.8659
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.8306 | ACC Train=0.8669 | ACC Test=0.8279 | F1 macro CV=0.7632 | F1 macro Test=0.7629 | ROC AUC OVR macro CV=0.9471 | ROC AUC OVR macro Test=0.9416 | AUCPR macro CV=0.8447 | AUCPR macro Test=0.8479
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.7658 | ACC Train=0.7915 | ACC Test=0.7561 | F1 macro CV=0.6943 | F1 macro Test=0.6848 | ROC AUC OVR macro CV=0.9169 | ROC AUC OVR macro Test=0.9080 | AUCPR macro CV=0.7678 | AUCPR macro Test=0.7534
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.7802 | ACC Train=0.8093 | ACC Test=0.7739 | F1 macro CV=0.7182 | F1 macro Test=0.7146 | ROC AUC OVR macro CV=0.9432 | ROC AUC OVR macro Test=0.9393 | AUCPR macro CV=0.8387 | AUCPR macro Test=0.8381
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.8170 | ACC Train=0.8800 | ACC Test=0.7997 | F1 macro CV=0.7446 | F1 macro Test=0.7301 | ROC AUC OVR macro CV=0.9214 | ROC AUC OVR macro Test=0.9137 | AUCPR macro CV=0.8038 | AUCPR macro Test=0.7907
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.6875 | ACC Train=0.8104 | ACC Test=0.6854 | F1 macro CV=0.6424 | F1 macro Test=0.6404 | ROC AUC OVR macro CV=0.9364 | ROC AUC OVR macro Test=0.9270 | AUCPR macro CV=0.8233 | AUCPR macro Test=0.8118
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.8031 | ACC Train=0.8420 | ACC Test=0.8056 | F1 macro CV=0.7425 | F1 macro Test=0.7487 | ROC AUC OVR macro CV=0.8868 | ROC AUC OVR macro Test=0.8880 | AUCPR macro CV=0.7032 | AUCPR macro Test=0.7108
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.7262 | ACC Train=0.8231 | ACC Test=0.7679 | F1 macro CV=0.6625 | F1 macro Test=0.7078 | ROC AUC OVR macro CV=0.9135 | ROC AUC OVR macro Test=0.9199 | AUCPR macro CV=0.7914 | AUCPR macro Test=0.8010
# 	Pipeline weight config: w_c2_10
# 	Evaluating multiclass classification for HY3_v2
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=None | ACC CV=0.4118 | ACC Train=0.3951 | ACC Test=0.4000 | F1 macro CV=0.3475 | F1 macro Test=0.3652 | ROC AUC OVR macro CV=0.7007 | ROC AUC OVR macro Test=0.7787 | AUCPR macro CV=0.4852 | AUCPR macro Test=0.5618
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=None | ACC CV=0.4777 | ACC Train=0.4859 | ACC Test=0.4791 | F1 macro CV=0.3802 | F1 macro Test=0.3898 | ROC AUC OVR macro CV=0.7889 | ROC AUC OVR macro Test=0.8751 | AUCPR macro CV=0.7138 | AUCPR macro Test=0.7885
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=None | ACC CV=0.4454 | ACC Train=0.4608 | ACC Test=0.4596 | F1 macro CV=0.3705 | F1 macro Test=0.3772 | ROC AUC OVR macro CV=0.7390 | ROC AUC OVR macro Test=0.8154 | AUCPR macro CV=0.6710 | AUCPR macro Test=0.7390
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=None | ACC CV=0.7486 | ACC Train=0.7913 | ACC Test=0.7700 | F1 macro CV=0.6787 | F1 macro Test=0.7015 | ROC AUC OVR macro CV=0.9307 | ROC AUC OVR macro Test=0.9330 | AUCPR macro CV=0.8087 | AUCPR macro Test=0.8305
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=None | ACC CV=0.7306 | ACC Train=0.7414 | ACC Test=0.7223 | F1 macro CV=0.6586 | F1 macro Test=0.6531 | ROC AUC OVR macro CV=0.9079 | ROC AUC OVR macro Test=0.9004 | AUCPR macro CV=0.7399 | AUCPR macro Test=0.7178
# Evaluating model: svm_reg
# svm_reg | Sampler=None | ACC CV=0.4619 | ACC Train=0.4836 | ACC Test=0.4801 | F1 macro CV=0.3725 | F1 macro Test=0.3948 | ROC AUC OVR macro CV=0.9326 | ROC AUC OVR macro Test=0.9312 | AUCPR macro CV=0.8263 | AUCPR macro Test=0.8288
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=None | ACC CV=0.7677 | ACC Train=0.8133 | ACC Test=0.7561 | F1 macro CV=0.6985 | F1 macro Test=0.6914 | ROC AUC OVR macro CV=0.9135 | ROC AUC OVR macro Test=0.9024 | AUCPR macro CV=0.7969 | AUCPR macro Test=0.7746
# Evaluating model: knn_reg
# knn_reg | Sampler=None | ACC CV=0.6681 | ACC Train=0.7656 | ACC Test=0.6847 | F1 macro CV=0.6287 | F1 macro Test=0.6437 | ROC AUC OVR macro CV=0.9281 | ROC AUC OVR macro Test=0.9176 | AUCPR macro CV=0.8143 | AUCPR macro Test=0.7994
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=None | ACC CV=0.7203 | ACC Train=0.7855 | ACC Test=0.7564 | F1 macro CV=0.6654 | F1 macro Test=0.6989 | ROC AUC OVR macro CV=0.8311 | ROC AUC OVR macro Test=0.8578 | AUCPR macro CV=0.6170 | AUCPR macro Test=0.6543
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=None | ACC CV=0.6113 | ACC Train=0.6707 | ACC Test=0.6537 | F1 macro CV=0.5414 | F1 macro Test=0.5871 | ROC AUC OVR macro CV=0.8545 | ROC AUC OVR macro Test=0.9016 | AUCPR macro CV=0.7165 | AUCPR macro Test=0.7632
# 	Evaluating with ROS sampler config: {2: 60}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.4254 | ACC Train=0.4975 | ACC Test=0.4889 | F1 macro CV=0.3646 | F1 macro Test=0.4389 | ROC AUC OVR macro CV=0.7250 | ROC AUC OVR macro Test=0.7560 | AUCPR macro CV=0.5091 | AUCPR macro Test=0.5403
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.4846 | ACC Train=0.5184 | ACC Test=0.5021 | F1 macro CV=0.3882 | F1 macro Test=0.4213 | ROC AUC OVR macro CV=0.8498 | ROC AUC OVR macro Test=0.8935 | AUCPR macro CV=0.7648 | AUCPR macro Test=0.8032
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.4588 | ACC Train=0.4775 | ACC Test=0.4659 | F1 macro CV=0.3762 | F1 macro Test=0.3792 | ROC AUC OVR macro CV=0.7751 | ROC AUC OVR macro Test=0.8491 | AUCPR macro CV=0.7076 | AUCPR macro Test=0.7644
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.7726 | ACC Train=0.8099 | ACC Test=0.7889 | F1 macro CV=0.7025 | F1 macro Test=0.7203 | ROC AUC OVR macro CV=0.9382 | ROC AUC OVR macro Test=0.9369 | AUCPR macro CV=0.8301 | AUCPR macro Test=0.8397
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.7417 | ACC Train=0.7486 | ACC Test=0.7289 | F1 macro CV=0.6705 | F1 macro Test=0.6619 | ROC AUC OVR macro CV=0.9095 | ROC AUC OVR macro Test=0.9089 | AUCPR macro CV=0.7457 | AUCPR macro Test=0.7364
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.4740 | ACC Train=0.5272 | ACC Test=0.5167 | F1 macro CV=0.3861 | F1 macro Test=0.4421 | ROC AUC OVR macro CV=0.9367 | ROC AUC OVR macro Test=0.9339 | AUCPR macro CV=0.8300 | AUCPR macro Test=0.8331
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.7852 | ACC Train=0.8331 | ACC Test=0.7721 | F1 macro CV=0.7152 | F1 macro Test=0.7085 | ROC AUC OVR macro CV=0.9164 | ROC AUC OVR macro Test=0.9065 | AUCPR macro CV=0.7995 | AUCPR macro Test=0.7802
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.6801 | ACC Train=0.7854 | ACC Test=0.6885 | F1 macro CV=0.6412 | F1 macro Test=0.6463 | ROC AUC OVR macro CV=0.9267 | ROC AUC OVR macro Test=0.9205 | AUCPR macro CV=0.8131 | AUCPR macro Test=0.8010
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.7510 | ACC Train=0.8063 | ACC Test=0.7707 | F1 macro CV=0.6926 | F1 macro Test=0.7125 | ROC AUC OVR macro CV=0.8508 | ROC AUC OVR macro Test=0.8668 | AUCPR macro CV=0.6452 | AUCPR macro Test=0.6704
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.6634 | ACC Train=0.7043 | ACC Test=0.6833 | F1 macro CV=0.5967 | F1 macro Test=0.6242 | ROC AUC OVR macro CV=0.8860 | ROC AUC OVR macro Test=0.8899 | AUCPR macro CV=0.7550 | AUCPR macro Test=0.7489
# 	Evaluating with SMOTE sampler config: {2: 60}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.4238 | ACC Train=0.4850 | ACC Test=0.4808 | F1 macro CV=0.3615 | F1 macro Test=0.4313 | ROC AUC OVR macro CV=0.7390 | ROC AUC OVR macro Test=0.7545 | AUCPR macro CV=0.5204 | AUCPR macro Test=0.5425
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.4905 | ACC Train=0.5253 | ACC Test=0.5118 | F1 macro CV=0.3934 | F1 macro Test=0.4322 | ROC AUC OVR macro CV=0.8593 | ROC AUC OVR macro Test=0.8967 | AUCPR macro CV=0.7743 | AUCPR macro Test=0.8080
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.4613 | ACC Train=0.4772 | ACC Test=0.4652 | F1 macro CV=0.3775 | F1 macro Test=0.3788 | ROC AUC OVR macro CV=0.7794 | ROC AUC OVR macro Test=0.8465 | AUCPR macro CV=0.7109 | AUCPR macro Test=0.7644
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.7780 | ACC Train=0.8149 | ACC Test=0.7892 | F1 macro CV=0.7089 | F1 macro Test=0.7198 | ROC AUC OVR macro CV=0.9387 | ROC AUC OVR macro Test=0.9362 | AUCPR macro CV=0.8317 | AUCPR macro Test=0.8382
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.7475 | ACC Train=0.7642 | ACC Test=0.7422 | F1 macro CV=0.6764 | F1 macro Test=0.6723 | ROC AUC OVR macro CV=0.9107 | ROC AUC OVR macro Test=0.9092 | AUCPR macro CV=0.7561 | AUCPR macro Test=0.7424
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.4717 | ACC Train=0.5250 | ACC Test=0.5132 | F1 macro CV=0.3840 | F1 macro Test=0.4386 | ROC AUC OVR macro CV=0.9359 | ROC AUC OVR macro Test=0.9331 | AUCPR macro CV=0.8273 | AUCPR macro Test=0.8289
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.7843 | ACC Train=0.8330 | ACC Test=0.7718 | F1 macro CV=0.7136 | F1 macro Test=0.7078 | ROC AUC OVR macro CV=0.9167 | ROC AUC OVR macro Test=0.9055 | AUCPR macro CV=0.8016 | AUCPR macro Test=0.7772
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.6765 | ACC Train=0.7750 | ACC Test=0.6833 | F1 macro CV=0.6415 | F1 macro Test=0.6450 | ROC AUC OVR macro CV=0.9298 | ROC AUC OVR macro Test=0.9220 | AUCPR macro CV=0.8170 | AUCPR macro Test=0.8044
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.7515 | ACC Train=0.8049 | ACC Test=0.7697 | F1 macro CV=0.6930 | F1 macro Test=0.7103 | ROC AUC OVR macro CV=0.8508 | ROC AUC OVR macro Test=0.8670 | AUCPR macro CV=0.6460 | AUCPR macro Test=0.6713
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.6636 | ACC Train=0.7144 | ACC Test=0.6937 | F1 macro CV=0.5974 | F1 macro Test=0.6358 | ROC AUC OVR macro CV=0.8829 | ROC AUC OVR macro Test=0.9038 | AUCPR macro CV=0.7518 | AUCPR macro Test=0.7657
# 	Evaluating with ROS sampler config: {2: 80}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.4411 | ACC Train=0.4991 | ACC Test=0.4732 | F1 macro CV=0.3907 | F1 macro Test=0.4313 | ROC AUC OVR macro CV=0.7470 | ROC AUC OVR macro Test=0.7519 | AUCPR macro CV=0.5330 | AUCPR macro Test=0.5372
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.5137 | ACC Train=0.5707 | ACC Test=0.5355 | F1 macro CV=0.4268 | F1 macro Test=0.4628 | ROC AUC OVR macro CV=0.8926 | ROC AUC OVR macro Test=0.9055 | AUCPR macro CV=0.7994 | AUCPR macro Test=0.8165
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.4709 | ACC Train=0.5023 | ACC Test=0.4780 | F1 macro CV=0.3805 | F1 macro Test=0.3876 | ROC AUC OVR macro CV=0.8350 | ROC AUC OVR macro Test=0.8738 | AUCPR macro CV=0.7516 | AUCPR macro Test=0.7902
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.7983 | ACC Train=0.8363 | ACC Test=0.8084 | F1 macro CV=0.7286 | F1 macro Test=0.7429 | ROC AUC OVR macro CV=0.9430 | ROC AUC OVR macro Test=0.9408 | AUCPR macro CV=0.8382 | AUCPR macro Test=0.8442
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.7498 | ACC Train=0.7688 | ACC Test=0.7348 | F1 macro CV=0.6764 | F1 macro Test=0.6654 | ROC AUC OVR macro CV=0.9141 | ROC AUC OVR macro Test=0.9104 | AUCPR macro CV=0.7532 | AUCPR macro Test=0.7477
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.5308 | ACC Train=0.6312 | ACC Test=0.6035 | F1 macro CV=0.4573 | F1 macro Test=0.5440 | ROC AUC OVR macro CV=0.9406 | ROC AUC OVR macro Test=0.9359 | AUCPR macro CV=0.8341 | AUCPR macro Test=0.8324
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.8019 | ACC Train=0.8555 | ACC Test=0.7854 | F1 macro CV=0.7295 | F1 macro Test=0.7187 | ROC AUC OVR macro CV=0.9192 | ROC AUC OVR macro Test=0.9110 | AUCPR macro CV=0.8021 | AUCPR macro Test=0.7850
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.6998 | ACC Train=0.8200 | ACC Test=0.6983 | F1 macro CV=0.6556 | F1 macro Test=0.6499 | ROC AUC OVR macro CV=0.9291 | ROC AUC OVR macro Test=0.9203 | AUCPR macro CV=0.8150 | AUCPR macro Test=0.7969
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.7808 | ACC Train=0.8263 | ACC Test=0.7913 | F1 macro CV=0.7205 | F1 macro Test=0.7305 | ROC AUC OVR macro CV=0.8729 | ROC AUC OVR macro Test=0.8808 | AUCPR macro CV=0.6769 | AUCPR macro Test=0.6921
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.7009 | ACC Train=0.7655 | ACC Test=0.7174 | F1 macro CV=0.6346 | F1 macro Test=0.6568 | ROC AUC OVR macro CV=0.9011 | ROC AUC OVR macro Test=0.9107 | AUCPR macro CV=0.7729 | AUCPR macro Test=0.7808
# 	Evaluating with SMOTE sampler config: {2: 80}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.4746 | ACC Train=0.5170 | ACC Test=0.4892 | F1 macro CV=0.4222 | F1 macro Test=0.4605 | ROC AUC OVR macro CV=0.7557 | ROC AUC OVR macro Test=0.7517 | AUCPR macro CV=0.5365 | AUCPR macro Test=0.5398
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.5476 | ACC Train=0.6146 | ACC Test=0.5829 | F1 macro CV=0.4673 | F1 macro Test=0.5171 | ROC AUC OVR macro CV=0.9100 | ROC AUC OVR macro Test=0.9146 | AUCPR macro CV=0.8142 | AUCPR macro Test=0.8264
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.4728 | ACC Train=0.5021 | ACC Test=0.4777 | F1 macro CV=0.3812 | F1 macro Test=0.3871 | ROC AUC OVR macro CV=0.8418 | ROC AUC OVR macro Test=0.8780 | AUCPR macro CV=0.7597 | AUCPR macro Test=0.7913
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.8127 | ACC Train=0.8489 | ACC Test=0.8150 | F1 macro CV=0.7447 | F1 macro Test=0.7473 | ROC AUC OVR macro CV=0.9443 | ROC AUC OVR macro Test=0.9414 | AUCPR macro CV=0.8403 | AUCPR macro Test=0.8466
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.7596 | ACC Train=0.7858 | ACC Test=0.7530 | F1 macro CV=0.6870 | F1 macro Test=0.6850 | ROC AUC OVR macro CV=0.9163 | ROC AUC OVR macro Test=0.9094 | AUCPR macro CV=0.7687 | AUCPR macro Test=0.7491
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.5191 | ACC Train=0.6200 | ACC Test=0.5969 | F1 macro CV=0.4441 | F1 macro Test=0.5379 | ROC AUC OVR macro CV=0.9392 | ROC AUC OVR macro Test=0.9354 | AUCPR macro CV=0.8292 | AUCPR macro Test=0.8278
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.8023 | ACC Train=0.8554 | ACC Test=0.7854 | F1 macro CV=0.7294 | F1 macro Test=0.7186 | ROC AUC OVR macro CV=0.9197 | ROC AUC OVR macro Test=0.9091 | AUCPR macro CV=0.8031 | AUCPR macro Test=0.7824
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.6815 | ACC Train=0.7924 | ACC Test=0.6857 | F1 macro CV=0.6418 | F1 macro Test=0.6479 | ROC AUC OVR macro CV=0.9343 | ROC AUC OVR macro Test=0.9249 | AUCPR macro CV=0.8225 | AUCPR macro Test=0.8059
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.7835 | ACC Train=0.8279 | ACC Test=0.7951 | F1 macro CV=0.7245 | F1 macro Test=0.7378 | ROC AUC OVR macro CV=0.8731 | ROC AUC OVR macro Test=0.8803 | AUCPR macro CV=0.6799 | AUCPR macro Test=0.6925
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.7027 | ACC Train=0.7760 | ACC Test=0.7345 | F1 macro CV=0.6362 | F1 macro Test=0.6741 | ROC AUC OVR macro CV=0.9074 | ROC AUC OVR macro Test=0.9121 | AUCPR macro CV=0.7832 | AUCPR macro Test=0.7848
# 	Evaluating with ROS sampler config: {2: 100}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.4982 | ACC Train=0.5473 | ACC Test=0.4962 | F1 macro CV=0.4530 | F1 macro Test=0.4556 | ROC AUC OVR macro CV=0.7401 | ROC AUC OVR macro Test=0.7434 | AUCPR macro CV=0.5260 | AUCPR macro Test=0.5383
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.5517 | ACC Train=0.6200 | ACC Test=0.5847 | F1 macro CV=0.4737 | F1 macro Test=0.5204 | ROC AUC OVR macro CV=0.9068 | ROC AUC OVR macro Test=0.9129 | AUCPR macro CV=0.8098 | AUCPR macro Test=0.8229
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.4800 | ACC Train=0.5288 | ACC Test=0.4909 | F1 macro CV=0.3866 | F1 macro Test=0.4031 | ROC AUC OVR macro CV=0.8670 | ROC AUC OVR macro Test=0.8879 | AUCPR macro CV=0.7792 | AUCPR macro Test=0.8039
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.8102 | ACC Train=0.8502 | ACC Test=0.8157 | F1 macro CV=0.7400 | F1 macro Test=0.7527 | ROC AUC OVR macro CV=0.9466 | ROC AUC OVR macro Test=0.9430 | AUCPR macro CV=0.8449 | AUCPR macro Test=0.8412
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.7393 | ACC Train=0.7548 | ACC Test=0.7261 | F1 macro CV=0.6665 | F1 macro Test=0.6600 | ROC AUC OVR macro CV=0.9155 | ROC AUC OVR macro Test=0.9094 | AUCPR macro CV=0.7564 | AUCPR macro Test=0.7440
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.6062 | ACC Train=0.6997 | ACC Test=0.6631 | F1 macro CV=0.5425 | F1 macro Test=0.6036 | ROC AUC OVR macro CV=0.9423 | ROC AUC OVR macro Test=0.9387 | AUCPR macro CV=0.8352 | AUCPR macro Test=0.8357
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.8072 | ACC Train=0.8707 | ACC Test=0.7934 | F1 macro CV=0.7326 | F1 macro Test=0.7227 | ROC AUC OVR macro CV=0.9194 | ROC AUC OVR macro Test=0.9124 | AUCPR macro CV=0.7985 | AUCPR macro Test=0.7890
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.7153 | ACC Train=0.8424 | ACC Test=0.7111 | F1 macro CV=0.6678 | F1 macro Test=0.6606 | ROC AUC OVR macro CV=0.9300 | ROC AUC OVR macro Test=0.9210 | AUCPR macro CV=0.8163 | AUCPR macro Test=0.8008
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.7994 | ACC Train=0.8373 | ACC Test=0.7997 | F1 macro CV=0.7368 | F1 macro Test=0.7380 | ROC AUC OVR macro CV=0.8865 | ROC AUC OVR macro Test=0.8877 | AUCPR macro CV=0.6985 | AUCPR macro Test=0.7050
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.7236 | ACC Train=0.7965 | ACC Test=0.7530 | F1 macro CV=0.6578 | F1 macro Test=0.6964 | ROC AUC OVR macro CV=0.9158 | ROC AUC OVR macro Test=0.9175 | AUCPR macro CV=0.7939 | AUCPR macro Test=0.7909
# 	Evaluating with SMOTE sampler config: {2: 100}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.5100 | ACC Train=0.5666 | ACC Test=0.5174 | F1 macro CV=0.4622 | F1 macro Test=0.4685 | ROC AUC OVR macro CV=0.7516 | ROC AUC OVR macro Test=0.7470 | AUCPR macro CV=0.5387 | AUCPR macro Test=0.5391
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.6126 | ACC Train=0.6853 | ACC Test=0.6533 | F1 macro CV=0.5422 | F1 macro Test=0.5904 | ROC AUC OVR macro CV=0.9247 | ROC AUC OVR macro Test=0.9241 | AUCPR macro CV=0.8271 | AUCPR macro Test=0.8341
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.4815 | ACC Train=0.5371 | ACC Test=0.4969 | F1 macro CV=0.3867 | F1 macro Test=0.4112 | ROC AUC OVR macro CV=0.8745 | ROC AUC OVR macro Test=0.8944 | AUCPR macro CV=0.7849 | AUCPR macro Test=0.8118
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.8306 | ACC Train=0.8669 | ACC Test=0.8279 | F1 macro CV=0.7632 | F1 macro Test=0.7629 | ROC AUC OVR macro CV=0.9471 | ROC AUC OVR macro Test=0.9416 | AUCPR macro CV=0.8447 | AUCPR macro Test=0.8479
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.7658 | ACC Train=0.7915 | ACC Test=0.7561 | F1 macro CV=0.6943 | F1 macro Test=0.6848 | ROC AUC OVR macro CV=0.9169 | ROC AUC OVR macro Test=0.9080 | AUCPR macro CV=0.7678 | AUCPR macro Test=0.7534
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.5825 | ACC Train=0.6793 | ACC Test=0.6411 | F1 macro CV=0.5176 | F1 macro Test=0.5829 | ROC AUC OVR macro CV=0.9411 | ROC AUC OVR macro Test=0.9368 | AUCPR macro CV=0.8303 | AUCPR macro Test=0.8252
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.8068 | ACC Train=0.8713 | ACC Test=0.7909 | F1 macro CV=0.7325 | F1 macro Test=0.7205 | ROC AUC OVR macro CV=0.9195 | ROC AUC OVR macro Test=0.9113 | AUCPR macro CV=0.8000 | AUCPR macro Test=0.7862
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.6875 | ACC Train=0.8104 | ACC Test=0.6854 | F1 macro CV=0.6424 | F1 macro Test=0.6404 | ROC AUC OVR macro CV=0.9364 | ROC AUC OVR macro Test=0.9270 | AUCPR macro CV=0.8233 | AUCPR macro Test=0.8118
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.8031 | ACC Train=0.8420 | ACC Test=0.8056 | F1 macro CV=0.7425 | F1 macro Test=0.7487 | ROC AUC OVR macro CV=0.8868 | ROC AUC OVR macro Test=0.8880 | AUCPR macro CV=0.7032 | AUCPR macro Test=0.7108
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.7262 | ACC Train=0.8231 | ACC Test=0.7679 | F1 macro CV=0.6625 | F1 macro Test=0.7078 | ROC AUC OVR macro CV=0.9135 | ROC AUC OVR macro Test=0.9199 | AUCPR macro CV=0.7914 | AUCPR macro Test=0.8010
# 	Pipeline weight config: w_c2_20
# 	Evaluating multiclass classification for HY3_v2
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=None | ACC CV=0.3187 | ACC Train=0.3496 | ACC Test=0.3477 | F1 macro CV=0.2637 | F1 macro Test=0.3128 | ROC AUC OVR macro CV=0.6818 | ROC AUC OVR macro Test=0.7106 | AUCPR macro CV=0.4703 | AUCPR macro Test=0.5054
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=None | ACC CV=0.4682 | ACC Train=0.4689 | ACC Test=0.4669 | F1 macro CV=0.3782 | F1 macro Test=0.3808 | ROC AUC OVR macro CV=0.7337 | ROC AUC OVR macro Test=0.8262 | AUCPR macro CV=0.6627 | AUCPR macro Test=0.7432
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=None | ACC CV=0.3917 | ACC Train=0.4383 | ACC Test=0.4362 | F1 macro CV=0.3423 | F1 macro Test=0.3665 | ROC AUC OVR macro CV=0.7071 | ROC AUC OVR macro Test=0.7470 | AUCPR macro CV=0.6461 | AUCPR macro Test=0.6839
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=None | ACC CV=0.7486 | ACC Train=0.7913 | ACC Test=0.7700 | F1 macro CV=0.6787 | F1 macro Test=0.7015 | ROC AUC OVR macro CV=0.9307 | ROC AUC OVR macro Test=0.9330 | AUCPR macro CV=0.8087 | AUCPR macro Test=0.8305
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=None | ACC CV=0.7306 | ACC Train=0.7414 | ACC Test=0.7223 | F1 macro CV=0.6586 | F1 macro Test=0.6531 | ROC AUC OVR macro CV=0.9079 | ROC AUC OVR macro Test=0.9004 | AUCPR macro CV=0.7399 | AUCPR macro Test=0.7178
# Evaluating model: svm_reg
# svm_reg | Sampler=None | ACC CV=0.4619 | ACC Train=0.4836 | ACC Test=0.4801 | F1 macro CV=0.3725 | F1 macro Test=0.3948 | ROC AUC OVR macro CV=0.9326 | ROC AUC OVR macro Test=0.9312 | AUCPR macro CV=0.8263 | AUCPR macro Test=0.8288
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=None | ACC CV=0.7640 | ACC Train=0.8090 | ACC Test=0.7530 | F1 macro CV=0.6944 | F1 macro Test=0.6882 | ROC AUC OVR macro CV=0.9129 | ROC AUC OVR macro Test=0.9017 | AUCPR macro CV=0.7958 | AUCPR macro Test=0.7729
# Evaluating model: knn_reg
# knn_reg | Sampler=None | ACC CV=0.6681 | ACC Train=0.7656 | ACC Test=0.6847 | F1 macro CV=0.6287 | F1 macro Test=0.6437 | ROC AUC OVR macro CV=0.9281 | ROC AUC OVR macro Test=0.9176 | AUCPR macro CV=0.8143 | AUCPR macro Test=0.7994
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=None | ACC CV=0.7203 | ACC Train=0.7855 | ACC Test=0.7564 | F1 macro CV=0.6654 | F1 macro Test=0.6989 | ROC AUC OVR macro CV=0.8311 | ROC AUC OVR macro Test=0.8578 | AUCPR macro CV=0.6170 | AUCPR macro Test=0.6543
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=None | ACC CV=0.6113 | ACC Train=0.6707 | ACC Test=0.6537 | F1 macro CV=0.5414 | F1 macro Test=0.5871 | ROC AUC OVR macro CV=0.8545 | ROC AUC OVR macro Test=0.9016 | AUCPR macro CV=0.7165 | AUCPR macro Test=0.7632
# 	Evaluating with ROS sampler config: {2: 60}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.3509 | ACC Train=0.4109 | ACC Test=0.3916 | F1 macro CV=0.3054 | F1 macro Test=0.3539 | ROC AUC OVR macro CV=0.6695 | ROC AUC OVR macro Test=0.7145 | AUCPR macro CV=0.4647 | AUCPR macro Test=0.4999
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.4716 | ACC Train=0.4835 | ACC Test=0.4742 | F1 macro CV=0.3799 | F1 macro Test=0.3884 | ROC AUC OVR macro CV=0.7824 | ROC AUC OVR macro Test=0.8576 | AUCPR macro CV=0.7053 | AUCPR macro Test=0.7671
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.4335 | ACC Train=0.4642 | ACC Test=0.4509 | F1 macro CV=0.3651 | F1 macro Test=0.3737 | ROC AUC OVR macro CV=0.7208 | ROC AUC OVR macro Test=0.7878 | AUCPR macro CV=0.6588 | AUCPR macro Test=0.7110
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.7726 | ACC Train=0.8099 | ACC Test=0.7889 | F1 macro CV=0.7025 | F1 macro Test=0.7203 | ROC AUC OVR macro CV=0.9382 | ROC AUC OVR macro Test=0.9369 | AUCPR macro CV=0.8301 | AUCPR macro Test=0.8397
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.7417 | ACC Train=0.7486 | ACC Test=0.7289 | F1 macro CV=0.6705 | F1 macro Test=0.6619 | ROC AUC OVR macro CV=0.9095 | ROC AUC OVR macro Test=0.9089 | AUCPR macro CV=0.7457 | AUCPR macro Test=0.7364
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.4740 | ACC Train=0.5272 | ACC Test=0.5167 | F1 macro CV=0.3861 | F1 macro Test=0.4421 | ROC AUC OVR macro CV=0.9367 | ROC AUC OVR macro Test=0.9339 | AUCPR macro CV=0.8300 | AUCPR macro Test=0.8331
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.7816 | ACC Train=0.8277 | ACC Test=0.7683 | F1 macro CV=0.7113 | F1 macro Test=0.7042 | ROC AUC OVR macro CV=0.9159 | ROC AUC OVR macro Test=0.9058 | AUCPR macro CV=0.7985 | AUCPR macro Test=0.7783
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.6801 | ACC Train=0.7854 | ACC Test=0.6885 | F1 macro CV=0.6412 | F1 macro Test=0.6463 | ROC AUC OVR macro CV=0.9267 | ROC AUC OVR macro Test=0.9205 | AUCPR macro CV=0.8131 | AUCPR macro Test=0.8010
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.7510 | ACC Train=0.8063 | ACC Test=0.7707 | F1 macro CV=0.6926 | F1 macro Test=0.7125 | ROC AUC OVR macro CV=0.8508 | ROC AUC OVR macro Test=0.8668 | AUCPR macro CV=0.6452 | AUCPR macro Test=0.6704
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.6634 | ACC Train=0.7043 | ACC Test=0.6833 | F1 macro CV=0.5967 | F1 macro Test=0.6242 | ROC AUC OVR macro CV=0.8860 | ROC AUC OVR macro Test=0.8899 | AUCPR macro CV=0.7550 | AUCPR macro Test=0.7489
# 	Evaluating with SMOTE sampler config: {2: 60}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.3612 | ACC Train=0.4171 | ACC Test=0.4003 | F1 macro CV=0.3131 | F1 macro Test=0.3685 | ROC AUC OVR macro CV=0.6752 | ROC AUC OVR macro Test=0.7293 | AUCPR macro CV=0.4719 | AUCPR macro Test=0.5144
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.4765 | ACC Train=0.4863 | ACC Test=0.4746 | F1 macro CV=0.3822 | F1 macro Test=0.3886 | ROC AUC OVR macro CV=0.7962 | ROC AUC OVR macro Test=0.8614 | AUCPR macro CV=0.7184 | AUCPR macro Test=0.7726
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.4362 | ACC Train=0.4626 | ACC Test=0.4477 | F1 macro CV=0.3665 | F1 macro Test=0.3719 | ROC AUC OVR macro CV=0.7235 | ROC AUC OVR macro Test=0.7838 | AUCPR macro CV=0.6615 | AUCPR macro Test=0.7074
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.7780 | ACC Train=0.8149 | ACC Test=0.7892 | F1 macro CV=0.7089 | F1 macro Test=0.7198 | ROC AUC OVR macro CV=0.9387 | ROC AUC OVR macro Test=0.9362 | AUCPR macro CV=0.8317 | AUCPR macro Test=0.8382
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.7475 | ACC Train=0.7642 | ACC Test=0.7422 | F1 macro CV=0.6764 | F1 macro Test=0.6723 | ROC AUC OVR macro CV=0.9107 | ROC AUC OVR macro Test=0.9092 | AUCPR macro CV=0.7561 | AUCPR macro Test=0.7424
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.4717 | ACC Train=0.5250 | ACC Test=0.5132 | F1 macro CV=0.3840 | F1 macro Test=0.4386 | ROC AUC OVR macro CV=0.9359 | ROC AUC OVR macro Test=0.9331 | AUCPR macro CV=0.8273 | AUCPR macro Test=0.8289
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.7812 | ACC Train=0.8296 | ACC Test=0.7655 | F1 macro CV=0.7106 | F1 macro Test=0.7003 | ROC AUC OVR macro CV=0.9162 | ROC AUC OVR macro Test=0.9049 | AUCPR macro CV=0.8004 | AUCPR macro Test=0.7760
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.6765 | ACC Train=0.7750 | ACC Test=0.6833 | F1 macro CV=0.6415 | F1 macro Test=0.6450 | ROC AUC OVR macro CV=0.9298 | ROC AUC OVR macro Test=0.9220 | AUCPR macro CV=0.8170 | AUCPR macro Test=0.8044
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.7515 | ACC Train=0.8049 | ACC Test=0.7697 | F1 macro CV=0.6930 | F1 macro Test=0.7103 | ROC AUC OVR macro CV=0.8508 | ROC AUC OVR macro Test=0.8670 | AUCPR macro CV=0.6460 | AUCPR macro Test=0.6713
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.6636 | ACC Train=0.7144 | ACC Test=0.6937 | F1 macro CV=0.5974 | F1 macro Test=0.6358 | ROC AUC OVR macro CV=0.8829 | ROC AUC OVR macro Test=0.9038 | AUCPR macro CV=0.7518 | AUCPR macro Test=0.7657
# 	Evaluating with ROS sampler config: {2: 80}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.4110 | ACC Train=0.4874 | ACC Test=0.4547 | F1 macro CV=0.3600 | F1 macro Test=0.4197 | ROC AUC OVR macro CV=0.6919 | ROC AUC OVR macro Test=0.6844 | AUCPR macro CV=0.4907 | AUCPR macro Test=0.4826
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.4879 | ACC Train=0.5210 | ACC Test=0.4948 | F1 macro CV=0.3973 | F1 macro Test=0.4120 | ROC AUC OVR macro CV=0.8489 | ROC AUC OVR macro Test=0.8777 | AUCPR macro CV=0.7589 | AUCPR macro Test=0.7886
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.4551 | ACC Train=0.4860 | ACC Test=0.4578 | F1 macro CV=0.3749 | F1 macro Test=0.3755 | ROC AUC OVR macro CV=0.7691 | ROC AUC OVR macro Test=0.8273 | AUCPR macro CV=0.6952 | AUCPR macro Test=0.7499
# ...
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.0852 | ACC Train=0.2854 | ACC Test=0.2767 | F1 macro CV=0.0591 | F1 macro Test=0.2624 | ROC AUC OVR macro CV=0.7033 | ROC AUC OVR macro Test=0.7215 | AUCPR macro CV=0.6211 | AUCPR macro Test=0.6567
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.7478 | ACC Train=0.7850 | ACC Test=0.7704 | F1 macro CV=0.6752 | F1 macro Test=0.7066 | ROC AUC OVR macro CV=0.9252 | ROC AUC OVR macro Test=0.9337 | AUCPR macro CV=0.7987 | AUCPR macro Test=0.8217
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.7339 | ACC Train=0.7398 | ACC Test=0.7282 | F1 macro CV=0.6610 | F1 macro Test=0.6601 | ROC AUC OVR macro CV=0.8978 | ROC AUC OVR macro Test=0.9021 | AUCPR macro CV=0.7336 | AUCPR macro Test=0.7502
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.4494 | ACC Train=0.4652 | ACC Test=0.4502 | F1 macro CV=0.3651 | F1 macro Test=0.3643 | ROC AUC OVR macro CV=0.9108 | ROC AUC OVR macro Test=0.9152 | AUCPR macro CV=0.7823 | AUCPR macro Test=0.8030
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.7099 | ACC Train=0.7766 | ACC Test=0.7080 | F1 macro CV=0.6380 | F1 macro Test=0.6430 | ROC AUC OVR macro CV=0.8759 | ROC AUC OVR macro Test=0.8782 | AUCPR macro CV=0.7410 | AUCPR macro Test=0.7651
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.4377 | ACC Train=0.6029 | ACC Test=0.4383 | F1 macro CV=0.2458 | F1 macro Test=0.2671 | ROC AUC OVR macro CV=0.8165 | ROC AUC OVR macro Test=0.7900 | AUCPR macro CV=0.6595 | AUCPR macro Test=0.6392
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.7203 | ACC Train=0.7873 | ACC Test=0.7568 | F1 macro CV=0.6606 | F1 macro Test=0.6960 | ROC AUC OVR macro CV=0.8339 | ROC AUC OVR macro Test=0.8729 | AUCPR macro CV=0.6167 | AUCPR macro Test=0.6663
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.5997 | ACC Train=0.6589 | ACC Test=0.6049 | F1 macro CV=0.5101 | F1 macro Test=0.5262 | ROC AUC OVR macro CV=0.7426 | ROC AUC OVR macro Test=0.7692 | AUCPR macro CV=0.5726 | AUCPR macro Test=0.5931
# 	Evaluating with SMOTE sampler config: {2: 60}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.4386 | ACC Train=0.4242 | ACC Test=0.4073 | F1 macro CV=0.3493 | F1 macro Test=0.3312 | ROC AUC OVR macro CV=0.6352 | ROC AUC OVR macro Test=0.6359 | AUCPR macro CV=0.4405 | AUCPR macro Test=0.4357
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.4064 | ACC Train=0.4551 | ACC Test=0.4352 | F1 macro CV=0.3495 | F1 macro Test=0.3629 | ROC AUC OVR macro CV=0.7178 | ROC AUC OVR macro Test=0.7657 | AUCPR macro CV=0.6296 | AUCPR macro Test=0.7037
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.0843 | ACC Train=0.2959 | ACC Test=0.2902 | F1 macro CV=0.0583 | F1 macro Test=0.2744 | ROC AUC OVR macro CV=0.7025 | ROC AUC OVR macro Test=0.7226 | AUCPR macro CV=0.6179 | AUCPR macro Test=0.6545
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.7487 | ACC Train=0.7966 | ACC Test=0.7732 | F1 macro CV=0.6769 | F1 macro Test=0.7081 | ROC AUC OVR macro CV=0.9257 | ROC AUC OVR macro Test=0.9342 | AUCPR macro CV=0.7981 | AUCPR macro Test=0.8265
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.7336 | ACC Train=0.7398 | ACC Test=0.7247 | F1 macro CV=0.6601 | F1 macro Test=0.6547 | ROC AUC OVR macro CV=0.8980 | ROC AUC OVR macro Test=0.9041 | AUCPR macro CV=0.7330 | AUCPR macro Test=0.7512
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.4465 | ACC Train=0.4619 | ACC Test=0.4474 | F1 macro CV=0.3644 | F1 macro Test=0.3637 | ROC AUC OVR macro CV=0.9113 | ROC AUC OVR macro Test=0.9164 | AUCPR macro CV=0.7836 | AUCPR macro Test=0.8151
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.7091 | ACC Train=0.7748 | ACC Test=0.7045 | F1 macro CV=0.6370 | F1 macro Test=0.6395 | ROC AUC OVR macro CV=0.8755 | ROC AUC OVR macro Test=0.8768 | AUCPR macro CV=0.7411 | AUCPR macro Test=0.7626
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.4409 | ACC Train=0.6021 | ACC Test=0.4474 | F1 macro CV=0.2742 | F1 macro Test=0.3225 | ROC AUC OVR macro CV=0.8377 | ROC AUC OVR macro Test=0.8163 | AUCPR macro CV=0.6813 | AUCPR macro Test=0.6737
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.7185 | ACC Train=0.7842 | ACC Test=0.7537 | F1 macro CV=0.6593 | F1 macro Test=0.6921 | ROC AUC OVR macro CV=0.8334 | ROC AUC OVR macro Test=0.8729 | AUCPR macro CV=0.6161 | AUCPR macro Test=0.6663
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.5967 | ACC Train=0.6816 | ACC Test=0.6192 | F1 macro CV=0.5104 | F1 macro Test=0.5386 | ROC AUC OVR macro CV=0.7488 | ROC AUC OVR macro Test=0.7970 | AUCPR macro CV=0.5802 | AUCPR macro Test=0.6253
# 	Evaluating with ROS sampler config: {2: 80}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.4371 | ACC Train=0.4485 | ACC Test=0.4157 | F1 macro CV=0.3484 | F1 macro Test=0.3379 | ROC AUC OVR macro CV=0.6325 | ROC AUC OVR macro Test=0.6315 | AUCPR macro CV=0.4400 | AUCPR macro Test=0.4381
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.4421 | ACC Train=0.4817 | ACC Test=0.4498 | F1 macro CV=0.3665 | F1 macro Test=0.3692 | ROC AUC OVR macro CV=0.7494 | ROC AUC OVR macro Test=0.7949 | AUCPR macro CV=0.6621 | AUCPR macro Test=0.7308
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.2822 | ACC Train=0.4144 | ACC Test=0.3798 | F1 macro CV=0.2651 | F1 macro Test=0.3371 | ROC AUC OVR macro CV=0.7146 | ROC AUC OVR macro Test=0.7342 | AUCPR macro CV=0.6305 | AUCPR macro Test=0.6727
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.7716 | ACC Train=0.8152 | ACC Test=0.7878 | F1 macro CV=0.6973 | F1 macro Test=0.7211 | ROC AUC OVR macro CV=0.9308 | ROC AUC OVR macro Test=0.9380 | AUCPR macro CV=0.8053 | AUCPR macro Test=0.8327
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.7193 | ACC Train=0.7385 | ACC Test=0.7199 | F1 macro CV=0.6442 | F1 macro Test=0.6508 | ROC AUC OVR macro CV=0.8954 | ROC AUC OVR macro Test=0.9041 | AUCPR macro CV=0.7191 | AUCPR macro Test=0.7537
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.4575 | ACC Train=0.4974 | ACC Test=0.4683 | F1 macro CV=0.3679 | F1 macro Test=0.3815 | ROC AUC OVR macro CV=0.9182 | ROC AUC OVR macro Test=0.9191 | AUCPR macro CV=0.7884 | AUCPR macro Test=0.8064
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.7370 | ACC Train=0.8142 | ACC Test=0.7240 | F1 macro CV=0.6628 | F1 macro Test=0.6586 | ROC AUC OVR macro CV=0.8819 | ROC AUC OVR macro Test=0.8771 | AUCPR macro CV=0.7399 | AUCPR macro Test=0.7522
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.4413 | ACC Train=0.6443 | ACC Test=0.4439 | F1 macro CV=0.2618 | F1 macro Test=0.2871 | ROC AUC OVR macro CV=0.7940 | ROC AUC OVR macro Test=0.7712 | AUCPR macro CV=0.6354 | AUCPR macro Test=0.6168
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.7614 | ACC Train=0.8152 | ACC Test=0.7770 | F1 macro CV=0.6970 | F1 macro Test=0.7141 | ROC AUC OVR macro CV=0.8696 | ROC AUC OVR macro Test=0.8906 | AUCPR macro CV=0.6643 | AUCPR macro Test=0.6920
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.6420 | ACC Train=0.7446 | ACC Test=0.6732 | F1 macro CV=0.5584 | F1 macro Test=0.6058 | ROC AUC OVR macro CV=0.7993 | ROC AUC OVR macro Test=0.8356 | AUCPR macro CV=0.6274 | AUCPR macro Test=0.6759
# 	Evaluating with SMOTE sampler config: {2: 80}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.4387 | ACC Train=0.4526 | ACC Test=0.4185 | F1 macro CV=0.3493 | F1 macro Test=0.3432 | ROC AUC OVR macro CV=0.6364 | ROC AUC OVR macro Test=0.6455 | AUCPR macro CV=0.4420 | AUCPR macro Test=0.4478
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.4568 | ACC Train=0.4884 | ACC Test=0.4596 | F1 macro CV=0.3730 | F1 macro Test=0.3743 | ROC AUC OVR macro CV=0.7702 | ROC AUC OVR macro Test=0.8177 | AUCPR macro CV=0.6800 | AUCPR macro Test=0.7484
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.3015 | ACC Train=0.4223 | ACC Test=0.3892 | F1 macro CV=0.2802 | F1 macro Test=0.3424 | ROC AUC OVR macro CV=0.7121 | ROC AUC OVR macro Test=0.7372 | AUCPR macro CV=0.6312 | AUCPR macro Test=0.6747
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.7963 | ACC Train=0.8379 | ACC Test=0.8038 | F1 macro CV=0.7239 | F1 macro Test=0.7371 | ROC AUC OVR macro CV=0.9338 | ROC AUC OVR macro Test=0.9403 | AUCPR macro CV=0.8151 | AUCPR macro Test=0.8442
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.7542 | ACC Train=0.7575 | ACC Test=0.7387 | F1 macro CV=0.6799 | F1 macro Test=0.6704 | ROC AUC OVR macro CV=0.9000 | ROC AUC OVR macro Test=0.9055 | AUCPR macro CV=0.7398 | AUCPR macro Test=0.7574
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.4529 | ACC Train=0.4867 | ACC Test=0.4540 | F1 macro CV=0.3668 | F1 macro Test=0.3673 | ROC AUC OVR macro CV=0.9180 | ROC AUC OVR macro Test=0.9206 | AUCPR macro CV=0.7920 | AUCPR macro Test=0.8232
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.7343 | ACC Train=0.8110 | ACC Test=0.7206 | F1 macro CV=0.6598 | F1 macro Test=0.6535 | ROC AUC OVR macro CV=0.8808 | ROC AUC OVR macro Test=0.8743 | AUCPR macro CV=0.7407 | AUCPR macro Test=0.7496
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.4512 | ACC Train=0.6406 | ACC Test=0.4571 | F1 macro CV=0.3325 | F1 macro Test=0.3701 | ROC AUC OVR macro CV=0.8292 | ROC AUC OVR macro Test=0.8112 | AUCPR macro CV=0.6741 | AUCPR macro Test=0.6756
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.7637 | ACC Train=0.8133 | ACC Test=0.7760 | F1 macro CV=0.6996 | F1 macro Test=0.7117 | ROC AUC OVR macro CV=0.8687 | ROC AUC OVR macro Test=0.8909 | AUCPR macro CV=0.6649 | AUCPR macro Test=0.6963
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.6359 | ACC Train=0.7554 | ACC Test=0.6669 | F1 macro CV=0.5514 | F1 macro Test=0.6005 | ROC AUC OVR macro CV=0.7930 | ROC AUC OVR macro Test=0.8399 | AUCPR macro CV=0.6235 | AUCPR macro Test=0.6868
# 	Evaluating with ROS sampler config: {2: 100}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=ros | ACC CV=0.4403 | ACC Train=0.4693 | ACC Test=0.4209 | F1 macro CV=0.3511 | F1 macro Test=0.3384 | ROC AUC OVR macro CV=0.6379 | ROC AUC OVR macro Test=0.6334 | AUCPR macro CV=0.4430 | AUCPR macro Test=0.4336
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=ros | ACC CV=0.4591 | ACC Train=0.5047 | ACC Test=0.4617 | F1 macro CV=0.3734 | F1 macro Test=0.3757 | ROC AUC OVR macro CV=0.7837 | ROC AUC OVR macro Test=0.8293 | AUCPR macro CV=0.6957 | AUCPR macro Test=0.7610
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=ros | ACC CV=0.3866 | ACC Train=0.4631 | ACC Test=0.4129 | F1 macro CV=0.3395 | F1 macro Test=0.3548 | ROC AUC OVR macro CV=0.7241 | ROC AUC OVR macro Test=0.7553 | AUCPR macro CV=0.6406 | AUCPR macro Test=0.6981
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=ros | ACC CV=0.7911 | ACC Train=0.8328 | ACC Test=0.8024 | F1 macro CV=0.7175 | F1 macro Test=0.7373 | ROC AUC OVR macro CV=0.9354 | ROC AUC OVR macro Test=0.9405 | AUCPR macro CV=0.8181 | AUCPR macro Test=0.8390
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=ros | ACC CV=0.7194 | ACC Train=0.7346 | ACC Test=0.7167 | F1 macro CV=0.6457 | F1 macro Test=0.6524 | ROC AUC OVR macro CV=0.8953 | ROC AUC OVR macro Test=0.9044 | AUCPR macro CV=0.7211 | AUCPR macro Test=0.7580
# Evaluating model: svm_reg
# svm_reg | Sampler=ros | ACC CV=0.4711 | ACC Train=0.5659 | ACC Test=0.5115 | F1 macro CV=0.3823 | F1 macro Test=0.4421 | ROC AUC OVR macro CV=0.9204 | ROC AUC OVR macro Test=0.9213 | AUCPR macro CV=0.7909 | AUCPR macro Test=0.8084
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=ros | ACC CV=0.7479 | ACC Train=0.8396 | ACC Test=0.7300 | F1 macro CV=0.6716 | F1 macro Test=0.6587 | ROC AUC OVR macro CV=0.8852 | ROC AUC OVR macro Test=0.8785 | AUCPR macro CV=0.7428 | AUCPR macro Test=0.7510
# Evaluating model: knn_reg
# knn_reg | Sampler=ros | ACC CV=0.4447 | ACC Train=0.6828 | ACC Test=0.4495 | F1 macro CV=0.2731 | F1 macro Test=0.3163 | ROC AUC OVR macro CV=0.7826 | ROC AUC OVR macro Test=0.7676 | AUCPR macro CV=0.6203 | AUCPR macro Test=0.6121
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=ros | ACC CV=0.7881 | ACC Train=0.8235 | ACC Test=0.7836 | F1 macro CV=0.7199 | F1 macro Test=0.7192 | ROC AUC OVR macro CV=0.8921 | ROC AUC OVR macro Test=0.9000 | AUCPR macro CV=0.6982 | AUCPR macro Test=0.7087
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=ros | ACC CV=0.6508 | ACC Train=0.7905 | ACC Test=0.7007 | F1 macro CV=0.5680 | F1 macro Test=0.6353 | ROC AUC OVR macro CV=0.8211 | ROC AUC OVR macro Test=0.8702 | AUCPR macro CV=0.6512 | AUCPR macro Test=0.7326
# 	Evaluating with SMOTE sampler config: {2: 100}
#
# Evaluating model: decision_tree_reg
# decision_tree_reg | Sampler=smote | ACC CV=0.4407 | ACC Train=0.4772 | ACC Test=0.4314 | F1 macro CV=0.3523 | F1 macro Test=0.3468 | ROC AUC OVR macro CV=0.6430 | ROC AUC OVR macro Test=0.6392 | AUCPR macro CV=0.4475 | AUCPR macro Test=0.4426
# Evaluating model: random_forest_reg
# random_forest_reg | Sampler=smote | ACC CV=0.4735 | ACC Train=0.5171 | ACC Test=0.4756 | F1 macro CV=0.3789 | F1 macro Test=0.3847 | ROC AUC OVR macro CV=0.8228 | ROC AUC OVR macro Test=0.8614 | AUCPR macro CV=0.7277 | AUCPR macro Test=0.7808
# Evaluating model: extra_trees_reg
# extra_trees_reg | Sampler=smote | ACC CV=0.3969 | ACC Train=0.4680 | ACC Test=0.4199 | F1 macro CV=0.3455 | F1 macro Test=0.3585 | ROC AUC OVR macro CV=0.7261 | ROC AUC OVR macro Test=0.7549 | AUCPR macro CV=0.6400 | AUCPR macro Test=0.6977
# Evaluating model: xgboost_reg
# xgboost_reg | Sampler=smote | ACC CV=0.8143 | ACC Train=0.8545 | ACC Test=0.8199 | F1 macro CV=0.7419 | F1 macro Test=0.7563 | ROC AUC OVR macro CV=0.9381 | ROC AUC OVR macro Test=0.9430 | AUCPR macro CV=0.8264 | AUCPR macro Test=0.8487
# Evaluating model: adaboost_reg
# adaboost_reg | Sampler=smote | ACC CV=0.7545 | ACC Train=0.7885 | ACC Test=0.7672 | F1 macro CV=0.6781 | F1 macro Test=0.6998 | ROC AUC OVR macro CV=0.8995 | ROC AUC OVR macro Test=0.9095 | AUCPR macro CV=0.7439 | AUCPR macro Test=0.7719
# Evaluating model: svm_reg
# svm_reg | Sampler=smote | ACC CV=0.4576 | ACC Train=0.5174 | ACC Test=0.4659 | F1 macro CV=0.3698 | F1 macro Test=0.3830 | ROC AUC OVR macro CV=0.9188 | ROC AUC OVR macro Test=0.9216 | AUCPR macro CV=0.7904 | AUCPR macro Test=0.8244
# Evaluating model: logistic_regression_reg
# logistic_regression_reg | Sampler=smote | ACC CV=0.7471 | ACC Train=0.8391 | ACC Test=0.7275 | F1 macro CV=0.6711 | F1 macro Test=0.6570 | ROC AUC OVR macro CV=0.8837 | ROC AUC OVR macro Test=0.8751 | AUCPR macro CV=0.7427 | AUCPR macro Test=0.7485
# Evaluating model: knn_reg
# knn_reg | Sampler=smote | ACC CV=0.4584 | ACC Train=0.6789 | ACC Test=0.4641 | F1 macro CV=0.3593 | F1 macro Test=0.3863 | ROC AUC OVR macro CV=0.8240 | ROC AUC OVR macro Test=0.8124 | AUCPR macro CV=0.6731 | AUCPR macro Test=0.6775
# Evaluating model: gaussian_nb_reg
# gaussian_nb_reg | Sampler=smote | ACC CV=0.7902 | ACC Train=0.8225 | ACC Test=0.7843 | F1 macro CV=0.7203 | F1 macro Test=0.7189 | ROC AUC OVR macro CV=0.8909 | ROC AUC OVR macro Test=0.8996 | AUCPR macro CV=0.7004 | AUCPR macro Test=0.7131
# Evaluating model: mlp3216_reg
# mlp3216_reg | Sampler=smote | ACC CV=0.6560 | ACC Train=0.7793 | ACC Test=0.6801 | F1 macro CV=0.5757 | F1 macro Test=0.6104 | ROC AUC OVR macro CV=0.8256 | ROC AUC OVR macro Test=0.8598 | AUCPR macro CV=0.6606 | AUCPR macro Test=0.7154
