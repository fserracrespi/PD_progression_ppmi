# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
current_dir = Path.cwd()
project_root = current_dir.parents[2]

# %% [markdown]
# # DATA BL V10

# %%
path_data = project_root / 'DATA_PPMI/Results/MODEL_DATA/DATA_BL_V10.csv'
data = pd.read_csv(path_data)[['PATNO','EVENT_ID','SEX','EDUCYRS','AGE_AT_VISIT','ENRLLRRK2','ENRLGBA','COHORT_DEFINITION']]
data = data.loc[data['EVENT_ID']=='BL',]
data.shape
# Out:
# (503, 8)

# %%
data[['COHORT_DEFINITION','SEX']].value_counts()
# Out:
# COHORT_DEFINITION    SEX
# Parkinson's Disease  1.0    165
# Prodromal            0.0    126
#                      1.0    119
# Parkinson's Disease  0.0     93
# Name: count, dtype: int64

# %%
data.groupby(['COHORT_DEFINITION','SEX'])['AGE_AT_VISIT'].mean()
# Out:
# COHORT_DEFINITION    SEX
# Parkinson's Disease  0.0    61.370968
#                      1.0    61.915758
# Prodromal            0.0    62.178571
#                      1.0    64.281513
# Name: AGE_AT_VISIT, dtype: float64

# %%
data.groupby(['COHORT_DEFINITION','SEX'])['EDUCYRS'].mean()
# Out:
# COHORT_DEFINITION    SEX
# Parkinson's Disease  0.0    15.688172
#                      1.0    16.696970
# Prodromal            0.0    16.968254
#                      1.0    16.991597
# Name: EDUCYRS, dtype: float64

# %% [markdown]
# # DATA BL V08

# %%
path_data = project_root / 'DATA_PPMI/Results/MODEL_DATA/DATA_BL_V08.csv'
data = pd.read_csv(path_data)[['PATNO','EVENT_ID','SEX','EDUCYRS','AGE_AT_VISIT','ENRLLRRK2','ENRLGBA','COHORT_DEFINITION']]
data = data.loc[data['EVENT_ID']=='BL',]
data.shape
# Out:
# (909, 8)

# %%
data[['COHORT_DEFINITION','SEX']].value_counts()
# Out:
# COHORT_DEFINITION    SEX
# Parkinson's Disease  1.0    265
# Prodromal            0.0    253
#                      1.0    237
# Parkinson's Disease  0.0    154
# Name: count, dtype: int64

# %%
data.groupby(['COHORT_DEFINITION','SEX'])['AGE_AT_VISIT'].mean()
# Out:
# COHORT_DEFINITION    SEX
# Parkinson's Disease  0.0    61.796753
#                      1.0    62.204528
# Prodromal            0.0    63.279447
#                      1.0    65.411392
# Name: AGE_AT_VISIT, dtype: float64

# %%
data.groupby(['COHORT_DEFINITION','SEX'])['EDUCYRS'].mean()
# Out:
# COHORT_DEFINITION    SEX
# Parkinson's Disease  0.0    15.558442
#                      1.0    16.622642
# Prodromal            0.0    16.924901
#                      1.0    16.911392
# Name: EDUCYRS, dtype: float64
